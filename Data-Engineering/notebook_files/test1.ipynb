# %%
import requests, json
from pprint import pprint
import pandas as pd

# %%
base_url = 'https://fantasy.premierleague.com/api/' 
data = requests.get(base_url+'bootstrap-static/').json() 
pprint(data, indent=2, depth=1, compact=True)
# Out:
# { 'element_stats': [...],
#   'element_types': [...],
#   'elements': [...],
#   'events': [...],
#   'game_settings': {...},
#   'phases': [...],
#   'teams': [...],
#   'total_players': 10225286}

# %%
data['events']
# Out:
# [{'id': 1,
#   'name': 'Gameweek 1',
#   'deadline_time': '2023-08-11T17:30:00Z',
#   'average_entry_score': 64,
#   'finished': True,
#   'data_checked': True,
#   'highest_scoring_entry': 3383750,
#   'deadline_time_epoch': 1691775000,
#   'deadline_time_game_offset': 0,
#   'highest_score': 127,
#   'is_previous': False,
#   'is_current': False,
#   'is_next': False,
#   'cup_leagues_created': False,
#   'h2h_ko_matches_created': False,
#   'chip_plays': [{'chip_name': 'bboost', 'num_played': 163222},
#    {'chip_name': '3xc', 'num_played': 287198}],
#   'most_selected': 355,
#   'most_transferred_in': 1,
#   'top_element': 395,
#   'top_element_info': {'id': 395, 'points': 14},
#   'transfers_made': 0,
#   'most_captained': 355,
#   'most_vice_captained': 19},
#  {'id': 2,
#   'name': 'Gameweek 2',
#   'deadline_time': '2023-08-18T17:15:00Z',
#   'average_entry_score': 44,
#   'finished': True,
#   'data_checked': True,
#   'highest_scoring_entry': 3338487,
#   'deadline_time_epoch': 1692378900,
#   'deadline_time_game_offset': 0,
#   'highest_score': 120,
#   'is_previous': False,
#   'is_current': False,
#   'is_next': False,
#   'cup_leagues_created': True,
#   'h2h_ko_matches_created': True,
#   'chip_plays': [{'chip_name': 'bboost', 'num_played': 126778},
#    {'chip_name': 'freehit', 'num_played': 112568},
#    {'chip_name': 'wildcard', 'num_played': 244166},
#    {'chip_name': '3xc', 'num_played': 213828}],
#   'most_selected': 355,
#   'most_transferred_in': 195,
#   'top_element': 108,
#   'top_element_info': {'id': 108, 'points': 16},
#   'transfers_made': 13130353,
#   'most_captained': 355,
#   'most_vice_captained': 19},
#  {'id': 3,
#   'name': 'Gameweek 3',
#   'deadline_time': '2023-08-25T17:30:00Z',
#   'average_entry_score': 44,
#   'finished': True,
#   'data_checked': True,
#   'highest_scoring_entry': 9368956,
#   'deadline_time_epoch': 1692984600,
#   'deadline_time_game_offset': 0,
#   'highest_score': 128,
#   'is_previous': False,
#   'is_current': False,
#   'is_next': False,
#   'cup_leagues_created': True,
#   'h2h_ko_matches_created': True,
#   'chip_plays': [{'chip_name': 'bboost', 'num_played': 124110},
#    {'chip_name': 'freehit', 'num_played': 111065},
#    {'chip_name': 'wildcard', 'num_played': 445328},
#    {'chip_name': '3xc', 'num_played': 245013}],
#   'most_selected': 355,
#   'most_transferred_in': 108,
#   'top_element': 216,
#   'top_element_info': {'id': 216, 'points': 19},
#   'transfers_made': 17619532,
#   'most_captained': 355,
#   'most_vice_captained': 19},
#  {'id': 4,
#   'name': 'Gameweek 4',
#   'deadline_time': '2023-09-01T17:30:00Z',
#   'average_entry_score': 72,
#   'finished': True,
#   'data_checked': True,
#   'highest_scoring_entry': 4354697,
#   'deadline_time_epoch': 1693589400,
#   'deadline_time_game_offset': 0,
#   'highest_score': 148,
#   'is_previous': False,
#   'is_current': False,
#   'is_next': False,
#   'cup_leagues_created': True,
#   'h2h_ko_matches_created': True,
#   'chip_plays': [{'chip_name': 'bboost', 'num_played': 109196},
#    {'chip_name': 'freehit', 'num_played': 119294},
#    {'chip_name': 'wildcard', 'num_played': 406918},
#    {'chip_name': '3xc', 'num_played': 164388}],
#   'most_selected': 355,
#   'most_transferred_in': 216,
#   'top_element': 516,
#   'top_element_info': {'id': 516, 'points': 20},
#   'transfers_made': 16035365,
#   'most_captained': 355,
#   'most_vice_captained': 19},
#  {'id': 5,
#   'name': 'Gameweek 5',
#   'deadline_time': '2023-09-16T10:00:00Z',
#   'average_entry_score': 44,
#   'finished': True,
#   'data_checked': True,
#   'highest_scoring_entry': 6211182,
#   'deadline_time_epoch': 1694858400,
#   'deadline_time_game_offset': 0,
#   'highest_score': 102,
#   'is_previous': False,
#   'is_current': False,
#   'is_next': False,
#   'cup_leagues_created': True,
#   'h2h_ko_matches_created': True,
#   'chip_plays': [{'chip_name': 'bboost', 'num_played': 96469},
#    {'chip_name': 'freehit', 'num_played': 81067},
#    {'chip_name': 'wildcard', 'num_played': 387941},
#    {'chip_name': '3xc', 'num_played': 123443}],
#   'most_selected': 355,
#   'most_transferred_in': 516,
#   'top_element': 344,
#   'top_element_info': {'id': 344, 'points': 13},
#   'transfers_made': 14363988,
#   'most_captained': 355,
#   'most_vice_captained': 19},
#  {'id': 6,
#   'name': 'Gameweek 6',
#   'deadline_time': '2023-09-23T12:30:00Z',
#   'average_entry_score': 68,
#   'finished': True,
#   'data_checked': True,
#   'highest_scoring_entry': 4494759,
#   'deadline_time_epoch': 1695472200,
#   'deadline_time_game_offset': 0,
#   'highest_score': 142,
#   'is_previous': True,
#   'is_current': False,
#   'is_next': False,
#   'cup_leagues_created': True,
#   'h2h_ko_matches_created': True,
#   'chip_plays': [{'chip_name': 'bboost', 'num_played': 78528},
#    {'chip_name': 'freehit', 'num_played': 60517},
#    {'chip_name': 'wildcard', 'num_played': 283333},
#    {'chip_name': '3xc', 'num_played': 192955}],
#   'most_selected': 355,
#   'most_transferred_in': 343,
#   'top_element': 430,
#   'top_element_info': {'id': 430, 'points': 18},
#   'transfers_made': 12109066,
#   'most_captained': 355,
#   'most_vice_captained': 308},
#  {'id': 7,
#   'name': 'Gameweek 7',
#   'deadline_time': '2023-09-30T10:00:00Z',
#   'average_entry_score': 49,
#   'finished': True,
#   'data_checked': True,
#   'highest_scoring_entry': 9335002,
#   'deadline_time_epoch': 1696068000,
#   'deadline_time_game_offset': 0,
#   'highest_score': 156,
#   'is_previous': False,
#   'is_current': True,
#   'is_next': False,
#   'cup_leagues_created': True,
#   'h2h_ko_matches_created': True,
#   'chip_plays': [{'chip_name': 'bboost', 'num_played': 79672},
#    {'chip_name': 'freehit', 'num_played': 141888},
#    {'chip_name': 'wildcard', 'num_played': 380176},
#    {'chip_name': '3xc', 'num_played': 90244}],
#   'most_selected': 355,
#   'most_transferred_in': 430,
#   'top_element': 60,
#   'top_element_info': {'id': 60, 'points': 23},
#   'transfers_made': 15579302,
#   'most_captained': 355,
#   'most_vice_captained': 308},
#  {'id': 8,
#   'name': 'Gameweek 8',
#   'deadline_time': '2023-10-07T10:00:00Z',
#   'average_entry_score': 0,
#   'finished': False,
#   'data_checked': False,
#   'highest_scoring_entry': None,
#   'deadline_time_epoch': 1696672800,
#   'deadline_time_game_offset': 0,
#   'highest_score': None,
#   'is_previous': False,
#   'is_current': False,
#   'is_next': True,
#   'cup_leagues_created': True,
#   'h2h_ko_matches_created': True,
#   'chip_plays': [{'chip_name': 'bboost', 'num_played': 23426},
#    {'chip_name': 'freehit', 'num_played': 41322},
#    {'chip_name': 'wildcard', 'num_played': 205326},
#    {'chip_name': '3xc', 'num_played': 22531}],
#   'most_selected': None,
#   'most_transferred_in': None,
#   'top_element': None,
#   'top_element_info': None,
#   'transfers_made': 6088221,
#   'most_captained': None,
#   'most_vice_captained': None},
#  {'id': 9,
#   'name': 'Gameweek 9',
#   'deadline_time': '2023-10-21T10:00:00Z',
#   'average_entry_score': 0,
#   'finished': False,
#   'data_checked': False,
#   'highest_scoring_entry': None,
#   'deadline_time_epoch': 1697882400,
#   'deadline_time_game_offset': 0,
#   'highest_score': None,
#   'is_previous': False,
#   'is_current': False,
#   'is_next': False,
#   'cup_leagues_created': False,
#   'h2h_ko_matches_created': False,
#   'chip_plays': [],
#   'most_selected': None,
#   'most_transferred_in': None,
#   'top_element': None,
#   'top_element_info': None,
#   'transfers_made': 0,
#   'most_captained': None,
#   'most_vice_captained': None},
#  {'id': 10,
#   'name': 'Gameweek 10',
#   'deadline_time': '2023-10-27T17:30:00Z',
#   'average_entry_score': 0,
#   'finished': False,
#   'data_checked': False,
#   'highest_scoring_entry': None,
#   'deadline_time_epoch': 1698427800,
#   'deadline_time_game_offset': 0,
#   'highest_score': None,
#   'is_previous': False,
#   'is_current': False,
#   'is_next': False,
#   'cup_leagues_created': False,
#   'h2h_ko_matches_created': False,
#   'chip_plays': [],
#   'most_selected': None,
#   'most_transferred_in': None,
#   'top_element': None,
#   'top_element_info': None,
#   'transfers_made': 0,
#   'most_captained': None,
#   'most_vice_captained': None},
#  {'id': 11,
#   'name': 'Gameweek 11',
#   'deadline_time': '2023-11-04T11:00:00Z',
#   'average_entry_score': 0,
#   'finished': False,
#   'data_checked': False,
#   'highest_scoring_entry': None,
#   'deadline_time_epoch': 1699095600,
#   'deadline_time_game_offset': 0,
#   'highest_score': None,
#   'is_previous': False,
#   'is_current': False,
#   'is_next': False,
#   'cup_leagues_created': False,
#   'h2h_ko_matches_created': False,
#   'chip_plays': [],
#   'most_selected': None,
#   'most_transferred_in': None,
#   'top_element': None,
#   'top_element_info': None,
#   'transfers_made': 0,
#   'most_captained': None,
#   'most_vice_captained': None},
#  {'id': 12,
#   'name': 'Gameweek 12',
#   'deadline_time': '2023-11-11T11:00:00Z',
#   'average_entry_score': 0,
#   'finished': False,
#   'data_checked': False,
#   'highest_scoring_entry': None,
#   'deadline_time_epoch': 1699700400,
#   'deadline_time_game_offset': 0,
#   'highest_score': None,
#   'is_previous': False,
#   'is_current': False,
#   'is_next': False,
#   'cup_leagues_created': False,
#   'h2h_ko_matches_created': False,
#   'chip_plays': [],
#   'most_selected': None,
#   'most_transferred_in': None,
#   'top_element': None,
#   'top_element_info': None,
#   'transfers_made': 0,
#   'most_captained': None,
#   'most_vice_captained': None},
#  {'id': 13,
#   'name': 'Gameweek 13',
#   'deadline_time': '2023-11-25T13:30:00Z',
#   'average_entry_score': 0,
#   'finished': False,
#   'data_checked': False,
#   'highest_scoring_entry': None,
#   'deadline_time_epoch': 1700919000,
#   'deadline_time_game_offset': 0,
#   'highest_score': None,
#   'is_previous': False,
#   'is_current': False,
#   'is_next': False,
#   'cup_leagues_created': False,
#   'h2h_ko_matches_created': False,
#   'chip_plays': [],
#   'most_selected': None,
#   'most_transferred_in': None,
#   'top_element': None,
#   'top_element_info': None,
#   'transfers_made': 0,
#   'most_captained': None,
#   'most_vice_captained': None},
#  {'id': 14,
#   'name': 'Gameweek 14',
#   'deadline_time': '2023-12-02T13:30:00Z',
#   'average_entry_score': 0,
#   'finished': False,
#   'data_checked': False,
#   'highest_scoring_entry': None,
#   'deadline_time_epoch': 1701523800,
#   'deadline_time_game_offset': 0,
#   'highest_score': None,
#   'is_previous': False,
#   'is_current': False,
#   'is_next': False,
#   'cup_leagues_created': False,
#   'h2h_ko_matches_created': False,
#   'chip_plays': [],
#   'most_selected': None,
#   'most_transferred_in': None,
#   'top_element': None,
#   'top_element_info': None,
#   'transfers_made': 0,
#   'most_captained': None,
#   'most_vice_captained': None},
#  {'id': 15,
#   'name': 'Gameweek 15',
#   'deadline_time': '2023-12-05T18:15:00Z',
#   'average_entry_score': 0,
#   'finished': False,
#   'data_checked': False,
#   'highest_scoring_entry': None,
#   'deadline_time_epoch': 1701800100,
#   'deadline_time_game_offset': 0,
#   'highest_score': None,
#   'is_previous': False,
#   'is_current': False,
#   'is_next': False,
#   'cup_leagues_created': False,
#   'h2h_ko_matches_created': False,
#   'chip_plays': [],
#   'most_selected': None,
#   'most_transferred_in': None,
#   'top_element': None,
#   'top_element_info': None,
#   'transfers_made': 0,
#   'most_captained': None,
#   'most_vice_captained': None},
#  {'id': 16,
#   'name': 'Gameweek 16',
#   'deadline_time': '2023-12-09T13:30:00Z',
#   'average_entry_score': 0,
#   'finished': False,
#   'data_checked': False,
#   'highest_scoring_entry': None,
#   'deadline_time_epoch': 1702128600,
#   'deadline_time_game_offset': 0,
#   'highest_score': None,
#   'is_previous': False,
#   'is_current': False,
#   'is_next': False,
#   'cup_leagues_created': False,
#   'h2h_ko_matches_created': False,
#   'chip_plays': [],
#   'most_selected': None,
#   'most_transferred_in': None,
#   'top_element': None,
#   'top_element_info': None,
#   'transfers_made': 0,
#   'most_captained': None,
#   'most_vice_captained': None},
#  {'id': 17,
#   'name': 'Gameweek 17',
#   'deadline_time': '2023-12-16T13:30:00Z',
#   'average_entry_score': 0,
#   'finished': False,
#   'data_checked': False,
#   'highest_scoring_entry': None,
#   'deadline_time_epoch': 1702733400,
#   'deadline_time_game_offset': 0,
#   'highest_score': None,
#   'is_previous': False,
#   'is_current': False,
#   'is_next': False,
#   'cup_leagues_created': False,
#   'h2h_ko_matches_created': False,
#   'chip_plays': [],
#   'most_selected': None,
#   'most_transferred_in': None,
#   'top_element': None,
#   'top_element_info': None,
#   'transfers_made': 0,
#   'most_captained': None,
#   'most_vice_captained': None},
#  {'id': 18,
#   'name': 'Gameweek 18',
#   'deadline_time': '2023-12-23T13:30:00Z',
#   'average_entry_score': 0,
#   'finished': False,
#   'data_checked': False,
#   'highest_scoring_entry': None,
#   'deadline_time_epoch': 1703338200,
#   'deadline_time_game_offset': 0,
#   'highest_score': None,
#   'is_previous': False,
#   'is_current': False,
#   'is_next': False,
#   'cup_leagues_created': False,
#   'h2h_ko_matches_created': False,
#   'chip_plays': [],
#   'most_selected': None,
#   'most_transferred_in': None,
#   'top_element': None,
#   'top_element_info': None,
#   'transfers_made': 0,
#   'most_captained': None,
#   'most_vice_captained': None},
#  {'id': 19,
#   'name': 'Gameweek 19',
#   'deadline_time': '2023-12-26T13:30:00Z',
#   'average_entry_score': 0,
#   'finished': False,
#   'data_checked': False,
#   'highest_scoring_entry': None,
#   'deadline_time_epoch': 1703597400,
#   'deadline_time_game_offset': 0,
#   'highest_score': None,
#   'is_previous': False,
#   'is_current': False,
#   'is_next': False,
#   'cup_leagues_created': False,
#   'h2h_ko_matches_created': False,
#   'chip_plays': [],
#   'most_selected': None,
#   'most_transferred_in': None,
#   'top_element': None,
#   'top_element_info': None,
#   'transfers_made': 0,
#   'most_captained': None,
#   'most_vice_captained': None},
#  {'id': 20,
#   'name': 'Gameweek 20',
#   'deadline_time': '2023-12-30T13:30:00Z',
#   'average_entry_score': 0,
#   'finished': False,
#   'data_checked': False,
#   'highest_scoring_entry': None,
#   'deadline_time_epoch': 1703943000,
#   'deadline_time_game_offset': 0,
#   'highest_score': None,
#   'is_previous': False,
#   'is_current': False,
#   'is_next': False,
#   'cup_leagues_created': False,
#   'h2h_ko_matches_created': False,
#   'chip_plays': [],
#   'most_selected': None,
#   'most_transferred_in': None,
#   'top_element': None,
#   'top_element_info': None,
#   'transfers_made': 0,
#   'most_captained': None,
#   'most_vice_captained': None},
#  {'id': 21,
#   'name': 'Gameweek 21',
#   'deadline_time': '2024-01-13T13:30:00Z',
#   'average_entry_score': 0,
#   'finished': False,
#   'data_checked': False,
#   'highest_scoring_entry': None,
#   'deadline_time_epoch': 1705152600,
#   'deadline_time_game_offset': 0,
#   'highest_score': None,
#   'is_previous': False,
#   'is_current': False,
#   'is_next': False,
#   'cup_leagues_created': False,
#   'h2h_ko_matches_created': False,
#   'chip_plays': [],
#   'most_selected': None,
#   'most_transferred_in': None,
#   'top_element': None,
#   'top_element_info': None,
#   'transfers_made': 0,
#   'most_captained': None,
#   'most_vice_captained': None},
#  {'id': 22,
#   'name': 'Gameweek 22',
#   'deadline_time': '2024-01-30T18:15:00Z',
#   'average_entry_score': 0,
#   'finished': False,
#   'data_checked': False,
#   'highest_scoring_entry': None,
#   'deadline_time_epoch': 1706638500,
#   'deadline_time_game_offset': 0,
#   'highest_score': None,
#   'is_previous': False,
#   'is_current': False,
#   'is_next': False,
#   'cup_leagues_created': False,
#   'h2h_ko_matches_created': False,
#   'chip_plays': [],
#   'most_selected': None,
#   'most_transferred_in': None,
#   'top_element': None,
#   'top_element_info': None,
#   'transfers_made': 0,
#   'most_captained': None,
#   'most_vice_captained': None},
#  {'id': 23,
#   'name': 'Gameweek 23',
#   'deadline_time': '2024-02-03T13:30:00Z',
#   'average_entry_score': 0,
#   'finished': False,
#   'data_checked': False,
#   'highest_scoring_entry': None,
#   'deadline_time_epoch': 1706967000,
#   'deadline_time_game_offset': 0,
#   'highest_score': None,
#   'is_previous': False,
#   'is_current': False,
#   'is_next': False,
#   'cup_leagues_created': False,
#   'h2h_ko_matches_created': False,
#   'chip_plays': [],
#   'most_selected': None,
#   'most_transferred_in': None,
#   'top_element': None,
#   'top_element_info': None,
#   'transfers_made': 0,
#   'most_captained': None,
#   'most_vice_captained': None},
#  {'id': 24,
#   'name': 'Gameweek 24',
#   'deadline_time': '2024-02-10T13:30:00Z',
#   'average_entry_score': 0,
#   'finished': False,
#   'data_checked': False,
#   'highest_scoring_entry': None,
#   'deadline_time_epoch': 1707571800,
#   'deadline_time_game_offset': 0,
#   'highest_score': None,
#   'is_previous': False,
#   'is_current': False,
#   'is_next': False,
#   'cup_leagues_created': False,
#   'h2h_ko_matches_created': False,
#   'chip_plays': [],
#   'most_selected': None,
#   'most_transferred_in': None,
#   'top_element': None,
#   'top_element_info': None,
#   'transfers_made': 0,
#   'most_captained': None,
#   'most_vice_captained': None},
#  {'id': 25,
#   'name': 'Gameweek 25',
#   'deadline_time': '2024-02-17T13:30:00Z',
#   'average_entry_score': 0,
#   'finished': False,
#   'data_checked': False,
#   'highest_scoring_entry': None,
#   'deadline_time_epoch': 1708176600,
#   'deadline_time_game_offset': 0,
#   'highest_score': None,
#   'is_previous': False,
#   'is_current': False,
#   'is_next': False,
#   'cup_leagues_created': False,
#   'h2h_ko_matches_created': False,
#   'chip_plays': [],
#   'most_selected': None,
#   'most_transferred_in': None,
#   'top_element': None,
#   'top_element_info': None,
#   'transfers_made': 0,
#   'most_captained': None,
#   'most_vice_captained': None},
#  {'id': 26,
#   'name': 'Gameweek 26',
#   'deadline_time': '2024-02-24T13:30:00Z',
#   'average_entry_score': 0,
#   'finished': False,
#   'data_checked': False,
#   'highest_scoring_entry': None,
#   'deadline_time_epoch': 1708781400,
#   'deadline_time_game_offset': 0,
#   'highest_score': None,
#   'is_previous': False,
#   'is_current': False,
#   'is_next': False,
#   'cup_leagues_created': False,
#   'h2h_ko_matches_created': False,
#   'chip_plays': [],
#   'most_selected': None,
#   'most_transferred_in': None,
#   'top_element': None,
#   'top_element_info': None,
#   'transfers_made': 0,
#   'most_captained': None,
#   'most_vice_captained': None},
#  {'id': 27,
#   'name': 'Gameweek 27',
#   'deadline_time': '2024-03-02T13:30:00Z',
#   'average_entry_score': 0,
#   'finished': False,
#   'data_checked': False,
#   'highest_scoring_entry': None,
#   'deadline_time_epoch': 1709386200,
#   'deadline_time_game_offset': 0,
#   'highest_score': None,
#   'is_previous': False,
#   'is_current': False,
#   'is_next': False,
#   'cup_leagues_created': False,
#   'h2h_ko_matches_created': False,
#   'chip_plays': [],
#   'most_selected': None,
#   'most_transferred_in': None,
#   'top_element': None,
#   'top_element_info': None,
#   'transfers_made': 0,
#   'most_captained': None,
#   'most_vice_captained': None},
#  {'id': 28,
#   'name': 'Gameweek 28',
#   'deadline_time': '2024-03-09T13:30:00Z',
#   'average_entry_score': 0,
#   'finished': False,
#   'data_checked': False,
#   'highest_scoring_entry': None,
#   'deadline_time_epoch': 1709991000,
#   'deadline_time_game_offset': 0,
#   'highest_score': None,
#   'is_previous': False,
#   'is_current': False,
#   'is_next': False,
#   'cup_leagues_created': False,
#   'h2h_ko_matches_created': False,
#   'chip_plays': [],
#   'most_selected': None,
#   'most_transferred_in': None,
#   'top_element': None,
#   'top_element_info': None,
#   'transfers_made': 0,
#   'most_captained': None,
#   'most_vice_captained': None},
#  {'id': 29,
#   'name': 'Gameweek 29',
#   'deadline_time': '2024-03-16T13:30:00Z',
#   'average_entry_score': 0,
#   'finished': False,
#   'data_checked': False,
#   'highest_scoring_entry': None,
#   'deadline_time_epoch': 1710595800,
#   'deadline_time_game_offset': 0,
#   'highest_score': None,
#   'is_previous': False,
#   'is_current': False,
#   'is_next': False,
#   'cup_leagues_created': False,
#   'h2h_ko_matches_created': False,
#   'chip_plays': [],
#   'most_selected': None,
#   'most_transferred_in': None,
#   'top_element': None,
#   'top_element_info': None,
#   'transfers_made': 0,
#   'most_captained': None,
#   'most_vice_captained': None},
#  {'id': 30,
#   'name': 'Gameweek 30',
#   'deadline_time': '2024-03-30T13:30:00Z',
#   'average_entry_score': 0,
#   'finished': False,
#   'data_checked': False,
#   'highest_scoring_entry': None,
#   'deadline_time_epoch': 1711805400,
#   'deadline_time_game_offset': 0,
#   'highest_score': None,
#   'is_previous': False,
#   'is_current': False,
#   'is_next': False,
#   'cup_leagues_created': False,
#   'h2h_ko_matches_created': False,
#   'chip_plays': [],
#   'most_selected': None,
#   'most_transferred_in': None,
#   'top_element': None,
#   'top_element_info': None,
#   'transfers_made': 0,
#   'most_captained': None,
#   'most_vice_captained': None},
#  {'id': 31,
#   'name': 'Gameweek 31',
#   'deadline_time': '2024-04-02T17:15:00Z',
#   'average_entry_score': 0,
#   'finished': False,
#   'data_checked': False,
#   'highest_scoring_entry': None,
#   'deadline_time_epoch': 1712078100,
#   'deadline_time_game_offset': 0,
#   'highest_score': None,
#   'is_previous': False,
#   'is_current': False,
#   'is_next': False,
#   'cup_leagues_created': False,
#   'h2h_ko_matches_created': False,
#   'chip_plays': [],
#   'most_selected': None,
#   'most_transferred_in': None,
#   'top_element': None,
#   'top_element_info': None,
#   'transfers_made': 0,
#   'most_captained': None,
#   'most_vice_captained': None},
#  {'id': 32,
#   'name': 'Gameweek 32',
#   'deadline_time': '2024-04-06T12:30:00Z',
#   'average_entry_score': 0,
#   'finished': False,
#   'data_checked': False,
#   'highest_scoring_entry': None,
#   'deadline_time_epoch': 1712406600,
#   'deadline_time_game_offset': 0,
#   'highest_score': None,
#   'is_previous': False,
#   'is_current': False,
#   'is_next': False,
#   'cup_leagues_created': False,
#   'h2h_ko_matches_created': False,
#   'chip_plays': [],
#   'most_selected': None,
#   'most_transferred_in': None,
#   'top_element': None,
#   'top_element_info': None,
#   'transfers_made': 0,
#   'most_captained': None,
#   'most_vice_captained': None},
#  {'id': 33,
#   'name': 'Gameweek 33',
#   'deadline_time': '2024-04-13T12:30:00Z',
#   'average_entry_score': 0,
#   'finished': False,
#   'data_checked': False,
#   'highest_scoring_entry': None,
#   'deadline_time_epoch': 1713011400,
#   'deadline_time_game_offset': 0,
#   'highest_score': None,
#   'is_previous': False,
#   'is_current': False,
#   'is_next': False,
#   'cup_leagues_created': False,
#   'h2h_ko_matches_created': False,
#   'chip_plays': [],
#   'most_selected': None,
#   'most_transferred_in': None,
#   'top_element': None,
#   'top_element_info': None,
#   'transfers_made': 0,
#   'most_captained': None,
#   'most_vice_captained': None},
#  {'id': 34,
#   'name': 'Gameweek 34',
#   'deadline_time': '2024-04-20T12:30:00Z',
#   'average_entry_score': 0,
#   'finished': False,
#   'data_checked': False,
#   'highest_scoring_entry': None,
#   'deadline_time_epoch': 1713616200,
#   'deadline_time_game_offset': 0,
#   'highest_score': None,
#   'is_previous': False,
#   'is_current': False,
#   'is_next': False,
#   'cup_leagues_created': False,
#   'h2h_ko_matches_created': False,
#   'chip_plays': [],
#   'most_selected': None,
#   'most_transferred_in': None,
#   'top_element': None,
#   'top_element_info': None,
#   'transfers_made': 0,
#   'most_captained': None,
#   'most_vice_captained': None},
#  {'id': 35,
#   'name': 'Gameweek 35',
#   'deadline_time': '2024-04-27T12:30:00Z',
#   'average_entry_score': 0,
#   'finished': False,
#   'data_checked': False,
#   'highest_scoring_entry': None,
#   'deadline_time_epoch': 1714221000,
#   'deadline_time_game_offset': 0,
#   'highest_score': None,
#   'is_previous': False,
#   'is_current': False,
#   'is_next': False,
#   'cup_leagues_created': False,
#   'h2h_ko_matches_created': False,
#   'chip_plays': [],
#   'most_selected': None,
#   'most_transferred_in': None,
#   'top_element': None,
#   'top_element_info': None,
#   'transfers_made': 0,
#   'most_captained': None,
#   'most_vice_captained': None},
#  {'id': 36,
#   'name': 'Gameweek 36',
#   'deadline_time': '2024-05-04T12:30:00Z',
#   'average_entry_score': 0,
#   'finished': False,
#   'data_checked': False,
#   'highest_scoring_entry': None,
#   'deadline_time_epoch': 1714825800,
#   'deadline_time_game_offset': 0,
#   'highest_score': None,
#   'is_previous': False,
#   'is_current': False,
#   'is_next': False,
#   'cup_leagues_created': False,
#   'h2h_ko_matches_created': False,
#   'chip_plays': [],
#   'most_selected': None,
#   'most_transferred_in': None,
#   'top_element': None,
#   'top_element_info': None,
#   'transfers_made': 0,
#   'most_captained': None,
#   'most_vice_captained': None},
#  {'id': 37,
#   'name': 'Gameweek 37',
#   'deadline_time': '2024-05-11T12:30:00Z',
#   'average_entry_score': 0,
#   'finished': False,
#   'data_checked': False,
#   'highest_scoring_entry': None,
#   'deadline_time_epoch': 1715430600,
#   'deadline_time_game_offset': 0,
#   'highest_score': None,
#   'is_previous': False,
#   'is_current': False,
#   'is_next': False,
#   'cup_leagues_created': False,
#   'h2h_ko_matches_created': False,
#   'chip_plays': [],
#   'most_selected': None,
#   'most_transferred_in': None,
#   'top_element': None,
#   'top_element_info': None,
#   'transfers_made': 0,
#   'most_captained': None,
#   'most_vice_captained': None},
#  {'id': 38,
#   'name': 'Gameweek 38',
#   'deadline_time': '2024-05-19T13:30:00Z',
#   'average_entry_score': 0,
#   'finished': False,
#   'data_checked': False,
#   'highest_scoring_entry': None,
#   'deadline_time_epoch': 1716125400,
#   'deadline_time_game_offset': 0,
#   'highest_score': None,
#   'is_previous': False,
#   'is_current': False,
#   'is_next': False,
#   'cup_leagues_created': False,
#   'h2h_ko_matches_created': False,
#   'chip_plays': [],
#   'most_selected': None,
#   'most_transferred_in': None,
#   'top_element': None,
#   'top_element_info': None,
#   'transfers_made': 0,
#   'most_captained': None,
#   'most_vice_captained': None}]

# %%
position_list = []
for i in data['element_types']:
    position_id = i['id']
    position_name = i['singular_name']
    position_short_name = i['singular_name_short']
    total_player_count = i['element_count']
    position_element = {'position_id':position_id, 'position_name':position_name,'position_short_name':position_short_name,
                       'total_player_count':total_player_count}
    position_list.append(position_element)

# %%
position_list
# Out:
# [{'position_id': 1,
#   'position_name': 'Goalkeeper',
#   'position_short_name': 'GKP',
#   'total_player_count': 85},
#  {'position_id': 2,
#   'position_name': 'Defender',
#   'position_short_name': 'DEF',
#   'total_player_count': 233},
#  {'position_id': 3,
#   'position_name': 'Midfielder',
#   'position_short_name': 'MID',
#   'total_player_count': 310},
#  {'position_id': 4,
#   'position_name': 'Forward',
#   'position_short_name': 'FWD',
#   'total_player_count': 94}]

# %%
position_df = pd.DataFrame.from_dict(position_list)

# %%
position_df.head()
# Out:
#    position_id position_name position_short_name  total_player_count
# 0            1    Goalkeeper                 GKP                  85
# 1            2      Defender                 DEF                 233
# 2            3    Midfielder                 MID                 310
# 3            4       Forward                 FWD                  94

# %%
data['element_types']
# Out:
# [{'id': 1,
#   'plural_name': 'Goalkeepers',
#   'plural_name_short': 'GKP',
#   'singular_name': 'Goalkeeper',
#   'singular_name_short': 'GKP',
#   'squad_select': 2,
#   'squad_min_play': 1,
#   'squad_max_play': 1,
#   'ui_shirt_specific': True,
#   'sub_positions_locked': [12],
#   'element_count': 85},
#  {'id': 2,
#   'plural_name': 'Defenders',
#   'plural_name_short': 'DEF',
#   'singular_name': 'Defender',
#   'singular_name_short': 'DEF',
#   'squad_select': 5,
#   'squad_min_play': 3,
#   'squad_max_play': 5,
#   'ui_shirt_specific': False,
#   'sub_positions_locked': [],
#   'element_count': 233},
#  {'id': 3,
#   'plural_name': 'Midfielders',
#   'plural_name_short': 'MID',
#   'singular_name': 'Midfielder',
#   'singular_name_short': 'MID',
#   'squad_select': 5,
#   'squad_min_play': 2,
#   'squad_max_play': 5,
#   'ui_shirt_specific': False,
#   'sub_positions_locked': [],
#   'element_count': 310},
#  {'id': 4,
#   'plural_name': 'Forwards',
#   'plural_name_short': 'FWD',
#   'singular_name': 'Forward',
#   'singular_name_short': 'FWD',
#   'squad_select': 3,
#   'squad_min_play': 1,
#   'squad_max_play': 3,
#   'ui_shirt_specific': False,
#   'sub_positions_locked': [],
#   'element_count': 94}]

# %%
base_url1 = 'https://fantasy.premierleague.com/api/' 
data2 = requests.get(base_url1+'fixtures/').json() 
pprint(data2, indent=2, depth=1, compact=True)
# Out:
# [ {...}, {...}, {...}, {...}, {...}, {...}, {...}, {...}, {...}, {...}, {...},
#   {...}, {...}, {...}, {...}, {...}, {...}, {...}, {...}, {...}, {...}, {...},
#   {...}, {...}, {...}, {...}, {...}, {...}, {...}, {...}, {...}, {...}, {...},
#   {...}, {...}, {...}, {...}, {...}, {...}, {...}, {...}, {...}, {...}, {...},
#   {...}, {...}, {...}, {...}, {...}, {...}, {...}, {...}, {...}, {...}, {...},
#   {...}, {...}, {...}, {...}, {...}, {...}, {...}, {...}, {...}, {...}, {...},
#   {...}, {...}, {...}, {...}, {...}, {...}, {...}, {...}, {...}, {...}, {...},
#   {...}, {...}, {...}, {...}, {...}, {...}, {...}, {...}, {...}, {...}, {...},
#   {...}, {...}, {...}, {...}, {...}, {...}, {...}, {...}, {...}, {...}, {...},
#   {...}, {...}, {...}, {...}, {...}, {...}, {...}, {...}, {...}, {...}, {...},
#   {...}, {...}, {...}, {...}, {...}, {...}, {...}, {...}, {...}, {...}, {...},
#   {...}, {...}, {...}, {...}, {...}, {...}, {...}, {...}, {...}, {...}, {...},
#   {...}, {...}, {...}, {...}, {...}, {...}, {...}, {...}, {...}, {...}, {...},
#   {...}, {...}, {...}, {...}, {...}, {...}, {...}, {...}, {...}, {...}, {...},
#   {...}, {...}, {...}, {...}, {...}, {...}, {...}, {...}, {...}, {...}, {...},
#   {...}, {...}, {...}, {...}, {...}, {...}, {...}, {...}, {...}, {...}, {...},
#   {...}, {...}, {...}, {...}, {...}, {...}, {...}, {...}, {...}, {...}, {...},
#   {...}, {...}, {...}, {...}, {...}, {...}, {...}, {...}, {...}, {...}, {...},
#   {...}, {...}, {...}, {...}, {...}, {...}, {...}, {...}, {...}, {...}, {...},
#   {...}, {...}, {...}, {...}, {...}, {...}, {...}, {...}, {...}, {...}, {...},
#   {...}, {...}, {...}, {...}, {...}, {...}, {...}, {...}, {...}, {...}, {...},
#   {...}, {...}, {...}, {...}, {...}, {...}, {...}, {...}, {...}, {...}, {...},
#   {...}, {...}, {...}, {...}, {...}, {...}, {...}, {...}, {...}, {...}, {...},
#   {...}, {...}, {...}, {...}, {...}, {...}, {...}, {...}, {...}, {...}, {...},
#   {...}, {...}, {...}, {...}, {...}, {...}, {...}, {...}, {...}, {...}, {...},
#   {...}, {...}, {...}, {...}, {...}, {...}, {...}, {...}, {...}, {...}, {...},
#   {...}, {...}, {...}, {...}, {...}, {...}, {...}, {...}, {...}, {...}, {...},
#   {...}, {...}, {...}, {...}, {...}, {...}, {...}, {...}, {...}, {...}, {...},
#   {...}, {...}, {...}, {...}, {...}, {...}, {...}, {...}, {...}, {...}, {...},
#   {...}, {...}, {...}, {...}, {...}, {...}, {...}, {...}, {...}, {...}, {...},
#   {...}, {...}, {...}, {...}, {...}, {...}, {...}, {...}, {...}, {...}, {...},
#   {...}, {...}, {...}, {...}, {...}, {...}, {...}, {...}, {...}, {...}, {...},
#   {...}, {...}, {...}, {...}, {...}, {...}, {...}, {...}, {...}, {...}, {...},
#   {...}, {...}, {...}, {...}, {...}, {...}, {...}, {...}, {...}, {...}, {...},
#   {...}, {...}, {...}, {...}, {...}, {...}]

# %%
data2[0]
# Out:
# {'code': 2367713,
#  'event': None,
#  'finished': False,
#  'finished_provisional': False,
#  'id': 176,
#  'kickoff_time': None,
#  'minutes': 0,
#  'provisional_start_time': False,
#  'started': None,
#  'team_a': 4,
#  'team_a_score': None,
#  'team_h': 13,
#  'team_h_score': None,
#  'stats': [],
#  'team_h_difficulty': 3,
#  'team_a_difficulty': 5,
#  'pulse_id': 93496}

# %%
data['teams']
# Out:
# [{'code': 3,
#   'draw': 0,
#   'form': None,
#   'id': 1,
#   'loss': 0,
#   'name': 'Arsenal',
#   'played': 0,
#   'points': 0,
#   'position': 0,
#   'short_name': 'ARS',
#   'strength': 4,
#   'team_division': None,
#   'unavailable': False,
#   'win': 0,
#   'strength_overall_home': 1230,
#   'strength_overall_away': 1285,
#   'strength_attack_home': 1250,
#   'strength_attack_away': 1250,
#   'strength_defence_home': 1210,
#   'strength_defence_away': 1320,
#   'pulse_id': 1},
#  {'code': 7,
#   'draw': 0,
#   'form': None,
#   'id': 2,
#   'loss': 0,
#   'name': 'Aston Villa',
#   'played': 0,
#   'points': 0,
#   'position': 0,
#   'short_name': 'AVL',
#   'strength': 3,
#   'team_division': None,
#   'unavailable': False,
#   'win': 0,
#   'strength_overall_home': 1115,
#   'strength_overall_away': 1175,
#   'strength_attack_home': 1130,
#   'strength_attack_away': 1190,
#   'strength_defence_home': 1100,
#   'strength_defence_away': 1160,
#   'pulse_id': 2},
#  {'code': 91,
#   'draw': 0,
#   'form': None,
#   'id': 3,
#   'loss': 0,
#   'name': 'Bournemouth',
#   'played': 0,
#   'points': 0,
#   'position': 0,
#   'short_name': 'BOU',
#   'strength': 3,
#   'team_division': None,
#   'unavailable': False,
#   'win': 0,
#   'strength_overall_home': 1060,
#   'strength_overall_away': 1095,
#   'strength_attack_home': 1050,
#   'strength_attack_away': 1100,
#   'strength_defence_home': 1060,
#   'strength_defence_away': 1090,
#   'pulse_id': 127},
#  {'code': 94,
#   'draw': 0,
#   'form': None,
#   'id': 4,
#   'loss': 0,
#   'name': 'Brentford',
#   'played': 0,
#   'points': 0,
#   'position': 0,
#   'short_name': 'BRE',
#   'strength': 3,
#   'team_division': None,
#   'unavailable': False,
#   'win': 0,
#   'strength_overall_home': 1125,
#   'strength_overall_away': 1205,
#   'strength_attack_home': 1120,
#   'strength_attack_away': 1220,
#   'strength_defence_home': 1130,
#   'strength_defence_away': 1190,
#   'pulse_id': 130},
#  {'code': 36,
#   'draw': 0,
#   'form': None,
#   'id': 5,
#   'loss': 0,
#   'name': 'Brighton',
#   'played': 0,
#   'points': 0,
#   'position': 0,
#   'short_name': 'BHA',
#   'strength': 3,
#   'team_division': None,
#   'unavailable': False,
#   'win': 0,
#   'strength_overall_home': 1165,
#   'strength_overall_away': 1210,
#   'strength_attack_home': 1120,
#   'strength_attack_away': 1200,
#   'strength_defence_home': 1210,
#   'strength_defence_away': 1240,
#   'pulse_id': 131},
#  {'code': 90,
#   'draw': 0,
#   'form': None,
#   'id': 6,
#   'loss': 0,
#   'name': 'Burnley',
#   'played': 0,
#   'points': 0,
#   'position': 0,
#   'short_name': 'BUR',
#   'strength': 2,
#   'team_division': None,
#   'unavailable': False,
#   'win': 0,
#   'strength_overall_home': 1060,
#   'strength_overall_away': 1080,
#   'strength_attack_home': 1060,
#   'strength_attack_away': 1080,
#   'strength_defence_home': 1060,
#   'strength_defence_away': 1080,
#   'pulse_id': 43},
#  {'code': 8,
#   'draw': 0,
#   'form': None,
#   'id': 7,
#   'loss': 0,
#   'name': 'Chelsea',
#   'played': 0,
#   'points': 0,
#   'position': 0,
#   'short_name': 'CHE',
#   'strength': 3,
#   'team_division': None,
#   'unavailable': False,
#   'win': 0,
#   'strength_overall_home': 1115,
#   'strength_overall_away': 1160,
#   'strength_attack_home': 1130,
#   'strength_attack_away': 1210,
#   'strength_defence_home': 1100,
#   'strength_defence_away': 1110,
#   'pulse_id': 4},
#  {'code': 31,
#   'draw': 0,
#   'form': None,
#   'id': 8,
#   'loss': 0,
#   'name': 'Crystal Palace',
#   'played': 0,
#   'points': 0,
#   'position': 0,
#   'short_name': 'CRY',
#   'strength': 3,
#   'team_division': None,
#   'unavailable': False,
#   'win': 0,
#   'strength_overall_home': 1100,
#   'strength_overall_away': 1100,
#   'strength_attack_home': 1140,
#   'strength_attack_away': 1170,
#   'strength_defence_home': 1080,
#   'strength_defence_away': 1085,
#   'pulse_id': 6},
#  {'code': 11,
#   'draw': 0,
#   'form': None,
#   'id': 9,
#   'loss': 0,
#   'name': 'Everton',
#   'played': 0,
#   'points': 0,
#   'position': 0,
#   'short_name': 'EVE',
#   'strength': 3,
#   'team_division': None,
#   'unavailable': False,
#   'win': 0,
#   'strength_overall_home': 1075,
#   'strength_overall_away': 1100,
#   'strength_attack_home': 1070,
#   'strength_attack_away': 1120,
#   'strength_defence_home': 1080,
#   'strength_defence_away': 1080,
#   'pulse_id': 7},
#  {'code': 54,
#   'draw': 0,
#   'form': None,
#   'id': 10,
#   'loss': 0,
#   'name': 'Fulham',
#   'played': 0,
#   'points': 0,
#   'position': 0,
#   'short_name': 'FUL',
#   'strength': 3,
#   'team_division': None,
#   'unavailable': False,
#   'win': 0,
#   'strength_overall_home': 1095,
#   'strength_overall_away': 1100,
#   'strength_attack_home': 1090,
#   'strength_attack_away': 1090,
#   'strength_defence_home': 1100,
#   'strength_defence_away': 1140,
#   'pulse_id': 34},
#  {'code': 14,
#   'draw': 0,
#   'form': None,
#   'id': 11,
#   'loss': 0,
#   'name': 'Liverpool',
#   'played': 0,
#   'points': 0,
#   'position': 0,
#   'short_name': 'LIV',
#   'strength': 4,
#   'team_division': None,
#   'unavailable': False,
#   'win': 0,
#   'strength_overall_home': 1220,
#   'strength_overall_away': 1285,
#   'strength_attack_home': 1170,
#   'strength_attack_away': 1270,
#   'strength_defence_home': 1260,
#   'strength_defence_away': 1300,
#   'pulse_id': 10},
#  {'code': 102,
#   'draw': 0,
#   'form': None,
#   'id': 12,
#   'loss': 0,
#   'name': 'Luton',
#   'played': 0,
#   'points': 0,
#   'position': 0,
#   'short_name': 'LUT',
#   'strength': 2,
#   'team_division': None,
#   'unavailable': False,
#   'win': 0,
#   'strength_overall_home': 1045,
#   'strength_overall_away': 1050,
#   'strength_attack_home': 1050,
#   'strength_attack_away': 1050,
#   'strength_defence_home': 1040,
#   'strength_defence_away': 1050,
#   'pulse_id': 163},
#  {'code': 43,
#   'draw': 0,
#   'form': None,
#   'id': 13,
#   'loss': 0,
#   'name': 'Man City',
#   'played': 0,
#   'points': 0,
#   'position': 0,
#   'short_name': 'MCI',
#   'strength': 5,
#   'team_division': None,
#   'unavailable': False,
#   'win': 0,
#   'strength_overall_home': 1350,
#   'strength_overall_away': 1355,
#   'strength_attack_home': 1320,
#   'strength_attack_away': 1340,
#   'strength_defence_home': 1320,
#   'strength_defence_away': 1370,
#   'pulse_id': 11},
#  {'code': 1,
#   'draw': 0,
#   'form': None,
#   'id': 14,
#   'loss': 0,
#   'name': 'Man Utd',
#   'played': 0,
#   'points': 0,
#   'position': 0,
#   'short_name': 'MUN',
#   'strength': 4,
#   'team_division': None,
#   'unavailable': False,
#   'win': 0,
#   'strength_overall_home': 1145,
#   'strength_overall_away': 1275,
#   'strength_attack_home': 1150,
#   'strength_attack_away': 1310,
#   'strength_defence_home': 1140,
#   'strength_defence_away': 1240,
#   'pulse_id': 12},
#  {'code': 4,
#   'draw': 0,
#   'form': None,
#   'id': 15,
#   'loss': 0,
#   'name': 'Newcastle',
#   'played': 0,
#   'points': 0,
#   'position': 0,
#   'short_name': 'NEW',
#   'strength': 4,
#   'team_division': None,
#   'unavailable': False,
#   'win': 0,
#   'strength_overall_home': 1220,
#   'strength_overall_away': 1280,
#   'strength_attack_home': 1250,
#   'strength_attack_away': 1310,
#   'strength_defence_home': 1190,
#   'strength_defence_away': 1250,
#   'pulse_id': 23},
#  {'code': 17,
#   'draw': 0,
#   'form': None,
#   'id': 16,
#   'loss': 0,
#   'name': "Nott'm Forest",
#   'played': 0,
#   'points': 0,
#   'position': 0,
#   'short_name': 'NFO',
#   'strength': 3,
#   'team_division': None,
#   'unavailable': False,
#   'win': 0,
#   'strength_overall_home': 1050,
#   'strength_overall_away': 1100,
#   'strength_attack_home': 1050,
#   'strength_attack_away': 1110,
#   'strength_defence_home': 1050,
#   'strength_defence_away': 1120,
#   'pulse_id': 15},
#  {'code': 49,
#   'draw': 0,
#   'form': None,
#   'id': 17,
#   'loss': 0,
#   'name': 'Sheffield Utd',
#   'played': 0,
#   'points': 0,
#   'position': 0,
#   'short_name': 'SHU',
#   'strength': 2,
#   'team_division': None,
#   'unavailable': False,
#   'win': 0,
#   'strength_overall_home': 1045,
#   'strength_overall_away': 1070,
#   'strength_attack_home': 1050,
#   'strength_attack_away': 1060,
#   'strength_defence_home': 1040,
#   'strength_defence_away': 1080,
#   'pulse_id': 18},
#  {'code': 6,
#   'draw': 0,
#   'form': None,
#   'id': 18,
#   'loss': 0,
#   'name': 'Spurs',
#   'played': 0,
#   'points': 0,
#   'position': 0,
#   'short_name': 'TOT',
#   'strength': 3,
#   'team_division': None,
#   'unavailable': False,
#   'win': 0,
#   'strength_overall_home': 1130,
#   'strength_overall_away': 1200,
#   'strength_attack_home': 1110,
#   'strength_attack_away': 1200,
#   'strength_defence_home': 1150,
#   'strength_defence_away': 1200,
#   'pulse_id': 21},
#  {'code': 21,
#   'draw': 0,
#   'form': None,
#   'id': 19,
#   'loss': 0,
#   'name': 'West Ham',
#   'played': 0,
#   'points': 0,
#   'position': 0,
#   'short_name': 'WHU',
#   'strength': 3,
#   'team_division': None,
#   'unavailable': False,
#   'win': 0,
#   'strength_overall_home': 1095,
#   'strength_overall_away': 1140,
#   'strength_attack_home': 1100,
#   'strength_attack_away': 1150,
#   'strength_defence_home': 1090,
#   'strength_defence_away': 1130,
#   'pulse_id': 25},
#  {'code': 39,
#   'draw': 0,
#   'form': None,
#   'id': 20,
#   'loss': 0,
#   'name': 'Wolves',
#   'played': 0,
#   'points': 0,
#   'position': 0,
#   'short_name': 'WOL',
#   'strength': 3,
#   'team_division': None,
#   'unavailable': False,
#   'win': 0,
#   'strength_overall_home': 1065,
#   'strength_overall_away': 1100,
#   'strength_attack_home': 1070,
#   'strength_attack_away': 1160,
#   'strength_defence_home': 1060,
#   'strength_defence_away': 1080,
#   'pulse_id': 38}]

# %%
data['elements'][176]['first_name']
# Out:
# 'Jordan'

# %%
#Player Data
data['elements'][11]
# Out:
# {'chance_of_playing_next_round': None,
#  'chance_of_playing_this_round': None,
#  'code': 205533,
#  'cost_change_event': 0,
#  'cost_change_event_fall': 0,
#  'cost_change_start': 0,
#  'cost_change_start_fall': 0,
#  'dreamteam_count': 1,
#  'element_type': 4,
#  'ep_next': '6.0',
#  'ep_this': '7.0',
#  'event_points': 17,
#  'first_name': 'Eddie',
#  'form': '6.0',
#  'id': 13,
#  'in_dreamteam': False,
#  'news': '',
#  'news_added': None,
#  'now_cost': 55,
#  'photo': '205533.jpg',
#  'points_per_game': '4.7',
#  'second_name': 'Nketiah',
#  'selected_by_percent': '6.6',
#  'special': False,
#  'squad_number': None,
#  'status': 'a',
#  'team': 1,
#  'team_code': 3,
#  'total_points': 47,
#  'transfers_in': 843214,
#  'transfers_in_event': 153839,
#  'transfers_out': 601802,
#  'transfers_out_event': 6909,
#  'value_form': '1.1',
#  'value_season': '8.5',
#  'web_name': 'Nketiah',
#  'minutes': 679,
#  'goals_scored': 5,
#  'assists': 2,
#  'clean_sheets': 6,
#  'goals_conceded': 4,
#  'own_goals': 0,
#  'penalties_saved': 0,
#  'penalties_missed': 0,
#  'yellow_cards': 2,
#  'red_cards': 0,
#  'saves': 0,
#  'bonus': 5,
#  'bps': 156,
#  'influence': '179.4',
#  'creativity': '77.6',
#  'threat': '257.0',
#  'ict_index': '50.6',
#  'starts': 8,
#  'expected_goals': '2.99',
#  'expected_assists': '0.30',
#  'expected_goal_involvements': '3.29',
#  'expected_goals_conceded': '4.51',
#  'influence_rank': 84,
#  'influence_rank_type': 11,
#  'creativity_rank': 139,
#  'creativity_rank_type': 15,
#  'threat_rank': 23,
#  'threat_rank_type': 11,
#  'ict_index_rank': 47,
#  'ict_index_rank_type': 12,
#  'corners_and_indirect_freekicks_order': None,
#  'corners_and_indirect_freekicks_text': '',
#  'direct_freekicks_order': None,
#  'direct_freekicks_text': '',
#  'penalties_order': None,
#  'penalties_text': '',
#  'expected_goals_per_90': 0.4,
#  'saves_per_90': 0.0,
#  'expected_assists_per_90': 0.04,
#  'expected_goal_involvements_per_90': 0.44,
#  'expected_goals_conceded_per_90': 0.6,
#  'goals_conceded_per_90': 0.53,
#  'now_cost_rank': 104,
#  'now_cost_rank_type': 31,
#  'form_rank': 13,
#  'form_rank_type': 2,
#  'points_per_game_rank': 31,
#  'points_per_game_rank_type': 8,
#  'selected_rank': 61,
#  'selected_rank_type': 11,
#  'starts_per_90': 1.06,
#  'clean_sheets_per_90': 0.8}

# %%
#Player Data
player_list = []
for i in data['elements']:
    player_id = i['id']
    player_first_name = i['first_name']
    player_last_name = i['second_name']
    player_team_id = i['team']
    player_type = i['element_type']
    minutes_played = i['minutes']
    player_form = i['form']
    player_form_rank = i['form_rank']
    goals_scored = i['goals_scored']
    assists_scored = i['assists']
    clean_sheets = i['clean_sheets']
    goals_conceded = i['goals_conceded']
    own_goals = i['own_goals']
    penalties_saved = i['penalties_saved']
    penalties_missed = i['penalties_missed']
    yellow_cards = i['yellow_cards']
    red_cards = i['red_cards']
    player_influence = i['influence']
    player_influence_rank = i['influence_rank']
    player_creativity = i['creativity']
    player_creativity_rank = i['creativity_rank']
    player_threat = i['threat']
    player_threat_rank = i['threat_rank']
    player_starts = i['starts']
    player_news = i['news']
    news_date = i['news_added']
    player_element = {'player_id':player_id,'first_name':player_first_name,'last_name':player_last_name,'team_id':player_team_id,
                     'player_type':player_type,'minutes_played':minutes_played,'form':player_form,'form_rank':player_form_rank,
                     'goals':goals_scored,'assists':assists_scored,'clean_sheets':clean_sheets,
                     'goals_conceded':goals_conceded,'own_goals':own_goals,'penalties_saved':penalties_saved,
                     'penalties_missed':penalties_missed,'yellow_cards':yellow_cards,'red_cards':red_cards,
                     'player_influence':player_influence,'player_influence_rank':player_influence_rank,
                     'player_creativity':player_creativity,'player_creativity_rank':player_creativity_rank,
                     'player_threat':player_threat, 'player_threat_rank':player_threat_rank,
                     'player_starts':player_starts,'player_news':player_news,'news_date':news_date}
    player_list.append(player_element)

# %%
player_list
# Out:
# [{'player_id': 1,
#   'first_name': 'Folarin',
#   'last_name': 'Balogun',
#   'team_id': 1,
#   'player_type': 4,
#   'minutes_played': 0,
#   'form': '0.0',
#   'form_rank': 533,
#   'goals': 0,
#   'assists': 0,
#   'clean_sheets': 0,
#   'goals_conceded': 0,
#   'own_goals': 0,
#   'penalties_saved': 0,
#   'penalties_missed': 0,
#   'yellow_cards': 0,
#   'red_cards': 0,
#   'player_influence': '0.0',
#   'player_influence_rank': 582,
#   'player_creativity': '0.0',
#   'player_creativity_rank': 574,
#   'player_threat': '0.0',
#   'player_threat_rank': 562,
#   'player_starts': 0,
#   'player_news': 'Transferred to Monaco',
#   'news_date': '2023-08-31T08:55:15.272751Z'},
#  {'player_id': 2,
#   'first_name': 'Cédric',
#   'last_name': 'Alves Soares',
#   'team_id': 1,
#   'player_type': 2,
#   'minutes_played': 0,
#   'form': '0.0',
#   'form_rank': 370,
#   'goals': 0,
#   'assists': 0,
#   'clean_sheets': 0,
#   'goals_conceded': 0,
#   'own_goals': 0,
#   'penalties_saved': 0,
#   'penalties_missed': 0,
#   'yellow_cards': 0,
#   'red_cards': 0,
#   'player_influence': '0.0',
#   'player_influence_rank': 446,
#   'player_creativity': '0.0',
#   'player_creativity_rank': 428,
#   'player_threat': '0.0',
#   'player_threat_rank': 402,
#   'player_starts': 0,
#   'player_news': '',
#   'news_date': None},
#  {'player_id': 3,
#   'first_name': 'Mohamed',
#   'last_name': 'Elneny',
#   'team_id': 1,
#   'player_type': 3,
#   'minutes_played': 1,
#   'form': '1.3',
#   'form_rank': 193,
#   'goals': 0,
#   'assists': 1,
#   'clean_sheets': 0,
#   'goals_conceded': 0,
#   'own_goals': 0,
#   'penalties_saved': 0,
#   'penalties_missed': 0,
#   'yellow_cards': 0,
#   'red_cards': 0,
#   'player_influence': '1.8',
#   'player_influence_rank': 431,
#   'player_creativity': '0.5',
#   'player_creativity_rank': 407,
#   'player_threat': '2.0',
#   'player_threat_rank': 382,
#   'player_starts': 0,
#   'player_news': '',
#   'news_date': '2023-08-11T13:00:06.079379Z'},
#  {'player_id': 4,
#   'first_name': 'Fábio',
#   'last_name': 'Ferreira Vieira',
#   'team_id': 1,
#   'player_type': 3,
#   'minutes_played': 202,
#   'form': '2.0',
#   'form_rank': 159,
#   'goals': 1,
#   'assists': 3,
#   'clean_sheets': 1,
#   'goals_conceded': 2,
#   'own_goals': 0,
#   'penalties_saved': 0,
#   'penalties_missed': 0,
#   'yellow_cards': 0,
#   'red_cards': 0,
#   'player_influence': '79.0',
#   'player_influence_rank': 230,
#   'player_creativity': '62.1',
#   'player_creativity_rank': 176,
#   'player_threat': '77.0',
#   'player_threat_rank': 130,
#   'player_starts': 2,
#   'player_news': '',
#   'news_date': '2023-09-29T10:30:07.948136Z'},
#  {'player_id': 5,
#   'first_name': 'Gabriel',
#   'last_name': 'dos Santos Magalhães',
#   'team_id': 1,
#   'player_type': 2,
#   'minutes_played': 564,
#   'form': '3.0',
#   'form_rank': 92,
#   'goals': 0,
#   'assists': 0,
#   'clean_sheets': 3,
#   'goals_conceded': 5,
#   'own_goals': 0,
#   'penalties_saved': 0,
#   'penalties_missed': 0,
#   'yellow_cards': 1,
#   'red_cards': 0,
#   'player_influence': '108.2',
#   'player_influence_rank': 172,
#   'player_creativity': '11.8',
#   'player_creativity_rank': 352,
#   'player_threat': '25.0',
#   'player_threat_rank': 250,
#   'player_starts': 6,
#   'player_news': '',
#   'news_date': '2023-09-30T23:00:07.672676Z'},
#  {'player_id': 6,
#   'first_name': 'Kai',
#   'last_name': 'Havertz',
#   'team_id': 1,
#   'player_type': 3,
#   'minutes_played': 563,
#   'form': '2.7',
#   'form_rank': 120,
#   'goals': 1,
#   'assists': 1,
#   'clean_sheets': 3,
#   'goals_conceded': 4,
#   'own_goals': 0,
#   'penalties_saved': 0,
#   'penalties_missed': 0,
#   'yellow_cards': 3,
#   'red_cards': 0,
#   'player_influence': '91.2',
#   'player_influence_rank': 207,
#   'player_creativity': '114.0',
#   'player_creativity_rank': 84,
#   'player_threat': '101.0',
#   'player_threat_rank': 95,
#   'player_starts': 6,
#   'player_news': '',
#   'news_date': None},
#  {'player_id': 8,
#   'first_name': 'Gabriel',
#   'last_name': 'Fernando de Jesus',
#   'team_id': 1,
#   'player_type': 4,
#   'minutes_played': 362,
#   'form': '1.0',
#   'form_rank': 264,
#   'goals': 1,
#   'assists': 1,
#   'clean_sheets': 2,
#   'goals_conceded': 4,
#   'own_goals': 0,
#   'penalties_saved': 0,
#   'penalties_missed': 0,
#   'yellow_cards': 2,
#   'red_cards': 0,
#   'player_influence': '67.8',
#   'player_influence_rank': 253,
#   'player_creativity': '58.7',
#   'player_creativity_rank': 186,
#   'player_threat': '144.0',
#   'player_threat_rank': 53,
#   'player_starts': 4,
#   'player_news': 'Hamstring injury - Expected back 02 Dec',
#   'news_date': '2023-10-24T23:30:07.618920Z'},
#  {'player_id': 9,
#   'first_name': 'Jorge Luiz',
#   'last_name': 'Frello Filho',
#   'team_id': 1,
#   'player_type': 3,
#   'minutes_played': 213,
#   'form': '1.3',
#   'form_rank': 214,
#   'goals': 0,
#   'assists': 0,
#   'clean_sheets': 1,
#   'goals_conceded': 4,
#   'own_goals': 0,
#   'penalties_saved': 0,
#   'penalties_missed': 0,
#   'yellow_cards': 1,
#   'red_cards': 0,
#   'player_influence': '33.8',
#   'player_influence_rank': 319,
#   'player_creativity': '33.1',
#   'player_creativity_rank': 253,
#   'player_threat': '6.0',
#   'player_threat_rank': 356,
#   'player_starts': 2,
#   'player_news': '',
#   'news_date': '2023-08-07T15:30:05.168632Z'},
#  {'player_id': 10,
#   'first_name': 'Jakub',
#   'last_name': 'Kiwior',
#   'team_id': 1,
#   'player_type': 2,
#   'minutes_played': 181,
#   'form': '2.0',
#   'form_rank': 144,
#   'goals': 0,
#   'assists': 0,
#   'clean_sheets': 1,
#   'goals_conceded': 2,
#   'own_goals': 0,
#   'penalties_saved': 0,
#   'penalties_missed': 0,
#   'yellow_cards': 0,
#   'red_cards': 0,
#   'player_influence': '29.4',
#   'player_influence_rank': 332,
#   'player_creativity': '6.4',
#   'player_creativity_rank': 365,
#   'player_threat': '16.0',
#   'player_threat_rank': 291,
#   'player_starts': 2,
#   'player_news': '',
#   'news_date': None},
#  {'player_id': 11,
#   'first_name': 'Marcus',
#   'last_name': 'Oliveira Alencar',
#   'team_id': 1,
#   'player_type': 3,
#   'minutes_played': 0,
#   'form': '0.0',
#   'form_rank': 601,
#   'goals': 0,
#   'assists': 0,
#   'clean_sheets': 0,
#   'goals_conceded': 0,
#   'own_goals': 0,
#   'penalties_saved': 0,
#   'penalties_missed': 0,
#   'yellow_cards': 0,
#   'red_cards': 0,
#   'player_influence': '0.0',
#   'player_influence_rank': 641,
#   'player_creativity': '0.0',
#   'player_creativity_rank': 638,
#   'player_threat': '0.0',
#   'player_threat_rank': 629,
#   'player_starts': 0,
#   'player_news': 'Season long loan to FC Nantes',
#   'news_date': '2023-08-14T03:57:12.475590Z'},
#  {'player_id': 12,
#   'first_name': 'Gabriel',
#   'last_name': 'Martinelli Silva',
#   'team_id': 1,
#   'player_type': 3,
#   'minutes_played': 543,
#   'form': '3.7',
#   'form_rank': 75,
#   'goals': 1,
#   'assists': 2,
#   'clean_sheets': 2,
#   'goals_conceded': 6,
#   'own_goals': 0,
#   'penalties_saved': 0,
#   'penalties_missed': 0,
#   'yellow_cards': 0,
#   'red_cards': 0,
#   'player_influence': '124.2',
#   'player_influence_rank': 153,
#   'player_creativity': '175.6',
#   'player_creativity_rank': 44,
#   'player_threat': '199.0',
#   'player_threat_rank': 36,
#   'player_starts': 7,
#   'player_news': '',
#   'news_date': '2023-09-17T20:30:06.235303Z'},
#  {'player_id': 13,
#   'first_name': 'Eddie',
#   'last_name': 'Nketiah',
#   'team_id': 1,
#   'player_type': 4,
#   'minutes_played': 679,
#   'form': '6.3',
#   'form_rank': 16,
#   'goals': 5,
#   'assists': 2,
#   'clean_sheets': 6,
#   'goals_conceded': 4,
#   'own_goals': 0,
#   'penalties_saved': 0,
#   'penalties_missed': 0,
#   'yellow_cards': 2,
#   'red_cards': 0,
#   'player_influence': '179.4',
#   'player_influence_rank': 84,
#   'player_creativity': '77.6',
#   'player_creativity_rank': 139,
#   'player_threat': '257.0',
#   'player_threat_rank': 23,
#   'player_starts': 8,
#   'player_news': '',
#   'news_date': None},
#  {'player_id': 14,
#   'first_name': 'Martin',
#   'last_name': 'Ødegaard',
#   'team_id': 1,
#   'player_type': 3,
#   'minutes_played': 789,
#   'form': '1.7',
#   'form_rank': 190,
#   'goals': 3,
#   'assists': 2,
#   'clean_sheets': 4,
#   'goals_conceded': 7,
#   'own_goals': 0,
#   'penalties_saved': 0,
#   'penalties_missed': 0,
#   'yellow_cards': 1,
#   'red_cards': 0,
#   'player_influence': '217.4',
#   'player_influence_rank': 44,
#   'player_creativity': '239.2',
#   'player_creativity_rank': 22,
#   'player_threat': '197.0',
#   'player_threat_rank': 37,
#   'player_starts': 9,
#   'player_news': '',
#   'news_date': None},
#  {'player_id': 15,
#   'first_name': 'Thomas',
#   'last_name': 'Partey',
#   'team_id': 1,
#   'player_type': 3,
#   'minutes_played': 250,
#   'form': '0.3',
#   'form_rank': 339,
#   'goals': 0,
#   'assists': 0,
#   'clean_sheets': 1,
#   'goals_conceded': 2,
#   'own_goals': 0,
#   'penalties_saved': 0,
#   'penalties_missed': 0,
#   'yellow_cards': 0,
#   'red_cards': 0,
#   'player_influence': '55.8',
#   'player_influence_rank': 273,
#   'player_creativity': '60.0',
#   'player_creativity_rank': 182,
#   'player_threat': '15.0',
#   'player_threat_rank': 302,
#   'player_starts': 3,
#   'player_news': 'Muscle injury - Unknown return date',
#   'news_date': '2023-10-25T12:00:07.465521Z'},
#  {'player_id': 16,
#   'first_name': 'Nicolas',
#   'last_name': 'Pépé',
#   'team_id': 1,
#   'player_type': 3,
#   'minutes_played': 0,
#   'form': '0.0',
#   'form_rank': 665,
#   'goals': 0,
#   'assists': 0,
#   'clean_sheets': 0,
#   'goals_conceded': 0,
#   'own_goals': 0,
#   'penalties_saved': 0,
#   'penalties_missed': 0,
#   'yellow_cards': 0,
#   'red_cards': 0,
#   'player_influence': '0.0',
#   'player_influence_rank': 688,
#   'player_creativity': '0.0',
#   'player_creativity_rank': 686,
#   'player_threat': '0.0',
#   'player_threat_rank': 682,
#   'player_starts': 0,
#   'player_news': 'Permanent move to Trabzonspor',
#   'news_date': '2023-09-11T14:13:51.462896Z'},
#  {'player_id': 17,
#   'first_name': 'Aaron',
#   'last_name': 'Ramsdale',
#   'team_id': 1,
#   'player_type': 1,
#   'minutes_played': 360,
#   'form': '0.0',
#   'form_rank': 639,
#   'goals': 0,
#   'assists': 0,
#   'clean_sheets': 1,
#   'goals_conceded': 4,
#   'own_goals': 0,
#   'penalties_saved': 0,
#   'penalties_missed': 0,
#   'yellow_cards': 0,
#   'red_cards': 0,
#   'player_influence': '51.0',
#   'player_influence_rank': 281,
#   'player_creativity': '0.0',
#   'player_creativity_rank': 669,
#   'player_threat': '0.0',
#   'player_threat_rank': 662,
#   'player_starts': 4,
#   'player_news': '',
#   'news_date': None},
#  {'player_id': 18,
#   'first_name': 'Rúnar Alex',
#   'last_name': 'Rúnarsson',
#   'team_id': 1,
#   'player_type': 1,
#   'minutes_played': 0,
#   'form': '0.0',
#   'form_rank': 407,
#   'goals': 0,
#   'assists': 0,
#   'clean_sheets': 0,
#   'goals_conceded': 0,
#   'own_goals': 0,
#   'penalties_saved': 0,
#   'penalties_missed': 0,
#   'yellow_cards': 0,
#   'red_cards': 0,
#   'player_influence': '0.0',
#   'player_influence_rank': 479,
#   'player_creativity': '0.0',
#   'player_creativity_rank': 465,
#   'player_threat': '0.0',
#   'player_threat_rank': 440,
#   'player_starts': 0,
#   'player_news': 'Season long loan to Cardiff City',
#   'news_date': '2023-08-20T06:33:02.960208Z'},
#  {'player_id': 19,
#   'first_name': 'Bukayo',
#   'last_name': 'Saka',
#   'team_id': 1,
#   'player_type': 3,
#   'minutes_played': 775,
#   'form': '3.7',
#   'form_rank': 76,
#   'goals': 4,
#   'assists': 5,
#   'clean_sheets': 4,
#   'goals_conceded': 8,
#   'own_goals': 0,
#   'penalties_saved': 0,
#   'penalties_missed': 0,
#   'yellow_cards': 1,
#   'red_cards': 0,
#   'player_influence': '305.0',
#   'player_influence_rank': 13,
#   'player_creativity': '352.7',
#   'player_creativity_rank': 6,
#   'player_threat': '314.0',
#   'player_threat_rank': 13,
#   'player_starts': 9,
#   'player_news': '',
#   'news_date': '2023-10-03T22:30:07.474324Z'},
#  {'player_id': 20,
#   'first_name': 'William',
#   'last_name': 'Saliba',
#   'team_id': 1,
#   'player_type': 2,
#   'minutes_played': 900,
#   'form': '5.0',
#   'form_rank': 33,
#   'goals': 0,
#   'assists': 1,
#   'clean_sheets': 5,
#   'goals_conceded': 8,
#   'own_goals': 0,
#   'penalties_saved': 0,
#   'penalties_missed': 0,
#   'yellow_cards': 0,
#   'red_cards': 0,
#   'player_influence': '189.8',
#   'player_influence_rank': 71,
#   'player_creativity': '46.2',
#   'player_creativity_rank': 217,
#   'player_threat': '9.0',
#   'player_threat_rank': 335,
#   'player_starts': 10,
#   'player_news': '',
#   'news_date': '2023-10-09T08:30:07.861646Z'},
#  {'player_id': 22,
#   'first_name': 'Emile',
#   'last_name': 'Smith Rowe',
#   'team_id': 1,
#   'player_type': 3,
#   'minutes_played': 104,
#   'form': '2.3',
#   'form_rank': 137,
#   'goals': 0,
#   'assists': 1,
#   'clean_sheets': 1,
#   'goals_conceded': 0,
#   'own_goals': 0,
#   'penalties_saved': 0,
#   'penalties_missed': 0,
#   'yellow_cards': 0,
#   'red_cards': 0,
#   'player_influence': '33.8',
#   'player_influence_rank': 320,
#   'player_creativity': '17.2',
#   'player_creativity_rank': 319,
#   'player_threat': '41.0',
#   'player_threat_rank': 197,
#   'player_starts': 1,
#   'player_news': 'Knee injury - Unknown return date',
#   'news_date': '2023-11-02T11:00:07.493976Z'},
#  {'player_id': 24,
#   'first_name': 'Kieran',
#   'last_name': 'Tierney',
#   'team_id': 1,
#   'player_type': 2,
#   'minutes_played': 0,
#   'form': '0.0',
#   'form_rank': 521,
#   'goals': 0,
#   'assists': 0,
#   'clean_sheets': 0,
#   'goals_conceded': 0,
#   'own_goals': 0,
#   'penalties_saved': 0,
#   'penalties_missed': 0,
#   'yellow_cards': 0,
#   'red_cards': 0,
#   'player_influence': '0.0',
#   'player_influence_rank': 573,
#   'player_creativity': '0.0',
#   'player_creativity_rank': 564,
#   'player_threat': '0.0',
#   'player_threat_rank': 550,
#   'player_starts': 0,
#   'player_news': 'Season long loan to Real Sociedad',
#   'news_date': '2023-08-29T07:46:59.686803Z'},
#  {'player_id': 25,
#   'first_name': 'Takehiro',
#   'last_name': 'Tomiyasu',
#   'team_id': 1,
#   'player_type': 2,
#   'minutes_played': 235,
#   'form': '3.0',
#   'form_rank': 90,
#   'goals': 1,
#   'assists': 0,
#   'clean_sheets': 1,
#   'goals_conceded': 2,
#   'own_goals': 0,
#   'penalties_saved': 0,
#   'penalties_missed': 0,
#   'yellow_cards': 0,
#   'red_cards': 1,
#   'player_influence': '51.8',
#   'player_influence_rank': 280,
#   'player_creativity': '14.9',
#   'player_creativity_rank': 330,
#   'player_threat': '40.0',
#   'player_threat_rank': 199,
#   'player_starts': 1,
#   'player_news': '',
#   'news_date': '2023-08-22T00:00:07.272418Z'},
#  {'player_id': 26,
#   'first_name': 'Leandro',
#   'last_name': 'Trossard',
#   'team_id': 1,
#   'player_type': 3,
#   'minutes_played': 209,
#   'form': '2.7',
#   'form_rank': 118,
#   'goals': 2,
#   'assists': 0,
#   'clean_sheets': 1,
#   'goals_conceded': 2,
#   'own_goals': 0,
#   'penalties_saved': 0,
#   'penalties_missed': 0,
#   'yellow_cards': 0,
#   'red_cards': 0,
#   'player_influence': '99.0',
#   'player_influence_rank': 187,
#   'player_creativity': '90.2',
#   'player_creativity_rank': 119,
#   'player_threat': '70.0',
#   'player_threat_rank': 139,
#   'player_starts': 2,
#   'player_news': '',
#   'news_date': '2023-10-09T08:30:07.911344Z'},
#  {'player_id': 29,
#   'first_name': 'Benjamin',
#   'last_name': 'White',
#   'team_id': 1,
#   'player_type': 2,
#   'minutes_played': 875,
#   'form': '5.0',
#   'form_rank': 35,
#   'goals': 1,
#   'assists': 1,
#   'clean_sheets': 5,
#   'goals_conceded': 8,
#   'own_goals': 0,
#   'penalties_saved': 0,
#   'penalties_missed': 0,
#   'yellow_cards': 2,
#   'red_cards': 0,
#   'player_influence': '212.6',
#   'player_influence_rank': 47,
#   'player_creativity': '159.3',
#   'player_creativity_rank': 52,
#   'player_threat': '77.0',
#   'player_threat_rank': 131,
#   'player_starts': 10,
#   'player_news': '',
#   'news_date': None},
#  {'player_id': 30,
#   'first_name': 'Granit',
#   'last_name': 'Xhaka',
#   'team_id': 1,
#   'player_type': 3,
#   'minutes_played': 0,
#   'form': '0.0',
#   'form_rank': 715,
#   'goals': 0,
#   'assists': 0,
#   'clean_sheets': 0,
#   'goals_conceded': 0,
#   'own_goals': 0,
#   'penalties_saved': 0,
#   'penalties_missed': 0,
#   'yellow_cards': 0,
#   'red_cards': 0,
#   'player_influence': '0.0',
#   'player_influence_rank': 723,
#   'player_creativity': '0.0',
#   'player_creativity_rank': 723,
#   'player_threat': '0.0',
#   'player_threat_rank': 723,
#   'player_starts': 0,
#   'player_news': 'Transferred to Bayer Leverkusen',
#   'news_date': '2023-07-11T08:41:07.159936Z'},
#  {'player_id': 31,
#   'first_name': 'Oleksandr',
#   'last_name': 'Zinchenko',
#   'team_id': 1,
#   'player_type': 2,
#   'minutes_played': 556,
#   'form': '5.0',
#   'form_rank': 32,
#   'goals': 0,
#   'assists': 0,
#   'clean_sheets': 4,
#   'goals_conceded': 5,
#   'own_goals': 0,
#   'penalties_saved': 0,
#   'penalties_missed': 0,
#   'yellow_cards': 1,
#   'red_cards': 0,
#   'player_influence': '86.2',
#   'player_influence_rank': 215,
#   'player_creativity': '130.0',
#   'player_creativity_rank': 67,
#   'player_threat': '48.0',
#   'player_threat_rank': 182,
#   'player_starts': 7,
#   'player_news': '',
#   'news_date': None},
#  {'player_id': 113,
#   'first_name': 'David',
#   'last_name': 'Raya Martin',
#   'team_id': 1,
#   'player_type': 1,
#   'minutes_played': 540,
#   'form': '4.7',
#   'form_rank': 39,
#   'goals': 0,
#   'assists': 0,
#   'clean_sheets': 4,
#   'goals_conceded': 4,
#   'own_goals': 0,
#   'penalties_saved': 0,
#   'penalties_missed': 0,
#   'yellow_cards': 0,
#   'red_cards': 0,
#   'player_influence': '82.6',
#   'player_influence_rank': 223,
#   'player_creativity': '0.0',
#   'player_creativity_rank': 676,
#   'player_threat': '0.0',
#   'player_threat_rank': 669,
#   'player_starts': 6,
#   'player_news': '',
#   'news_date': None},
#  {'player_id': 540,
#   'first_name': 'Declan',
#   'last_name': 'Rice',
#   'team_id': 1,
#   'player_type': 3,
#   'minutes_played': 843,
#   'form': '6.0',
#   'form_rank': 20,
#   'goals': 2,
#   'assists': 1,
#   'clean_sheets': 5,
#   'goals_conceded': 7,
#   'own_goals': 0,
#   'penalties_saved': 0,
#   'penalties_missed': 0,
#   'yellow_cards': 0,
#   'red_cards': 0,
#   'player_influence': '239.6',
#   'player_influence_rank': 33,
#   'player_creativity': '120.3',
#   'player_creativity_rank': 74,
#   'player_threat': '87.0',
#   'player_threat_rank': 115,
#   'player_starts': 10,
#   'player_news': '',
#   'news_date': '2023-09-24T22:30:08.321972Z'},
#  {'player_id': 578,
#   'first_name': 'Reiss',
#   'last_name': 'Nelson',
#   'team_id': 1,
#   'player_type': 3,
#   'minutes_played': 52,
#   'form': '0.3',
#   'form_rank': 345,
#   'goals': 0,
#   'assists': 0,
#   'clean_sheets': 0,
#   'goals_conceded': 0,
#   'own_goals': 0,
#   'penalties_saved': 0,
#   'penalties_missed': 0,
#   'yellow_cards': 0,
#   'red_cards': 0,
#   'player_influence': '10.8',
#   'player_influence_rank': 384,
#   'player_creativity': '32.4',
#   'player_creativity_rank': 257,
#   'player_threat': '10.0',
#   'player_threat_rank': 329,
#   'player_starts': 0,
#   'player_news': '',
#   'news_date': '2023-08-07T15:30:06.067296Z'},
#  {'player_id': 585,
#   'first_name': 'Jurriën',
#   'last_name': 'Timber',
#   'team_id': 1,
#   'player_type': 2,
#   'minutes_played': 49,
#   'form': '0.0',
#   'form_rank': 635,
#   'goals': 0,
#   'assists': 0,
#   'clean_sheets': 0,
#   'goals_conceded': 0,
#   'own_goals': 0,
#   'penalties_saved': 0,
#   'penalties_missed': 0,
#   'yellow_cards': 1,
#   'red_cards': 0,
#   'player_influence': '3.6',
#   'player_influence_rank': 422,
#   'player_creativity': '2.4',
#   'player_creativity_rank': 387,
#   'player_threat': '0.0',
#   'player_threat_rank': 660,
#   'player_starts': 1,
#   'player_news': 'Knee injury - Unknown return date',
#   'news_date': '2023-08-12T18:00:07.121160Z'},
#  {'player_id': 646,
#   'first_name': 'Karl',
#   'last_name': 'Hein',
#   'team_id': 1,
#   'player_type': 1,
#   'minutes_played': 0,
#   'form': '0.0',
#   'form_rank': 455,
#   'goals': 0,
#   'assists': 0,
#   'clean_sheets': 0,
#   'goals_conceded': 0,
#   'own_goals': 0,
#   'penalties_saved': 0,
#   'penalties_missed': 0,
#   'yellow_cards': 0,
#   'red_cards': 0,
#   'player_influence': '0.0',
#   'player_influence_rank': 523,
#   'player_creativity': '0.0',
#   'player_creativity_rank': 509,
#   'player_threat': '0.0',
#   'player_threat_rank': 486,
#   'player_starts': 0,
#   'player_news': '',
#   'news_date': None},
#  {'player_id': 32,
#   'first_name': 'Alexandre',
#   'last_name': 'Moreno Lopera',
#   'team_id': 2,
#   'player_type': 2,
#   'minutes_played': 0,
#   'form': '0.0',
#   'form_rank': 677,
#   'goals': 0,
#   'assists': 0,
#   'clean_sheets': 0,
#   'goals_conceded': 0,
#   'own_goals': 0,
#   'penalties_saved': 0,
#   'penalties_missed': 0,
#   'yellow_cards': 0,
#   'red_cards': 0,
#   'player_influence': '0.0',
#   'player_influence_rank': 699,
#   'player_creativity': '0.0',
#   'player_creativity_rank': 695,
#   'player_threat': '0.0',
#   'player_threat_rank': 692,
#   'player_starts': 0,
#   'player_news': 'Hamstring injury - 25% chance of playing',
#   'news_date': '2023-09-24T22:30:06.810510Z'},
#  {'player_id': 34,
#   'first_name': 'Leon',
#   'last_name': 'Bailey',
#   'team_id': 2,
#   'player_type': 3,
#   'minutes_played': 268,
#   'form': '3.7',
#   'form_rank': 71,
#   'goals': 3,
#   'assists': 2,
#   'clean_sheets': 1,
#   'goals_conceded': 5,
#   'own_goals': 0,
#   'penalties_saved': 0,
#   'penalties_missed': 0,
#   'yellow_cards': 1,
#   'red_cards': 0,
#   'player_influence': '149.4',
#   'player_influence_rank': 118,
#   'player_creativity': '91.4',
#   'player_creativity_rank': 117,
#   'player_threat': '96.0',
#   'player_threat_rank': 103,
#   'player_starts': 2,
#   'player_news': '',
#   'news_date': '2023-09-28T04:00:07.310756Z'},
#  {'player_id': 35,
#   'first_name': 'Emiliano',
#   'last_name': 'Buendía Stati',
#   'team_id': 2,
#   'player_type': 3,
#   'minutes_played': 0,
#   'form': '0.0',
#   'form_rank': 710,
#   'goals': 0,
#   'assists': 0,
#   'clean_sheets': 0,
#   'goals_conceded': 0,
#   'own_goals': 0,
#   'penalties_saved': 0,
#   'penalties_missed': 0,
#   'yellow_cards': 0,
#   'red_cards': 0,
#   'player_influence': '0.0',
#   'player_influence_rank': 720,
#   'player_creativity': '0.0',
#   'player_creativity_rank': 720,
#   'player_threat': '0.0',
#   'player_threat_rank': 720,
#   'player_starts': 0,
#   'player_news': 'Knee injury - Expected back 10 Feb',
#   'news_date': '2023-08-10T11:00:05.686871Z'},
#  {'player_id': 36,
#   'first_name': 'Matty',
#   'last_name': 'Cash',
#   'team_id': 2,
#   'player_type': 2,
#   'minutes_played': 875,
#   'form': '3.0',
#   'form_rank': 95,
#   'goals': 2,
#   'assists': 1,
#   'clean_sheets': 3,
#   'goals_conceded': 12,
#   'own_goals': 1,
#   'penalties_saved': 0,
#   'penalties_missed': 0,
#   'yellow_cards': 3,
#   'red_cards': 0,
#   'player_influence': '227.0',
#   'player_influence_rank': 38,
#   'player_creativity': '72.9',
#   'player_creativity_rank': 149,
#   'player_threat': '225.0',
#   'player_threat_rank': 29,
#   'player_starts': 10,
#   'player_news': '',
#   'news_date': None},
#  {'player_id': 37,
#   'first_name': 'Calum',
#   'last_name': 'Chambers',
#   'team_id': 2,
#   'player_type': 2,
#   'minutes_played': 0,
#   'form': '0.0',
#   'form_rank': 374,
#   'goals': 0,
#   'assists': 0,
#   'clean_sheets': 0,
#   'goals_conceded': 0,
#   'own_goals': 0,
#   'penalties_saved': 0,
#   'penalties_missed': 0,
#   'yellow_cards': 0,
#   'red_cards': 0,
#   'player_influence': '0.0',
#   'player_influence_rank': 450,
#   'player_creativity': '0.0',
#   'player_creativity_rank': 433,
#   'player_threat': '0.0',
#   'player_threat_rank': 407,
#   'player_starts': 0,
#   'player_news': '',
#   'news_date': None},
#  {'player_id': 38,
#   'first_name': 'Philippe',
#   'last_name': 'Coutinho Correia',
#   'team_id': 2,
#   'player_type': 3,
#   'minutes_played': 24,
#   'form': '0.0',
#   'form_rank': 711,
#   'goals': 0,
#   'assists': 0,
#   'clean_sheets': 0,
#   'goals_conceded': 1,
#   'own_goals': 0,
#   'penalties_saved': 0,
#   'penalties_missed': 0,
#   'yellow_cards': 0,
#   'red_cards': 0,
#   'player_influence': '4.0',
#   'player_influence_rank': 420,
#   'player_creativity': '2.8',
#   'player_creativity_rank': 384,
#   'player_threat': '12.0',
#   'player_threat_rank': 320,
#   'player_starts': 0,
#   'player_news': 'Joined Al-Duhail on loan for the rest of the season',
#   'news_date': '2023-08-20T22:00:05.790965Z'},
#  {'player_id': 39,
#   'first_name': 'Keinan',
#   'last_name': 'Davis',
#   'team_id': 2,
#   'player_type': 4,
#   'minutes_played': 0,
#   'form': '0.0',
#   'form_rank': 669,
#   'goals': 0,
#   'assists': 0,
#   'clean_sheets': 0,
#   'goals_conceded': 0,
#   'own_goals': 0,
#   'penalties_saved': 0,
#   'penalties_missed': 0,
#   'yellow_cards': 0,
#   'red_cards': 0,
#   'player_influence': '0.0',
#   'player_influence_rank': 691,
#   'player_creativity': '0.0',
#   'player_creativity_rank': 689,
#   'player_threat': '0.0',
#   'player_threat_rank': 685,
#   'player_starts': 0,
#   'player_news': 'Transferred to Udinese',
#   'news_date': '2023-09-03T20:12:01.415986Z'},
#  {'player_id': 40,
#   'first_name': 'Leander',
#   'last_name': 'Dendoncker',
#   'team_id': 2,
#   'player_type': 3,
#   'minutes_played': 3,
#   'form': '0.3',
#   'form_rank': 344,
#   'goals': 0,
#   'assists': 0,
#   'clean_sheets': 0,
#   'goals_conceded': 0,
#   'own_goals': 0,
#   'penalties_saved': 0,
#   'penalties_missed': 0,
#   'yellow_cards': 0,
#   'red_cards': 0,
#   'player_influence': '7.4',
#   'player_influence_rank': 404,
#   'player_creativity': '0.1',
#   'player_creativity_rank': 425,
#   'player_threat': '0.0',
#   'player_threat_rank': 679,
#   'player_starts': 0,
#   'player_news': '',
#   'news_date': '2023-08-10T15:00:04.947940Z'},
#  {'player_id': 41,
#   'first_name': 'Diego Carlos',
#   'last_name': 'Santos Silva',
#   'team_id': 2,
#   'player_type': 2,
#   'minutes_played': 261,
#   'form': '1.0',
#   'form_rank': 227,
#   'goals': 0,
#   'assists': 0,
#   'clean_sheets': 0,
#   'goals_conceded': 6,
#   'own_goals': 0,
#   'penalties_saved': 0,
#   'penalties_missed': 0,
#   'yellow_cards': 0,
#   'red_cards': 0,
#   'player_influence': '53.8',
#   'player_influence_rank': 277,
#   'player_creativity': '12.4',
#   'player_creativity_rank': 347,
#   'player_threat': '45.0',
#   'player_threat_rank': 187,
#   'player_starts': 3,
#   'player_news': '',
#   'news_date': '2023-09-04T05:00:07.186249Z'},
#  {'player_id': 42,
#   'first_name': 'Lucas',
#   'last_name': 'Digne',
#   'team_id': 2,
#   'player_type': 2,
#   'minutes_played': 890,
#   'form': '2.0',
#   'form_rank': 151,
#   'goals': 0,
#   'assists': 3,
#   'clean_sheets': 2,
#   'goals_conceded': 14,
#   'own_goals': 0,
#   'penalties_saved': 0,
#   'penalties_missed': 0,
#   'yellow_cards': 4,
#   'red_cards': 0,
#   'player_influence': '187.8',
#   'player_influence_rank': 72,
#   'player_creativity': '291.6',
#   'player_creativity_rank': 15,
#   'player_threat': '55.0',
#   'player_threat_rank': 168,
#   'player_starts': 10,
#   'player_news': '',
#   'news_date': None},
#  {'player_id': 43,
#   'first_name': 'Douglas Luiz',
#   'last_name': 'Soares de Paulo',
#   'team_id': 2,
#   'player_type': 3,
#   'minutes_played': 848,
#   'form': '8.0',
#   'form_rank': 5,
#   'goals': 5,
#   'assists': 1,
#   'clean_sheets': 2,
#   'goals_conceded': 14,
#   'own_goals': 0,
#   'penalties_saved': 0,
#   'penalties_missed': 0,
#   'yellow_cards': 4,
#   'red_cards': 0,
#   'player_influence': '321.0',
#   'player_influence_rank': 7,
#   'player_creativity': '215.3',
#   'player_creativity_rank': 27,
#   'player_threat': '133.0',
#   'player_threat_rank': 62,
#   'player_starts': 10,
#   'player_news': '',
#   'news_date': None},
#  {'player_id': 44,
#   'first_name': 'Jhon',
#   'last_name': 'Durán',
#   'team_id': 2,
#   'player_type': 4,
#   'minutes_played': 68,
#   'form': '0.0',
#   'form_rank': 690,
#   'goals': 2,
#   'assists': 0,
#   'clean_sheets': 0,
#   'goals_conceded': 0,
#   'own_goals': 0,
#   'penalties_saved': 0,
#   'penalties_missed': 0,
#   'yellow_cards': 2,
#   'red_cards': 0,
#   'player_influence': '72.6',
#   'player_influence_rank': 242,
#   'player_creativity': '14.2',
#   'player_creativity_rank': 335,
#   'player_threat': '55.0',
#   'player_threat_rank': 169,
#   'player_starts': 0,
#   'player_news': 'Toe Injury - 75% chance of playing',
#   'news_date': '2023-10-29T22:00:09.647546Z'},
#  {'player_id': 45,
#   'first_name': 'Kortney',
#   'last_name': 'Hause',
#   'team_id': 2,
#   'player_type': 2,
#   'minutes_played': 0,
#   'form': '0.0',
#   'form_rank': 411,
#   'goals': 0,
#   'assists': 0,
#   'clean_sheets': 0,
#   'goals_conceded': 0,
#   'own_goals': 0,
#   'penalties_saved': 0,
#   'penalties_missed': 0,
#   'yellow_cards': 0,
#   'red_cards': 0,
#   'player_influence': '0.0',
#   'player_influence_rank': 483,
#   'player_creativity': '0.0',
#   'player_creativity_rank': 469,
#   'player_threat': '0.0',
#   'player_threat_rank': 444,
#   'player_starts': 0,
#   'player_news': '',
#   'news_date': None},
#  {'player_id': 46,
#   'first_name': 'Tim',
#   'last_name': 'Iroegbunam',
#   'team_id': 2,
#   'player_type': 3,
#   'minutes_played': 0,
#   'form': '0.0',
#   'form_rank': 553,
#   'goals': 0,
#   'assists': 0,
#   'clean_sheets': 0,
#   'goals_conceded': 0,
#   'own_goals': 0,
#   'penalties_saved': 0,
#   'penalties_missed': 0,
#   'yellow_cards': 0,
#   'red_cards': 0,
#   'player_influence': '0.0',
#   'player_influence_rank': 598,
#   'player_creativity': '0.0',
#   'player_creativity_rank': 591,
#   'player_threat': '0.0',
#   'player_threat_rank': 579,
#   'player_starts': 0,
#   'player_news': '',
#   'news_date': '2023-08-10T15:00:04.998490Z'},
#  {'player_id': 47,
#   'first_name': 'Boubacar',
#   'last_name': 'Kamara',
#   'team_id': 2,
#   'player_type': 3,
#   'minutes_played': 844,
#   'form': '1.7',
#   'form_rank': 181,
#   'goals': 0,
#   'assists': 0,
#   'clean_sheets': 3,
#   'goals_conceded': 13,
#   'own_goals': 0,
#   'penalties_saved': 0,
#   'penalties_missed': 0,
#   'yellow_cards': 3,
#   'red_cards': 0,
#   'player_influence': '127.6',
#   'player_influence_rank': 142,
#   'player_creativity': '173.8',
#   'player_creativity_rank': 46,
#   'player_threat': '13.0',
#   'player_threat_rank': 312,
#   'player_starts': 10,
#   'player_news': '',
#   'news_date': '2023-09-30T23:00:07.886006Z'},
#  {'player_id': 48,
#   'first_name': 'Ezri',
#   'last_name': 'Konsa Ngoyo',
#   'team_id': 2,
#   'player_type': 2,
#   'minutes_played': 900,
#   'form': '3.3',
#   'form_rank': 77,
#   'goals': 0,
#   'assists': 1,
#   'clean_sheets': 2,
#   'goals_conceded': 14,
#   'own_goals': 0,
#   'penalties_saved': 0,
#   'penalties_missed': 0,
#   'yellow_cards': 1,
#   'red_cards': 0,
#   'player_influence': '184.6',
#   'player_influence_rank': 76,
#   'player_creativity': '34.9',
#   'player_creativity_rank': 248,
#   'player_threat': '85.0',
#   'player_threat_rank': 119,
#   'player_starts': 10,
#   'player_news': '',
#   'news_date': None},
#  {'player_id': 49,
#   'first_name': 'Emiliano',
#   'last_name': 'Martínez Romero',
#   'team_id': 2,
#   'player_type': 1,
#   'minutes_played': 810,
#   'form': '2.0',
#   'form_rank': 153,
#   'goals': 0,
#   'assists': 0,
#   'clean_sheets': 2,
#   'goals_conceded': 13,
#   'own_goals': 1,
#   'penalties_saved': 0,
#   'penalties_missed': 0,
#   'yellow_cards': 2,
#   'red_cards': 0,
#   'player_influence': '202.4',
#   'player_influence_rank': 57,
#   'player_creativity': '0.0',
#   'player_creativity_rank': 682,
#   'player_threat': '0.0',
#   'player_threat_rank': 677,
#   'player_starts': 9,
#   'player_news': '',
#   'news_date': '2023-08-25T14:00:08.378829Z'},
#  {'player_id': 50,
#   'first_name': 'John',
#   'last_name': 'McGinn',
#   'team_id': 2,
#   'player_type': 3,
#   'minutes_played': 837,
#   'form': '4.7',
#   'form_rank': 43,
#   'goals': 2,
#   'assists': 2,
#   'clean_sheets': 2,
#   'goals_conceded': 12,
#   'own_goals': 0,
#   'penalties_saved': 0,
#   'penalties_missed': 0,
#   'yellow_cards': 2,
#   'red_cards': 0,
#   'player_influence': '169.8',
#   'player_influence_rank': 95,
#   'player_creativity': '209.1',
#   'player_creativity_rank': 29,
#   'player_threat': '113.0',
#   'player_threat_rank': 85,
#   'player_starts': 10,
#   'player_news': '',
#   'news_date': None},
#  {'player_id': 51,
#   'first_name': 'Tyrone',
#   'last_name': 'Mings',
#   'team_id': 2,
#   'player_type': 2,
#   'minutes_played': 30,
#   'form': '0.0',
#   'form_rank': 482,
#   'goals': 0,
#   'assists': 0,
#   'clean_sheets': 0,
#   'goals_conceded': 2,
#   'own_goals': 0,
#   'penalties_saved': 0,
#   'penalties_missed': 0,
#   'yellow_cards': 0,
#   'red_cards': 0,
#   'player_influence': '3.6',
#   'player_influence_rank': 421,
#   'player_creativity': '13.0',
#   'player_creativity_rank': 342,
#   'player_threat': '5.0',
#   'player_threat_rank': 358,
#   'player_starts': 1,
#   'player_news': 'Knee injury - Unknown return date',
#   'news_date': '2023-08-12T21:30:06.077936Z'},
#  {'player_id': 53,
#   'first_name': 'Robin',
#   'last_name': 'Olsen',
#   'team_id': 2,
#   'player_type': 1,
#   'minutes_played': 90,
#   'form': '0.0',
#   'form_rank': 405,
#   'goals': 0,
#   'assists': 0,
#   'clean_sheets': 0,
#   'goals_conceded': 1,
#   'own_goals': 0,
#   'penalties_saved': 0,
#   'penalties_missed': 0,
#   'yellow_cards': 0,
#   'red_cards': 0,
#   'player_influence': '12.0',
#   'player_influence_rank': 377,
#   'player_creativity': '0.0',
#   'player_creativity_rank': 463,
#   'player_threat': '0.0',
#   'player_threat_rank': 438,
#   'player_starts': 1,
#   'player_news': '',
#   'news_date': None},
#  {'player_id': 54,
#   'first_name': 'Jaden',
#   'last_name': 'Philogene-Bidace',
#   'team_id': 2,
#   'player_type': 3,
#   'minutes_played': 3,
#   'form': '0.0',
#   'form_rank': 603,
#   'goals': 0,
#   'assists': 0,
#   'clean_sheets': 0,
#   'goals_conceded': 1,
#   'own_goals': 0,
#   'penalties_saved': 0,
#   'penalties_missed': 0,
#   'yellow_cards': 0,
#   'red_cards': 0,
#   'player_influence': '0.4',
#   'player_influence_rank': 439,
#   'player_creativity': '0.3',
#   'player_creativity_rank': 412,
#   'player_threat': '2.0',
#   'player_threat_rank': 387,
#   'player_starts': 0,
#   'player_news': 'Transferred to Hull City',
#   'news_date': '2023-09-02T08:48:12.680336Z'},
#  {'player_id': 55,
#   'first_name': 'Jacob',
#   'last_name': 'Ramsey',
#   'team_id': 2,
#   'player_type': 3,
#   'minutes_played': 48,
#   'form': '0.0',
#   'form_rank': 714,
#   'goals': 1,
#   'assists': 0,
#   'clean_sheets': 0,
#   'goals_conceded': 0,
#   'own_goals': 0,
#   'penalties_saved': 0,
#   'penalties_missed': 0,
#   'yellow_cards': 0,
#   'red_cards': 0,
#   'player_influence': '43.8',
#   'player_influence_rank': 293,
#   'player_creativity': '1.6',
#   'player_creativity_rank': 395,
#   'player_threat': '28.0',
#   'player_threat_rank': 238,
#   'player_starts': 0,
#   'player_news': 'Foot injury - Unknown return date',
#   'news_date': '2023-10-04T15:30:08.354887Z'},
#  {'player_id': 56,
#   'first_name': 'Morgan',
#   'last_name': 'Sanson',
#   'team_id': 2,
#   'player_type': 3,
#   'minutes_played': 0,
#   'form': '0.0',
#   'form_rank': 562,
#   'goals': 0,
#   'assists': 0,
#   'clean_sheets': 0,
#   'goals_conceded': 0,
#   'own_goals': 0,
#   'penalties_saved': 0,
#   'penalties_missed': 0,
#   'yellow_cards': 0,
#   'red_cards': 0,
#   'player_influence': '0.0',
#   'player_influence_rank': 606,
#   'player_creativity': '0.0',
#   'player_creativity_rank': 602,
#   'player_threat': '0.0',
#   'player_threat_rank': 591,
#   'player_starts': 0,
#   'player_news': 'Joined OGC Nice on a season-long loan',
#   'news_date': '2023-07-26T11:26:30.137805Z'},
#  {'player_id': 57,
#   'first_name': 'Viljami',
#   'last_name': 'Sinisalo',
#   'team_id': 2,
#   'player_type': 1,
#   'minutes_played': 0,
#   'form': '0.0',
#   'form_rank': 437,
#   'goals': 0,
#   'assists': 0,
#   'clean_sheets': 0,
#   'goals_conceded': 0,
#   'own_goals': 0,
#   'penalties_saved': 0,
#   'penalties_missed': 0,
#   'yellow_cards': 0,
#   'red_cards': 0,
#   'player_influence': '0.0',
#   'player_influence_rank': 507,
#   'player_creativity': '0.0',
#   'player_creativity_rank': 493,
#   'player_threat': '0.0',
#   'player_threat_rank': 469,
#   'player_starts': 0,
#   'player_news': 'Joined Exeter City on a season-long loan',
#   'news_date': '2023-07-20T08:38:58.947431Z'},
#  {'player_id': 58,
#   'first_name': 'Youri',
#   'last_name': 'Tielemans',
#   'team_id': 2,
#   'player_type': 3,
#   'minutes_played': 160,
#   'form': '2.0',
#   'form_rank': 161,
#   'goals': 0,
#   'assists': 1,
#   'clean_sheets': 0,
#   'goals_conceded': 4,
#   'own_goals': 0,
#   'penalties_saved': 0,
#   'penalties_missed': 0,
#   'yellow_cards': 0,
#   'red_cards': 0,
#   'player_influence': '39.2',
#   'player_influence_rank': 305,
#   'player_creativity': '37.6',
#   'player_creativity_rank': 239,
#   'player_threat': '12.0',
#   'player_threat_rank': 319,
#   'player_starts': 0,
#   'player_news': '',
#   'news_date': None},
#  {'player_id': 59,
#   'first_name': 'Bertrand',
#   'last_name': 'Traoré',
#   'team_id': 2,
#   'player_type': 3,
#   'minutes_played': 10,
#   'form': '0.3',
#   'form_rank': 350,
#   'goals': 0,
#   'assists': 0,
#   'clean_sheets': 0,
#   'goals_conceded': 0,
#   'own_goals': 0,
#   'penalties_saved': 0,
#   'penalties_missed': 0,
#   'yellow_cards': 0,
#   'red_cards': 0,
#   'player_influence': '3.0',
#   'player_influence_rank': 425,
#   'player_creativity': '0.0',
#   'player_creativity_rank': 697,
#   'player_threat': '0.0',
#   'player_threat_rank': 694,
#   'player_starts': 0,
#   'player_news': '',
#   'news_date': '2023-09-01T15:29:59.576149Z'},
#  {'player_id': 60,
#   'first_name': 'Ollie',
#   'last_name': 'Watkins',
#   'team_id': 2,
#   'player_type': 4,
#   'minutes_played': 860,
#   'form': '6.0',
#   'form_rank': 21,
#   'goals': 5,
#   'assists': 8,
#   'clean_sheets': 2,
#   'goals_conceded': 14,
#   'own_goals': 0,
#   'penalties_saved': 0,
#   'penalties_missed': 0,
#   'yellow_cards': 0,
#   'red_cards': 0,
#   'player_influence': '312.2',
#   'player_influence_rank': 11,
#   'player_creativity': '220.8',
#   'player_creativity_rank': 26,
#   'player_threat': '429.0',
#   'player_threat_rank': 3,
#   'player_starts': 10,
#   'player_news': '',
#   'news_date': None},
#  {'player_id': 61,
#   'first_name': 'Wesley',
#   'last_name': 'Moraes Ferreira da Silva',
#   'team_id': 2,
#   'player_type': 4,
#   'minutes_played': 0,
#   'form': '0.0',
#   'form_rank': 686,
#   'goals': 0,
#   'assists': 0,
#   'clean_sheets': 0,
#   'goals_conceded': 0,
#   'own_goals': 0,
#   'penalties_saved': 0,
#   'penalties_missed': 0,
#   'yellow_cards': 0,
#   'red_cards': 0,
#   'player_influence': '0.0',
#   'player_influence_rank': 705,
#   'player_creativity': '0.0',
#   'player_creativity_rank': 703,
#   'player_threat': '0.0',
#   'player_threat_rank': 700,
#   'player_starts': 0,
#   'player_news': 'Permanent transfer to Stoke',
#   'news_date': '2023-07-31T07:08:09.572672Z'},
#  {'player_id': 584,
#   'first_name': 'Pau',
#   'last_name': 'Torres',
#   'team_id': 2,
#   'player_type': 2,
#   'minutes_played': 869,
#   'form': '4.7',
#   'form_rank': 38,
#   'goals': 1,
#   'assists': 0,
#   'clean_sheets': 2,
#   'goals_conceded': 12,
#   'own_goals': 0,
#   'penalties_saved': 0,
#   'penalties_missed': 0,
#   'yellow_cards': 0,
#   'red_cards': 0,
#   'player_influence': '169.6',
#   'player_influence_rank': 96,
#   'player_creativity': '54.2',
#   'player_creativity_rank': 196,
#   'player_threat': '54.0',
#   'player_threat_rank': 173,
#   'player_starts': 9,
#   'player_news': '',
#   'news_date': None},
#  {'player_id': 599,
#   'first_name': 'Moussa',
#   'last_name': 'Diaby',
#   'team_id': 2,
#   'player_type': 3,
#   'minutes_played': 793,
#   'form': '5.7',
#   'form_rank': 22,
#   'goals': 3,
#   'assists': 5,
#   'clean_sheets': 2,
#   'goals_conceded': 13,
#   'own_goals': 0,
#   'penalties_saved': 0,
#   'penalties_missed': 0,
#   'yellow_cards': 0,
#   'red_cards': 0,
#   'player_influence': '208.2',
#   'player_influence_rank': 51,
#   'player_creativity': '223.0',
#   'player_creativity_rank': 24,
#   'player_threat': '251.0',
#   'player_threat_rank': 26,
#   'player_starts': 10,
#   'player_news': '',
#   'news_date': '2023-09-30T23:00:09.545623Z'},
#  {'player_id': 618,
#   'first_name': 'Omari',
#   'last_name': 'Kellyman',
#   'team_id': 2,
#   'player_type': 3,
#   'minutes_played': 0,
#   'form': '0.0',
#   'form_rank': 629,
#   'goals': 0,
#   'assists': 0,
#   'clean_sheets': 0,
#   'goals_conceded': 0,
#   'own_goals': 0,
#   'penalties_saved': 0,
#   'penalties_missed': 0,
#   'yellow_cards': 0,
#   'red_cards': 0,
#   'player_influence': '0.0',
#   'player_influence_rank': 664,
#   'player_creativity': '0.0',
#   'player_creativity_rank': 661,
#   'player_threat': '0.0',
#   'player_threat_rank': 653,
#   'player_starts': 0,
#   'player_news': '',
#   'news_date': None},
#  {'player_id': 670,
#   'first_name': 'Filip',
#   'last_name': 'Marschall',
#   'team_id': 2,
#   'player_type': 1,
#   'minutes_played': 0,
#   'form': '0.0',
#   'form_rank': 453,
#   'goals': 0,
#   'assists': 0,
#   'clean_sheets': 0,
#   'goals_conceded': 0,
#   'own_goals': 0,
#   'penalties_saved': 0,
#   'penalties_missed': 0,
#   'yellow_cards': 0,
#   'red_cards': 0,
#   'player_influence': '0.0',
#   'player_influence_rank': 521,
#   'player_creativity': '0.0',
#   'player_creativity_rank': 507,
#   'player_threat': '0.0',
#   'player_threat_rank': 484,
#   'player_starts': 0,
#   'player_news': '',
#   'news_date': None},
#  {'player_id': 672,
#   'first_name': 'Nicolò',
#   'last_name': 'Zaniolo',
#   'team_id': 2,
#   'player_type': 3,
#   'minutes_played': 376,
#   'form': '1.0',
#   'form_rank': 260,
#   'goals': 0,
#   'assists': 0,
#   'clean_sheets': 1,
#   'goals_conceded': 3,
#   'own_goals': 0,
#   'penalties_saved': 0,
#   'penalties_missed': 0,
#   'yellow_cards': 2,
#   'red_cards': 0,
#   'player_influence': '30.4',
#   'player_influence_rank': 327,
#   'player_creativity': '70.1',
#   'player_creativity_rank': 161,
#   'player_threat': '169.0',
#   'player_threat_rank': 46,
#   'player_starts': 5,
#   'player_news': '',
#   'news_date': None},
#  {'player_id': 686,
#   'first_name': 'Oliwier',
#   'last_name': 'Zych',
#   'team_id': 2,
#   'player_type': 1,
#   'minutes_played': 0,
#   'form': '0.0',
#   'form_rank': 471,
#   'goals': 0,
#   'assists': 0,
#   'clean_sheets': 0,
#   'goals_conceded': 0,
#   'own_goals': 0,
#   'penalties_saved': 0,
#   'penalties_missed': 0,
#   'yellow_cards': 0,
#   'red_cards': 0,
#   'player_influence': '0.0',
#   'player_influence_rank': 538,
#   'player_creativity': '0.0',
#   'player_creativity_rank': 523,
#   'player_threat': '0.0',
#   'player_threat_rank': 501,
#   'player_starts': 0,
#   'player_news': 'On loan to Puszcza Niepolomice',
#   'news_date': '2023-09-11T14:12:20.141802Z'},
#  {'player_id': 699,
#   'first_name': 'Clément',
#   'last_name': 'Lenglet',
#   'team_id': 2,
#   'player_type': 2,
#   'minutes_played': 0,
#   'form': '0.0',
#   'form_rank': 566,
#   'goals': 0,
#   'assists': 0,
#   'clean_sheets': 0,
#   'goals_conceded': 0,
#   'own_goals': 0,
#   'penalties_saved': 0,
#   'penalties_missed': 0,
#   'yellow_cards': 0,
#   'red_cards': 0,
#   'player_influence': '0.0',
#   'player_influence_rank': 609,
#   'player_creativity': '0.0',
#   'player_creativity_rank': 605,
#   'player_threat': '0.0',
#   'player_threat_rank': 594,
#   'player_starts': 0,
#   'player_news': '',
#   'news_date': None},
#  {'player_id': 62,
#   'first_name': 'Jaidon',
#   'last_name': 'Anthony',
#   'team_id': 3,
#   'player_type': 3,
#   'minutes_played': 151,
#   'form': '0.0',
#   'form_rank': 673,
#   'goals': 0,
#   'assists': 0,
#   'clean_sheets': 0,
#   'goals_conceded': 5,
#   'own_goals': 0,
#   'penalties_saved': 0,
#   'penalties_missed': 0,
#   'yellow_cards': 1,
#   'red_cards': 0,
#   'player_influence': '9.0',
#   'player_influence_rank': 396,
#   'player_creativity': '4.6',
#   'player_creativity_rank': 373,
#   'player_threat': '16.0',
#   'player_threat_rank': 297,
#   'player_starts': 2,
#   'player_news': 'Season-long loan to Leeds United',
#   'news_date': '2023-09-03T20:09:06.556250Z'},
#  {'player_id': 63,
#   'first_name': 'Philip',
#   'last_name': 'Billing',
#   'team_id': 3,
#   'player_type': 3,
#   'minutes_played': 861,
#   'form': '5.3',
#   'form_rank': 25,
#   'goals': 1,
#   'assists': 1,
#   'clean_sheets': 1,
#   'goals_conceded': 20,
#   'own_goals': 0,
#   'penalties_saved': 0,
#   'penalties_missed': 0,
#   'yellow_cards': 1,
#   'red_cards': 0,
#   'player_influence': '191.0',
#   'player_influence_rank': 69,
#   'player_creativity': '152.0',
#   'player_creativity_rank': 53,
#   'player_threat': '138.0',
#   'player_threat_rank': 57,
#   'player_starts': 10,
#   'player_news': '',
#   'news_date': '2023-10-10T12:00:08.143954Z'},
#  {'player_id': 64,
#   'first_name': 'David',
#   'last_name': 'Brooks',
#   'team_id': 3,
#   'player_type': 3,
#   'minutes_played': 223,
#   'form': '0.7',
#   'form_rank': 296,
#   'goals': 1,
#   'assists': 0,
#   'clean_sheets': 0,
#   'goals_conceded': 3,
#   'own_goals': 0,
#   'penalties_saved': 0,
#   'penalties_missed': 0,
#   'yellow_cards': 1,
#   'red_cards': 0,
#   'player_influence': '61.8',
#   'player_influence_rank': 262,
#   'player_creativity': '82.0',
#   'player_creativity_rank': 130,
#   'player_threat': '83.0',
#   'player_threat_rank': 123,
#   'player_starts': 2,
#   'player_news': '',
#   'news_date': None},
#  {'player_id': 65,
#   'first_name': 'Ryan',
#   'last_name': 'Christie',
#   'team_id': 3,
#   'player_type': 3,
#   'minutes_played': 692,
#   'form': '1.3',
#   'form_rank': 209,
#   'goals': 0,
#   'assists': 1,
#   'clean_sheets': 1,
#   'goals_conceded': 16,
#   'own_goals': 0,
#   'penalties_saved': 0,
#   'penalties_missed': 0,
#   'yellow_cards': 0,
#   'red_cards': 0,
#   'player_influence': '98.4',
#   'player_influence_rank': 189,
#   'player_creativity': '151.6',
#   'player_creativity_rank': 56,
#   'player_threat': '106.0',
#   'player_threat_rank': 91,
#   'player_starts': 9,
#   'player_news': '',
#   'news_date': '2023-08-06T23:30:05.398527Z'},
#  {'player_id': 66,
#   'first_name': 'Lewis',
#   'last_name': 'Cook',
#   'team_id': 3,
#   'player_type': 3,
#   'minutes_played': 524,
#   'form': '0.0',
#   'form_rank': 680,
#   'goals': 0,
#   'assists': 0,
#   'clean_sheets': 1,
#   'goals_conceded': 15,
#   'own_goals': 0,
#   'penalties_saved': 0,
#   'penalties_missed': 0,
#   'yellow_cards': 0,
#   'red_cards': 1,
#   'player_influence': '76.6',
#   'player_influence_rank': 234,
#   'player_creativity': '62.3',
#   'player_creativity_rank': 175,
#   'player_threat': '18.0',
#   'player_threat_rank': 276,
#   'player_starts': 6,
#   'player_news': 'Suspended until 11 Nov',
#   'news_date': '2023-10-21T17:30:07.277985Z'},
#  {'player_id': 67,
#   'first_name': 'Siriki',
#   'last_name': 'Dembélé',
#   'team_id': 3,
#   'player_type': 3,
#   'minutes_played': 0,
#   'form': '0.0',
#   'form_rank': 581,
#   'goals': 0,
#   'assists': 0,
#   'clean_sheets': 0,
#   'goals_conceded': 0,
#   'own_goals': 0,
#   'penalties_saved': 0,
#   'penalties_missed': 0,
#   'yellow_cards': 0,
#   'red_cards': 0,
#   'player_influence': '0.0',
#   'player_influence_rank': 622,
#   'player_creativity': '0.0',
#   'player_creativity_rank': 619,
#   'player_threat': '0.0',
#   'player_threat_rank': 609,
#   'player_starts': 0,
#   'player_news': 'Permanent Transfer to Birmingham',
#   'news_date': '2023-07-17T06:20:36.127600Z'},
#  {'player_id': 68,
#   'first_name': 'Ryan',
#   'last_name': 'Fredericks',
#   'team_id': 3,
#   'player_type': 2,
#   'minutes_played': 0,
#   'form': '0.0',
#   'form_rank': 508,
#   'goals': 0,
#   'assists': 0,
#   'clean_sheets': 0,
#   'goals_conceded': 0,
#   'own_goals': 0,
#   'penalties_saved': 0,
#   'penalties_missed': 0,
#   'yellow_cards': 0,
#   'red_cards': 0,
#   'player_influence': '0.0',
#   'player_influence_rank': 562,
#   'player_creativity': '0.0',
#   'player_creativity_rank': 553,
#   'player_threat': '0.0',
#   'player_threat_rank': 538,
#   'player_starts': 0,
#   'player_news': 'Calf injury - Unknown return date',
#   'news_date': '2023-08-06T23:30:05.414382Z'},
#  {'player_id': 69,
#   'first_name': 'James',
#   'last_name': 'Hill',
#   'team_id': 3,
#   'player_type': 2,
#   'minutes_played': 15,
#   'form': '0.0',
#   'form_rank': 456,
#   'goals': 0,
#   'assists': 0,
#   'clean_sheets': 0,
#   'goals_conceded': 0,
#   'own_goals': 0,
#   'penalties_saved': 0,
#   'penalties_missed': 0,
#   'yellow_cards': 0,
#   'red_cards': 0,
#   'player_influence': '0.0',
#   'player_influence_rank': 524,
#   'player_creativity': '1.8',
#   'player_creativity_rank': 391,
#   'player_threat': '0.0',
#   'player_threat_rank': 487,
#   'player_starts': 0,
#   'player_news': 'Season-long loan to Blackburn Rovers',
#   'news_date': '2023-09-01T14:44:09.529285Z'},
#  {'player_id': 70,
#   'first_name': 'Lloyd',
#   'last_name': 'Kelly',
#   'team_id': 3,
#   'player_type': 2,
#   'minutes_played': 456,
#   'form': '1.0',
#   'form_rank': 238,
#   'goals': 0,
#   'assists': 0,
#   'clean_sheets': 1,
#   'goals_conceded': 8,
#   'own_goals': 0,
#   'penalties_saved': 0,
#   'penalties_missed': 0,
#   'yellow_cards': 1,
#   'red_cards': 0,
#   'player_influence': '80.2',
#   'player_influence_rank': 227,
#   'player_creativity': '36.1',
#   'player_creativity_rank': 245,
#   'player_threat': '6.0',
#   'player_threat_rank': 348,
#   'player_starts': 5,
#   'player_news': '',
#   'news_date': '2023-09-25T14:30:07.504064Z'},
#  {'player_id': 71,
#   'first_name': 'Gavin',
#   'last_name': 'Kilkenny',
#   'team_id': 3,
#   'player_type': 3,
#   'minutes_played': 0,
#   'form': '0.0',
#   'form_rank': 544,
#   'goals': 0,
#   'assists': 0,
#   'clean_sheets': 0,
#   'goals_conceded': 0,
#   'own_goals': 0,
#   'penalties_saved': 0,
#   'penalties_missed': 0,
#   'yellow_cards': 0,
#   'red_cards': 0,
#   'player_influence': '0.0',
#   'player_influence_rank': 592,
#   'player_creativity': '0.0',
#   'player_creativity_rank': 584,
#   'player_threat': '0.0',
#   'player_threat_rank': 572,
#   'player_starts': 0,
#   'player_news': '',
#   'news_date': None},
#  {'player_id': 72,
#   'first_name': 'Justin',
#   'last_name': 'Kluivert',
#   'team_id': 3,
#   'player_type': 3,
#   'minutes_played': 334,
#   'form': '0.0',
#   'form_rank': 634,
#   'goals': 0,
#   'assists': 0,
#   'clean_sheets': 0,
#   'goals_conceded': 7,
#   'own_goals': 0,
#   'penalties_saved': 0,
#   'penalties_missed': 0,
#   'yellow_cards': 0,
#   'red_cards': 0,
#   'player_influence': '25.6',
#   'player_influence_rank': 340,
#   'player_creativity': '53.4',
#   'player_creativity_rank': 199,
#   'player_threat': '56.0',
#   'player_threat_rank': 164,
#   'player_starts': 4,
#   'player_news': '',
#   'news_date': None},
#  {'player_id': 73,
#   'first_name': 'Jamal',
# ...
#   'player_type': 4,
#   'minutes_played': 250,
#   'form': '0.3',
#   'form_rank': 357,
#   'goals': 0,
#   'assists': 0,
#   'clean_sheets': 1,
#   'goals_conceded': 7,
#   'own_goals': 0,
#   'penalties_saved': 0,
#   'penalties_missed': 0,
#   'yellow_cards': 1,
#   'red_cards': 0,
#   'player_influence': '25.2',
#   'player_influence_rank': 344,
#   'player_creativity': '51.3',
#   'player_creativity_rank': 203,
#   'player_threat': '93.0',
#   'player_threat_rank': 106,
#   'player_starts': 3,
#   'player_news': '',
#   'news_date': None},
#  {'player_id': 554,
#   'first_name': 'Gonçalo Manuel',
#   'last_name': 'Ganchinho Guedes',
#   'team_id': 20,
#   'player_type': 3,
#   'minutes_played': 0,
#   'form': '0.0',
#   'form_rank': 705,
#   'goals': 0,
#   'assists': 0,
#   'clean_sheets': 0,
#   'goals_conceded': 0,
#   'own_goals': 0,
#   'penalties_saved': 0,
#   'penalties_missed': 0,
#   'yellow_cards': 0,
#   'red_cards': 0,
#   'player_influence': '0.0',
#   'player_influence_rank': 714,
#   'player_creativity': '0.0',
#   'player_creativity_rank': 714,
#   'player_threat': '0.0',
#   'player_threat_rank': 712,
#   'player_starts': 0,
#   'player_news': 'Season-long loan to Benfica',
#   'news_date': '2023-08-31T08:54:37.485544Z'},
#  {'player_id': 555,
#   'first_name': 'Joe',
#   'last_name': 'Hodge',
#   'team_id': 20,
#   'player_type': 3,
#   'minutes_played': 0,
#   'form': '0.0',
#   'form_rank': 535,
#   'goals': 0,
#   'assists': 0,
#   'clean_sheets': 0,
#   'goals_conceded': 0,
#   'own_goals': 0,
#   'penalties_saved': 0,
#   'penalties_missed': 0,
#   'yellow_cards': 0,
#   'red_cards': 0,
#   'player_influence': '0.0',
#   'player_influence_rank': 584,
#   'player_creativity': '0.0',
#   'player_creativity_rank': 576,
#   'player_threat': '0.0',
#   'player_threat_rank': 564,
#   'player_starts': 0,
#   'player_news': 'Shoulder injury - Expected back 22 Jan',
#   'news_date': '2023-10-27T13:30:09.209650Z'},
#  {'player_id': 556,
#   'first_name': 'Ki-Jana',
#   'last_name': 'Hoever',
#   'team_id': 20,
#   'player_type': 2,
#   'minutes_played': 0,
#   'form': '0.0',
#   'form_rank': 443,
#   'goals': 0,
#   'assists': 0,
#   'clean_sheets': 0,
#   'goals_conceded': 0,
#   'own_goals': 0,
#   'penalties_saved': 0,
#   'penalties_missed': 0,
#   'yellow_cards': 0,
#   'red_cards': 0,
#   'player_influence': '0.0',
#   'player_influence_rank': 512,
#   'player_creativity': '0.0',
#   'player_creativity_rank': 498,
#   'player_threat': '0.0',
#   'player_threat_rank': 474,
#   'player_starts': 0,
#   'player_news': 'Season long loan to Stoke City',
#   'news_date': '2023-07-24T09:58:05.682494Z'},
#  {'player_id': 557,
#   'first_name': 'Hwang',
#   'last_name': 'Hee-chan',
#   'team_id': 20,
#   'player_type': 3,
#   'minutes_played': 591,
#   'form': '7.0',
#   'form_rank': 9,
#   'goals': 6,
#   'assists': 1,
#   'clean_sheets': 0,
#   'goals_conceded': 9,
#   'own_goals': 0,
#   'penalties_saved': 0,
#   'penalties_missed': 0,
#   'yellow_cards': 3,
#   'red_cards': 0,
#   'player_influence': '248.2',
#   'player_influence_rank': 30,
#   'player_creativity': '102.4',
#   'player_creativity_rank': 105,
#   'player_threat': '203.0',
#   'player_threat_rank': 34,
#   'player_starts': 7,
#   'player_news': '',
#   'news_date': '2023-08-26T21:00:08.675337Z'},
#  {'player_id': 559,
#   'first_name': 'João Victor',
#   'last_name': 'Gomes da Silva',
#   'team_id': 20,
#   'player_type': 3,
#   'minutes_played': 673,
#   'form': '1.3',
#   'form_rank': 208,
#   'goals': 0,
#   'assists': 1,
#   'clean_sheets': 1,
#   'goals_conceded': 14,
#   'own_goals': 0,
#   'penalties_saved': 0,
#   'penalties_missed': 0,
#   'yellow_cards': 3,
#   'red_cards': 0,
#   'player_influence': '68.4',
#   'player_influence_rank': 249,
#   'player_creativity': '69.0',
#   'player_creativity_rank': 163,
#   'player_threat': '26.0',
#   'player_threat_rank': 243,
#   'player_starts': 9,
#   'player_news': '',
#   'news_date': None},
#  {'player_id': 560,
#   'first_name': 'Jonathan',
#   'last_name': 'Castro Otto',
#   'team_id': 20,
#   'player_type': 2,
#   'minutes_played': 4,
#   'form': '0.0',
#   'form_rank': 487,
#   'goals': 0,
#   'assists': 0,
#   'clean_sheets': 0,
#   'goals_conceded': 0,
#   'own_goals': 0,
#   'penalties_saved': 0,
#   'penalties_missed': 0,
#   'yellow_cards': 0,
#   'red_cards': 0,
#   'player_influence': '5.0',
#   'player_influence_rank': 413,
#   'player_creativity': '0.0',
#   'player_creativity_rank': 537,
#   'player_threat': '0.0',
#   'player_threat_rank': 518,
#   'player_starts': 0,
#   'player_news': '',
#   'news_date': None},
#  {'player_id': 561,
#   'first_name': 'Bruno',
#   'last_name': 'Cavaco Jordão',
#   'team_id': 20,
#   'player_type': 3,
#   'minutes_played': 0,
#   'form': '0.0',
#   'form_rank': 541,
#   'goals': 0,
#   'assists': 0,
#   'clean_sheets': 0,
#   'goals_conceded': 0,
#   'own_goals': 0,
#   'penalties_saved': 0,
#   'penalties_missed': 0,
#   'yellow_cards': 0,
#   'red_cards': 0,
#   'player_influence': '0.0',
#   'player_influence_rank': 590,
#   'player_creativity': '0.0',
#   'player_creativity_rank': 582,
#   'player_threat': '0.0',
#   'player_threat_rank': 570,
#   'player_starts': 0,
#   'player_news': '',
#   'news_date': None},
#  {'player_id': 562,
#   'first_name': 'Sasa',
#   'last_name': 'Kalajdzic',
#   'team_id': 20,
#   'player_type': 4,
#   'minutes_played': 51,
#   'form': '3.3',
#   'form_rank': 79,
#   'goals': 2,
#   'assists': 0,
#   'clean_sheets': 0,
#   'goals_conceded': 1,
#   'own_goals': 0,
#   'penalties_saved': 0,
#   'penalties_missed': 0,
#   'yellow_cards': 0,
#   'red_cards': 0,
#   'player_influence': '83.8',
#   'player_influence_rank': 219,
#   'player_creativity': '22.1',
#   'player_creativity_rank': 298,
#   'player_threat': '58.0',
#   'player_threat_rank': 163,
#   'player_starts': 0,
#   'player_news': '',
#   'news_date': None},
#  {'player_id': 563,
#   'first_name': 'Max',
#   'last_name': 'Kilman',
#   'team_id': 20,
#   'player_type': 2,
#   'minutes_played': 900,
#   'form': '1.3',
#   'form_rank': 197,
#   'goals': 0,
#   'assists': 0,
#   'clean_sheets': 1,
#   'goals_conceded': 17,
#   'own_goals': 0,
#   'penalties_saved': 0,
#   'penalties_missed': 0,
#   'yellow_cards': 2,
#   'red_cards': 0,
#   'player_influence': '218.0',
#   'player_influence_rank': 43,
#   'player_creativity': '70.4',
#   'player_creativity_rank': 159,
#   'player_threat': '60.0',
#   'player_threat_rank': 155,
#   'player_starts': 10,
#   'player_news': '',
#   'news_date': None},
#  {'player_id': 564,
#   'first_name': 'Tom',
#   'last_name': 'King',
#   'team_id': 20,
#   'player_type': 1,
#   'minutes_played': 0,
#   'form': '0.0',
#   'form_rank': 413,
#   'goals': 0,
#   'assists': 0,
#   'clean_sheets': 0,
#   'goals_conceded': 0,
#   'own_goals': 0,
#   'penalties_saved': 0,
#   'penalties_missed': 0,
#   'yellow_cards': 0,
#   'red_cards': 0,
#   'player_influence': '0.0',
#   'player_influence_rank': 485,
#   'player_creativity': '0.0',
#   'player_creativity_rank': 471,
#   'player_threat': '0.0',
#   'player_threat_rank': 446,
#   'player_starts': 0,
#   'player_news': '',
#   'news_date': None},
#  {'player_id': 565,
#   'first_name': 'Mario',
#   'last_name': 'Lemina',
#   'team_id': 20,
#   'player_type': 3,
#   'minutes_played': 792,
#   'form': '2.7',
#   'form_rank': 114,
#   'goals': 1,
#   'assists': 0,
#   'clean_sheets': 1,
#   'goals_conceded': 14,
#   'own_goals': 0,
#   'penalties_saved': 0,
#   'penalties_missed': 0,
#   'yellow_cards': 4,
#   'red_cards': 1,
#   'player_influence': '146.0',
#   'player_influence_rank': 121,
#   'player_creativity': '55.5',
#   'player_creativity_rank': 193,
#   'player_threat': '110.0',
#   'player_threat_rank': 87,
#   'player_starts': 9,
#   'player_news': '',
#   'news_date': '2023-10-08T19:00:08.456027Z'},
#  {'player_id': 567,
#   'first_name': 'Pedro',
#   'last_name': 'Lomba Neto',
#   'team_id': 20,
#   'player_type': 3,
#   'minutes_played': 886,
#   'form': '4.7',
#   'form_rank': 44,
#   'goals': 1,
#   'assists': 8,
#   'clean_sheets': 1,
#   'goals_conceded': 17,
#   'own_goals': 0,
#   'penalties_saved': 0,
#   'penalties_missed': 0,
#   'yellow_cards': 3,
#   'red_cards': 0,
#   'player_influence': '248.0',
#   'player_influence_rank': 31,
#   'player_creativity': '388.1',
#   'player_creativity_rank': 4,
#   'player_threat': '207.0',
#   'player_threat_rank': 32,
#   'player_starts': 10,
#   'player_news': 'Hamstring injury - 25% chance of playing',
#   'news_date': '2023-10-28T19:30:09.445880Z'},
#  {'player_id': 568,
#   'first_name': 'Daniel',
#   'last_name': 'Castelo Podence',
#   'team_id': 20,
#   'player_type': 3,
#   'minutes_played': 0,
#   'form': '0.0',
#   'form_rank': 700,
#   'goals': 0,
#   'assists': 0,
#   'clean_sheets': 0,
#   'goals_conceded': 0,
#   'own_goals': 0,
#   'penalties_saved': 0,
#   'penalties_missed': 0,
#   'yellow_cards': 0,
#   'red_cards': 0,
#   'player_influence': '0.0',
#   'player_influence_rank': 712,
#   'player_creativity': '0.0',
#   'player_creativity_rank': 712,
#   'player_threat': '0.0',
#   'player_threat_rank': 709,
#   'player_starts': 0,
#   'player_news': 'On loan to Olympiakos',
#   'news_date': '2023-09-06T09:27:43.215497Z'},
#  {'player_id': 569,
#   'first_name': 'José',
#   'last_name': 'Malheiro de Sá',
#   'team_id': 20,
#   'player_type': 1,
#   'minutes_played': 900,
#   'form': '2.3',
#   'form_rank': 133,
#   'goals': 0,
#   'assists': 0,
#   'clean_sheets': 1,
#   'goals_conceded': 17,
#   'own_goals': 0,
#   'penalties_saved': 0,
#   'penalties_missed': 0,
#   'yellow_cards': 1,
#   'red_cards': 0,
#   'player_influence': '303.4',
#   'player_influence_rank': 16,
#   'player_creativity': '0.0',
#   'player_creativity_rank': 699,
#   'player_threat': '0.0',
#   'player_threat_rank': 696,
#   'player_starts': 10,
#   'player_news': '',
#   'news_date': None},
#  {'player_id': 570,
#   'first_name': 'Pablo',
#   'last_name': 'Sarabia',
#   'team_id': 20,
#   'player_type': 3,
#   'minutes_played': 187,
#   'form': '0.0',
#   'form_rank': 647,
#   'goals': 0,
#   'assists': 1,
#   'clean_sheets': 1,
#   'goals_conceded': 1,
#   'own_goals': 0,
#   'penalties_saved': 0,
#   'penalties_missed': 0,
#   'yellow_cards': 1,
#   'red_cards': 0,
#   'player_influence': '47.0',
#   'player_influence_rank': 289,
#   'player_creativity': '111.2',
#   'player_creativity_rank': 89,
#   'player_threat': '53.0',
#   'player_threat_rank': 174,
#   'player_starts': 2,
#   'player_news': '',
#   'news_date': None},
#  {'player_id': 571,
#   'first_name': 'Matija',
#   'last_name': 'Šarkić',
#   'team_id': 20,
#   'player_type': 1,
#   'minutes_played': 0,
#   'form': '0.0',
#   'form_rank': 425,
#   'goals': 0,
#   'assists': 0,
#   'clean_sheets': 0,
#   'goals_conceded': 0,
#   'own_goals': 0,
#   'penalties_saved': 0,
#   'penalties_missed': 0,
#   'yellow_cards': 0,
#   'red_cards': 0,
#   'player_influence': '0.0',
#   'player_influence_rank': 497,
#   'player_creativity': '0.0',
#   'player_creativity_rank': 483,
#   'player_threat': '0.0',
#   'player_threat_rank': 458,
#   'player_starts': 0,
#   'player_news': 'Permanent transfer to Millwall',
#   'news_date': '2023-08-07T07:47:40.181414Z'},
#  {'player_id': 572,
#   'first_name': 'Nélson',
#   'last_name': 'Cabral Semedo',
#   'team_id': 20,
#   'player_type': 2,
#   'minutes_played': 803,
#   'form': '0.7',
#   'form_rank': 285,
#   'goals': 0,
#   'assists': 0,
#   'clean_sheets': 1,
#   'goals_conceded': 16,
#   'own_goals': 0,
#   'penalties_saved': 0,
#   'penalties_missed': 0,
#   'yellow_cards': 4,
#   'red_cards': 0,
#   'player_influence': '154.0',
#   'player_influence_rank': 112,
#   'player_creativity': '73.2',
#   'player_creativity_rank': 147,
#   'player_threat': '32.0',
#   'player_threat_rank': 224,
#   'player_starts': 9,
#   'player_news': '',
#   'news_date': '2023-10-19T12:00:09.529330Z'},
#  {'player_id': 573,
#   'first_name': 'Toti António',
#   'last_name': 'Gomes',
#   'team_id': 20,
#   'player_type': 2,
#   'minutes_played': 413,
#   'form': '2.7',
#   'form_rank': 106,
#   'goals': 0,
#   'assists': 1,
#   'clean_sheets': 0,
#   'goals_conceded': 6,
#   'own_goals': 0,
#   'penalties_saved': 0,
#   'penalties_missed': 0,
#   'yellow_cards': 0,
#   'red_cards': 0,
#   'player_influence': '86.2',
#   'player_influence_rank': 214,
#   'player_creativity': '15.6',
#   'player_creativity_rank': 327,
#   'player_threat': '2.0',
#   'player_threat_rank': 386,
#   'player_starts': 4,
#   'player_news': '',
#   'news_date': None},
#  {'player_id': 574,
#   'first_name': 'Boubacar',
#   'last_name': 'Traoré',
#   'team_id': 20,
#   'player_type': 3,
#   'minutes_played': 234,
#   'form': '1.0',
#   'form_rank': 234,
#   'goals': 0,
#   'assists': 0,
#   'clean_sheets': 0,
#   'goals_conceded': 7,
#   'own_goals': 0,
#   'penalties_saved': 0,
#   'penalties_missed': 0,
#   'yellow_cards': 1,
#   'red_cards': 0,
#   'player_influence': '27.6',
#   'player_influence_rank': 337,
#   'player_creativity': '20.7',
#   'player_creativity_rank': 306,
#   'player_threat': '9.0',
#   'player_threat_rank': 332,
#   'player_starts': 2,
#   'player_news': '',
#   'news_date': None},
#  {'player_id': 590,
#   'first_name': 'Matheus',
#   'last_name': 'Santos Carneiro Da Cunha',
#   'team_id': 20,
#   'player_type': 4,
#   'minutes_played': 801,
#   'form': '3.7',
#   'form_rank': 72,
#   'goals': 2,
#   'assists': 1,
#   'clean_sheets': 1,
#   'goals_conceded': 15,
#   'own_goals': 0,
#   'penalties_saved': 0,
#   'penalties_missed': 0,
#   'yellow_cards': 1,
#   'red_cards': 0,
#   'player_influence': '186.2',
#   'player_influence_rank': 74,
#   'player_creativity': '111.6',
#   'player_creativity_rank': 87,
#   'player_threat': '273.0',
#   'player_threat_rank': 20,
#   'player_starts': 10,
#   'player_news': '',
#   'news_date': '2023-08-11T13:30:07.246810Z'},
#  {'player_id': 598,
#   'first_name': 'Matt',
#   'last_name': 'Doherty',
#   'team_id': 20,
#   'player_type': 2,
#   'minutes_played': 226,
#   'form': '1.0',
#   'form_rank': 224,
#   'goals': 0,
#   'assists': 0,
#   'clean_sheets': 0,
#   'goals_conceded': 5,
#   'own_goals': 0,
#   'penalties_saved': 0,
#   'penalties_missed': 0,
#   'yellow_cards': 0,
#   'red_cards': 0,
#   'player_influence': '42.8',
#   'player_influence_rank': 298,
#   'player_creativity': '52.0',
#   'player_creativity_rank': 202,
#   'player_threat': '21.0',
#   'player_threat_rank': 261,
#   'player_starts': 1,
#   'player_news': '',
#   'news_date': None},
#  {'player_id': 697,
#   'first_name': 'Santiago',
#   'last_name': 'Bueno',
#   'team_id': 20,
#   'player_type': 2,
#   'minutes_played': 0,
#   'form': '0.0',
#   'form_rank': 576,
#   'goals': 0,
#   'assists': 0,
#   'clean_sheets': 0,
#   'goals_conceded': 0,
#   'own_goals': 0,
#   'penalties_saved': 0,
#   'penalties_missed': 0,
#   'yellow_cards': 0,
#   'red_cards': 0,
#   'player_influence': '0.0',
#   'player_influence_rank': 618,
#   'player_creativity': '0.0',
#   'player_creativity_rank': 614,
#   'player_threat': '0.0',
#   'player_threat_rank': 604,
#   'player_starts': 0,
#   'player_news': '',
#   'news_date': '2023-10-06T16:00:11.039996Z'},
#  {'player_id': 698,
#   'first_name': 'Enso',
#   'last_name': 'González',
#   'team_id': 20,
#   'player_type': 3,
#   'minutes_played': 0,
#   'form': '0.0',
#   'form_rank': 693,
#   'goals': 0,
#   'assists': 0,
#   'clean_sheets': 0,
#   'goals_conceded': 0,
#   'own_goals': 0,
#   'penalties_saved': 0,
#   'penalties_missed': 0,
#   'yellow_cards': 0,
#   'red_cards': 0,
#   'player_influence': '0.0',
#   'player_influence_rank': 710,
#   'player_creativity': '0.0',
#   'player_creativity_rank': 708,
#   'player_threat': '0.0',
#   'player_threat_rank': 705,
#   'player_starts': 0,
#   'player_news': '',
#   'news_date': None},
#  {'player_id': 704,
#   'first_name': 'Nathan',
#   'last_name': 'Fraser',
#   'team_id': 20,
#   'player_type': 4,
#   'minutes_played': 0,
#   'form': '0.0',
#   'form_rank': 622,
#   'goals': 0,
#   'assists': 0,
#   'clean_sheets': 0,
#   'goals_conceded': 0,
#   'own_goals': 0,
#   'penalties_saved': 0,
#   'penalties_missed': 0,
#   'yellow_cards': 0,
#   'red_cards': 0,
#   'player_influence': '0.0',
#   'player_influence_rank': 660,
#   'player_creativity': '0.0',
#   'player_creativity_rank': 656,
#   'player_threat': '0.0',
#   'player_threat_rank': 648,
#   'player_starts': 0,
#   'player_news': '',
#   'news_date': None},
#  {'player_id': 715,
#   'first_name': 'Jean-Ricner',
#   'last_name': 'Bellegarde',
#   'team_id': 20,
#   'player_type': 3,
#   'minutes_played': 114,
#   'form': '0.0',
#   'form_rank': 688,
#   'goals': 0,
#   'assists': 0,
#   'clean_sheets': 0,
#   'goals_conceded': 2,
#   'own_goals': 0,
#   'penalties_saved': 0,
#   'penalties_missed': 0,
#   'yellow_cards': 0,
#   'red_cards': 1,
#   'player_influence': '9.6',
#   'player_influence_rank': 391,
#   'player_creativity': '13.3',
#   'player_creativity_rank': 340,
#   'player_threat': '9.0',
#   'player_threat_rank': 334,
#   'player_starts': 2,
#   'player_news': 'Muscle injury - 75% chance of playing',
#   'news_date': '2023-10-21T18:00:09.560300Z'}]

# %%
player_df = pd.DataFrame.from_dict(player_list)

# %%
player_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 731 entries, 0 to 730
# Data columns (total 26 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   player_id               731 non-null    int64
#  1   first_name              731 non-null    object
#  2   last_name               731 non-null    object
#  3   team_id                 731 non-null    int64
#  4   player_type             731 non-null    int64
#  5   minutes_played          731 non-null    int64
#  6   form                    731 non-null    object
#  7   form_rank               731 non-null    int64
#  8   goals                   731 non-null    int64
#  9   assists                 731 non-null    int64
#  10  clean_sheets            731 non-null    int64
#  11  goals_conceded          731 non-null    int64
#  12  own_goals               731 non-null    int64
#  13  penalties_saved         731 non-null    int64
#  14  penalties_missed        731 non-null    int64
#  15  yellow_cards            731 non-null    int64
#  16  red_cards               731 non-null    int64
#  17  player_influence        731 non-null    object
#  18  player_influence_rank   731 non-null    int64
#  19  player_creativity       731 non-null    object
#  20  player_creativity_rank  731 non-null    int64
#  21  player_threat           731 non-null    object
#  22  player_threat_rank      731 non-null    int64
#  23  player_starts           731 non-null    int64
#  24  player_news             731 non-null    object
#  25  news_date               447 non-null    object
# dtypes: int64(18), object(8)
# memory usage: 148.6+ KB

# %%
player_df.loc[player_df['player_id'] == 13]
# Out:
#     player_id first_name last_name  team_id  player_type  minutes_played form  \
# 11         13      Eddie   Nketiah        1            4             679  6.3
#
#     form_rank  goals  assists  ...  red_cards  player_influence  \
# 11         16      5        2  ...          0             179.4
#
#     player_influence_rank  player_creativity  player_creativity_rank  \
# 11                     84               77.6                     139
#
#     player_threat  player_threat_rank player_starts  player_news news_date
# 11          257.0                  23             8                   None
#
# [1 rows x 26 columns]

# %%
player_df.tail(10)
# Out:
#      player_id    first_name                 last_name  team_id  player_type  \
# 721        571        Matija                    Šarkić       20            1
# 722        572        Nélson             Cabral Semedo       20            2
# 723        573  Toti António                     Gomes       20            2
# 724        574      Boubacar                    Traoré       20            3
# 725        590       Matheus  Santos Carneiro Da Cunha       20            4
# 726        598          Matt                   Doherty       20            2
# 727        697      Santiago                     Bueno       20            2
# 728        698          Enso                  González       20            3
# 729        704        Nathan                    Fraser       20            4
# 730        715   Jean-Ricner                Bellegarde       20            3
#
#      minutes_played form  form_rank  goals  assists  ...  red_cards  \
# 721               0  0.0        442      0        0  ...          0
# 722             803  1.0        245      0        0  ...          0
# 723             413  2.5        112      0        1  ...          0
# 724             234  1.0        240      0        0  ...          0
# 725             801  4.0         62      2        1  ...          0
# 726             226  1.0        232      0        0  ...          0
# 727               0  0.0        588      0        0  ...          0
# 728               0  0.0        696      0        0  ...          0
# 729               0  0.0        632      0        0  ...          0
# 730             114  0.0        691      0        0  ...          1
#
#      player_influence  player_influence_rank  player_creativity  \
# 721               0.0                    497                0.0
# 722             154.0                    112               73.2
# 723              86.2                    214               15.6
# 724              27.6                    337               20.7
# 725             186.2                     74              111.6
# 726              42.8                    298               52.0
# 727               0.0                    618                0.0
# 728               0.0                    710                0.0
# 729               0.0                    660                0.0
# 730               9.6                    391               13.3
#
#      player_creativity_rank  player_threat  player_threat_rank player_starts  \
# 721                     483            0.0                 458             0
# 722                     147           32.0                 224             9
# 723                     327            2.0                 386             4
# 724                     306            9.0                 332             2
# 725                      87          273.0                  20            10
# 726                     202           21.0                 261             1
# 727                     615            0.0                 605             0
# 728                     708            0.0                 705             0
# 729                     657            0.0                 649             0
# 730                     340            9.0                 334             2
#
#                                player_news                    news_date
# 721         Permanent transfer to Millwall  2023-08-07T07:47:40.181414Z
# 722                                         2023-10-19T12:00:09.529330Z
# 723                                                                None
# 724                                                                None
# 725                                         2023-08-11T13:30:07.246810Z
# 726                                                                None
# 727                                         2023-10-06T16:00:11.039996Z
# 728                                                                None
# 729                                                                None
# 730  Muscle injury - 75% chance of playing  2023-10-21T18:00:09.560300Z
#
# [10 rows x 26 columns]

# %%
player_df.sort_values(by='goals',ascending=False).head(10)
# Out:
#      player_id first_name  last_name  team_id  player_type  minutes_played  \
# 444        355     Erling    Haaland       13            4             619
# 648        516        Son  Heung-min       18            3             550
# 664        526     Jarrod      Bowen       19            3             630
# 531        433     Callum     Wilson       15            4             255
# 145        132       Evan   Ferguson        5            4             300
# 119        108      Bryan     Mbeumo        4            3             630
# 513        415  Alexander       Isak       15            4             386
# 700        557      Hwang   Hee-chan       20            3             326
# 57          60      Ollie    Watkins        2            4             590
# 269        225    Odsonne    Edouard        8            4             518
#
#      form  form_rank  goals  assists  ...  red_cards  player_influence  \
# 444   4.7         43      8        1  ...          0             304.0
# 648   7.7          6      6        0  ...          0             239.0
# 664   6.0         23      5        1  ...          0             239.2
# 531   3.7         76      4        0  ...          0             154.4
# 145   1.0        255      4        0  ...          0             157.2
# 119   1.7        203      4        0  ...          0             191.2
# 513   3.7         75      4        0  ...          0             153.6
# 700   5.0         35      4        0  ...          0             146.0
# 57   12.3          2      4        6  ...          0             225.2
# 269   3.3         83      4        0  ...          0             172.0
#
#      player_influence_rank  player_creativity  player_creativity_rank  \
# 444                      1              102.2                      60
# 648                     11              149.9                      33
# 664                     10               83.1                      90
# 531                     54               19.8                     257
# 145                     50               33.4                     206
# 119                     26              196.0                      20
# 513                     55               42.6                     179
# 700                     64               25.8                     237
# 57                      13              174.0                      25
# 269                     38               68.5                     118
#
#      player_threat  player_threat_rank player_starts  \
# 444          416.0                   1             7
# 648          256.0                   8             7
# 664          319.0                   2             7
# 531          229.0                  16             2
# 145          189.0                  25             4
# 119          213.0                  18             7
# 513          200.0                  21             5
# 700          114.0                  52             4
# 57           283.0                   5             7
# 269          276.0                   6             6
#
#                                   player_news                    news_date
# 444                                                                   None
# 648                                            2023-09-29T13:30:09.441382Z
# 664                                            2023-09-22T11:30:08.260489Z
# 531  Hamstring injury - 50% chance of playing  2023-09-28T03:30:09.763557Z
# 145                                            2023-09-28T04:00:07.613334Z
# 119                                            2023-08-06T23:30:05.510200Z
# 513                                            2023-09-28T03:30:09.681318Z
# 700                                            2023-08-26T21:00:08.675337Z
# 57                                                                    None
# 269                                            2023-09-24T18:00:07.480397Z
#
# [10 rows x 26 columns]

# %%
player_df['news_date'] = pd.to_datetime(player_df['news_date'])

# %%
player_df.head()
# Out:
#    player_id first_name             last_name  team_id  player_type  \
# 0          1    Folarin               Balogun        1            4
# 1          2     Cédric          Alves Soares        1            2
# 2          3    Mohamed                Elneny        1            3
# 3          4      Fábio       Ferreira Vieira        1            3
# 4          5    Gabriel  dos Santos Magalhães        1            2
#
#    minutes_played form  form_rank  goals  assists  ...  red_cards  \
# 0               0  0.0        535      0        0  ...          0
# 1               0  0.0        377      0        0  ...          0
# 2               0  0.0        511      0        0  ...          0
# 3             185  1.2        229      0        3  ...          0
# 4             384  3.0         82      0        0  ...          0
#
#    player_influence  player_influence_rank  player_creativity  \
# 0               0.0                    566                0.0
# 1               0.0                    429                0.0
# 2               0.0                    548                0.0
# 3              45.6                    263               56.5
# 4              86.6                    166                8.4
#
#    player_creativity_rank  player_threat  player_threat_rank player_starts  \
# 0                     555            0.0                 540             0
# 1                     410            0.0                 382             0
# 2                     537            0.0                 520             0
# 3                     157           58.0                 139             2
# 4                     340            8.0                 318             4
#
#              player_news                        news_date
# 0  Transferred to Monaco 2023-08-31 08:55:15.272751+00:00
# 1                                                     NaT
# 2                        2023-08-11 13:00:06.079379+00:00
# 3                        2023-09-29 10:30:07.948136+00:00
# 4                        2023-09-30 23:00:07.672676+00:00
#
# [5 rows x 26 columns]

# %%
player_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 724 entries, 0 to 723
# Data columns (total 26 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   player_id               724 non-null    int64
#  1   first_name              724 non-null    object
#  2   last_name               724 non-null    object
#  3   team_id                 724 non-null    int64
#  4   player_type             724 non-null    int64
#  5   minutes_played          724 non-null    int64
#  6   form                    724 non-null    object
#  7   form_rank               724 non-null    int64
#  8   goals                   724 non-null    int64
#  9   assists                 724 non-null    int64
#  10  clean_sheets            724 non-null    int64
#  11  goals_conceded          724 non-null    int64
#  12  own_goals               724 non-null    int64
#  13  penalties_saved         724 non-null    int64
#  14  penalties_missed        724 non-null    int64
#  15  yellow_cards            724 non-null    int64
#  16  red_cards               724 non-null    int64
#  17  player_influence        724 non-null    object
#  18  player_influence_rank   724 non-null    int64
#  19  player_creativity       724 non-null    object
#  20  player_creativity_rank  724 non-null    int64
#  21  player_threat           724 non-null    object
#  22  player_threat_rank      724 non-null    int64
#  23  player_starts           724 non-null    int64
#  24  player_news             724 non-null    object
#  25  news_date               408 non-null    datetime64[ns, UTC]
# dtypes: datetime64[ns, UTC](1), int64(18), object(7)
# memory usage: 147.2+ KB

# %%
player_df[player_df['news_date']]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_1944\615372759.py in <module>
# ----> 1 player_df[player_df['news_date']]
#
# G:\Big Data\Big Data Bootcamp\Anaconda\conda\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    3509             if is_iterator(key):
#    3510                 key = list(key)
# -> 3511             indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    3512
#    3513         # take() does not accept boolean indexers
#
# G:\Big Data\Big Data Bootcamp\Anaconda\conda\lib\site-packages\pandas\core\indexes\base.py in _get_indexer_strict(self, key, axis_name)
#    5794             keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
#    5795
# -> 5796         self._raise_if_missing(keyarr, indexer, axis_name)
#    5797
#    5798         keyarr = self.take(indexer)
#
# G:\Big Data\Big Data Bootcamp\Anaconda\conda\lib\site-packages\pandas\core\indexes\base.py in _raise_if_missing(self, key, indexer, axis_name)
#    5854                 if use_interval_msg:
#    5855                     key = list(key)
# -> 5856                 raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    5857
#    5858             not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
#
# KeyError: "None of [DatetimeIndex(['2023-08-31 08:55:15.272751+00:00',\n                                            'NaT',\n               '2023-08-11 13:00:06.079379+00:00',\n               '2023-09-29 10:30:07.948136+00:00',\n               '2023-09-30 23:00:07.672676+00:00',\n                                            'NaT',\n               '2023-09-30 23:30:06.990139+00:00',\n               '2023-08-07 15:30:05.168632+00:00',\n                                            'NaT',\n               '2023-08-14 03:57:12.475590+00:00',\n               ...\n               '2023-08-07 07:47:40.181414+00:00',\n                                            'NaT',\n                                            'NaT',\n                                            'NaT',\n               '2023-08-11 13:30:07.246810+00:00',\n                                            'NaT',\n               '2023-10-06 16:00:11.039996+00:00',\n                                            'NaT',\n                                            'NaT',\n               '2023-09-23 21:30:07.990147+00:00'],\n              dtype='datetime64[ns, UTC]', length=724, freq=None)] are in the [columns]"

# %%
player_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 722 entries, 0 to 721
# Data columns (total 25 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   player_id               722 non-null    int64
#  1   first_name              722 non-null    object
#  2   last_name               722 non-null    object
#  3   team_id                 722 non-null    int64
#  4   minutes_played          722 non-null    int64
#  5   form                    722 non-null    object
#  6   form_rank               722 non-null    int64
#  7   goals                   722 non-null    int64
#  8   assists                 722 non-null    int64
#  9   clean_sheets            722 non-null    int64
#  10  goals_conceded          722 non-null    int64
#  11  own_goals               722 non-null    int64
#  12  penalties_saved         722 non-null    int64
#  13  penalties_missed        722 non-null    int64
#  14  yellow_cards            722 non-null    int64
#  15  red_cards               722 non-null    int64
#  16  player_influence        722 non-null    object
#  17  player_influence_rank   722 non-null    int64
#  18  player_creativity       722 non-null    object
#  19  player_creativity_rank  722 non-null    int64
#  20  player_threat           722 non-null    object
#  21  player_threat_rank      722 non-null    int64
#  22  player_starts           722 non-null    int64
#  23  player_news             722 non-null    object
#  24  news_date               394 non-null    object
# dtypes: int64(17), object(8)
# memory usage: 141.1+ KB

# %%
album_list = []
for row in data['items']:
    album_id = row['track']['album']['id']
    album_name = row['track']['album']['name']
    album_release_date = row['track']['album']['release_date']
    album_total_tracks = row['track']['album']['total_tracks']
    album_url = row['track']['album']['external_urls']['spotify']
    album_element = {'album_id':album_id,'name':album_name,'release_date':album_release_date,
                        'total_tracks':album_total_tracks,'url':album_url}
    album_list.append(album_element)

# %%
#team Data
team_list = []
for i in data['teams']:
    team_id = i['id']
    team_name = i['name']
    team_played = i['played']
    win = i['win']
    loss = i['loss']
    draw = i['draw']
    team_position = i['position']
    team_strength = i['strength']
    team_form = i['form']
    short_name = i['short_name']
    team_code = i['code']
    team_element = {'team_id':team_id,'team_name':team_name,'team_played':team_played,
                    'win':win,'loss':loss,'draw':draw, 'team_position':team_position,'team_strength':team_strength,
                     'team_form':team_form,'short_name':short_name,'team_code':team_code}
    team_list.append(team_element)

# %%
team_list
# Out:
# [{'team_id': 1,
#   'team_name': 'Arsenal',
#   'team_played': 0,
#   'win': 0,
#   'loss': 0,
#   'draw': 0,
#   'team_position': 0,
#   'team_strength': 4,
#   'team_form': None,
#   'short_name': 'ARS',
#   'team_code': 3},
#  {'team_id': 2,
#   'team_name': 'Aston Villa',
#   'team_played': 0,
#   'win': 0,
#   'loss': 0,
#   'draw': 0,
#   'team_position': 0,
#   'team_strength': 3,
#   'team_form': None,
#   'short_name': 'AVL',
#   'team_code': 7},
#  {'team_id': 3,
#   'team_name': 'Bournemouth',
#   'team_played': 0,
#   'win': 0,
#   'loss': 0,
#   'draw': 0,
#   'team_position': 0,
#   'team_strength': 3,
#   'team_form': None,
#   'short_name': 'BOU',
#   'team_code': 91},
#  {'team_id': 4,
#   'team_name': 'Brentford',
#   'team_played': 0,
#   'win': 0,
#   'loss': 0,
#   'draw': 0,
#   'team_position': 0,
#   'team_strength': 3,
#   'team_form': None,
#   'short_name': 'BRE',
#   'team_code': 94},
#  {'team_id': 5,
#   'team_name': 'Brighton',
#   'team_played': 0,
#   'win': 0,
#   'loss': 0,
#   'draw': 0,
#   'team_position': 0,
#   'team_strength': 3,
#   'team_form': None,
#   'short_name': 'BHA',
#   'team_code': 36},
#  {'team_id': 6,
#   'team_name': 'Burnley',
#   'team_played': 0,
#   'win': 0,
#   'loss': 0,
#   'draw': 0,
#   'team_position': 0,
#   'team_strength': 2,
#   'team_form': None,
#   'short_name': 'BUR',
#   'team_code': 90},
#  {'team_id': 7,
#   'team_name': 'Chelsea',
#   'team_played': 0,
#   'win': 0,
#   'loss': 0,
#   'draw': 0,
#   'team_position': 0,
#   'team_strength': 3,
#   'team_form': None,
#   'short_name': 'CHE',
#   'team_code': 8},
#  {'team_id': 8,
#   'team_name': 'Crystal Palace',
#   'team_played': 0,
#   'win': 0,
#   'loss': 0,
#   'draw': 0,
#   'team_position': 0,
#   'team_strength': 3,
#   'team_form': None,
#   'short_name': 'CRY',
#   'team_code': 31},
#  {'team_id': 9,
#   'team_name': 'Everton',
#   'team_played': 0,
#   'win': 0,
#   'loss': 0,
#   'draw': 0,
#   'team_position': 0,
#   'team_strength': 3,
#   'team_form': None,
#   'short_name': 'EVE',
#   'team_code': 11},
#  {'team_id': 10,
#   'team_name': 'Fulham',
#   'team_played': 0,
#   'win': 0,
#   'loss': 0,
#   'draw': 0,
#   'team_position': 0,
#   'team_strength': 3,
#   'team_form': None,
#   'short_name': 'FUL',
#   'team_code': 54},
#  {'team_id': 11,
#   'team_name': 'Liverpool',
#   'team_played': 0,
#   'win': 0,
#   'loss': 0,
#   'draw': 0,
#   'team_position': 0,
#   'team_strength': 4,
#   'team_form': None,
#   'short_name': 'LIV',
#   'team_code': 14},
#  {'team_id': 12,
#   'team_name': 'Luton',
#   'team_played': 0,
#   'win': 0,
#   'loss': 0,
#   'draw': 0,
#   'team_position': 0,
#   'team_strength': 2,
#   'team_form': None,
#   'short_name': 'LUT',
#   'team_code': 102},
#  {'team_id': 13,
#   'team_name': 'Man City',
#   'team_played': 0,
#   'win': 0,
#   'loss': 0,
#   'draw': 0,
#   'team_position': 0,
#   'team_strength': 5,
#   'team_form': None,
#   'short_name': 'MCI',
#   'team_code': 43},
#  {'team_id': 14,
#   'team_name': 'Man Utd',
#   'team_played': 0,
#   'win': 0,
#   'loss': 0,
#   'draw': 0,
#   'team_position': 0,
#   'team_strength': 4,
#   'team_form': None,
#   'short_name': 'MUN',
#   'team_code': 1},
#  {'team_id': 15,
#   'team_name': 'Newcastle',
#   'team_played': 0,
#   'win': 0,
#   'loss': 0,
#   'draw': 0,
#   'team_position': 0,
#   'team_strength': 4,
#   'team_form': None,
#   'short_name': 'NEW',
#   'team_code': 4},
#  {'team_id': 16,
#   'team_name': "Nott'm Forest",
#   'team_played': 0,
#   'win': 0,
#   'loss': 0,
#   'draw': 0,
#   'team_position': 0,
#   'team_strength': 3,
#   'team_form': None,
#   'short_name': 'NFO',
#   'team_code': 17},
#  {'team_id': 17,
#   'team_name': 'Sheffield Utd',
#   'team_played': 0,
#   'win': 0,
#   'loss': 0,
#   'draw': 0,
#   'team_position': 0,
#   'team_strength': 2,
#   'team_form': None,
#   'short_name': 'SHU',
#   'team_code': 49},
#  {'team_id': 18,
#   'team_name': 'Spurs',
#   'team_played': 0,
#   'win': 0,
#   'loss': 0,
#   'draw': 0,
#   'team_position': 0,
#   'team_strength': 3,
#   'team_form': None,
#   'short_name': 'TOT',
#   'team_code': 6},
#  {'team_id': 19,
#   'team_name': 'West Ham',
#   'team_played': 0,
#   'win': 0,
#   'loss': 0,
#   'draw': 0,
#   'team_position': 0,
#   'team_strength': 3,
#   'team_form': None,
#   'short_name': 'WHU',
#   'team_code': 21},
#  {'team_id': 20,
#   'team_name': 'Wolves',
#   'team_played': 0,
#   'win': 0,
#   'loss': 0,
#   'draw': 0,
#   'team_position': 0,
#   'team_strength': 3,
#   'team_form': None,
#   'short_name': 'WOL',
#   'team_code': 39}]

# %%
team_df = pd.DataFrame.from_dict(team_list)

# %%
team_df.head(20)
# Out:
#     team_id       team_name  team_played  win  loss  draw  team_position  \
# 0         1         Arsenal            0    0     0     0              0
# 1         2     Aston Villa            0    0     0     0              0
# 2         3     Bournemouth            0    0     0     0              0
# 3         4       Brentford            0    0     0     0              0
# 4         5        Brighton            0    0     0     0              0
# 5         6         Burnley            0    0     0     0              0
# 6         7         Chelsea            0    0     0     0              0
# 7         8  Crystal Palace            0    0     0     0              0
# 8         9         Everton            0    0     0     0              0
# 9        10          Fulham            0    0     0     0              0
# 10       11       Liverpool            0    0     0     0              0
# 11       12           Luton            0    0     0     0              0
# 12       13        Man City            0    0     0     0              0
# 13       14         Man Utd            0    0     0     0              0
# 14       15       Newcastle            0    0     0     0              0
# 15       16   Nott'm Forest            0    0     0     0              0
# 16       17   Sheffield Utd            0    0     0     0              0
# 17       18           Spurs            0    0     0     0              0
# 18       19        West Ham            0    0     0     0              0
# 19       20          Wolves            0    0     0     0              0
#
#     team_strength team_form short_name  team_code
# 0               4      None        ARS          3
# 1               3      None        AVL          7
# 2               3      None        BOU         91
# 3               3      None        BRE         94
# 4               3      None        BHA         36
# 5               2      None        BUR         90
# 6               3      None        CHE          8
# 7               3      None        CRY         31
# 8               3      None        EVE         11
# 9               3      None        FUL         54
# 10              4      None        LIV         14
# 11              2      None        LUT        102
# 12              5      None        MCI         43
# 13              4      None        MUN          1
# 14              4      None        NEW          4
# 15              3      None        NFO         17
# 16              2      None        SHU         49
# 17              3      None        TOT          6
# 18              3      None        WHU         21
# 19              3      None        WOL         39

# %%
#team data
data['teams']
# Out:
# [{'code': 3,
#   'draw': 0,
#   'form': None,
#   'id': 1,
#   'loss': 0,
#   'name': 'Arsenal',
#   'played': 0,
#   'points': 0,
#   'position': 0,
#   'short_name': 'ARS',
#   'strength': 4,
#   'team_division': None,
#   'unavailable': False,
#   'win': 0,
#   'strength_overall_home': 1230,
#   'strength_overall_away': 1285,
#   'strength_attack_home': 1250,
#   'strength_attack_away': 1250,
#   'strength_defence_home': 1210,
#   'strength_defence_away': 1320,
#   'pulse_id': 1},
#  {'code': 7,
#   'draw': 0,
#   'form': None,
#   'id': 2,
#   'loss': 0,
#   'name': 'Aston Villa',
#   'played': 0,
#   'points': 0,
#   'position': 0,
#   'short_name': 'AVL',
#   'strength': 3,
#   'team_division': None,
#   'unavailable': False,
#   'win': 0,
#   'strength_overall_home': 1115,
#   'strength_overall_away': 1175,
#   'strength_attack_home': 1130,
#   'strength_attack_away': 1190,
#   'strength_defence_home': 1100,
#   'strength_defence_away': 1160,
#   'pulse_id': 2},
#  {'code': 91,
#   'draw': 0,
#   'form': None,
#   'id': 3,
#   'loss': 0,
#   'name': 'Bournemouth',
#   'played': 0,
#   'points': 0,
#   'position': 0,
#   'short_name': 'BOU',
#   'strength': 3,
#   'team_division': None,
#   'unavailable': False,
#   'win': 0,
#   'strength_overall_home': 1060,
#   'strength_overall_away': 1095,
#   'strength_attack_home': 1050,
#   'strength_attack_away': 1100,
#   'strength_defence_home': 1060,
#   'strength_defence_away': 1090,
#   'pulse_id': 127},
#  {'code': 94,
#   'draw': 0,
#   'form': None,
#   'id': 4,
#   'loss': 0,
#   'name': 'Brentford',
#   'played': 0,
#   'points': 0,
#   'position': 0,
#   'short_name': 'BRE',
#   'strength': 3,
#   'team_division': None,
#   'unavailable': False,
#   'win': 0,
#   'strength_overall_home': 1125,
#   'strength_overall_away': 1205,
#   'strength_attack_home': 1120,
#   'strength_attack_away': 1220,
#   'strength_defence_home': 1130,
#   'strength_defence_away': 1190,
#   'pulse_id': 130},
#  {'code': 36,
#   'draw': 0,
#   'form': None,
#   'id': 5,
#   'loss': 0,
#   'name': 'Brighton',
#   'played': 0,
#   'points': 0,
#   'position': 0,
#   'short_name': 'BHA',
#   'strength': 3,
#   'team_division': None,
#   'unavailable': False,
#   'win': 0,
#   'strength_overall_home': 1165,
#   'strength_overall_away': 1210,
#   'strength_attack_home': 1120,
#   'strength_attack_away': 1200,
#   'strength_defence_home': 1210,
#   'strength_defence_away': 1240,
#   'pulse_id': 131},
#  {'code': 90,
#   'draw': 0,
#   'form': None,
#   'id': 6,
#   'loss': 0,
#   'name': 'Burnley',
#   'played': 0,
#   'points': 0,
#   'position': 0,
#   'short_name': 'BUR',
#   'strength': 2,
#   'team_division': None,
#   'unavailable': False,
#   'win': 0,
#   'strength_overall_home': 1060,
#   'strength_overall_away': 1080,
#   'strength_attack_home': 1060,
#   'strength_attack_away': 1080,
#   'strength_defence_home': 1060,
#   'strength_defence_away': 1080,
#   'pulse_id': 43},
#  {'code': 8,
#   'draw': 0,
#   'form': None,
#   'id': 7,
#   'loss': 0,
#   'name': 'Chelsea',
#   'played': 0,
#   'points': 0,
#   'position': 0,
#   'short_name': 'CHE',
#   'strength': 3,
#   'team_division': None,
#   'unavailable': False,
#   'win': 0,
#   'strength_overall_home': 1115,
#   'strength_overall_away': 1160,
#   'strength_attack_home': 1130,
#   'strength_attack_away': 1210,
#   'strength_defence_home': 1100,
#   'strength_defence_away': 1110,
#   'pulse_id': 4},
#  {'code': 31,
#   'draw': 0,
#   'form': None,
#   'id': 8,
#   'loss': 0,
#   'name': 'Crystal Palace',
#   'played': 0,
#   'points': 0,
#   'position': 0,
#   'short_name': 'CRY',
#   'strength': 3,
#   'team_division': None,
#   'unavailable': False,
#   'win': 0,
#   'strength_overall_home': 1100,
#   'strength_overall_away': 1100,
#   'strength_attack_home': 1140,
#   'strength_attack_away': 1170,
#   'strength_defence_home': 1080,
#   'strength_defence_away': 1085,
#   'pulse_id': 6},
#  {'code': 11,
#   'draw': 0,
#   'form': None,
#   'id': 9,
#   'loss': 0,
#   'name': 'Everton',
#   'played': 0,
#   'points': 0,
#   'position': 0,
#   'short_name': 'EVE',
#   'strength': 3,
#   'team_division': None,
#   'unavailable': False,
#   'win': 0,
#   'strength_overall_home': 1075,
#   'strength_overall_away': 1100,
#   'strength_attack_home': 1070,
#   'strength_attack_away': 1120,
#   'strength_defence_home': 1080,
#   'strength_defence_away': 1080,
#   'pulse_id': 7},
#  {'code': 54,
#   'draw': 0,
#   'form': None,
#   'id': 10,
#   'loss': 0,
#   'name': 'Fulham',
#   'played': 0,
#   'points': 0,
#   'position': 0,
#   'short_name': 'FUL',
#   'strength': 3,
#   'team_division': None,
#   'unavailable': False,
#   'win': 0,
#   'strength_overall_home': 1095,
#   'strength_overall_away': 1100,
#   'strength_attack_home': 1090,
#   'strength_attack_away': 1090,
#   'strength_defence_home': 1100,
#   'strength_defence_away': 1140,
#   'pulse_id': 34},
#  {'code': 14,
#   'draw': 0,
#   'form': None,
#   'id': 11,
#   'loss': 0,
#   'name': 'Liverpool',
#   'played': 0,
#   'points': 0,
#   'position': 0,
#   'short_name': 'LIV',
#   'strength': 4,
#   'team_division': None,
#   'unavailable': False,
#   'win': 0,
#   'strength_overall_home': 1220,
#   'strength_overall_away': 1285,
#   'strength_attack_home': 1170,
#   'strength_attack_away': 1270,
#   'strength_defence_home': 1260,
#   'strength_defence_away': 1300,
#   'pulse_id': 10},
#  {'code': 102,
#   'draw': 0,
#   'form': None,
#   'id': 12,
#   'loss': 0,
#   'name': 'Luton',
#   'played': 0,
#   'points': 0,
#   'position': 0,
#   'short_name': 'LUT',
#   'strength': 2,
#   'team_division': None,
#   'unavailable': False,
#   'win': 0,
#   'strength_overall_home': 1045,
#   'strength_overall_away': 1050,
#   'strength_attack_home': 1050,
#   'strength_attack_away': 1050,
#   'strength_defence_home': 1040,
#   'strength_defence_away': 1050,
#   'pulse_id': 163},
#  {'code': 43,
#   'draw': 0,
#   'form': None,
#   'id': 13,
#   'loss': 0,
#   'name': 'Man City',
#   'played': 0,
#   'points': 0,
#   'position': 0,
#   'short_name': 'MCI',
#   'strength': 5,
#   'team_division': None,
#   'unavailable': False,
#   'win': 0,
#   'strength_overall_home': 1350,
#   'strength_overall_away': 1355,
#   'strength_attack_home': 1320,
#   'strength_attack_away': 1340,
#   'strength_defence_home': 1320,
#   'strength_defence_away': 1370,
#   'pulse_id': 11},
#  {'code': 1,
#   'draw': 0,
#   'form': None,
#   'id': 14,
#   'loss': 0,
#   'name': 'Man Utd',
#   'played': 0,
#   'points': 0,
#   'position': 0,
#   'short_name': 'MUN',
#   'strength': 4,
#   'team_division': None,
#   'unavailable': False,
#   'win': 0,
#   'strength_overall_home': 1145,
#   'strength_overall_away': 1275,
#   'strength_attack_home': 1150,
#   'strength_attack_away': 1310,
#   'strength_defence_home': 1140,
#   'strength_defence_away': 1240,
#   'pulse_id': 12},
#  {'code': 4,
#   'draw': 0,
#   'form': None,
#   'id': 15,
#   'loss': 0,
#   'name': 'Newcastle',
#   'played': 0,
#   'points': 0,
#   'position': 0,
#   'short_name': 'NEW',
#   'strength': 4,
#   'team_division': None,
#   'unavailable': False,
#   'win': 0,
#   'strength_overall_home': 1220,
#   'strength_overall_away': 1280,
#   'strength_attack_home': 1250,
#   'strength_attack_away': 1310,
#   'strength_defence_home': 1190,
#   'strength_defence_away': 1250,
#   'pulse_id': 23},
#  {'code': 17,
#   'draw': 0,
#   'form': None,
#   'id': 16,
#   'loss': 0,
#   'name': "Nott'm Forest",
#   'played': 0,
#   'points': 0,
#   'position': 0,
#   'short_name': 'NFO',
#   'strength': 3,
#   'team_division': None,
#   'unavailable': False,
#   'win': 0,
#   'strength_overall_home': 1050,
#   'strength_overall_away': 1100,
#   'strength_attack_home': 1050,
#   'strength_attack_away': 1110,
#   'strength_defence_home': 1050,
#   'strength_defence_away': 1120,
#   'pulse_id': 15},
#  {'code': 49,
#   'draw': 0,
#   'form': None,
#   'id': 17,
#   'loss': 0,
#   'name': 'Sheffield Utd',
#   'played': 0,
#   'points': 0,
#   'position': 0,
#   'short_name': 'SHU',
#   'strength': 2,
#   'team_division': None,
#   'unavailable': False,
#   'win': 0,
#   'strength_overall_home': 1045,
#   'strength_overall_away': 1070,
#   'strength_attack_home': 1050,
#   'strength_attack_away': 1060,
#   'strength_defence_home': 1040,
#   'strength_defence_away': 1080,
#   'pulse_id': 18},
#  {'code': 6,
#   'draw': 0,
#   'form': None,
#   'id': 18,
#   'loss': 0,
#   'name': 'Spurs',
#   'played': 0,
#   'points': 0,
#   'position': 0,
#   'short_name': 'TOT',
#   'strength': 3,
#   'team_division': None,
#   'unavailable': False,
#   'win': 0,
#   'strength_overall_home': 1130,
#   'strength_overall_away': 1200,
#   'strength_attack_home': 1110,
#   'strength_attack_away': 1200,
#   'strength_defence_home': 1150,
#   'strength_defence_away': 1200,
#   'pulse_id': 21},
#  {'code': 21,
#   'draw': 0,
#   'form': None,
#   'id': 19,
#   'loss': 0,
#   'name': 'West Ham',
#   'played': 0,
#   'points': 0,
#   'position': 0,
#   'short_name': 'WHU',
#   'strength': 3,
#   'team_division': None,
#   'unavailable': False,
#   'win': 0,
#   'strength_overall_home': 1095,
#   'strength_overall_away': 1140,
#   'strength_attack_home': 1100,
#   'strength_attack_away': 1150,
#   'strength_defence_home': 1090,
#   'strength_defence_away': 1130,
#   'pulse_id': 25},
#  {'code': 39,
#   'draw': 0,
#   'form': None,
#   'id': 20,
#   'loss': 0,
#   'name': 'Wolves',
#   'played': 0,
#   'points': 0,
#   'position': 0,
#   'short_name': 'WOL',
#   'strength': 3,
#   'team_division': None,
#   'unavailable': False,
#   'win': 0,
#   'strength_overall_home': 1065,
#   'strength_overall_away': 1100,
#   'strength_attack_home': 1070,
#   'strength_attack_away': 1160,
#   'strength_defence_home': 1060,
#   'strength_defence_away': 1080,
#   'pulse_id': 38}]

# %%
#Each Gameweek data
data['events']
# Out:
# [{'id': 1,
#   'name': 'Gameweek 1',
#   'deadline_time': '2023-08-11T17:30:00Z',
#   'average_entry_score': 64,
#   'finished': True,
#   'data_checked': True,
#   'highest_scoring_entry': 3383750,
#   'deadline_time_epoch': 1691775000,
#   'deadline_time_game_offset': 0,
#   'highest_score': 127,
#   'is_previous': False,
#   'is_current': False,
#   'is_next': False,
#   'cup_leagues_created': False,
#   'h2h_ko_matches_created': False,
#   'chip_plays': [{'chip_name': 'bboost', 'num_played': 163222},
#    {'chip_name': '3xc', 'num_played': 287198}],
#   'most_selected': 355,
#   'most_transferred_in': 1,
#   'top_element': 395,
#   'top_element_info': {'id': 395, 'points': 14},
#   'transfers_made': 0,
#   'most_captained': 355,
#   'most_vice_captained': 19},
#  {'id': 2,
#   'name': 'Gameweek 2',
#   'deadline_time': '2023-08-18T17:15:00Z',
#   'average_entry_score': 44,
#   'finished': True,
#   'data_checked': True,
#   'highest_scoring_entry': 3338487,
#   'deadline_time_epoch': 1692378900,
#   'deadline_time_game_offset': 0,
#   'highest_score': 120,
#   'is_previous': False,
#   'is_current': False,
#   'is_next': False,
#   'cup_leagues_created': True,
#   'h2h_ko_matches_created': True,
#   'chip_plays': [{'chip_name': 'bboost', 'num_played': 126778},
#    {'chip_name': 'freehit', 'num_played': 112568},
#    {'chip_name': 'wildcard', 'num_played': 244166},
#    {'chip_name': '3xc', 'num_played': 213828}],
#   'most_selected': 355,
#   'most_transferred_in': 195,
#   'top_element': 108,
#   'top_element_info': {'id': 108, 'points': 16},
#   'transfers_made': 13130353,
#   'most_captained': 355,
#   'most_vice_captained': 19},
#  {'id': 3,
#   'name': 'Gameweek 3',
#   'deadline_time': '2023-08-25T17:30:00Z',
#   'average_entry_score': 44,
#   'finished': True,
#   'data_checked': True,
#   'highest_scoring_entry': 9368956,
#   'deadline_time_epoch': 1692984600,
#   'deadline_time_game_offset': 0,
#   'highest_score': 128,
#   'is_previous': False,
#   'is_current': False,
#   'is_next': False,
#   'cup_leagues_created': True,
#   'h2h_ko_matches_created': True,
#   'chip_plays': [{'chip_name': 'bboost', 'num_played': 124110},
#    {'chip_name': 'freehit', 'num_played': 111065},
#    {'chip_name': 'wildcard', 'num_played': 445328},
#    {'chip_name': '3xc', 'num_played': 245013}],
#   'most_selected': 355,
#   'most_transferred_in': 108,
#   'top_element': 216,
#   'top_element_info': {'id': 216, 'points': 19},
#   'transfers_made': 17619532,
#   'most_captained': 355,
#   'most_vice_captained': 19},
#  {'id': 4,
#   'name': 'Gameweek 4',
#   'deadline_time': '2023-09-01T17:30:00Z',
#   'average_entry_score': 72,
#   'finished': True,
#   'data_checked': True,
#   'highest_scoring_entry': 4354697,
#   'deadline_time_epoch': 1693589400,
#   'deadline_time_game_offset': 0,
#   'highest_score': 148,
#   'is_previous': True,
#   'is_current': False,
#   'is_next': False,
#   'cup_leagues_created': True,
#   'h2h_ko_matches_created': True,
#   'chip_plays': [{'chip_name': 'bboost', 'num_played': 109196},
#    {'chip_name': 'freehit', 'num_played': 119294},
#    {'chip_name': 'wildcard', 'num_played': 406918},
#    {'chip_name': '3xc', 'num_played': 164388}],
#   'most_selected': 355,
#   'most_transferred_in': 216,
#   'top_element': 516,
#   'top_element_info': {'id': 516, 'points': 20},
#   'transfers_made': 16035365,
#   'most_captained': 355,
#   'most_vice_captained': 19},
#  {'id': 5,
#   'name': 'Gameweek 5',
#   'deadline_time': '2023-09-16T10:00:00Z',
#   'average_entry_score': 29,
#   'finished': False,
#   'data_checked': False,
#   'highest_scoring_entry': 6637820,
#   'deadline_time_epoch': 1694858400,
#   'deadline_time_game_offset': 0,
#   'highest_score': 88,
#   'is_previous': False,
#   'is_current': True,
#   'is_next': False,
#   'cup_leagues_created': True,
#   'h2h_ko_matches_created': True,
#   'chip_plays': [{'chip_name': 'bboost', 'num_played': 96469},
#    {'chip_name': 'freehit', 'num_played': 81067},
#    {'chip_name': 'wildcard', 'num_played': 387941},
#    {'chip_name': '3xc', 'num_played': 123443}],
#   'most_selected': 355,
#   'most_transferred_in': 516,
#   'top_element': 344,
#   'top_element_info': {'id': 344, 'points': 13},
#   'transfers_made': 14363988,
#   'most_captained': 355,
#   'most_vice_captained': 19},
#  {'id': 6,
#   'name': 'Gameweek 6',
#   'deadline_time': '2023-09-23T12:30:00Z',
#   'average_entry_score': 0,
#   'finished': False,
#   'data_checked': False,
#   'highest_scoring_entry': None,
#   'deadline_time_epoch': 1695472200,
#   'deadline_time_game_offset': 0,
#   'highest_score': None,
#   'is_previous': False,
#   'is_current': False,
#   'is_next': True,
#   'cup_leagues_created': False,
#   'h2h_ko_matches_created': False,
#   'chip_plays': [],
#   'most_selected': None,
#   'most_transferred_in': None,
#   'top_element': None,
#   'top_element_info': None,
#   'transfers_made': 0,
#   'most_captained': None,
#   'most_vice_captained': None},
#  {'id': 7,
#   'name': 'Gameweek 7',
#   'deadline_time': '2023-09-30T10:00:00Z',
#   'average_entry_score': 0,
#   'finished': False,
#   'data_checked': False,
#   'highest_scoring_entry': None,
#   'deadline_time_epoch': 1696068000,
#   'deadline_time_game_offset': 0,
#   'highest_score': None,
#   'is_previous': False,
#   'is_current': False,
#   'is_next': False,
#   'cup_leagues_created': False,
#   'h2h_ko_matches_created': False,
#   'chip_plays': [],
#   'most_selected': None,
#   'most_transferred_in': None,
#   'top_element': None,
#   'top_element_info': None,
#   'transfers_made': 0,
#   'most_captained': None,
#   'most_vice_captained': None},
#  {'id': 8,
#   'name': 'Gameweek 8',
#   'deadline_time': '2023-10-07T10:00:00Z',
#   'average_entry_score': 0,
#   'finished': False,
#   'data_checked': False,
#   'highest_scoring_entry': None,
#   'deadline_time_epoch': 1696672800,
#   'deadline_time_game_offset': 0,
#   'highest_score': None,
#   'is_previous': False,
#   'is_current': False,
#   'is_next': False,
#   'cup_leagues_created': False,
#   'h2h_ko_matches_created': False,
#   'chip_plays': [],
#   'most_selected': None,
#   'most_transferred_in': None,
#   'top_element': None,
#   'top_element_info': None,
#   'transfers_made': 0,
#   'most_captained': None,
#   'most_vice_captained': None},
#  {'id': 9,
#   'name': 'Gameweek 9',
#   'deadline_time': '2023-10-21T10:00:00Z',
#   'average_entry_score': 0,
#   'finished': False,
#   'data_checked': False,
#   'highest_scoring_entry': None,
#   'deadline_time_epoch': 1697882400,
#   'deadline_time_game_offset': 0,
#   'highest_score': None,
#   'is_previous': False,
#   'is_current': False,
#   'is_next': False,
#   'cup_leagues_created': False,
#   'h2h_ko_matches_created': False,
#   'chip_plays': [],
#   'most_selected': None,
#   'most_transferred_in': None,
#   'top_element': None,
#   'top_element_info': None,
#   'transfers_made': 0,
#   'most_captained': None,
#   'most_vice_captained': None},
#  {'id': 10,
#   'name': 'Gameweek 10',
#   'deadline_time': '2023-10-27T17:30:00Z',
#   'average_entry_score': 0,
#   'finished': False,
#   'data_checked': False,
#   'highest_scoring_entry': None,
#   'deadline_time_epoch': 1698427800,
#   'deadline_time_game_offset': 0,
#   'highest_score': None,
#   'is_previous': False,
#   'is_current': False,
#   'is_next': False,
#   'cup_leagues_created': False,
#   'h2h_ko_matches_created': False,
#   'chip_plays': [],
#   'most_selected': None,
#   'most_transferred_in': None,
#   'top_element': None,
#   'top_element_info': None,
#   'transfers_made': 0,
#   'most_captained': None,
#   'most_vice_captained': None},
#  {'id': 11,
#   'name': 'Gameweek 11',
#   'deadline_time': '2023-11-04T11:00:00Z',
#   'average_entry_score': 0,
#   'finished': False,
#   'data_checked': False,
#   'highest_scoring_entry': None,
#   'deadline_time_epoch': 1699095600,
#   'deadline_time_game_offset': 0,
#   'highest_score': None,
#   'is_previous': False,
#   'is_current': False,
#   'is_next': False,
#   'cup_leagues_created': False,
#   'h2h_ko_matches_created': False,
#   'chip_plays': [],
#   'most_selected': None,
#   'most_transferred_in': None,
#   'top_element': None,
#   'top_element_info': None,
#   'transfers_made': 0,
#   'most_captained': None,
#   'most_vice_captained': None},
#  {'id': 12,
#   'name': 'Gameweek 12',
#   'deadline_time': '2023-11-11T11:00:00Z',
#   'average_entry_score': 0,
#   'finished': False,
#   'data_checked': False,
#   'highest_scoring_entry': None,
#   'deadline_time_epoch': 1699700400,
#   'deadline_time_game_offset': 0,
#   'highest_score': None,
#   'is_previous': False,
#   'is_current': False,
#   'is_next': False,
#   'cup_leagues_created': False,
#   'h2h_ko_matches_created': False,
#   'chip_plays': [],
#   'most_selected': None,
#   'most_transferred_in': None,
#   'top_element': None,
#   'top_element_info': None,
#   'transfers_made': 0,
#   'most_captained': None,
#   'most_vice_captained': None},
#  {'id': 13,
#   'name': 'Gameweek 13',
#   'deadline_time': '2023-11-25T13:30:00Z',
#   'average_entry_score': 0,
#   'finished': False,
#   'data_checked': False,
#   'highest_scoring_entry': None,
#   'deadline_time_epoch': 1700919000,
#   'deadline_time_game_offset': 0,
#   'highest_score': None,
#   'is_previous': False,
#   'is_current': False,
#   'is_next': False,
#   'cup_leagues_created': False,
#   'h2h_ko_matches_created': False,
#   'chip_plays': [],
#   'most_selected': None,
#   'most_transferred_in': None,
#   'top_element': None,
#   'top_element_info': None,
#   'transfers_made': 0,
#   'most_captained': None,
#   'most_vice_captained': None},
#  {'id': 14,
#   'name': 'Gameweek 14',
#   'deadline_time': '2023-12-02T13:30:00Z',
#   'average_entry_score': 0,
#   'finished': False,
#   'data_checked': False,
#   'highest_scoring_entry': None,
#   'deadline_time_epoch': 1701523800,
#   'deadline_time_game_offset': 0,
#   'highest_score': None,
#   'is_previous': False,
#   'is_current': False,
#   'is_next': False,
#   'cup_leagues_created': False,
#   'h2h_ko_matches_created': False,
#   'chip_plays': [],
#   'most_selected': None,
#   'most_transferred_in': None,
#   'top_element': None,
#   'top_element_info': None,
#   'transfers_made': 0,
#   'most_captained': None,
#   'most_vice_captained': None},
#  {'id': 15,
#   'name': 'Gameweek 15',
#   'deadline_time': '2023-12-05T18:15:00Z',
#   'average_entry_score': 0,
#   'finished': False,
#   'data_checked': False,
#   'highest_scoring_entry': None,
#   'deadline_time_epoch': 1701800100,
#   'deadline_time_game_offset': 0,
#   'highest_score': None,
#   'is_previous': False,
#   'is_current': False,
#   'is_next': False,
#   'cup_leagues_created': False,
#   'h2h_ko_matches_created': False,
#   'chip_plays': [],
#   'most_selected': None,
#   'most_transferred_in': None,
#   'top_element': None,
#   'top_element_info': None,
#   'transfers_made': 0,
#   'most_captained': None,
#   'most_vice_captained': None},
#  {'id': 16,
#   'name': 'Gameweek 16',
#   'deadline_time': '2023-12-09T13:30:00Z',
#   'average_entry_score': 0,
#   'finished': False,
#   'data_checked': False,
#   'highest_scoring_entry': None,
#   'deadline_time_epoch': 1702128600,
#   'deadline_time_game_offset': 0,
#   'highest_score': None,
#   'is_previous': False,
#   'is_current': False,
#   'is_next': False,
#   'cup_leagues_created': False,
#   'h2h_ko_matches_created': False,
#   'chip_plays': [],
#   'most_selected': None,
#   'most_transferred_in': None,
#   'top_element': None,
#   'top_element_info': None,
#   'transfers_made': 0,
#   'most_captained': None,
#   'most_vice_captained': None},
#  {'id': 17,
#   'name': 'Gameweek 17',
#   'deadline_time': '2023-12-16T13:30:00Z',
#   'average_entry_score': 0,
#   'finished': False,
#   'data_checked': False,
#   'highest_scoring_entry': None,
#   'deadline_time_epoch': 1702733400,
#   'deadline_time_game_offset': 0,
#   'highest_score': None,
#   'is_previous': False,
#   'is_current': False,
#   'is_next': False,
#   'cup_leagues_created': False,
#   'h2h_ko_matches_created': False,
#   'chip_plays': [],
#   'most_selected': None,
#   'most_transferred_in': None,
#   'top_element': None,
#   'top_element_info': None,
#   'transfers_made': 0,
#   'most_captained': None,
#   'most_vice_captained': None},
#  {'id': 18,
#   'name': 'Gameweek 18',
#   'deadline_time': '2023-12-23T13:30:00Z',
#   'average_entry_score': 0,
#   'finished': False,
#   'data_checked': False,
#   'highest_scoring_entry': None,
#   'deadline_time_epoch': 1703338200,
#   'deadline_time_game_offset': 0,
#   'highest_score': None,
#   'is_previous': False,
#   'is_current': False,
#   'is_next': False,
#   'cup_leagues_created': False,
#   'h2h_ko_matches_created': False,
#   'chip_plays': [],
#   'most_selected': None,
#   'most_transferred_in': None,
#   'top_element': None,
#   'top_element_info': None,
#   'transfers_made': 0,
#   'most_captained': None,
#   'most_vice_captained': None},
#  {'id': 19,
#   'name': 'Gameweek 19',
#   'deadline_time': '2023-12-26T13:30:00Z',
#   'average_entry_score': 0,
#   'finished': False,
#   'data_checked': False,
#   'highest_scoring_entry': None,
#   'deadline_time_epoch': 1703597400,
#   'deadline_time_game_offset': 0,
#   'highest_score': None,
#   'is_previous': False,
#   'is_current': False,
#   'is_next': False,
#   'cup_leagues_created': False,
#   'h2h_ko_matches_created': False,
#   'chip_plays': [],
#   'most_selected': None,
#   'most_transferred_in': None,
#   'top_element': None,
#   'top_element_info': None,
#   'transfers_made': 0,
#   'most_captained': None,
#   'most_vice_captained': None},
#  {'id': 20,
#   'name': 'Gameweek 20',
#   'deadline_time': '2023-12-30T13:30:00Z',
#   'average_entry_score': 0,
#   'finished': False,
#   'data_checked': False,
#   'highest_scoring_entry': None,
#   'deadline_time_epoch': 1703943000,
#   'deadline_time_game_offset': 0,
#   'highest_score': None,
#   'is_previous': False,
#   'is_current': False,
#   'is_next': False,
#   'cup_leagues_created': False,
#   'h2h_ko_matches_created': False,
#   'chip_plays': [],
#   'most_selected': None,
#   'most_transferred_in': None,
#   'top_element': None,
#   'top_element_info': None,
#   'transfers_made': 0,
#   'most_captained': None,
#   'most_vice_captained': None},
#  {'id': 21,
#   'name': 'Gameweek 21',
#   'deadline_time': '2024-01-13T13:30:00Z',
#   'average_entry_score': 0,
#   'finished': False,
#   'data_checked': False,
#   'highest_scoring_entry': None,
#   'deadline_time_epoch': 1705152600,
#   'deadline_time_game_offset': 0,
#   'highest_score': None,
#   'is_previous': False,
#   'is_current': False,
#   'is_next': False,
#   'cup_leagues_created': False,
#   'h2h_ko_matches_created': False,
#   'chip_plays': [],
#   'most_selected': None,
#   'most_transferred_in': None,
#   'top_element': None,
#   'top_element_info': None,
#   'transfers_made': 0,
#   'most_captained': None,
#   'most_vice_captained': None},
#  {'id': 22,
#   'name': 'Gameweek 22',
#   'deadline_time': '2024-01-30T18:15:00Z',
#   'average_entry_score': 0,
#   'finished': False,
#   'data_checked': False,
#   'highest_scoring_entry': None,
#   'deadline_time_epoch': 1706638500,
#   'deadline_time_game_offset': 0,
#   'highest_score': None,
#   'is_previous': False,
#   'is_current': False,
#   'is_next': False,
#   'cup_leagues_created': False,
#   'h2h_ko_matches_created': False,
#   'chip_plays': [],
#   'most_selected': None,
#   'most_transferred_in': None,
#   'top_element': None,
#   'top_element_info': None,
#   'transfers_made': 0,
#   'most_captained': None,
#   'most_vice_captained': None},
#  {'id': 23,
#   'name': 'Gameweek 23',
#   'deadline_time': '2024-02-03T13:30:00Z',
#   'average_entry_score': 0,
#   'finished': False,
#   'data_checked': False,
#   'highest_scoring_entry': None,
#   'deadline_time_epoch': 1706967000,
#   'deadline_time_game_offset': 0,
#   'highest_score': None,
#   'is_previous': False,
#   'is_current': False,
#   'is_next': False,
#   'cup_leagues_created': False,
#   'h2h_ko_matches_created': False,
#   'chip_plays': [],
#   'most_selected': None,
#   'most_transferred_in': None,
#   'top_element': None,
#   'top_element_info': None,
#   'transfers_made': 0,
#   'most_captained': None,
#   'most_vice_captained': None},
#  {'id': 24,
#   'name': 'Gameweek 24',
#   'deadline_time': '2024-02-10T13:30:00Z',
#   'average_entry_score': 0,
#   'finished': False,
#   'data_checked': False,
#   'highest_scoring_entry': None,
#   'deadline_time_epoch': 1707571800,
#   'deadline_time_game_offset': 0,
#   'highest_score': None,
#   'is_previous': False,
#   'is_current': False,
#   'is_next': False,
#   'cup_leagues_created': False,
#   'h2h_ko_matches_created': False,
#   'chip_plays': [],
#   'most_selected': None,
#   'most_transferred_in': None,
#   'top_element': None,
#   'top_element_info': None,
#   'transfers_made': 0,
#   'most_captained': None,
#   'most_vice_captained': None},
#  {'id': 25,
#   'name': 'Gameweek 25',
#   'deadline_time': '2024-02-17T13:30:00Z',
#   'average_entry_score': 0,
#   'finished': False,
#   'data_checked': False,
#   'highest_scoring_entry': None,
#   'deadline_time_epoch': 1708176600,
#   'deadline_time_game_offset': 0,
#   'highest_score': None,
#   'is_previous': False,
#   'is_current': False,
#   'is_next': False,
#   'cup_leagues_created': False,
#   'h2h_ko_matches_created': False,
#   'chip_plays': [],
#   'most_selected': None,
#   'most_transferred_in': None,
#   'top_element': None,
#   'top_element_info': None,
#   'transfers_made': 0,
#   'most_captained': None,
#   'most_vice_captained': None},
#  {'id': 26,
#   'name': 'Gameweek 26',
#   'deadline_time': '2024-02-24T13:30:00Z',
#   'average_entry_score': 0,
#   'finished': False,
#   'data_checked': False,
#   'highest_scoring_entry': None,
#   'deadline_time_epoch': 1708781400,
#   'deadline_time_game_offset': 0,
#   'highest_score': None,
#   'is_previous': False,
#   'is_current': False,
#   'is_next': False,
#   'cup_leagues_created': False,
#   'h2h_ko_matches_created': False,
#   'chip_plays': [],
#   'most_selected': None,
#   'most_transferred_in': None,
#   'top_element': None,
#   'top_element_info': None,
#   'transfers_made': 0,
#   'most_captained': None,
#   'most_vice_captained': None},
#  {'id': 27,
#   'name': 'Gameweek 27',
#   'deadline_time': '2024-03-02T13:30:00Z',
#   'average_entry_score': 0,
#   'finished': False,
#   'data_checked': False,
#   'highest_scoring_entry': None,
#   'deadline_time_epoch': 1709386200,
#   'deadline_time_game_offset': 0,
#   'highest_score': None,
#   'is_previous': False,
#   'is_current': False,
#   'is_next': False,
#   'cup_leagues_created': False,
#   'h2h_ko_matches_created': False,
#   'chip_plays': [],
#   'most_selected': None,
#   'most_transferred_in': None,
#   'top_element': None,
#   'top_element_info': None,
#   'transfers_made': 0,
#   'most_captained': None,
#   'most_vice_captained': None},
#  {'id': 28,
#   'name': 'Gameweek 28',
#   'deadline_time': '2024-03-09T13:30:00Z',
#   'average_entry_score': 0,
#   'finished': False,
#   'data_checked': False,
#   'highest_scoring_entry': None,
#   'deadline_time_epoch': 1709991000,
#   'deadline_time_game_offset': 0,
#   'highest_score': None,
#   'is_previous': False,
#   'is_current': False,
#   'is_next': False,
#   'cup_leagues_created': False,
#   'h2h_ko_matches_created': False,
#   'chip_plays': [],
#   'most_selected': None,
#   'most_transferred_in': None,
#   'top_element': None,
#   'top_element_info': None,
#   'transfers_made': 0,
#   'most_captained': None,
#   'most_vice_captained': None},
#  {'id': 29,
#   'name': 'Gameweek 29',
#   'deadline_time': '2024-03-16T13:30:00Z',
#   'average_entry_score': 0,
#   'finished': False,
#   'data_checked': False,
#   'highest_scoring_entry': None,
#   'deadline_time_epoch': 1710595800,
#   'deadline_time_game_offset': 0,
#   'highest_score': None,
#   'is_previous': False,
#   'is_current': False,
#   'is_next': False,
#   'cup_leagues_created': False,
#   'h2h_ko_matches_created': False,
#   'chip_plays': [],
#   'most_selected': None,
#   'most_transferred_in': None,
#   'top_element': None,
#   'top_element_info': None,
#   'transfers_made': 0,
#   'most_captained': None,
#   'most_vice_captained': None},
#  {'id': 30,
#   'name': 'Gameweek 30',
#   'deadline_time': '2024-03-30T13:30:00Z',
#   'average_entry_score': 0,
#   'finished': False,
#   'data_checked': False,
#   'highest_scoring_entry': None,
#   'deadline_time_epoch': 1711805400,
#   'deadline_time_game_offset': 0,
#   'highest_score': None,
#   'is_previous': False,
#   'is_current': False,
#   'is_next': False,
#   'cup_leagues_created': False,
#   'h2h_ko_matches_created': False,
#   'chip_plays': [],
#   'most_selected': None,
#   'most_transferred_in': None,
#   'top_element': None,
#   'top_element_info': None,
#   'transfers_made': 0,
#   'most_captained': None,
#   'most_vice_captained': None},
#  {'id': 31,
#   'name': 'Gameweek 31',
#   'deadline_time': '2024-04-02T17:15:00Z',
#   'average_entry_score': 0,
#   'finished': False,
#   'data_checked': False,
#   'highest_scoring_entry': None,
#   'deadline_time_epoch': 1712078100,
#   'deadline_time_game_offset': 0,
#   'highest_score': None,
#   'is_previous': False,
#   'is_current': False,
#   'is_next': False,
#   'cup_leagues_created': False,
#   'h2h_ko_matches_created': False,
#   'chip_plays': [],
#   'most_selected': None,
#   'most_transferred_in': None,
#   'top_element': None,
#   'top_element_info': None,
#   'transfers_made': 0,
#   'most_captained': None,
#   'most_vice_captained': None},
#  {'id': 32,
#   'name': 'Gameweek 32',
#   'deadline_time': '2024-04-06T12:30:00Z',
#   'average_entry_score': 0,
#   'finished': False,
#   'data_checked': False,
#   'highest_scoring_entry': None,
#   'deadline_time_epoch': 1712406600,
#   'deadline_time_game_offset': 0,
#   'highest_score': None,
#   'is_previous': False,
#   'is_current': False,
#   'is_next': False,
#   'cup_leagues_created': False,
#   'h2h_ko_matches_created': False,
#   'chip_plays': [],
#   'most_selected': None,
#   'most_transferred_in': None,
#   'top_element': None,
#   'top_element_info': None,
#   'transfers_made': 0,
#   'most_captained': None,
#   'most_vice_captained': None},
#  {'id': 33,
#   'name': 'Gameweek 33',
#   'deadline_time': '2024-04-13T12:30:00Z',
#   'average_entry_score': 0,
#   'finished': False,
#   'data_checked': False,
#   'highest_scoring_entry': None,
#   'deadline_time_epoch': 1713011400,
#   'deadline_time_game_offset': 0,
#   'highest_score': None,
#   'is_previous': False,
#   'is_current': False,
#   'is_next': False,
#   'cup_leagues_created': False,
#   'h2h_ko_matches_created': False,
#   'chip_plays': [],
#   'most_selected': None,
#   'most_transferred_in': None,
#   'top_element': None,
#   'top_element_info': None,
#   'transfers_made': 0,
#   'most_captained': None,
#   'most_vice_captained': None},
#  {'id': 34,
#   'name': 'Gameweek 34',
#   'deadline_time': '2024-04-20T12:30:00Z',
#   'average_entry_score': 0,
#   'finished': False,
#   'data_checked': False,
#   'highest_scoring_entry': None,
#   'deadline_time_epoch': 1713616200,
#   'deadline_time_game_offset': 0,
#   'highest_score': None,
#   'is_previous': False,
#   'is_current': False,
#   'is_next': False,
#   'cup_leagues_created': False,
#   'h2h_ko_matches_created': False,
#   'chip_plays': [],
#   'most_selected': None,
#   'most_transferred_in': None,
#   'top_element': None,
#   'top_element_info': None,
#   'transfers_made': 0,
#   'most_captained': None,
#   'most_vice_captained': None},
#  {'id': 35,
#   'name': 'Gameweek 35',
#   'deadline_time': '2024-04-27T12:30:00Z',
#   'average_entry_score': 0,
#   'finished': False,
#   'data_checked': False,
#   'highest_scoring_entry': None,
#   'deadline_time_epoch': 1714221000,
#   'deadline_time_game_offset': 0,
#   'highest_score': None,
#   'is_previous': False,
#   'is_current': False,
#   'is_next': False,
#   'cup_leagues_created': False,
#   'h2h_ko_matches_created': False,
#   'chip_plays': [],
#   'most_selected': None,
#   'most_transferred_in': None,
#   'top_element': None,
#   'top_element_info': None,
#   'transfers_made': 0,
#   'most_captained': None,
#   'most_vice_captained': None},
#  {'id': 36,
#   'name': 'Gameweek 36',
#   'deadline_time': '2024-05-04T12:30:00Z',
#   'average_entry_score': 0,
#   'finished': False,
#   'data_checked': False,
#   'highest_scoring_entry': None,
#   'deadline_time_epoch': 1714825800,
#   'deadline_time_game_offset': 0,
#   'highest_score': None,
#   'is_previous': False,
#   'is_current': False,
#   'is_next': False,
#   'cup_leagues_created': False,
#   'h2h_ko_matches_created': False,
#   'chip_plays': [],
#   'most_selected': None,
#   'most_transferred_in': None,
#   'top_element': None,
#   'top_element_info': None,
#   'transfers_made': 0,
#   'most_captained': None,
#   'most_vice_captained': None},
#  {'id': 37,
#   'name': 'Gameweek 37',
#   'deadline_time': '2024-05-11T12:30:00Z',
#   'average_entry_score': 0,
#   'finished': False,
#   'data_checked': False,
#   'highest_scoring_entry': None,
#   'deadline_time_epoch': 1715430600,
#   'deadline_time_game_offset': 0,
#   'highest_score': None,
#   'is_previous': False,
#   'is_current': False,
#   'is_next': False,
#   'cup_leagues_created': False,
#   'h2h_ko_matches_created': False,
#   'chip_plays': [],
#   'most_selected': None,
#   'most_transferred_in': None,
#   'top_element': None,
#   'top_element_info': None,
#   'transfers_made': 0,
#   'most_captained': None,
#   'most_vice_captained': None},
#  {'id': 38,
#   'name': 'Gameweek 38',
#   'deadline_time': '2024-05-19T13:30:00Z',
#   'average_entry_score': 0,
#   'finished': False,
#   'data_checked': False,
#   'highest_scoring_entry': None,
#   'deadline_time_epoch': 1716125400,
#   'deadline_time_game_offset': 0,
#   'highest_score': None,
#   'is_previous': False,
#   'is_current': False,
#   'is_next': False,
#   'cup_leagues_created': False,
#   'h2h_ko_matches_created': False,
#   'chip_plays': [],
#   'most_selected': None,
#   'most_transferred_in': None,
#   'top_element': None,
#   'top_element_info': None,
#   'transfers_made': 0,
#   'most_captained': None,
#   'most_vice_captained': None}]

# %%
data['events']

# %%
base_url = 'https://fantasy.premierleague.com/api/event/8/live/' 
data2 = requests.get(base_url).json() 
pprint(data2, indent=2, depth=1, compact=True)
# Out:
# {'elements': [...]}

# %%
data2
# Out:
# {'elements': [{'id': 1,
#    'stats': {'minutes': 0,
#     'goals_scored': 0,
#     'assists': 0,
#     'clean_sheets': 0,
#     'goals_conceded': 0,
#     'own_goals': 0,
#     'penalties_saved': 0,
#     'penalties_missed': 0,
#     'yellow_cards': 0,
#     'red_cards': 0,
#     'saves': 0,
#     'bonus': 0,
#     'bps': 0,
#     'influence': '0.0',
#     'creativity': '0.0',
#     'threat': '0.0',
#     'ict_index': '0.0',
#     'starts': 0,
#     'expected_goals': '0.00',
#     'expected_assists': '0.00',
#     'expected_goal_involvements': '0.00',
#     'expected_goals_conceded': '0.00',
#     'total_points': 0,
#     'in_dreamteam': False},
#    'explain': [{'fixture': 71,
#      'stats': [{'identifier': 'minutes', 'points': 0, 'value': 0}]}]},
#   {'id': 2,
#    'stats': {'minutes': 0,
#     'goals_scored': 0,
#     'assists': 0,
#     'clean_sheets': 0,
#     'goals_conceded': 0,
#     'own_goals': 0,
#     'penalties_saved': 0,
#     'penalties_missed': 0,
#     'yellow_cards': 0,
#     'red_cards': 0,
#     'saves': 0,
#     'bonus': 0,
#     'bps': 0,
#     'influence': '0.0',
#     'creativity': '0.0',
#     'threat': '0.0',
#     'ict_index': '0.0',
#     'starts': 0,
#     'expected_goals': '0.00',
#     'expected_assists': '0.00',
#     'expected_goal_involvements': '0.00',
#     'expected_goals_conceded': '0.00',
#     'total_points': 0,
#     'in_dreamteam': False},
#    'explain': [{'fixture': 71,
#      'stats': [{'identifier': 'minutes', 'points': 0, 'value': 0}]}]},
#   {'id': 3,
#    'stats': {'minutes': 0,
#     'goals_scored': 0,
#     'assists': 0,
#     'clean_sheets': 0,
#     'goals_conceded': 0,
#     'own_goals': 0,
#     'penalties_saved': 0,
#     'penalties_missed': 0,
#     'yellow_cards': 0,
#     'red_cards': 0,
#     'saves': 0,
#     'bonus': 0,
#     'bps': 0,
#     'influence': '0.0',
#     'creativity': '0.0',
#     'threat': '0.0',
#     'ict_index': '0.0',
#     'starts': 0,
#     'expected_goals': '0.00',
#     'expected_assists': '0.00',
#     'expected_goal_involvements': '0.00',
#     'expected_goals_conceded': '0.00',
#     'total_points': 0,
#     'in_dreamteam': False},
#    'explain': [{'fixture': 71,
#      'stats': [{'identifier': 'minutes', 'points': 0, 'value': 0}]}]},
#   {'id': 4,
#    'stats': {'minutes': 0,
#     'goals_scored': 0,
#     'assists': 0,
#     'clean_sheets': 0,
#     'goals_conceded': 0,
#     'own_goals': 0,
#     'penalties_saved': 0,
#     'penalties_missed': 0,
#     'yellow_cards': 0,
#     'red_cards': 0,
#     'saves': 0,
#     'bonus': 0,
#     'bps': 0,
#     'influence': '0.0',
#     'creativity': '0.0',
#     'threat': '0.0',
#     'ict_index': '0.0',
#     'starts': 0,
#     'expected_goals': '0.00',
#     'expected_assists': '0.00',
#     'expected_goal_involvements': '0.00',
#     'expected_goals_conceded': '0.00',
#     'total_points': 0,
#     'in_dreamteam': False},
#    'explain': [{'fixture': 71,
#      'stats': [{'identifier': 'minutes', 'points': 0, 'value': 0}]}]},
#   {'id': 5,
#    'stats': {'minutes': 90,
#     'goals_scored': 0,
#     'assists': 0,
#     'clean_sheets': 1,
#     'goals_conceded': 0,
#     'own_goals': 0,
#     'penalties_saved': 0,
#     'penalties_missed': 0,
#     'yellow_cards': 0,
#     'red_cards': 0,
#     'saves': 0,
#     'bonus': 2,
#     'bps': 27,
#     'influence': '11.2',
#     'creativity': '1.3',
#     'threat': '0.0',
#     'ict_index': '1.3',
#     'starts': 1,
#     'expected_goals': '0.00',
#     'expected_assists': '0.00',
#     'expected_goal_involvements': '0.00',
#     'expected_goals_conceded': '0.55',
#     'total_points': 8,
#     'in_dreamteam': False},
#    'explain': [{'fixture': 71,
#      'stats': [{'identifier': 'minutes', 'points': 2, 'value': 90},
#       {'identifier': 'clean_sheets', 'points': 4, 'value': 1},
#       {'identifier': 'bonus', 'points': 2, 'value': 2}]}]},
#   {'id': 6,
#    'stats': {'minutes': 15,
#     'goals_scored': 0,
#     'assists': 1,
#     'clean_sheets': 0,
#     'goals_conceded': 0,
#     'own_goals': 0,
#     'penalties_saved': 0,
#     'penalties_missed': 0,
#     'yellow_cards': 0,
#     'red_cards': 0,
#     'saves': 0,
#     'bonus': 0,
#     'bps': 12,
#     'influence': '17.2',
#     'creativity': '11.4',
#     'threat': '6.0',
#     'ict_index': '3.5',
#     'starts': 0,
#     'expected_goals': '0.00',
#     'expected_assists': '0.03',
#     'expected_goal_involvements': '0.03',
#     'expected_goals_conceded': '0.00',
#     'total_points': 4,
#     'in_dreamteam': False},
#    'explain': [{'fixture': 71,
#      'stats': [{'identifier': 'minutes', 'points': 1, 'value': 15},
#       {'identifier': 'assists', 'points': 3, 'value': 1}]}]},
#   {'id': 7,
#    'stats': {'minutes': 0,
#     'goals_scored': 0,
#     'assists': 0,
#     'clean_sheets': 0,
#     'goals_conceded': 0,
#     'own_goals': 0,
#     'penalties_saved': 0,
#     'penalties_missed': 0,
#     'yellow_cards': 0,
#     'red_cards': 0,
#     'saves': 0,
#     'bonus': 0,
#     'bps': 0,
#     'influence': '0.0',
#     'creativity': '0.0',
#     'threat': '0.0',
#     'ict_index': '0.0',
#     'starts': 0,
#     'expected_goals': '0.00',
#     'expected_assists': '0.00',
#     'expected_goal_involvements': '0.00',
#     'expected_goals_conceded': '0.00',
#     'total_points': 0,
#     'in_dreamteam': False},
#    'explain': [{'fixture': 74,
#      'stats': [{'identifier': 'minutes', 'points': 0, 'value': 0}]}]},
#   {'id': 8,
#    'stats': {'minutes': 90,
#     'goals_scored': 0,
#     'assists': 0,
#     'clean_sheets': 1,
#     'goals_conceded': 0,
#     'own_goals': 0,
#     'penalties_saved': 0,
#     'penalties_missed': 0,
#     'yellow_cards': 1,
#     'red_cards': 0,
#     'saves': 0,
#     'bonus': 0,
#     'bps': -1,
#     'influence': '9.2',
#     'creativity': '8.2',
#     'threat': '17.0',
#     'ict_index': '3.4',
#     'starts': 1,
#     'expected_goals': '0.02',
#     'expected_assists': '0.05',
#     'expected_goal_involvements': '0.07',
#     'expected_goals_conceded': '0.55',
#     'total_points': 1,
#     'in_dreamteam': False},
#    'explain': [{'fixture': 71,
#      'stats': [{'identifier': 'minutes', 'points': 2, 'value': 90},
#       {'identifier': 'yellow_cards', 'points': -1, 'value': 1}]}]},
#   {'id': 9,
#    'stats': {'minutes': 74,
#     'goals_scored': 0,
#     'assists': 0,
#     'clean_sheets': 1,
#     'goals_conceded': 0,
#     'own_goals': 0,
#     'penalties_saved': 0,
#     'penalties_missed': 0,
#     'yellow_cards': 1,
#     'red_cards': 0,
#     'saves': 0,
#     'bonus': 0,
#     'bps': 9,
#     'influence': '4.2',
#     'creativity': '8.0',
#     'threat': '0.0',
#     'ict_index': '1.2',
#     'starts': 1,
#     'expected_goals': '0.00',
#     'expected_assists': '0.04',
#     'expected_goal_involvements': '0.04',
#     'expected_goals_conceded': '0.55',
#     'total_points': 2,
#     'in_dreamteam': False},
#    'explain': [{'fixture': 71,
#      'stats': [{'identifier': 'minutes', 'points': 2, 'value': 74},
#       {'identifier': 'clean_sheets', 'points': 1, 'value': 1},
#       {'identifier': 'yellow_cards', 'points': -1, 'value': 1}]}]},
#   {'id': 10,
#    'stats': {'minutes': 0,
#     'goals_scored': 0,
#     'assists': 0,
#     'clean_sheets': 0,
#     'goals_conceded': 0,
#     'own_goals': 0,
#     'penalties_saved': 0,
#     'penalties_missed': 0,
#     'yellow_cards': 0,
#     'red_cards': 0,
#     'saves': 0,
#     'bonus': 0,
#     'bps': 0,
#     'influence': '0.0',
#     'creativity': '0.0',
#     'threat': '0.0',
#     'ict_index': '0.0',
#     'starts': 0,
#     'expected_goals': '0.00',
#     'expected_assists': '0.00',
#     'expected_goal_involvements': '0.00',
#     'expected_goals_conceded': '0.00',
#     'total_points': 0,
#     'in_dreamteam': False},
#    'explain': [{'fixture': 71,
#      'stats': [{'identifier': 'minutes', 'points': 0, 'value': 0}]}]},
#   {'id': 11,
#    'stats': {'minutes': 0,
#     'goals_scored': 0,
#     'assists': 0,
#     'clean_sheets': 0,
#     'goals_conceded': 0,
#     'own_goals': 0,
#     'penalties_saved': 0,
#     'penalties_missed': 0,
#     'yellow_cards': 0,
#     'red_cards': 0,
#     'saves': 0,
#     'bonus': 0,
#     'bps': 0,
#     'influence': '0.0',
#     'creativity': '0.0',
#     'threat': '0.0',
#     'ict_index': '0.0',
#     'starts': 0,
#     'expected_goals': '0.00',
#     'expected_assists': '0.00',
#     'expected_goal_involvements': '0.00',
#     'expected_goals_conceded': '0.00',
#     'total_points': 0,
#     'in_dreamteam': False},
#    'explain': [{'fixture': 71,
#      'stats': [{'identifier': 'minutes', 'points': 0, 'value': 0}]}]},
#   {'id': 12,
#    'stats': {'minutes': 45,
#     'goals_scored': 1,
#     'assists': 0,
#     'clean_sheets': 0,
#     'goals_conceded': 0,
#     'own_goals': 0,
#     'penalties_saved': 0,
#     'penalties_missed': 0,
#     'yellow_cards': 0,
#     'red_cards': 0,
#     'saves': 0,
#     'bonus': 0,
#     'bps': 25,
#     'influence': '41.2',
#     'creativity': '11.5',
#     'threat': '24.0',
#     'ict_index': '7.7',
#     'starts': 0,
#     'expected_goals': '0.07',
#     'expected_assists': '0.01',
#     'expected_goal_involvements': '0.08',
#     'expected_goals_conceded': '0.14',
#     'total_points': 6,
#     'in_dreamteam': False},
#    'explain': [{'fixture': 71,
#      'stats': [{'identifier': 'minutes', 'points': 1, 'value': 45},
#       {'identifier': 'goals_scored', 'points': 5, 'value': 1}]}]},
#   {'id': 13,
#    'stats': {'minutes': 74,
#     'goals_scored': 0,
#     'assists': 0,
#     'clean_sheets': 1,
#     'goals_conceded': 0,
#     'own_goals': 0,
#     'penalties_saved': 0,
#     'penalties_missed': 0,
#     'yellow_cards': 0,
#     'red_cards': 0,
#     'saves': 0,
#     'bonus': 0,
#     'bps': -1,
#     'influence': '0.0',
#     'creativity': '0.8',
#     'threat': '21.0',
#     'ict_index': '1.6',
#     'starts': 1,
#     'expected_goals': '0.16',
#     'expected_assists': '0.00',
#     'expected_goal_involvements': '0.16',
#     'expected_goals_conceded': '0.55',
#     'total_points': 2,
#     'in_dreamteam': False},
#    'explain': [{'fixture': 71,
#      'stats': [{'identifier': 'minutes', 'points': 2, 'value': 74}]}]},
#   {'id': 14,
#    'stats': {'minutes': 90,
#     'goals_scored': 0,
#     'assists': 0,
#     'clean_sheets': 1,
#     'goals_conceded': 0,
#     'own_goals': 0,
#     'penalties_saved': 0,
#     'penalties_missed': 0,
#     'yellow_cards': 0,
#     'red_cards': 0,
#     'saves': 0,
#     'bonus': 0,
#     'bps': 7,
#     'influence': '12.0',
#     'creativity': '32.4',
#     'threat': '10.0',
#     'ict_index': '5.4',
#     'starts': 1,
#     'expected_goals': '0.08',
#     'expected_assists': '0.16',
#     'expected_goal_involvements': '0.24',
#     'expected_goals_conceded': '0.55',
#     'total_points': 3,
#     'in_dreamteam': False},
#    'explain': [{'fixture': 71,
#      'stats': [{'identifier': 'minutes', 'points': 2, 'value': 90},
#       {'identifier': 'clean_sheets', 'points': 1, 'value': 1}]}]},
#   {'id': 15,
#    'stats': {'minutes': 15,
#     'goals_scored': 0,
#     'assists': 0,
#     'clean_sheets': 0,
#     'goals_conceded': 0,
#     'own_goals': 0,
#     'penalties_saved': 0,
#     'penalties_missed': 0,
#     'yellow_cards': 0,
#     'red_cards': 0,
#     'saves': 0,
#     'bonus': 0,
#     'bps': 3,
#     'influence': '2.4',
#     'creativity': '1.8',
#     'threat': '0.0',
#     'ict_index': '0.4',
#     'starts': 0,
#     'expected_goals': '0.00',
#     'expected_assists': '0.02',
#     'expected_goal_involvements': '0.02',
#     'expected_goals_conceded': '0.00',
#     'total_points': 1,
#     'in_dreamteam': False},
#    'explain': [{'fixture': 71,
#      'stats': [{'identifier': 'minutes', 'points': 1, 'value': 15}]}]},
#   {'id': 16,
#    'stats': {'minutes': 0,
#     'goals_scored': 0,
#     'assists': 0,
#     'clean_sheets': 0,
#     'goals_conceded': 0,
#     'own_goals': 0,
#     'penalties_saved': 0,
#     'penalties_missed': 0,
#     'yellow_cards': 0,
#     'red_cards': 0,
#     'saves': 0,
#     'bonus': 0,
#     'bps': 0,
#     'influence': '0.0',
#     'creativity': '0.0',
#     'threat': '0.0',
#     'ict_index': '0.0',
#     'starts': 0,
#     'expected_goals': '0.00',
#     'expected_assists': '0.00',
#     'expected_goal_involvements': '0.00',
#     'expected_goals_conceded': '0.00',
#     'total_points': 0,
#     'in_dreamteam': False},
#    'explain': [{'fixture': 71,
#      'stats': [{'identifier': 'minutes', 'points': 0, 'value': 0}]}]},
#   {'id': 17,
#    'stats': {'minutes': 0,
#     'goals_scored': 0,
#     'assists': 0,
#     'clean_sheets': 0,
#     'goals_conceded': 0,
#     'own_goals': 0,
#     'penalties_saved': 0,
#     'penalties_missed': 0,
#     'yellow_cards': 0,
#     'red_cards': 0,
#     'saves': 0,
#     'bonus': 0,
#     'bps': 0,
#     'influence': '0.0',
#     'creativity': '0.0',
#     'threat': '0.0',
#     'ict_index': '0.0',
#     'starts': 0,
#     'expected_goals': '0.00',
#     'expected_assists': '0.00',
#     'expected_goal_involvements': '0.00',
#     'expected_goals_conceded': '0.00',
#     'total_points': 0,
#     'in_dreamteam': False},
#    'explain': [{'fixture': 71,
#      'stats': [{'identifier': 'minutes', 'points': 0, 'value': 0}]}]},
#   {'id': 18,
#    'stats': {'minutes': 0,
#     'goals_scored': 0,
#     'assists': 0,
#     'clean_sheets': 0,
#     'goals_conceded': 0,
#     'own_goals': 0,
#     'penalties_saved': 0,
#     'penalties_missed': 0,
#     'yellow_cards': 0,
#     'red_cards': 0,
#     'saves': 0,
#     'bonus': 0,
#     'bps': 0,
#     'influence': '0.0',
#     'creativity': '0.0',
#     'threat': '0.0',
#     'ict_index': '0.0',
#     'starts': 0,
#     'expected_goals': '0.00',
#     'expected_assists': '0.00',
#     'expected_goal_involvements': '0.00',
#     'expected_goals_conceded': '0.00',
#     'total_points': 0,
#     'in_dreamteam': False},
#    'explain': [{'fixture': 71,
#      'stats': [{'identifier': 'minutes', 'points': 0, 'value': 0}]}]},
#   {'id': 19,
#    'stats': {'minutes': 0,
#     'goals_scored': 0,
#     'assists': 0,
#     'clean_sheets': 0,
#     'goals_conceded': 0,
#     'own_goals': 0,
#     'penalties_saved': 0,
#     'penalties_missed': 0,
#     'yellow_cards': 0,
#     'red_cards': 0,
#     'saves': 0,
#     'bonus': 0,
#     'bps': 0,
#     'influence': '0.0',
#     'creativity': '0.0',
#     'threat': '0.0',
#     'ict_index': '0.0',
#     'starts': 0,
#     'expected_goals': '0.00',
#     'expected_assists': '0.00',
#     'expected_goal_involvements': '0.00',
#     'expected_goals_conceded': '0.00',
#     'total_points': 0,
#     'in_dreamteam': False},
#    'explain': [{'fixture': 71,
#      'stats': [{'identifier': 'minutes', 'points': 0, 'value': 0}]}]},
#   {'id': 20,
#    'stats': {'minutes': 90,
#     'goals_scored': 0,
#     'assists': 0,
#     'clean_sheets': 1,
#     'goals_conceded': 0,
#     'own_goals': 0,
#     'penalties_saved': 0,
#     'penalties_missed': 0,
#     'yellow_cards': 0,
#     'red_cards': 0,
#     'saves': 0,
#     'bonus': 1,
#     'bps': 26,
#     'influence': '14.0',
#     'creativity': '1.3',
#     'threat': '0.0',
#     'ict_index': '1.5',
#     'starts': 1,
#     'expected_goals': '0.00',
#     'expected_assists': '0.01',
#     'expected_goal_involvements': '0.01',
#     'expected_goals_conceded': '0.55',
#     'total_points': 7,
#     'in_dreamteam': False},
#    'explain': [{'fixture': 71,
#      'stats': [{'identifier': 'minutes', 'points': 2, 'value': 90},
#       {'identifier': 'clean_sheets', 'points': 4, 'value': 1},
#       {'identifier': 'bonus', 'points': 1, 'value': 1}]}]},
#   {'id': 21,
#    'stats': {'minutes': 0,
#     'goals_scored': 0,
#     'assists': 0,
#     'clean_sheets': 0,
#     'goals_conceded': 0,
#     'own_goals': 0,
#     'penalties_saved': 0,
#     'penalties_missed': 0,
#     'yellow_cards': 0,
#     'red_cards': 0,
#     'saves': 0,
#     'bonus': 0,
#     'bps': 0,
#     'influence': '0.0',
#     'creativity': '0.0',
#     'threat': '0.0',
#     'ict_index': '0.0',
#     'starts': 0,
#     'expected_goals': '0.00',
#     'expected_assists': '0.00',
#     'expected_goal_involvements': '0.00',
#     'expected_goals_conceded': '0.00',
#     'total_points': 0,
#     'in_dreamteam': False},
#    'explain': [{'fixture': 77,
#      'stats': [{'identifier': 'minutes', 'points': 0, 'value': 0}]}]},
#   {'id': 22,
#    'stats': {'minutes': 0,
#     'goals_scored': 0,
#     'assists': 0,
#     'clean_sheets': 0,
#     'goals_conceded': 0,
#     'own_goals': 0,
#     'penalties_saved': 0,
#     'penalties_missed': 0,
#     'yellow_cards': 0,
#     'red_cards': 0,
#     'saves': 0,
#     'bonus': 0,
#     'bps': 0,
#     'influence': '0.0',
#     'creativity': '0.0',
#     'threat': '0.0',
#     'ict_index': '0.0',
#     'starts': 0,
#     'expected_goals': '0.00',
#     'expected_assists': '0.00',
#     'expected_goal_involvements': '0.00',
#     'expected_goals_conceded': '0.00',
#     'total_points': 0,
#     'in_dreamteam': False},
#    'explain': [{'fixture': 71,
#      'stats': [{'identifier': 'minutes', 'points': 0, 'value': 0}]}]},
#   {'id': 23,
#    'stats': {'minutes': 0,
#     'goals_scored': 0,
#     'assists': 0,
#     'clean_sheets': 0,
#     'goals_conceded': 0,
#     'own_goals': 0,
#     'penalties_saved': 0,
#     'penalties_missed': 0,
#     'yellow_cards': 0,
#     'red_cards': 0,
#     'saves': 0,
#     'bonus': 0,
#     'bps': 0,
#     'influence': '0.0',
#     'creativity': '0.0',
#     'threat': '0.0',
#     'ict_index': '0.0',
#     'starts': 0,
#     'expected_goals': '0.00',
#     'expected_assists': '0.00',
#     'expected_goal_involvements': '0.00',
#     'expected_goals_conceded': '0.00',
#     'total_points': 0,
#     'in_dreamteam': False},
#    'explain': [{'fixture': 74,
#      'stats': [{'identifier': 'minutes', 'points': 0, 'value': 0}]}]},
#   {'id': 24,
#    'stats': {'minutes': 0,
#     'goals_scored': 0,
#     'assists': 0,
#     'clean_sheets': 0,
#     'goals_conceded': 0,
#     'own_goals': 0,
#     'penalties_saved': 0,
#     'penalties_missed': 0,
#     'yellow_cards': 0,
#     'red_cards': 0,
#     'saves': 0,
#     'bonus': 0,
#     'bps': 0,
#     'influence': '0.0',
#     'creativity': '0.0',
#     'threat': '0.0',
#     'ict_index': '0.0',
#     'starts': 0,
#     'expected_goals': '0.00',
#     'expected_assists': '0.00',
#     'expected_goal_involvements': '0.00',
#     'expected_goals_conceded': '0.00',
#     'total_points': 0,
#     'in_dreamteam': False},
#    'explain': [{'fixture': 71,
#      'stats': [{'identifier': 'minutes', 'points': 0, 'value': 0}]}]},
#   {'id': 25,
#    'stats': {'minutes': 15,
#     'goals_scored': 0,
#     'assists': 0,
#     'clean_sheets': 0,
#     'goals_conceded': 0,
#     'own_goals': 0,
#     'penalties_saved': 0,
#     'penalties_missed': 0,
#     'yellow_cards': 0,
#     'red_cards': 0,
#     'saves': 0,
#     'bonus': 0,
#     'bps': 3,
#     'influence': '0.2',
#     'creativity': '1.3',
#     'threat': '0.0',
#     'ict_index': '0.2',
#     'starts': 0,
#     'expected_goals': '0.00',
#     'expected_assists': '0.04',
#     'expected_goal_involvements': '0.04',
#     'expected_goals_conceded': '0.00',
#     'total_points': 1,
#     'in_dreamteam': False},
#    'explain': [{'fixture': 71,
#      'stats': [{'identifier': 'minutes', 'points': 1, 'value': 15}]}]},
#   {'id': 26,
#    'stats': {'minutes': 45,
#     'goals_scored': 0,
#     'assists': 0,
#     'clean_sheets': 0,
#     'goals_conceded': 0,
#     'own_goals': 0,
#     'penalties_saved': 0,
#     'penalties_missed': 0,
#     'yellow_cards': 0,
#     'red_cards': 0,
#     'saves': 0,
#     'bonus': 0,
#     'bps': 3,
#     'influence': '1.6',
#     'creativity': '11.3',
#     'threat': '0.0',
#     'ict_index': '1.3',
#     'starts': 1,
#     'expected_goals': '0.00',
#     'expected_assists': '0.01',
#     'expected_goal_involvements': '0.01',
#     'expected_goals_conceded': '0.42',
#     'total_points': 1,
#     'in_dreamteam': False},
#    'explain': [{'fixture': 71,
#      'stats': [{'identifier': 'minutes', 'points': 1, 'value': 45}]}]},
#   {'id': 27,
#    'stats': {'minutes': 90,
#     'goals_scored': 0,
#     'assists': 0,
#     'clean_sheets': 0,
#     'goals_conceded': 3,
#     'own_goals': 0,
#     'penalties_saved': 0,
#     'penalties_missed': 0,
#     'yellow_cards': 0,
#     'red_cards': 0,
#     'saves': 0,
#     'bonus': 0,
#     'bps': 11,
#     'influence': '38.8',
#     'creativity': '10.2',
#     'threat': '2.0',
#     'ict_index': '5.1',
#     'starts': 1,
#     'expected_goals': '0.00',
#     'expected_assists': '0.00',
#     'expected_goal_involvements': '0.00',
#     'expected_goals_conceded': '2.14',
#     'total_points': 1,
#     'in_dreamteam': False},
#    'explain': [{'fixture': 76,
#      'stats': [{'identifier': 'minutes', 'points': 2, 'value': 90},
#       {'identifier': 'goals_conceded', 'points': -1, 'value': 3}]}]},
#   {'id': 28,
#    'stats': {'minutes': 90,
#     'goals_scored': 0,
#     'assists': 0,
#     'clean_sheets': 1,
#     'goals_conceded': 0,
#     'own_goals': 0,
#     'penalties_saved': 0,
#     'penalties_missed': 0,
#     'yellow_cards': 0,
#     'red_cards': 0,
#     'saves': 2,
#     'bonus': 0,
#     'bps': 25,
#     'influence': '16.8',
#     'creativity': '0.0',
#     'threat': '0.0',
#     'ict_index': '1.7',
#     'starts': 1,
#     'expected_goals': '0.00',
#     'expected_assists': '0.00',
#     'expected_goal_involvements': '0.00',
#     'expected_goals_conceded': '0.81',
#     'total_points': 6,
#     'in_dreamteam': False},
#    'explain': [{'fixture': 74,
#      'stats': [{'identifier': 'minutes', 'points': 2, 'value': 90},
#       {'identifier': 'clean_sheets', 'points': 4, 'value': 1}]}]},
#   {'id': 29,
#    'stats': {'minutes': 90,
#     'goals_scored': 0,
#     'assists': 0,
#     'clean_sheets': 1,
#     'goals_conceded': 0,
#     'own_goals': 0,
#     'penalties_saved': 0,
#     'penalties_missed': 0,
#     'yellow_cards': 0,
#     'red_cards': 0,
#     'saves': 0,
#     'bonus': 3,
#     'bps': 31,
#     'influence': '16.0',
#     'creativity': '23.6',
#     'threat': '6.0',
#     'ict_index': '4.6',
#     'starts': 1,
#     'expected_goals': '0.00',
#     'expected_assists': '0.07',
#     'expected_goal_involvements': '0.07',
#     'expected_goals_conceded': '0.55',
#     'total_points': 9,
#     'in_dreamteam': True},
#    'explain': [{'fixture': 71,
#      'stats': [{'identifier': 'minutes', 'points': 2, 'value': 90},
#       {'identifier': 'clean_sheets', 'points': 4, 'value': 1},
#       {'identifier': 'bonus', 'points': 3, 'value': 3}]}]},
#   {'id': 30,
#    'stats': {'minutes': 0,
#     'goals_scored': 0,
#     'assists': 0,
#     'clean_sheets': 0,
#     'goals_conceded': 0,
#     'own_goals': 0,
#     'penalties_saved': 0,
#     'penalties_missed': 0,
#     'yellow_cards': 0,
#     'red_cards': 0,
#     'saves': 0,
#     'bonus': 0,
#     'bps': 0,
#     'influence': '0.0',
#     'creativity': '0.0',
#     'threat': '0.0',
#     'ict_index': '0.0',
#     'starts': 0,
#     'expected_goals': '0.00',
#     'expected_assists': '0.00',
#     'expected_goal_involvements': '0.00',
#     'expected_goals_conceded': '0.00',
#     'total_points': 0,
#     'in_dreamteam': False},
#    'explain': [{'fixture': 71,
#      'stats': [{'identifier': 'minutes', 'points': 0, 'value': 0}]}]},
#   {'id': 31,
#    'stats': {'minutes': 74,
#     'goals_scored': 0,
#     'assists': 0,
#     'clean_sheets': 1,
#     'goals_conceded': 0,
#     'own_goals': 0,
#     'penalties_saved': 0,
#     'penalties_missed': 0,
#     'yellow_cards': 0,
#     'red_cards': 0,
#     'saves': 0,
#     'bonus': 1,
#     'bps': 26,
#     'influence': '6.4',
#     'creativity': '12.4',
#     'threat': '8.0',
#     'ict_index': '2.7',
#     'starts': 1,
#     'expected_goals': '0.08',
#     'expected_assists': '0.01',
#     'expected_goal_involvements': '0.09',
#     'expected_goals_conceded': '0.55',
#     'total_points': 7,
#     'in_dreamteam': False},
#    'explain': [{'fixture': 71,
#      'stats': [{'identifier': 'minutes', 'points': 2, 'value': 74},
#       {'identifier': 'clean_sheets', 'points': 4, 'value': 1},
#       {'identifier': 'bonus', 'points': 1, 'value': 1}]}]},
#   {'id': 32,
#    'stats': {'minutes': 0,
#     'goals_scored': 0,
#     'assists': 0,
#     'clean_sheets': 0,
#     'goals_conceded': 0,
#     'own_goals': 0,
#     'penalties_saved': 0,
#     'penalties_missed': 0,
#     'yellow_cards': 0,
#     'red_cards': 0,
#     'saves': 0,
#     'bonus': 0,
#     'bps': 0,
#     'influence': '0.0',
#     'creativity': '0.0',
#     'threat': '0.0',
#     'ict_index': '0.0',
#     'starts': 0,
#     'expected_goals': '0.00',
#     'expected_assists': '0.00',
#     'expected_goal_involvements': '0.00',
#     'expected_goals_conceded': '0.00',
#     'total_points': 0,
#     'in_dreamteam': False},
#    'explain': [{'fixture': 80,
#      'stats': [{'identifier': 'minutes', 'points': 0, 'value': 0}]}]},
#   {'id': 33,
#    'stats': {'minutes': 78,
#     'goals_scored': 0,
#     'assists': 0,
#     'clean_sheets': 0,
#     'goals_conceded': 2,
#     'own_goals': 0,
#     'penalties_saved': 0,
#     'penalties_missed': 0,
#     'yellow_cards': 0,
#     'red_cards': 0,
#     'saves': 0,
#     'bonus': 0,
#     'bps': 7,
#     'influence': '9.8',
#     'creativity': '22.3',
#     'threat': '12.0',
#     'ict_index': '4.4',
#     'starts': 1,
#     'expected_goals': '0.00',
#     'expected_assists': '0.01',
#     'expected_goal_involvements': '0.01',
#     'expected_goals_conceded': '1.81',
#     'total_points': 2,
#     'in_dreamteam': False},
#    'explain': [{'fixture': 76,
#      'stats': [{'identifier': 'minutes', 'points': 2, 'value': 78}]}]},
#   {'id': 34,
#    'stats': {'minutes': 8,
#     'goals_scored': 0,
#     'assists': 0,
#     'clean_sheets': 0,
#     'goals_conceded': 0,
#     'own_goals': 0,
#     'penalties_saved': 0,
#     'penalties_missed': 0,
#     'yellow_cards': 0,
#     'red_cards': 0,
#     'saves': 0,
#     'bonus': 0,
#     'bps': 4,
#     'influence': '4.4',
#     'creativity': '14.8',
#     'threat': '2.0',
#     'ict_index': '2.1',
#     'starts': 0,
#     'expected_goals': '0.00',
#     'expected_assists': '0.06',
#     'expected_goal_involvements': '0.06',
#     'expected_goals_conceded': '0.14',
#     'total_points': 1,
#     'in_dreamteam': False},
#    'explain': [{'fixture': 80,
#      'stats': [{'identifier': 'minutes', 'points': 1, 'value': 8}]}]},
#   {'id': 35,
#    'stats': {'minutes': 0,
#     'goals_scored': 0,
#     'assists': 0,
#     'clean_sheets': 0,
#     'goals_conceded': 0,
#     'own_goals': 0,
#     'penalties_saved': 0,
#     'penalties_missed': 0,
#     'yellow_cards': 0,
#     'red_cards': 0,
#     'saves': 0,
#     'bonus': 0,
#     'bps': 0,
#     'influence': '0.0',
#     'creativity': '0.0',
#     'threat': '0.0',
#     'ict_index': '0.0',
#     'starts': 0,
#     'expected_goals': '0.00',
#     'expected_assists': '0.00',
#     'expected_goal_involvements': '0.00',
#     'expected_goals_conceded': '0.00',
#     'total_points': 0,
#     'in_dreamteam': False},
#    'explain': [{'fixture': 80,
#      'stats': [{'identifier': 'minutes', 'points': 0, 'value': 0}]}]},
#   {'id': 36,
#    'stats': {'minutes': 81,
#     'goals_scored': 0,
#     'assists': 0,
#     'clean_sheets': 0,
#     'goals_conceded': 1,
#     'own_goals': 0,
#     'penalties_saved': 0,
#     'penalties_missed': 0,
#     'yellow_cards': 0,
#     'red_cards': 0,
#     'saves': 0,
#     'bonus': 0,
#     'bps': 6,
#     'influence': '9.6',
#     'creativity': '1.0',
#     'threat': '26.0',
#     'ict_index': '3.7',
#     'starts': 1,
#     'expected_goals': '0.23',
#     'expected_assists': '0.01',
#     'expected_goal_involvements': '0.24',
#     'expected_goals_conceded': '1.05',
#     'total_points': 2,
#     'in_dreamteam': False},
#    'explain': [{'fixture': 80,
#      'stats': [{'identifier': 'minutes', 'points': 2, 'value': 81}]}]},
#   {'id': 37,
#    'stats': {'minutes': 0,
#     'goals_scored': 0,
#     'assists': 0,
#     'clean_sheets': 0,
#     'goals_conceded': 0,
#     'own_goals': 0,
#     'penalties_saved': 0,
#     'penalties_missed': 0,
#     'yellow_cards': 0,
#     'red_cards': 0,
#     'saves': 0,
#     'bonus': 0,
#     'bps': 0,
#     'influence': '0.0',
#     'creativity': '0.0',
#     'threat': '0.0',
#     'ict_index': '0.0',
#     'starts': 0,
#     'expected_goals': '0.00',
#     'expected_assists': '0.00',
#     'expected_goal_involvements': '0.00',
#     'expected_goals_conceded': '0.00',
#     'total_points': 0,
#     'in_dreamteam': False},
#    'explain': [{'fixture': 80,
#      'stats': [{'identifier': 'minutes', 'points': 0, 'value': 0}]}]},
#   {'id': 38,
#    'stats': {'minutes': 0,
#     'goals_scored': 0,
#     'assists': 0,
#     'clean_sheets': 0,
#     'goals_conceded': 0,
#     'own_goals': 0,
#     'penalties_saved': 0,
#     'penalties_missed': 0,
#     'yellow_cards': 0,
#     'red_cards': 0,
#     'saves': 0,
#     'bonus': 0,
#     'bps': 0,
#     'influence': '0.0',
#     'creativity': '0.0',
#     'threat': '0.0',
#     'ict_index': '0.0',
#     'starts': 0,
#     'expected_goals': '0.00',
#     'expected_assists': '0.00',
#     'expected_goal_involvements': '0.00',
#     'expected_goals_conceded': '0.00',
#     'total_points': 0,
#     'in_dreamteam': False},
#    'explain': [{'fixture': 80,
#      'stats': [{'identifier': 'minutes', 'points': 0, 'value': 0}]}]},
#   {'id': 39,
#    'stats': {'minutes': 0,
#     'goals_scored': 0,
#     'assists': 0,
#     'clean_sheets': 0,
#     'goals_conceded': 0,
#     'own_goals': 0,
#     'penalties_saved': 0,
#     'penalties_missed': 0,
#     'yellow_cards': 0,
#     'red_cards': 0,
#     'saves': 0,
#     'bonus': 0,
#     'bps': 0,
#     'influence': '0.0',
#     'creativity': '0.0',
#     'threat': '0.0',
#     'ict_index': '0.0',
#     'starts': 0,
#     'expected_goals': '0.00',
#     'expected_assists': '0.00',
#     'expected_goal_involvements': '0.00',
#     'expected_goals_conceded': '0.00',
#     'total_points': 0,
#     'in_dreamteam': False},
#    'explain': [{'fixture': 80,
#      'stats': [{'identifier': 'minutes', 'points': 0, 'value': 0}]}]},
#   {'id': 40,
#    'stats': {'minutes': 0,
#     'goals_scored': 0,
#     'assists': 0,
#     'clean_sheets': 0,
#     'goals_conceded': 0,
#     'own_goals': 0,
#     'penalties_saved': 0,
#     'penalties_missed': 0,
#     'yellow_cards': 0,
#     'red_cards': 0,
#     'saves': 0,
#     'bonus': 0,
#     'bps': 0,
#     'influence': '0.0',
#     'creativity': '0.0',
#     'threat': '0.0',
#     'ict_index': '0.0',
#     'starts': 0,
#     'expected_goals': '0.00',
#     'expected_assists': '0.00',
#     'expected_goal_involvements': '0.00',
#     'expected_goals_conceded': '0.00',
#     'total_points': 0,
#     'in_dreamteam': False},
#    'explain': [{'fixture': 80,
#      'stats': [{'identifier': 'minutes', 'points': 0, 'value': 0}]}]},
#   {'id': 41,
#    'stats': {'minutes': 90,
#     'goals_scored': 0,
#     'assists': 0,
#     'clean_sheets': 0,
#     'goals_conceded': 1,
#     'own_goals': 0,
#     'penalties_saved': 0,
#     'penalties_missed': 0,
#     'yellow_cards': 0,
#     'red_cards': 0,
#     'saves': 0,
#     'bonus': 0,
#     'bps': 13,
#     'influence': '11.2',
#     'creativity': '10.8',
#     'threat': '0.0',
#     'ict_index': '2.2',
#     'starts': 1,
#     'expected_goals': '0.00',
#     'expected_assists': '0.01',
#     'expected_goal_involvements': '0.01',
#     'expected_goals_conceded': '1.19',
#     'total_points': 2,
#     'in_dreamteam': False},
#    'explain': [{'fixture': 80,
#      'stats': [{'identifier': 'minutes', 'points': 2, 'value': 90}]}]},
#   {'id': 42,
#    'stats': {'minutes': 90,
#     'goals_scored': 0,
#     'assists': 0,
#     'clean_sheets': 0,
#     'goals_conceded': 1,
#     'own_goals': 0,
#     'penalties_saved': 0,
#     'penalties_missed': 0,
#     'yellow_cards': 0,
#     'red_cards': 0,
#     'saves': 0,
#     'bonus': 0,
#     'bps': 13,
#     'influence': '9.6',
#     'creativity': '30.8',
#     'threat': '2.0',
#     'ict_index': '4.2',
#     'starts': 1,
#     'expected_goals': '0.00',
#     'expected_assists': '0.18',
#     'expected_goal_involvements': '0.18',
#     'expected_goals_conceded': '1.19',
#     'total_points': 2,
#     'in_dreamteam': False},
#    'explain': [{'fixture': 80,
#      'stats': [{'identifier': 'minutes', 'points': 2, 'value': 90}]}]},
#   {'id': 43,
#    'stats': {'minutes': 90,
#     'goals_scored': 0,
#     'assists': 0,
#     'clean_sheets': 0,
#     'goals_conceded': 1,
#     'own_goals': 0,
#     'penalties_saved': 0,
#     'penalties_missed': 0,
#     'yellow_cards': 0,
#     'red_cards': 0,
#     'saves': 0,
#     'bonus': 0,
#     'bps': 13,
#     'influence': '8.6',
#     'creativity': '16.7',
#     'threat': '21.0',
#     'ict_index': '4.6',
#     'starts': 1,
#     'expected_goals': '0.33',
#     'expected_assists': '0.11',
#     'expected_goal_involvements': '0.44',
#     'expected_goals_conceded': '1.19',
#     'total_points': 2,
#     'in_dreamteam': False},
#    'explain': [{'fixture': 80,
#      'stats': [{'identifier': 'minutes', 'points': 2, 'value': 90}]}]},
#   {'id': 44,
#    'stats': {'minutes': 0,
#     'goals_scored': 0,
#     'assists': 0,
#     'clean_sheets': 0,
#     'goals_conceded': 0,
#     'own_goals': 0,
#     'penalties_saved': 0,
#     'penalties_missed': 0,
#     'yellow_cards': 0,
#     'red_cards': 0,
#     'saves': 0,
#     'bonus': 0,
#     'bps': 0,
#     'influence': '0.0',
#     'creativity': '0.0',
#     'threat': '0.0',
#     'ict_index': '0.0',
#     'starts': 0,
#     'expected_goals': '0.00',
#     'expected_assists': '0.00',
#     'expected_goal_involvements': '0.00',
#     'expected_goals_conceded': '0.00',
#     'total_points': 0,
#     'in_dreamteam': False},
#    'explain': [{'fixture': 80,
#      'stats': [{'identifier': 'minutes', 'points': 0, 'value': 0}]}]},
#   {'id': 45,
#    'stats': {'minutes': 0,
#     'goals_scored': 0,
#     'assists': 0,
#     'clean_sheets': 0,
#     'goals_conceded': 0,
#     'own_goals': 0,
#     'penalties_saved': 0,
#     'penalties_missed': 0,
#     'yellow_cards': 0,
#     'red_cards': 0,
#     'saves': 0,
#     'bonus': 0,
#     'bps': 0,
#     'influence': '0.0',
#     'creativity': '0.0',
#     'threat': '0.0',
#     'ict_index': '0.0',
#     'starts': 0,
#     'expected_goals': '0.00',
#     'expected_assists': '0.00',
#     'expected_goal_involvements': '0.00',
#     'expected_goals_conceded': '0.00',
#     'total_points': 0,
#     'in_dreamteam': False},
#    'explain': [{'fixture': 80,
#      'stats': [{'identifier': 'minutes', 'points': 0, 'value': 0}]}]},
#   {'id': 46,
#    'stats': {'minutes': 0,
#     'goals_scored': 0,
#     'assists': 0,
#     'clean_sheets': 0,
#     'goals_conceded': 0,
#     'own_goals': 0,
#     'penalties_saved': 0,
#     'penalties_missed': 0,
#     'yellow_cards': 0,
#     'red_cards': 0,
#     'saves': 0,
#     'bonus': 0,
#     'bps': 0,
#     'influence': '0.0',
#     'creativity': '0.0',
#     'threat': '0.0',
#     'ict_index': '0.0',
#     'starts': 0,
#     'expected_goals': '0.00',
#     'expected_assists': '0.00',
#     'expected_goal_involvements': '0.00',
#     'expected_goals_conceded': '0.00',
#     'total_points': 0,
#     'in_dreamteam': False},
#    'explain': [{'fixture': 80,
#      'stats': [{'identifier': 'minutes', 'points': 0, 'value': 0}]}]},
#   {'id': 47,
#    'stats': {'minutes': 81,
#     'goals_scored': 0,
#     'assists': 0,
#     'clean_sheets': 0,
#     'goals_conceded': 1,
#     'own_goals': 0,
#     'penalties_saved': 0,
#     'penalties_missed': 0,
#     'yellow_cards': 1,
#     'red_cards': 0,
#     'saves': 0,
#     'bonus': 0,
#     'bps': 2,
#     'influence': '6.0',
#     'creativity': '14.1',
#     'threat': '0.0',
#     'ict_index': '2.0',
#     'starts': 1,
#     'expected_goals': '0.00',
#     'expected_assists': '0.00',
#     'expected_goal_involvements': '0.00',
#     'expected_goals_conceded': '1.05',
#     'total_points': 1,
#     'in_dreamteam': False},
#    'explain': [{'fixture': 80,
#      'stats': [{'identifier': 'minutes', 'points': 2, 'value': 81},
#       {'identifier': 'yellow_cards', 'points': -1, 'value': 1}]}]},
#   {'id': 48,
#    'stats': {'minutes': 90,
#     'goals_scored': 0,
#     'assists': 0,
#     'clean_sheets': 0,
#     'goals_conceded': 1,
#     'own_goals': 0,
#     'penalties_saved': 0,
#     'penalties_missed': 0,
#     'yellow_cards': 0,
#     'red_cards': 0,
#     'saves': 0,
#     'bonus': 0,
#     'bps': 11,
#     'influence': '16.4',
#     'creativity': '12.1',
#     'threat': '22.0',
#     'ict_index': '5.1',
#     'starts': 1,
#     'expected_goals': '0.23',
#     'expected_assists': '0.02',
#     'expected_goal_involvements': '0.25',
#     'expected_goals_conceded': '1.19',
#     'total_points': 2,
#     'in_dreamteam': False},
#    'explain': [{'fixture': 80,
#      'stats': [{'identifier': 'minutes', 'points': 2, 'value': 90}]}]},
#   {'id': 49,
#    'stats': {'minutes': 90,
#     'goals_scored': 0,
#     'assists': 0,
#     'clean_sheets': 0,
#     'goals_conceded': 1,
#     'own_goals': 0,
#     'penalties_saved': 0,
#     'penalties_missed': 0,
#     'yellow_cards': 0,
#     'red_cards': 0,
#     'saves': 2,
#     'bonus': 1,
#     'bps': 18,
#     'influence': '19.4',
#     'creativity': '0.0',
#     'threat': '0.0',
#     'ict_index': '1.9',
#     'starts': 1,
#     'expected_goals': '0.00',
#     'expected_assists': '0.00',
#     'expected_goal_involvements': '0.00',
#     'expected_goals_conceded': '1.19',
#     'total_points': 3,
#     'in_dreamteam': False},
#    'explain': [{'fixture': 80,
#      'stats': [{'identifier': 'minutes', 'points': 2, 'value': 90},
#       {'identifier': 'bonus', 'points': 1, 'value': 1}]}]},
#   {'id': 50,
#    'stats': {'minutes': 90,
#     'goals_scored': 0,
#     'assists': 0,
#     'clean_sheets': 0,
#     'goals_conceded': 1,
#     'own_goals': 0,
#     'penalties_saved': 0,
#     'penalties_missed': 0,
#     'yellow_cards': 1,
#     'red_cards': 0,
#     'saves': 0,
#     'bonus': 0,
#     'bps': 9,
#     'influence': '10.8',
#     'creativity': '54.9',
#     'threat': '4.0',
#     'ict_index': '7.0',
#     'starts': 1,
#     'expected_goals': '0.09',
#     'expected_assists': '0.17',
#     'expected_goal_involvements': '0.26',
#     'expected_goals_conceded': '1.19',
#     'total_points': 1,
#     'in_dreamteam': False},
#    'explain': [{'fixture': 80,
#      'stats': [{'identifier': 'minutes', 'points': 2, 'value': 90},
#       {'identifier': 'yellow_cards', 'points': -1, 'value': 1}]}]},
#   {'id': 51,
#    'stats': {'minutes': 0,
#     'goals_scored': 0,
#     'assists': 0,
#     'clean_sheets': 0,
#     'goals_conceded': 0,
#     'own_goals': 0,
#     'penalties_saved': 0,
#     'penalties_missed': 0,
#     'yellow_cards': 0,
#     'red_cards': 0,
#     'saves': 0,
#     'bonus': 0,
#     'bps': 0,
#     'influence': '0.0',
#     'creativity': '0.0',
#     'threat': '0.0',
#     'ict_index': '0.0',
#     'starts': 0,
#     'expected_goals': '0.00',
#     'expected_assists': '0.00',
#     'expected_goal_involvements': '0.00',
#     'expected_goals_conceded': '0.00',
#     'total_points': 0,
#     'in_dreamteam': False},
#    'explain': [{'fixture': 80,
#      'stats': [{'identifier': 'minutes', 'points': 0, 'value': 0}]}]},
#   {'id': 52,
#    'stats': {'minutes': 90,
#     'goals_scored': 0,
#     'assists': 0,
#     'clean_sheets': 0,
#     'goals_conceded': 1,
#     'own_goals': 0,
#     'penalties_saved': 0,
#     'penalties_missed': 0,
#     'yellow_cards': 0,
#     'red_cards': 0,
#     'saves': 0,
#     'bonus': 0,
#     'bps': 4,
#     'influence': '12.2',
#     'creativity': '12.3',
#     'threat': '3.0',
#     'ict_index': '2.8',
#     'starts': 1,
#     'expected_goals': '0.03',
#     'expected_assists': '0.10',
#     'expected_goal_involvements': '0.13',
#     'expected_goals_conceded': '1.99',
#     'total_points': 2,
#     'in_dreamteam': False},
#    'explain': [{'fixture': 77,
#      'stats': [{'identifier': 'minutes', 'points': 2, 'value': 90}]}]},
#   {'id': 53,
#    'stats': {'minutes': 0,
#     'goals_scored': 0,
#     'assists': 0,
#     'clean_sheets': 0,
#     'goals_conceded': 0,
#     'own_goals': 0,
#     'penalties_saved': 0,
#     'penalties_missed': 0,
#     'yellow_cards': 0,
#     'red_cards': 0,
#     'saves': 0,
#     'bonus': 0,
#     'bps': 0,
#     'influence': '0.0',
#     'creativity': '0.0',
#     'threat': '0.0',
#     'ict_index': '0.0',
#     'starts': 0,
#     'expected_goals': '0.00',
#     'expected_assists': '0.00',
#     'expected_goal_involvements': '0.00',
#     'expected_goals_conceded': '0.00',
#     'total_points': 0,
#     'in_dreamteam': False},
#    'explain': [{'fixture': 80,
#      'stats': [{'identifier': 'minutes', 'points': 0, 'value': 0}]}]},
#   {'id': 54,
#    'stats': {'minutes': 0,
#     'goals_scored': 0,
#     'assists': 0,
#     'clean_sheets': 0,
#     'goals_conceded': 0,
#     'own_goals': 0,
#     'penalties_saved': 0,
#     'penalties_missed': 0,
#     'yellow_cards': 0,
#     'red_cards': 0,
#     'saves': 0,
#     'bonus': 0,
#     'bps': 0,
#     'influence': '0.0',
#     'creativity': '0.0',
#     'threat': '0.0',
#     'ict_index': '0.0',
#     'starts': 0,
#     'expected_goals': '0.00',
#     'expected_assists': '0.00',
#     'expected_goal_involvements': '0.00',
#     'expected_goals_conceded': '0.00',
#     'total_points': 0,
#     'in_dreamteam': False},
#    'explain': [{'fixture': 80,
#      'stats': [{'identifier': 'minutes', 'points': 0, 'value': 0}]}]},
#   {'id': 55,
#    'stats': {'minutes': 0,
#     'goals_scored': 0,
#     'assists': 0,
#     'clean_sheets': 0,
#     'goals_conceded': 0,
#     'own_goals': 0,
#     'penalties_saved': 0,
#     'penalties_missed': 0,
#     'yellow_cards': 0,
#     'red_cards': 0,
#     'saves': 0,
#     'bonus': 0,
#     'bps': 0,
#     'influence': '0.0',
#     'creativity': '0.0',
#     'threat': '0.0',
#     'ict_index': '0.0',
#     'starts': 0,
#     'expected_goals': '0.00',
#     'expected_assists': '0.00',
#     'expected_goal_involvements': '0.00',
#     'expected_goals_conceded': '0.00',
#     'total_points': 0,
#     'in_dreamteam': False},
#    'explain': [{'fixture': 80,
#      'stats': [{'identifier': 'minutes', 'points': 0, 'value': 0}]}]},
#   {'id': 56,
#    'stats': {'minutes': 0,
#     'goals_scored': 0,
#     'assists': 0,
#     'clean_sheets': 0,
#     'goals_conceded': 0,
#     'own_goals': 0,
#     'penalties_saved': 0,
#     'penalties_missed': 0,
#     'yellow_cards': 0,
#     'red_cards': 0,
#     'saves': 0,
#     'bonus': 0,
#     'bps': 0,
#     'influence': '0.0',
#     'creativity': '0.0',
#     'threat': '0.0',
#     'ict_index': '0.0',
#     'starts': 0,
#     'expected_goals': '0.00',
#     'expected_assists': '0.00',
#     'expected_goal_involvements': '0.00',
#     'expected_goals_conceded': '0.00',
#     'total_points': 0,
#     'in_dreamteam': False},
#    'explain': [{'fixture': 80,
#      'stats': [{'identifier': 'minutes', 'points': 0, 'value': 0}]}]},
#   {'id': 57,
#    'stats': {'minutes': 0,
#     'goals_scored': 0,
#     'assists': 0,
#     'clean_sheets': 0,
#     'goals_conceded': 0,
#     'own_goals': 0,
#     'penalties_saved': 0,
#     'penalties_missed': 0,
#     'yellow_cards': 0,
#     'red_cards': 0,
#     'saves': 0,
#     'bonus': 0,
#     'bps': 0,
#     'influence': '0.0',
#     'creativity': '0.0',
#     'threat': '0.0',
#     'ict_index': '0.0',
#     'starts': 0,
#     'expected_goals': '0.00',
#     'expected_assists': '0.00',
#     'expected_goal_involvements': '0.00',
#     'expected_goals_conceded': '0.00',
#     'total_points': 0,
#     'in_dreamteam': False},
#    'explain': [{'fixture': 80,
#      'stats': [{'identifier': 'minutes', 'points': 0, 'value': 0}]}]},
#   {'id': 58,
#    'stats': {'minutes': 8,
#     'goals_scored': 0,
#     'assists': 0,
#     'clean_sheets': 0,
#     'goals_conceded': 0,
#     'own_goals': 0,
#     'penalties_saved': 0,
#     'penalties_missed': 0,
#     'yellow_cards': 0,
#     'red_cards': 0,
#     'saves': 0,
#     'bonus': 0,
#     'bps': 3,
#     'influence': '0.8',
#     'creativity': '1.3',
#     'threat': '0.0',
#     'ict_index': '0.2',
#     'starts': 0,
#     'expected_goals': '0.00',
#     'expected_assists': '0.00',
#     'expected_goal_involvements': '0.00',
#     'expected_goals_conceded': '0.14',
#     'total_points': 1,
#     'in_dreamteam': False},
#    'explain': [{'fixture': 80,
#      'stats': [{'identifier': 'minutes', 'points': 1, 'value': 8}]}]},
#   {'id': 59,
#    'stats': {'minutes': 0,
#     'goals_scored': 0,
#     'assists': 0,
#     'clean_sheets': 0,
#     'goals_conceded': 0,
#     'own_goals': 0,
#     'penalties_saved': 0,
#     'penalties_missed': 0,
#     'yellow_cards': 0,
#     'red_cards': 0,
#     'saves': 0,
#     'bonus': 0,
#     'bps': 0,
#     'influence': '0.0',
#     'creativity': '0.0',
#     'threat': '0.0',
#     'ict_index': '0.0',
#     'starts': 0,
#     'expected_goals': '0.00',
#     'expected_assists': '0.00',
#     'expected_goal_involvements': '0.00',
#     'expected_goals_conceded': '0.00',
#     'total_points': 0,
#     'in_dreamteam': False},
#    'explain': [{'fixture': 80,
#      'stats': [{'identifier': 'minutes', 'points': 0, 'value': 0}]}]},
#   {'id': 60,
#    'stats': {'minutes': 90,
#     'goals_scored': 0,
#     'assists': 1,
#     'clean_sheets': 0,
#     'goals_conceded': 1,
#     'own_goals': 0,
#     'penalties_saved': 0,
#     'penalties_missed': 0,
#     'yellow_cards': 0,
#     'red_cards': 0,
#     'saves': 0,
#     'bonus': 0,
#     'bps': 16,
#     'influence': '16.2',
#     'creativity': '10.6',
#     'threat': '37.0',
#     'ict_index': '6.4',
#     'starts': 1,
#     'expected_goals': '0.31',
#     'expected_assists': '0.22',
#     'expected_goal_involvements': '0.53',
#     'expected_goals_conceded': '1.19',
#     'total_points': 5,
#     'in_dreamteam': False},
#    'explain': [{'fixture': 80,
#      'stats': [{'identifier': 'minutes', 'points': 2, 'value': 90},
#       {'identifier': 'assists', 'points': 3, 'value': 1}]}]},
#   {'id': 61,
#    'stats': {'minutes': 0,
#     'goals_scored': 0,
#     'assists': 0,
#     'clean_sheets': 0,
#     'goals_conceded': 0,
#     'own_goals': 0,
#     'penalties_saved': 0,
#     'penalties_missed': 0,
#     'yellow_cards': 0,
#     'red_cards': 0,
#     'saves': 0,
#     'bonus': 0,
#     'bps': 0,
#     'influence': '0.0',
#     'creativity': '0.0',
#     'threat': '0.0',
#     'ict_index': '0.0',
#     'starts': 0,
#     'expected_goals': '0.00',
#     'expected_assists': '0.00',
#     'expected_goal_involvements': '0.00',
#     'expected_goals_conceded': '0.00',
#     'total_points': 0,
#     'in_dreamteam': False},
#    'explain': [{'fixture': 80,
#      'stats': [{'identifier': 'minutes', 'points': 0, 'value': 0}]}]},
#   {'id': 62,
#    'stats': {'minutes': 0,
#     'goals_scored': 0,
#     'assists': 0,
#     'clean_sheets': 0,
#     'goals_conceded': 0,
#     'own_goals': 0,
#     'penalties_saved': 0,
#     'penalties_missed': 0,
#     'yellow_cards': 0,
#     'red_cards': 0,
#     'saves': 0,
#     'bonus': 0,
#     'bps': 0,
#     'influence': '0.0',
#     'creativity': '0.0',
#     'threat': '0.0',
#     'ict_index': '0.0',
#     'starts': 0,
#     'expected_goals': '0.00',
#     'expected_assists': '0.00',
#     'expected_goal_involvements': '0.00',
#     'expected_goals_conceded': '0.00',
#     'total_points': 0,
#     'in_dreamteam': False},
#    'explain': [{'fixture': 75,
#      'stats': [{'identifier': 'minutes', 'points': 0, 'value': 0}]}]},
#   {'id': 63,
#    'stats': {'minutes': 90,
#     'goals_scored': 0,
#     'assists': 0,
#     'clean_sheets': 0,
#     'goals_conceded': 3,
#     'own_goals': 0,
#     'penalties_saved': 0,
#     'penalties_missed': 0,
#     'yellow_cards': 0,
#     'red_cards': 0,
#     'saves': 0,
#     'bonus': 0,
#     'bps': 12,
#     'influence': '21.0',
#     'creativity': '13.3',
#     'threat': '15.0',
#     'ict_index': '4.9',
#     'starts': 1,
#     'expected_goals': '0.10',
#     'expected_assists': '0.18',
#     'expected_goal_involvements': '0.28',
#     'expected_goals_conceded': '2.71',
#     'total_points': 2,
#     'in_dreamteam': False},
#    'explain': [{'fixture': 75,
#      'stats': [{'identifier': 'minutes', 'points': 2, 'value': 90}]}]},
#   {'id': 64,
#    'stats': {'minutes': 23,
#     'goals_scored': 0,
#     'assists': 0,
#     'clean_sheets': 0,
#     'goals_conceded': 0,
#     'own_goals': 0,
#     'penalties_saved': 0,
#     'penalties_missed': 0,
#     'yellow_cards': 0,
#     'red_cards': 0,
#     'saves': 0,
#     'bonus': 0,
#     'bps': 3,
#     'influence': '2.4',
#     'creativity': '4.3',
#     'threat': '0.0',
#     'ict_index': '0.7',
#     'starts': 0,
#     'expected_goals': '0.00',
#     'expected_assists': '0.02',
#     'expected_goal_involvements': '0.02',
#     'expected_goals_conceded': '0.51',
#     'total_points': 1,
#     'in_dreamteam': False},
#    'explain': [{'fixture': 75,
#      'stats': [{'identifier': 'minutes', 'points': 1, 'value': 23}]}]},
#   {'id': 65,
#    'stats': {'minutes': 45,
#     'goals_scored': 0,
#     'assists': 0,
#     'clean_sheets': 0,
#     'goals_conceded': 2,
#     'own_goals': 0,
#     'penalties_saved': 0,
#     'penalties_missed': 0,
#     'yellow_cards': 0,
#     'red_cards': 0,
#     'saves': 0,
#     'bonus': 0,
#     'bps': 2,
#     'influence': '3.0',
#     'creativity': '1.8',
#     'threat': '2.0',
#     'ict_index': '0.7',
#     'starts': 1,
#     'expected_goals': '0.00',
#     'expected_assists': '0.01',
#     'expected_goal_involvements': '0.01',
#     'expected_goals_conceded': '0.86',
#     'total_points': 1,
#     'in_dreamteam': False},
#    'explain': [{'fixture': 75,
#      'stats': [{'identifier': 'minutes', 'points': 1, 'value': 45}]}]},
#   {'id': 66,
#    'stats': {'minutes': 66,
#     'goals_scored': 0,
#     'assists': 0,
#     'clean_sheets': 0,
#     'goals_conceded': 3,
#     'own_goals': 0,
#     'penalties_saved': 0,
#     'penalties_missed': 0,
#     'yellow_cards': 0,
#     'red_cards': 0,
#     'saves': 0,
#     'bonus': 0,
#     'bps': 16,
#     'influence': '14.0',
#     'creativity': '15.8',
#     'threat': '0.0',
#     'ict_index': '3.0',
#     'starts': 1,
#     'expected_goals': '0.00',
#     'expected_assists': '0.07',
#     'expected_goal_involvements': '0.07',
#     'expected_goals_conceded': '2.20',
#     'total_points': 2,
#     'in_dreamteam': False},
#    'explain': [{'fixture': 75,
#      'stats': [{'identifier': 'minutes', 'points': 2, 'value': 66}]}]},
#   {'id': 67,
#    'stats': {'minutes': 0,
#     'goals_scored': 0,
#     'assists': 0,
#     'clean_sheets': 0,
#     'goals_conceded': 0,
#     'own_goals': 0,
#     'penalties_saved': 0,
#     'penalties_missed': 0,
#     'yellow_cards': 0,
#     'red_cards': 0,
#     'saves': 0,
#     'bonus': 0,
#     'bps': 0,
#     'influence': '0.0',
#     'creativity': '0.0',
#     'threat': '0.0',
#     'ict_index': '0.0',
#     'starts': 0,
#     'expected_goals': '0.00',
#     'expected_assists': '0.00',
#     'expected_goal_involvements': '0.00',
#     'expected_goals_conceded': '0.00',
#     'total_points': 0,
# ...
#     'saves': 0,
#     'bonus': 0,
#     'bps': 0,
#     'influence': '0.0',
#     'creativity': '0.0',
#     'threat': '0.0',
#     'ict_index': '0.0',
#     'starts': 0,
#     'expected_goals': '0.00',
#     'expected_assists': '0.00',
#     'expected_goal_involvements': '0.00',
#     'expected_goals_conceded': '0.00',
#     'total_points': 0,
#     'in_dreamteam': False},
#    'explain': [{'fixture': 80,
#      'stats': [{'identifier': 'minutes', 'points': 0, 'value': 0}]}]},
#   {'id': 705,
#    'stats': {'minutes': 33,
#     'goals_scored': 0,
#     'assists': 0,
#     'clean_sheets': 0,
#     'goals_conceded': 1,
#     'own_goals': 0,
#     'penalties_saved': 0,
#     'penalties_missed': 0,
#     'yellow_cards': 0,
#     'red_cards': 0,
#     'saves': 0,
#     'bonus': 0,
#     'bps': 6,
#     'influence': '9.6',
#     'creativity': '22.4',
#     'threat': '6.0',
#     'ict_index': '3.8',
#     'starts': 0,
#     'expected_goals': '0.00',
#     'expected_assists': '0.25',
#     'expected_goal_involvements': '0.25',
#     'expected_goals_conceded': '1.69',
#     'total_points': 1,
#     'in_dreamteam': False},
#    'explain': [{'fixture': 75,
#      'stats': [{'identifier': 'minutes', 'points': 1, 'value': 33}]}]},
#   {'id': 706,
#    'stats': {'minutes': 60,
#     'goals_scored': 0,
#     'assists': 0,
#     'clean_sheets': 0,
#     'goals_conceded': 2,
#     'own_goals': 0,
#     'penalties_saved': 0,
#     'penalties_missed': 0,
#     'yellow_cards': 0,
#     'red_cards': 0,
#     'saves': 0,
#     'bonus': 0,
#     'bps': -1,
#     'influence': '3.4',
#     'creativity': '0.1',
#     'threat': '7.0',
#     'ict_index': '1.1',
#     'starts': 1,
#     'expected_goals': '0.21',
#     'expected_assists': '0.00',
#     'expected_goal_involvements': '0.21',
#     'expected_goals_conceded': '1.19',
#     'total_points': 2,
#     'in_dreamteam': False},
#    'explain': [{'fixture': 73,
#      'stats': [{'identifier': 'minutes', 'points': 2, 'value': 60}]}]},
#   {'id': 707,
#    'stats': {'minutes': 0,
#     'goals_scored': 0,
#     'assists': 0,
#     'clean_sheets': 0,
#     'goals_conceded': 0,
#     'own_goals': 0,
#     'penalties_saved': 0,
#     'penalties_missed': 0,
#     'yellow_cards': 0,
#     'red_cards': 0,
#     'saves': 0,
#     'bonus': 0,
#     'bps': 0,
#     'influence': '0.0',
#     'creativity': '0.0',
#     'threat': '0.0',
#     'ict_index': '0.0',
#     'starts': 0,
#     'expected_goals': '0.00',
#     'expected_assists': '0.00',
#     'expected_goal_involvements': '0.00',
#     'expected_goals_conceded': '0.00',
#     'total_points': 0,
#     'in_dreamteam': False},
#    'explain': [{'fixture': 76,
#      'stats': [{'identifier': 'minutes', 'points': 0, 'value': 0}]}]},
#   {'id': 708,
#    'stats': {'minutes': 45,
#     'goals_scored': 0,
#     'assists': 0,
#     'clean_sheets': 0,
#     'goals_conceded': 1,
#     'own_goals': 0,
#     'penalties_saved': 0,
#     'penalties_missed': 0,
#     'yellow_cards': 0,
#     'red_cards': 0,
#     'saves': 0,
#     'bonus': 0,
#     'bps': 0,
#     'influence': '6.4',
#     'creativity': '2.0',
#     'threat': '26.0',
#     'ict_index': '3.4',
#     'starts': 0,
#     'expected_goals': '0.78',
#     'expected_assists': '0.01',
#     'expected_goal_involvements': '0.79',
#     'expected_goals_conceded': '1.66',
#     'total_points': 1,
#     'in_dreamteam': False},
#    'explain': [{'fixture': 72,
#      'stats': [{'identifier': 'minutes', 'points': 1, 'value': 45}]}]},
#   {'id': 709,
#    'stats': {'minutes': 86,
#     'goals_scored': 0,
#     'assists': 0,
#     'clean_sheets': 0,
#     'goals_conceded': 1,
#     'own_goals': 0,
#     'penalties_saved': 0,
#     'penalties_missed': 0,
#     'yellow_cards': 0,
#     'red_cards': 0,
#     'saves': 0,
#     'bonus': 0,
#     'bps': 14,
#     'influence': '12.4',
#     'creativity': '39.6',
#     'threat': '2.0',
#     'ict_index': '5.4',
#     'starts': 1,
#     'expected_goals': '0.00',
#     'expected_assists': '0.12',
#     'expected_goal_involvements': '0.12',
#     'expected_goals_conceded': '0.95',
#     'total_points': 2,
#     'in_dreamteam': False},
#    'explain': [{'fixture': 78,
#      'stats': [{'identifier': 'minutes', 'points': 2, 'value': 86}]}]},
#   {'id': 710,
#    'stats': {'minutes': 0,
#     'goals_scored': 0,
#     'assists': 0,
#     'clean_sheets': 0,
#     'goals_conceded': 0,
#     'own_goals': 0,
#     'penalties_saved': 0,
#     'penalties_missed': 0,
#     'yellow_cards': 0,
#     'red_cards': 0,
#     'saves': 0,
#     'bonus': 0,
#     'bps': 0,
#     'influence': '0.0',
#     'creativity': '0.0',
#     'threat': '0.0',
#     'ict_index': '0.0',
#     'starts': 0,
#     'expected_goals': '0.00',
#     'expected_assists': '0.00',
#     'expected_goal_involvements': '0.00',
#     'expected_goals_conceded': '0.00',
#     'total_points': 0,
#     'in_dreamteam': False},
#    'explain': [{'fixture': 74,
#      'stats': [{'identifier': 'minutes', 'points': 0, 'value': 0}]}]},
#   {'id': 711,
#    'stats': {'minutes': 0,
#     'goals_scored': 0,
#     'assists': 0,
#     'clean_sheets': 0,
#     'goals_conceded': 0,
#     'own_goals': 0,
#     'penalties_saved': 0,
#     'penalties_missed': 0,
#     'yellow_cards': 0,
#     'red_cards': 0,
#     'saves': 0,
#     'bonus': 0,
#     'bps': 0,
#     'influence': '0.0',
#     'creativity': '0.0',
#     'threat': '0.0',
#     'ict_index': '0.0',
#     'starts': 0,
#     'expected_goals': '0.00',
#     'expected_assists': '0.00',
#     'expected_goal_involvements': '0.00',
#     'expected_goals_conceded': '0.00',
#     'total_points': 0,
#     'in_dreamteam': False},
#    'explain': [{'fixture': 74,
#      'stats': [{'identifier': 'minutes', 'points': 0, 'value': 0}]}]},
#   {'id': 712,
#    'stats': {'minutes': 90,
#     'goals_scored': 0,
#     'assists': 0,
#     'clean_sheets': 1,
#     'goals_conceded': 0,
#     'own_goals': 0,
#     'penalties_saved': 0,
#     'penalties_missed': 0,
#     'yellow_cards': 0,
#     'red_cards': 0,
#     'saves': 0,
#     'bonus': 0,
#     'bps': 11,
#     'influence': '12.4',
#     'creativity': '7.8',
#     'threat': '21.0',
#     'ict_index': '4.1',
#     'starts': 1,
#     'expected_goals': '0.03',
#     'expected_assists': '0.17',
#     'expected_goal_involvements': '0.20',
#     'expected_goals_conceded': '0.81',
#     'total_points': 3,
#     'in_dreamteam': False},
#    'explain': [{'fixture': 74,
#      'stats': [{'identifier': 'minutes', 'points': 2, 'value': 90},
#       {'identifier': 'clean_sheets', 'points': 1, 'value': 1}]}]},
#   {'id': 713,
#    'stats': {'minutes': 75,
#     'goals_scored': 0,
#     'assists': 0,
#     'clean_sheets': 1,
#     'goals_conceded': 0,
#     'own_goals': 0,
#     'penalties_saved': 0,
#     'penalties_missed': 0,
#     'yellow_cards': 0,
#     'red_cards': 0,
#     'saves': 0,
#     'bonus': 0,
#     'bps': 6,
#     'influence': '11.6',
#     'creativity': '11.5',
#     'threat': '4.0',
#     'ict_index': '2.7',
#     'starts': 1,
#     'expected_goals': '0.00',
#     'expected_assists': '0.05',
#     'expected_goal_involvements': '0.05',
#     'expected_goals_conceded': '0.78',
#     'total_points': 3,
#     'in_dreamteam': False},
#    'explain': [{'fixture': 74,
#      'stats': [{'identifier': 'minutes', 'points': 2, 'value': 75},
#       {'identifier': 'clean_sheets', 'points': 1, 'value': 1}]}]},
#   {'id': 714,
#    'stats': {'minutes': 14,
#     'goals_scored': 0,
#     'assists': 0,
#     'clean_sheets': 0,
#     'goals_conceded': 0,
#     'own_goals': 0,
#     'penalties_saved': 0,
#     'penalties_missed': 0,
#     'yellow_cards': 0,
#     'red_cards': 0,
#     'saves': 0,
#     'bonus': 0,
#     'bps': 2,
#     'influence': '0.0',
#     'creativity': '0.3',
#     'threat': '2.0',
#     'ict_index': '0.2',
#     'starts': 0,
#     'expected_goals': '0.00',
#     'expected_assists': '0.00',
#     'expected_goal_involvements': '0.00',
#     'expected_goals_conceded': '0.03',
#     'total_points': 1,
#     'in_dreamteam': False},
#    'explain': [{'fixture': 74,
#      'stats': [{'identifier': 'minutes', 'points': 1, 'value': 14}]}]},
#   {'id': 715,
#    'stats': {'minutes': 0,
#     'goals_scored': 0,
#     'assists': 0,
#     'clean_sheets': 0,
#     'goals_conceded': 0,
#     'own_goals': 0,
#     'penalties_saved': 0,
#     'penalties_missed': 0,
#     'yellow_cards': 0,
#     'red_cards': 0,
#     'saves': 0,
#     'bonus': 0,
#     'bps': 0,
#     'influence': '0.0',
#     'creativity': '0.0',
#     'threat': '0.0',
#     'ict_index': '0.0',
#     'starts': 0,
#     'expected_goals': '0.00',
#     'expected_assists': '0.00',
#     'expected_goal_involvements': '0.00',
#     'expected_goals_conceded': '0.00',
#     'total_points': 0,
#     'in_dreamteam': False},
#    'explain': [{'fixture': 80,
#      'stats': [{'identifier': 'minutes', 'points': 0, 'value': 0}]}]},
#   {'id': 716,
#    'stats': {'minutes': 0,
#     'goals_scored': 0,
#     'assists': 0,
#     'clean_sheets': 0,
#     'goals_conceded': 0,
#     'own_goals': 0,
#     'penalties_saved': 0,
#     'penalties_missed': 0,
#     'yellow_cards': 0,
#     'red_cards': 0,
#     'saves': 0,
#     'bonus': 0,
#     'bps': 0,
#     'influence': '0.0',
#     'creativity': '0.0',
#     'threat': '0.0',
#     'ict_index': '0.0',
#     'starts': 0,
#     'expected_goals': '0.00',
#     'expected_assists': '0.00',
#     'expected_goal_involvements': '0.00',
#     'expected_goals_conceded': '0.00',
#     'total_points': 0,
#     'in_dreamteam': False},
#    'explain': [{'fixture': 73,
#      'stats': [{'identifier': 'minutes', 'points': 0, 'value': 0}]}]},
#   {'id': 717,
#    'stats': {'minutes': 0,
#     'goals_scored': 0,
#     'assists': 0,
#     'clean_sheets': 0,
#     'goals_conceded': 0,
#     'own_goals': 0,
#     'penalties_saved': 0,
#     'penalties_missed': 0,
#     'yellow_cards': 0,
#     'red_cards': 0,
#     'saves': 0,
#     'bonus': 0,
#     'bps': 0,
#     'influence': '0.0',
#     'creativity': '0.0',
#     'threat': '0.0',
#     'ict_index': '0.0',
#     'starts': 0,
#     'expected_goals': '0.00',
#     'expected_assists': '0.00',
#     'expected_goal_involvements': '0.00',
#     'expected_goals_conceded': '0.00',
#     'total_points': 0,
#     'in_dreamteam': False},
#    'explain': [{'fixture': 73,
#      'stats': [{'identifier': 'minutes', 'points': 0, 'value': 0}]}]},
#   {'id': 718,
#    'stats': {'minutes': 0,
#     'goals_scored': 0,
#     'assists': 0,
#     'clean_sheets': 0,
#     'goals_conceded': 0,
#     'own_goals': 0,
#     'penalties_saved': 0,
#     'penalties_missed': 0,
#     'yellow_cards': 0,
#     'red_cards': 0,
#     'saves': 0,
#     'bonus': 0,
#     'bps': 0,
#     'influence': '0.0',
#     'creativity': '0.0',
#     'threat': '0.0',
#     'ict_index': '0.0',
#     'starts': 0,
#     'expected_goals': '0.00',
#     'expected_assists': '0.00',
#     'expected_goal_involvements': '0.00',
#     'expected_goals_conceded': '0.00',
#     'total_points': 0,
#     'in_dreamteam': False},
#    'explain': [{'fixture': 73,
#      'stats': [{'identifier': 'minutes', 'points': 0, 'value': 0}]}]},
#   {'id': 719,
#    'stats': {'minutes': 0,
#     'goals_scored': 0,
#     'assists': 0,
#     'clean_sheets': 0,
#     'goals_conceded': 0,
#     'own_goals': 0,
#     'penalties_saved': 0,
#     'penalties_missed': 0,
#     'yellow_cards': 0,
#     'red_cards': 0,
#     'saves': 0,
#     'bonus': 0,
#     'bps': 0,
#     'influence': '0.0',
#     'creativity': '0.0',
#     'threat': '0.0',
#     'ict_index': '0.0',
#     'starts': 0,
#     'expected_goals': '0.00',
#     'expected_assists': '0.00',
#     'expected_goal_involvements': '0.00',
#     'expected_goals_conceded': '0.00',
#     'total_points': 0,
#     'in_dreamteam': False},
#    'explain': [{'fixture': 75,
#      'stats': [{'identifier': 'minutes', 'points': 0, 'value': 0}]}]},
#   {'id': 720,
#    'stats': {'minutes': 0,
#     'goals_scored': 0,
#     'assists': 0,
#     'clean_sheets': 0,
#     'goals_conceded': 0,
#     'own_goals': 0,
#     'penalties_saved': 0,
#     'penalties_missed': 0,
#     'yellow_cards': 0,
#     'red_cards': 0,
#     'saves': 0,
#     'bonus': 0,
#     'bps': 0,
#     'influence': '0.0',
#     'creativity': '0.0',
#     'threat': '0.0',
#     'ict_index': '0.0',
#     'starts': 0,
#     'expected_goals': '0.00',
#     'expected_assists': '0.00',
#     'expected_goal_involvements': '0.00',
#     'expected_goals_conceded': '0.00',
#     'total_points': 0,
#     'in_dreamteam': False},
#    'explain': [{'fixture': 74,
#      'stats': [{'identifier': 'minutes', 'points': 0, 'value': 0}]}]},
#   {'id': 721,
#    'stats': {'minutes': 0,
#     'goals_scored': 0,
#     'assists': 0,
#     'clean_sheets': 0,
#     'goals_conceded': 0,
#     'own_goals': 0,
#     'penalties_saved': 0,
#     'penalties_missed': 0,
#     'yellow_cards': 0,
#     'red_cards': 0,
#     'saves': 0,
#     'bonus': 0,
#     'bps': 0,
#     'influence': '0.0',
#     'creativity': '0.0',
#     'threat': '0.0',
#     'ict_index': '0.0',
#     'starts': 0,
#     'expected_goals': '0.00',
#     'expected_assists': '0.00',
#     'expected_goal_involvements': '0.00',
#     'expected_goals_conceded': '0.00',
#     'total_points': 0,
#     'in_dreamteam': False},
#    'explain': [{'fixture': 74,
#      'stats': [{'identifier': 'minutes', 'points': 0, 'value': 0}]}]},
#   {'id': 722,
#    'stats': {'minutes': 0,
#     'goals_scored': 0,
#     'assists': 0,
#     'clean_sheets': 0,
#     'goals_conceded': 0,
#     'own_goals': 0,
#     'penalties_saved': 0,
#     'penalties_missed': 0,
#     'yellow_cards': 0,
#     'red_cards': 0,
#     'saves': 0,
#     'bonus': 0,
#     'bps': 0,
#     'influence': '0.0',
#     'creativity': '0.0',
#     'threat': '0.0',
#     'ict_index': '0.0',
#     'starts': 0,
#     'expected_goals': '0.00',
#     'expected_assists': '0.00',
#     'expected_goal_involvements': '0.00',
#     'expected_goals_conceded': '0.00',
#     'total_points': 0,
#     'in_dreamteam': False},
#    'explain': [{'fixture': 77,
#      'stats': [{'identifier': 'minutes', 'points': 0, 'value': 0}]}]},
#   {'id': 723,
#    'stats': {'minutes': 0,
#     'goals_scored': 0,
#     'assists': 0,
#     'clean_sheets': 0,
#     'goals_conceded': 0,
#     'own_goals': 0,
#     'penalties_saved': 0,
#     'penalties_missed': 0,
#     'yellow_cards': 0,
#     'red_cards': 0,
#     'saves': 0,
#     'bonus': 0,
#     'bps': 0,
#     'influence': '0.0',
#     'creativity': '0.0',
#     'threat': '0.0',
#     'ict_index': '0.0',
#     'starts': 0,
#     'expected_goals': '0.00',
#     'expected_assists': '0.00',
#     'expected_goal_involvements': '0.00',
#     'expected_goals_conceded': '0.00',
#     'total_points': 0,
#     'in_dreamteam': False},
#    'explain': [{'fixture': 73,
#      'stats': [{'identifier': 'minutes', 'points': 0, 'value': 0}]}]},
#   {'id': 724,
#    'stats': {'minutes': 0,
#     'goals_scored': 0,
#     'assists': 0,
#     'clean_sheets': 0,
#     'goals_conceded': 0,
#     'own_goals': 0,
#     'penalties_saved': 0,
#     'penalties_missed': 0,
#     'yellow_cards': 0,
#     'red_cards': 0,
#     'saves': 0,
#     'bonus': 0,
#     'bps': 0,
#     'influence': '0.0',
#     'creativity': '0.0',
#     'threat': '0.0',
#     'ict_index': '0.0',
#     'starts': 0,
#     'expected_goals': '0.00',
#     'expected_assists': '0.00',
#     'expected_goal_involvements': '0.00',
#     'expected_goals_conceded': '0.00',
#     'total_points': 0,
#     'in_dreamteam': False},
#    'explain': [{'fixture': 74,
#      'stats': [{'identifier': 'minutes', 'points': 0, 'value': 0}]}]},
#   {'id': 725,
#    'stats': {'minutes': 0,
#     'goals_scored': 0,
#     'assists': 0,
#     'clean_sheets': 0,
#     'goals_conceded': 0,
#     'own_goals': 0,
#     'penalties_saved': 0,
#     'penalties_missed': 0,
#     'yellow_cards': 0,
#     'red_cards': 0,
#     'saves': 0,
#     'bonus': 0,
#     'bps': 0,
#     'influence': '0.0',
#     'creativity': '0.0',
#     'threat': '0.0',
#     'ict_index': '0.0',
#     'starts': 0,
#     'expected_goals': '0.00',
#     'expected_assists': '0.00',
#     'expected_goal_involvements': '0.00',
#     'expected_goals_conceded': '0.00',
#     'total_points': 0,
#     'in_dreamteam': False},
#    'explain': [{'fixture': 78,
#      'stats': [{'identifier': 'minutes', 'points': 0, 'value': 0}]}]},
#   {'id': 726,
#    'stats': {'minutes': 0,
#     'goals_scored': 0,
#     'assists': 0,
#     'clean_sheets': 0,
#     'goals_conceded': 0,
#     'own_goals': 0,
#     'penalties_saved': 0,
#     'penalties_missed': 0,
#     'yellow_cards': 0,
#     'red_cards': 0,
#     'saves': 0,
#     'bonus': 0,
#     'bps': 0,
#     'influence': '0.0',
#     'creativity': '0.0',
#     'threat': '0.0',
#     'ict_index': '0.0',
#     'starts': 0,
#     'expected_goals': '0.00',
#     'expected_assists': '0.00',
#     'expected_goal_involvements': '0.00',
#     'expected_goals_conceded': '0.00',
#     'total_points': 0,
#     'in_dreamteam': False},
#    'explain': [{'fixture': 72,
#      'stats': [{'identifier': 'minutes', 'points': 0, 'value': 0}]}]}]}

# %%
#individual player data
data2['elements'][354]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_17528\1296047809.py in <module>
#       1 #individual player data
# ----> 2 data2['elements'][354]
#
# IndexError: list index out of range

# %%
data['element_types']
# Out:
# [{'id': 1,
#   'plural_name': 'Goalkeepers',
#   'plural_name_short': 'GKP',
#   'singular_name': 'Goalkeeper',
#   'singular_name_short': 'GKP',
#   'squad_select': 2,
#   'squad_min_play': 1,
#   'squad_max_play': 1,
#   'ui_shirt_specific': True,
#   'sub_positions_locked': [12],
#   'element_count': 85},
#  {'id': 2,
#   'plural_name': 'Defenders',
#   'plural_name_short': 'DEF',
#   'singular_name': 'Defender',
#   'singular_name_short': 'DEF',
#   'squad_select': 5,
#   'squad_min_play': 3,
#   'squad_max_play': 5,
#   'ui_shirt_specific': False,
#   'sub_positions_locked': [],
#   'element_count': 231},
#  {'id': 3,
#   'plural_name': 'Midfielders',
#   'plural_name_short': 'MID',
#   'singular_name': 'Midfielder',
#   'singular_name_short': 'MID',
#   'squad_select': 5,
#   'squad_min_play': 2,
#   'squad_max_play': 5,
#   'ui_shirt_specific': False,
#   'sub_positions_locked': [],
#   'element_count': 307},
#  {'id': 4,
#   'plural_name': 'Forwards',
#   'plural_name_short': 'FWD',
#   'singular_name': 'Forward',
#   'singular_name_short': 'FWD',
#   'squad_select': 3,
#   'squad_min_play': 1,
#   'squad_max_play': 3,
#   'ui_shirt_specific': False,
#   'sub_positions_locked': [],
#   'element_count': 91}]

# %%
data2['elements'][63]['stats']
# Out:
# {'minutes': 74,
#  'goals_scored': 0,
#  'assists': 0,
#  'clean_sheets': 0,
#  'goals_conceded': 1,
#  'own_goals': 0,
#  'penalties_saved': 0,
#  'penalties_missed': 0,
#  'yellow_cards': 0,
#  'red_cards': 0,
#  'saves': 0,
#  'bonus': 0,
#  'bps': 4,
#  'influence': '5.2',
#  'creativity': '13.8',
#  'threat': '16.0',
#  'ict_index': '3.5',
#  'starts': 1,
#  'expected_goals': '0.16',
#  'expected_assists': '0.02',
#  'expected_goal_involvements': '0.18',
#  'expected_goals_conceded': '0.88',
#  'total_points': 2,
#  'in_dreamteam': False}

# %%
base_url = 'https://fantasy.premierleague.com/api/element-summary/355/' 
data3 = requests.get(base_url).json() 
pprint(data3, indent=2, depth=1, compact=True)
# Out:
# {'fixtures': [...], 'history': [...], 'history_past': [...]}

# %%
data3
# Out:
# {'fixtures': [{'id': 86,
#    'code': 2367623,
#    'team_h': 13,
#    'team_h_score': None,
#    'team_a': 5,
#    'team_a_score': None,
#    'event': 9,
#    'finished': False,
#    'minutes': 0,
#    'provisional_start_time': False,
#    'kickoff_time': '2023-10-21T14:00:00Z',
#    'event_name': 'Gameweek 9',
#    'is_home': True,
#    'difficulty': 3},
#   {'id': 98,
#    'code': 2367635,
#    'team_h': 14,
#    'team_h_score': None,
#    'team_a': 13,
#    'team_a_score': None,
#    'event': 10,
#    'finished': False,
#    'minutes': 0,
#    'provisional_start_time': False,
#    'kickoff_time': '2023-10-29T15:30:00Z',
#    'event_name': 'Gameweek 10',
#    'is_home': False,
#    'difficulty': 4},
#   {'id': 106,
#    'code': 2367643,
#    'team_h': 13,
#    'team_h_score': None,
#    'team_a': 3,
#    'team_a_score': None,
#    'event': 11,
#    'finished': False,
#    'minutes': 0,
#    'provisional_start_time': False,
#    'kickoff_time': '2023-11-04T15:00:00Z',
#    'event_name': 'Gameweek 11',
#    'is_home': True,
#    'difficulty': 2},
#   {'id': 115,
#    'code': 2367652,
#    'team_h': 7,
#    'team_h_score': None,
#    'team_a': 13,
#    'team_a_score': None,
#    'event': 12,
#    'finished': False,
#    'minutes': 0,
#    'provisional_start_time': False,
#    'kickoff_time': '2023-11-12T16:30:00Z',
#    'event_name': 'Gameweek 12',
#    'is_home': False,
#    'difficulty': 3},
#   {'id': 126,
#    'code': 2367663,
#    'team_h': 13,
#    'team_h_score': None,
#    'team_a': 11,
#    'team_a_score': None,
#    'event': 13,
#    'finished': False,
#    'minutes': 0,
#    'provisional_start_time': False,
#    'kickoff_time': '2023-11-25T15:00:00Z',
#    'event_name': 'Gameweek 13',
#    'is_home': True,
#    'difficulty': 4},
#   {'id': 137,
#    'code': 2367674,
#    'team_h': 13,
#    'team_h_score': None,
#    'team_a': 18,
#    'team_a_score': None,
#    'event': 14,
#    'finished': False,
#    'minutes': 0,
#    'provisional_start_time': False,
#    'kickoff_time': '2023-12-02T15:00:00Z',
#    'event_name': 'Gameweek 14',
#    'is_home': True,
#    'difficulty': 3},
#   {'id': 141,
#    'code': 2367678,
#    'team_h': 2,
#    'team_h_score': None,
#    'team_a': 13,
#    'team_a_score': None,
#    'event': 15,
#    'finished': False,
#    'minutes': 0,
#    'provisional_start_time': False,
#    'kickoff_time': '2023-12-05T19:45:00Z',
#    'event_name': 'Gameweek 15',
#    'is_home': False,
#    'difficulty': 3},
#   {'id': 156,
#    'code': 2367693,
#    'team_h': 12,
#    'team_h_score': None,
#    'team_a': 13,
#    'team_a_score': None,
#    'event': 16,
#    'finished': False,
#    'minutes': 0,
#    'provisional_start_time': False,
#    'kickoff_time': '2023-12-09T15:00:00Z',
#    'event_name': 'Gameweek 16',
#    'is_home': False,
#    'difficulty': 2},
#   {'id': 167,
#    'code': 2367704,
#    'team_h': 13,
#    'team_h_score': None,
#    'team_a': 8,
#    'team_a_score': None,
#    'event': 17,
#    'finished': False,
#    'minutes': 0,
#    'provisional_start_time': False,
#    'kickoff_time': '2023-12-16T15:00:00Z',
#    'event_name': 'Gameweek 17',
#    'is_home': True,
#    'difficulty': 2},
#   {'id': 187,
#    'code': 2367724,
#    'team_h': 9,
#    'team_h_score': None,
#    'team_a': 13,
#    'team_a_score': None,
#    'event': 19,
#    'finished': False,
#    'minutes': 0,
#    'provisional_start_time': False,
#    'kickoff_time': '2023-12-26T15:00:00Z',
#    'event_name': 'Gameweek 19',
#    'is_home': False,
#    'difficulty': 2},
#   {'id': 196,
#    'code': 2367733,
#    'team_h': 13,
#    'team_h_score': None,
#    'team_a': 17,
#    'team_a_score': None,
#    'event': 20,
#    'finished': False,
#    'minutes': 0,
#    'provisional_start_time': False,
#    'kickoff_time': '2023-12-30T15:00:00Z',
#    'event_name': 'Gameweek 20',
#    'is_home': True,
#    'difficulty': 2},
#   {'id': 209,
#    'code': 2367746,
#    'team_h': 15,
#    'team_h_score': None,
#    'team_a': 13,
#    'team_a_score': None,
#    'event': 21,
#    'finished': False,
#    'minutes': 0,
#    'provisional_start_time': False,
#    'kickoff_time': '2024-01-13T15:00:00Z',
#    'event_name': 'Gameweek 21',
#    'is_home': False,
#    'difficulty': 4},
#   {'id': 220,
#    'code': 2367757,
#    'team_h': 13,
#    'team_h_score': None,
#    'team_a': 6,
#    'team_a_score': None,
#    'event': 22,
#    'finished': False,
#    'minutes': 0,
#    'provisional_start_time': False,
#    'kickoff_time': '2024-01-31T20:00:00Z',
#    'event_name': 'Gameweek 22',
#    'is_home': True,
#    'difficulty': 2},
#   {'id': 223,
#    'code': 2367760,
#    'team_h': 4,
#    'team_h_score': None,
#    'team_a': 13,
#    'team_a_score': None,
#    'event': 23,
#    'finished': False,
#    'minutes': 0,
#    'provisional_start_time': False,
#    'kickoff_time': '2024-02-03T15:00:00Z',
#    'event_name': 'Gameweek 23',
#    'is_home': False,
#    'difficulty': 3},
#   {'id': 236,
#    'code': 2367773,
#    'team_h': 13,
#    'team_h_score': None,
#    'team_a': 9,
#    'team_a_score': None,
#    'event': 24,
#    'finished': False,
#    'minutes': 0,
#    'provisional_start_time': False,
#    'kickoff_time': '2024-02-10T15:00:00Z',
#    'event_name': 'Gameweek 24',
#    'is_home': True,
#    'difficulty': 2},
#   {'id': 246,
#    'code': 2367783,
#    'team_h': 13,
#    'team_h_score': None,
#    'team_a': 7,
#    'team_a_score': None,
#    'event': 25,
#    'finished': False,
#    'minutes': 0,
#    'provisional_start_time': False,
#    'kickoff_time': '2024-02-17T15:00:00Z',
#    'event_name': 'Gameweek 25',
#    'is_home': True,
#    'difficulty': 3},
#   {'id': 253,
#    'code': 2367788,
#    'team_h': 3,
#    'team_h_score': None,
#    'team_a': 13,
#    'team_a_score': None,
#    'event': 26,
#    'finished': False,
#    'minutes': 0,
#    'provisional_start_time': False,
#    'kickoff_time': '2024-02-24T15:00:00Z',
#    'event_name': 'Gameweek 26',
#    'is_home': False,
#    'difficulty': 2},
#   {'id': 266,
#    'code': 2367803,
#    'team_h': 13,
#    'team_h_score': None,
#    'team_a': 14,
#    'team_a_score': None,
#    'event': 27,
#    'finished': False,
#    'minutes': 0,
#    'provisional_start_time': False,
#    'kickoff_time': '2024-03-02T15:00:00Z',
#    'event_name': 'Gameweek 27',
#    'is_home': True,
#    'difficulty': 3},
#   {'id': 277,
#    'code': 2367814,
#    'team_h': 11,
#    'team_h_score': None,
#    'team_a': 13,
#    'team_a_score': None,
#    'event': 28,
#    'finished': False,
#    'minutes': 0,
#    'provisional_start_time': False,
#    'kickoff_time': '2024-03-09T15:00:00Z',
#    'event_name': 'Gameweek 28',
#    'is_home': False,
#    'difficulty': 4},
#   {'id': 282,
#    'code': 2367819,
#    'team_h': 5,
#    'team_h_score': None,
#    'team_a': 13,
#    'team_a_score': None,
#    'event': 29,
#    'finished': False,
#    'minutes': 0,
#    'provisional_start_time': False,
#    'kickoff_time': '2024-03-16T15:00:00Z',
#    'event_name': 'Gameweek 29',
#    'is_home': False,
#    'difficulty': 3},
#   {'id': 296,
#    'code': 2367833,
#    'team_h': 13,
#    'team_h_score': None,
#    'team_a': 1,
#    'team_a_score': None,
#    'event': 30,
#    'finished': False,
#    'minutes': 0,
#    'provisional_start_time': False,
#    'kickoff_time': '2024-03-30T15:00:00Z',
#    'event_name': 'Gameweek 30',
#    'is_home': True,
#    'difficulty': 4},
#   {'id': 309,
#    'code': 2367846,
#    'team_h': 13,
#    'team_h_score': None,
#    'team_a': 2,
#    'team_a_score': None,
#    'event': 31,
#    'finished': False,
#    'minutes': 0,
#    'provisional_start_time': False,
#    'kickoff_time': '2024-04-03T19:00:00Z',
#    'event_name': 'Gameweek 31',
#    'is_home': True,
#    'difficulty': 3},
#   {'id': 313,
#    'code': 2367850,
#    'team_h': 8,
#    'team_h_score': None,
#    'team_a': 13,
#    'team_a_score': None,
#    'event': 32,
#    'finished': False,
#    'minutes': 0,
#    'provisional_start_time': False,
#    'kickoff_time': '2024-04-06T14:00:00Z',
#    'event_name': 'Gameweek 32',
#    'is_home': False,
#    'difficulty': 2},
#   {'id': 327,
#    'code': 2367864,
#    'team_h': 13,
#    'team_h_score': None,
#    'team_a': 12,
#    'team_a_score': None,
#    'event': 33,
#    'finished': False,
#    'minutes': 0,
#    'provisional_start_time': False,
#    'kickoff_time': '2024-04-13T14:00:00Z',
#    'event_name': 'Gameweek 33',
#    'is_home': True,
#    'difficulty': 2},
#   {'id': 339,
#    'code': 2367876,
#    'team_h': 18,
#    'team_h_score': None,
#    'team_a': 13,
#    'team_a_score': None,
#    'event': 34,
#    'finished': False,
#    'minutes': 0,
#    'provisional_start_time': False,
#    'kickoff_time': '2024-04-20T14:00:00Z',
#    'event_name': 'Gameweek 34',
#    'is_home': False,
#    'difficulty': 3},
#   {'id': 347,
#    'code': 2367884,
#    'team_h': 16,
#    'team_h_score': None,
#    'team_a': 13,
#    'team_a_score': None,
#    'event': 35,
#    'finished': False,
#    'minutes': 0,
#    'provisional_start_time': False,
#    'kickoff_time': '2024-04-27T14:00:00Z',
#    'event_name': 'Gameweek 35',
#    'is_home': False,
#    'difficulty': 2},
#   {'id': 359,
#    'code': 2367896,
#    'team_h': 13,
#    'team_h_score': None,
#    'team_a': 20,
#    'team_a_score': None,
#    'event': 36,
#    'finished': False,
#    'minutes': 0,
#    'provisional_start_time': False,
#    'kickoff_time': '2024-05-04T14:00:00Z',
#    'event_name': 'Gameweek 36',
#    'is_home': True,
#    'difficulty': 2},
#   {'id': 364,
#    'code': 2367901,
#    'team_h': 10,
#    'team_h_score': None,
#    'team_a': 13,
#    'team_a_score': None,
#    'event': 37,
#    'finished': False,
#    'minutes': 0,
#    'provisional_start_time': False,
#    'kickoff_time': '2024-05-11T14:00:00Z',
#    'event_name': 'Gameweek 37',
#    'is_home': False,
#    'difficulty': 2},
#   {'id': 379,
#    'code': 2367916,
#    'team_h': 13,
#    'team_h_score': None,
#    'team_a': 19,
#    'team_a_score': None,
#    'event': 38,
#    'finished': False,
#    'minutes': 0,
#    'provisional_start_time': False,
#    'kickoff_time': '2024-05-19T15:00:00Z',
#    'event_name': 'Gameweek 38',
#    'is_home': True,
#    'difficulty': 2},
#   {'id': 176,
#    'code': 2367713,
#    'team_h': 13,
#    'team_h_score': None,
#    'team_a': 4,
#    'team_a_score': None,
#    'event': None,
#    'finished': False,
#    'minutes': 0,
#    'provisional_start_time': False,
#    'kickoff_time': None,
#    'is_home': True,
#    'difficulty': 3}],
#  'history': [{'element': 355,
#    'fixture': 1,
#    'opponent_team': 6,
#    'total_points': 13,
#    'was_home': False,
#    'kickoff_time': '2023-08-11T19:00:00Z',
#    'team_h_score': 0,
#    'team_a_score': 3,
#    'round': 1,
#    'minutes': 79,
#    'goals_scored': 2,
#    'assists': 0,
#    'clean_sheets': 1,
#    'goals_conceded': 0,
#    'own_goals': 0,
#    'penalties_saved': 0,
#    'penalties_missed': 0,
#    'yellow_cards': 0,
#    'red_cards': 0,
#    'saves': 0,
#    'bonus': 3,
#    'bps': 56,
#    'influence': '67.6',
#    'creativity': '23.7',
#    'threat': '48.0',
#    'ict_index': '13.9',
#    'starts': 1,
#    'expected_goals': '0.60',
#    'expected_assists': '0.05',
#    'expected_goal_involvements': '0.65',
#    'expected_goals_conceded': '0.23',
#    'value': 140,
#    'transfers_balance': 0,
#    'selected': 7200159,
#    'transfers_in': 0,
#    'transfers_out': 0},
#   {'element': 355,
#    'fixture': 16,
#    'opponent_team': 15,
#    'total_points': 2,
#    'was_home': True,
#    'kickoff_time': '2023-08-19T19:00:00Z',
#    'team_h_score': 1,
#    'team_a_score': 0,
#    'round': 2,
#    'minutes': 90,
#    'goals_scored': 0,
#    'assists': 0,
#    'clean_sheets': 1,
#    'goals_conceded': 0,
#    'own_goals': 0,
#    'penalties_saved': 0,
#    'penalties_missed': 0,
#    'yellow_cards': 0,
#    'red_cards': 0,
#    'saves': 0,
#    'bonus': 0,
#    'bps': 1,
#    'influence': '3.2',
#    'creativity': '11.8',
#    'threat': '48.0',
#    'ict_index': '6.3',
#    'starts': 1,
#    'expected_goals': '0.43',
#    'expected_assists': '0.02',
#    'expected_goal_involvements': '0.45',
#    'expected_goals_conceded': '0.29',
#    'value': 140,
#    'transfers_balance': 132944,
#    'selected': 8231668,
#    'transfers_in': 161773,
#    'transfers_out': 28829},
#   {'element': 355,
#    'fixture': 30,
#    'opponent_team': 17,
#    'total_points': 4,
#    'was_home': False,
#    'kickoff_time': '2023-08-27T13:00:00Z',
#    'team_h_score': 1,
#    'team_a_score': 2,
#    'round': 3,
#    'minutes': 90,
#    'goals_scored': 1,
#    'assists': 0,
#    'clean_sheets': 0,
#    'goals_conceded': 1,
#    'own_goals': 0,
#    'penalties_saved': 0,
#    'penalties_missed': 1,
#    'yellow_cards': 0,
#    'red_cards': 0,
#    'saves': 0,
#    'bonus': 0,
#    'bps': 14,
#    'influence': '34.2',
#    'creativity': '12.9',
#    'threat': '97.0',
#    'ict_index': '14.4',
#    'starts': 1,
#    'expected_goals': '1.93',
#    'expected_assists': '0.01',
#    'expected_goal_involvements': '1.94',
#    'expected_goals_conceded': '0.73',
#    'value': 140,
#    'transfers_balance': 64397,
#    'selected': 8571562,
#    'transfers_in': 91189,
#    'transfers_out': 26792},
#   {'element': 355,
#    'fixture': 39,
#    'opponent_team': 10,
#    'total_points': 20,
#    'was_home': True,
#    'kickoff_time': '2023-09-02T14:00:00Z',
#    'team_h_score': 5,
#    'team_a_score': 1,
#    'round': 4,
#    'minutes': 90,
#    'goals_scored': 3,
#    'assists': 1,
#    'clean_sheets': 0,
#    'goals_conceded': 1,
#    'own_goals': 0,
#    'penalties_saved': 0,
#    'penalties_missed': 0,
#    'yellow_cards': 0,
#    'red_cards': 0,
#    'saves': 0,
#    'bonus': 3,
#    'bps': 90,
#    'influence': '119.4',
#    'creativity': '23.4',
#    'threat': '55.0',
#    'ict_index': '19.8',
#    'starts': 1,
#    'expected_goals': '1.58',
#    'expected_assists': '0.10',
#    'expected_goal_involvements': '1.68',
#    'expected_goals_conceded': '1.45',
#    'value': 140,
#    'transfers_balance': 27163,
#    'selected': 8787213,
#    'transfers_in': 53175,
#    'transfers_out': 26012},
#   {'element': 355,
#    'fixture': 49,
#    'opponent_team': 19,
#    'total_points': 6,
#    'was_home': False,
#    'kickoff_time': '2023-09-16T14:00:00Z',
#    'team_h_score': 1,
#    'team_a_score': 3,
#    'round': 5,
#    'minutes': 90,
#    'goals_scored': 1,
#    'assists': 0,
#    'clean_sheets': 0,
#    'goals_conceded': 1,
#    'own_goals': 0,
#    'penalties_saved': 0,
#    'penalties_missed': 0,
#    'yellow_cards': 0,
#    'red_cards': 0,
#    'saves': 0,
#    'bonus': 0,
#    'bps': 15,
#    'influence': '41.2',
#    'creativity': '14.5',
#    'threat': '118.0',
#    'ict_index': '17.4',
#    'starts': 1,
#    'expected_goals': '2.56',
#    'expected_assists': '0.03',
#    'expected_goal_involvements': '2.59',
#    'expected_goals_conceded': '0.94',
#    'value': 141,
#    'transfers_balance': 88573,
#    'selected': 9070132,
#    'transfers_in': 102747,
#    'transfers_out': 14174},
#   {'element': 355,
#    'fixture': 59,
#    'opponent_team': 16,
#    'total_points': 6,
#    'was_home': True,
#    'kickoff_time': '2023-09-23T14:00:00Z',
#    'team_h_score': 2,
#    'team_a_score': 0,
#    'round': 6,
#    'minutes': 90,
#    'goals_scored': 1,
#    'assists': 0,
#    'clean_sheets': 1,
#    'goals_conceded': 0,
#    'own_goals': 0,
#    'penalties_saved': 0,
#    'penalties_missed': 0,
#    'yellow_cards': 0,
#    'red_cards': 0,
#    'saves': 0,
#    'bonus': 0,
#    'bps': 24,
#    'influence': '32.4',
#    'creativity': '3.3',
#    'threat': '23.0',
#    'ict_index': '5.9',
#    'starts': 1,
#    'expected_goals': '0.69',
#    'expected_assists': '0.01',
#    'expected_goal_involvements': '0.70',
#    'expected_goals_conceded': '1.03',
#    'value': 141,
#    'transfers_balance': 39924,
#    'selected': 9176859,
#    'transfers_in': 50069,
#    'transfers_out': 10145},
#   {'element': 355,
#    'fixture': 70,
#    'opponent_team': 20,
#    'total_points': 2,
#    'was_home': False,
#    'kickoff_time': '2023-09-30T14:00:00Z',
#    'team_h_score': 2,
#    'team_a_score': 1,
#    'round': 7,
#    'minutes': 90,
#    'goals_scored': 0,
#    'assists': 0,
#    'clean_sheets': 0,
#    'goals_conceded': 2,
#    'own_goals': 0,
#    'penalties_saved': 0,
#    'penalties_missed': 0,
#    'yellow_cards': 0,
#    'red_cards': 0,
#    'saves': 0,
#    'bonus': 0,
#    'bps': 7,
#    'influence': '6.0',
#    'creativity': '12.6',
#    'threat': '27.0',
#    'ict_index': '4.6',
#    'starts': 1,
#    'expected_goals': '0.06',
#    'expected_assists': '0.03',
#    'expected_goal_involvements': '0.09',
#    'expected_goals_conceded': '0.44',
#    'value': 141,
#    'transfers_balance': 3265,
#    'selected': 9241818,
#    'transfers_in': 28710,
#    'transfers_out': 25445},
#   {'element': 355,
#    'fixture': 71,
#    'opponent_team': 1,
#    'total_points': 2,
#    'was_home': False,
#    'kickoff_time': '2023-10-08T15:30:00Z',
#    'team_h_score': 1,
#    'team_a_score': 0,
#    'round': 8,
#    'minutes': 90,
#    'goals_scored': 0,
#    'assists': 0,
#    'clean_sheets': 0,
#    'goals_conceded': 1,
#    'own_goals': 0,
#    'penalties_saved': 0,
#    'penalties_missed': 0,
#    'yellow_cards': 0,
#    'red_cards': 0,
#    'saves': 0,
#    'bonus': 0,
#    'bps': 11,
#    'influence': '7.8',
#    'creativity': '21.8',
#    'threat': '8.0',
#    'ict_index': '3.8',
#    'starts': 1,
#    'expected_goals': '0.00',
#    'expected_assists': '0.17',
#    'expected_goal_involvements': '0.17',
#    'expected_goals_conceded': '0.41',
#    'value': 141,
#    'transfers_balance': -236407,
#    'selected': 9008161,
#    'transfers_in': 28394,
#    'transfers_out': 264801}],
#  'history_past': [{'season_name': '2022/23',
#    'element_code': 223094,
#    'start_cost': 115,
#    'end_cost': 124,
#    'total_points': 272,
#    'minutes': 2767,
#    'goals_scored': 36,
#    'assists': 9,
#    'clean_sheets': 13,
#    'goals_conceded': 26,
#    'own_goals': 0,
#    'penalties_saved': 0,
#    'penalties_missed': 0,
#    'yellow_cards': 5,
#    'red_cards': 0,
#    'saves': 0,
#    'bonus': 40,
#    'bps': 1040,
#    'influence': '1390.0',
#    'creativity': '371.0',
#    'threat': '1825.0',
#    'ict_index': '358.1',
#    'starts': 33,
#    'expected_goals': '28.54',
#    'expected_assists': '3.11',
#    'expected_goal_involvements': '31.65',
#    'expected_goals_conceded': '25.24'}]}

# %%
data3['history']
# Out:
# [{'element': 355,
#   'fixture': 1,
#   'opponent_team': 6,
#   'total_points': 13,
#   'was_home': False,
#   'kickoff_time': '2023-08-11T19:00:00Z',
#   'team_h_score': 0,
#   'team_a_score': 3,
#   'round': 1,
#   'minutes': 79,
#   'goals_scored': 2,
#   'assists': 0,
#   'clean_sheets': 1,
#   'goals_conceded': 0,
#   'own_goals': 0,
#   'penalties_saved': 0,
#   'penalties_missed': 0,
#   'yellow_cards': 0,
#   'red_cards': 0,
#   'saves': 0,
#   'bonus': 3,
#   'bps': 56,
#   'influence': '67.6',
#   'creativity': '23.7',
#   'threat': '48.0',
#   'ict_index': '13.9',
#   'starts': 1,
#   'expected_goals': '0.60',
#   'expected_assists': '0.05',
#   'expected_goal_involvements': '0.65',
#   'expected_goals_conceded': '0.23',
#   'value': 140,
#   'transfers_balance': 0,
#   'selected': 7200159,
#   'transfers_in': 0,
#   'transfers_out': 0},
#  {'element': 355,
#   'fixture': 16,
#   'opponent_team': 15,
#   'total_points': 2,
#   'was_home': True,
#   'kickoff_time': '2023-08-19T19:00:00Z',
#   'team_h_score': 1,
#   'team_a_score': 0,
#   'round': 2,
#   'minutes': 90,
#   'goals_scored': 0,
#   'assists': 0,
#   'clean_sheets': 1,
#   'goals_conceded': 0,
#   'own_goals': 0,
#   'penalties_saved': 0,
#   'penalties_missed': 0,
#   'yellow_cards': 0,
#   'red_cards': 0,
#   'saves': 0,
#   'bonus': 0,
#   'bps': 1,
#   'influence': '3.2',
#   'creativity': '11.8',
#   'threat': '48.0',
#   'ict_index': '6.3',
#   'starts': 1,
#   'expected_goals': '0.43',
#   'expected_assists': '0.02',
#   'expected_goal_involvements': '0.45',
#   'expected_goals_conceded': '0.29',
#   'value': 140,
#   'transfers_balance': 132944,
#   'selected': 8231668,
#   'transfers_in': 161773,
#   'transfers_out': 28829},
#  {'element': 355,
#   'fixture': 30,
#   'opponent_team': 17,
#   'total_points': 4,
#   'was_home': False,
#   'kickoff_time': '2023-08-27T13:00:00Z',
#   'team_h_score': 1,
#   'team_a_score': 2,
#   'round': 3,
#   'minutes': 90,
#   'goals_scored': 1,
#   'assists': 0,
#   'clean_sheets': 0,
#   'goals_conceded': 1,
#   'own_goals': 0,
#   'penalties_saved': 0,
#   'penalties_missed': 1,
#   'yellow_cards': 0,
#   'red_cards': 0,
#   'saves': 0,
#   'bonus': 0,
#   'bps': 14,
#   'influence': '34.2',
#   'creativity': '12.9',
#   'threat': '97.0',
#   'ict_index': '14.4',
#   'starts': 1,
#   'expected_goals': '1.93',
#   'expected_assists': '0.01',
#   'expected_goal_involvements': '1.94',
#   'expected_goals_conceded': '0.73',
#   'value': 140,
#   'transfers_balance': 64397,
#   'selected': 8571562,
#   'transfers_in': 91189,
#   'transfers_out': 26792},
#  {'element': 355,
#   'fixture': 39,
#   'opponent_team': 10,
#   'total_points': 20,
#   'was_home': True,
#   'kickoff_time': '2023-09-02T14:00:00Z',
#   'team_h_score': 5,
#   'team_a_score': 1,
#   'round': 4,
#   'minutes': 90,
#   'goals_scored': 3,
#   'assists': 1,
#   'clean_sheets': 0,
#   'goals_conceded': 1,
#   'own_goals': 0,
#   'penalties_saved': 0,
#   'penalties_missed': 0,
#   'yellow_cards': 0,
#   'red_cards': 0,
#   'saves': 0,
#   'bonus': 3,
#   'bps': 90,
#   'influence': '119.4',
#   'creativity': '23.4',
#   'threat': '55.0',
#   'ict_index': '19.8',
#   'starts': 1,
#   'expected_goals': '1.58',
#   'expected_assists': '0.10',
#   'expected_goal_involvements': '1.68',
#   'expected_goals_conceded': '1.45',
#   'value': 140,
#   'transfers_balance': 27163,
#   'selected': 8787213,
#   'transfers_in': 53175,
#   'transfers_out': 26012},
#  {'element': 355,
#   'fixture': 49,
#   'opponent_team': 19,
#   'total_points': 6,
#   'was_home': False,
#   'kickoff_time': '2023-09-16T14:00:00Z',
#   'team_h_score': 1,
#   'team_a_score': 3,
#   'round': 5,
#   'minutes': 90,
#   'goals_scored': 1,
#   'assists': 0,
#   'clean_sheets': 0,
#   'goals_conceded': 1,
#   'own_goals': 0,
#   'penalties_saved': 0,
#   'penalties_missed': 0,
#   'yellow_cards': 0,
#   'red_cards': 0,
#   'saves': 0,
#   'bonus': 0,
#   'bps': 15,
#   'influence': '41.2',
#   'creativity': '14.5',
#   'threat': '118.0',
#   'ict_index': '17.4',
#   'starts': 1,
#   'expected_goals': '2.56',
#   'expected_assists': '0.03',
#   'expected_goal_involvements': '2.59',
#   'expected_goals_conceded': '0.94',
#   'value': 141,
#   'transfers_balance': 88573,
#   'selected': 9070132,
#   'transfers_in': 102747,
#   'transfers_out': 14174},
#  {'element': 355,
#   'fixture': 59,
#   'opponent_team': 16,
#   'total_points': 6,
#   'was_home': True,
#   'kickoff_time': '2023-09-23T14:00:00Z',
#   'team_h_score': 2,
#   'team_a_score': 0,
#   'round': 6,
#   'minutes': 90,
#   'goals_scored': 1,
#   'assists': 0,
#   'clean_sheets': 1,
#   'goals_conceded': 0,
#   'own_goals': 0,
#   'penalties_saved': 0,
#   'penalties_missed': 0,
#   'yellow_cards': 0,
#   'red_cards': 0,
#   'saves': 0,
#   'bonus': 0,
#   'bps': 24,
#   'influence': '32.4',
#   'creativity': '3.3',
#   'threat': '23.0',
#   'ict_index': '5.9',
#   'starts': 1,
#   'expected_goals': '0.69',
#   'expected_assists': '0.01',
#   'expected_goal_involvements': '0.70',
#   'expected_goals_conceded': '1.03',
#   'value': 141,
#   'transfers_balance': 39924,
#   'selected': 9176859,
#   'transfers_in': 50069,
#   'transfers_out': 10145},
#  {'element': 355,
#   'fixture': 70,
#   'opponent_team': 20,
#   'total_points': 2,
#   'was_home': False,
#   'kickoff_time': '2023-09-30T14:00:00Z',
#   'team_h_score': 2,
#   'team_a_score': 1,
#   'round': 7,
#   'minutes': 90,
#   'goals_scored': 0,
#   'assists': 0,
#   'clean_sheets': 0,
#   'goals_conceded': 2,
#   'own_goals': 0,
#   'penalties_saved': 0,
#   'penalties_missed': 0,
#   'yellow_cards': 0,
#   'red_cards': 0,
#   'saves': 0,
#   'bonus': 0,
#   'bps': 7,
#   'influence': '6.0',
#   'creativity': '12.6',
#   'threat': '27.0',
#   'ict_index': '4.6',
#   'starts': 1,
#   'expected_goals': '0.06',
#   'expected_assists': '0.03',
#   'expected_goal_involvements': '0.09',
#   'expected_goals_conceded': '0.44',
#   'value': 141,
#   'transfers_balance': 3265,
#   'selected': 9241818,
#   'transfers_in': 28710,
#   'transfers_out': 25445},
#  {'element': 355,
#   'fixture': 71,
#   'opponent_team': 1,
#   'total_points': 2,
#   'was_home': False,
#   'kickoff_time': '2023-10-08T15:30:00Z',
#   'team_h_score': 1,
#   'team_a_score': 0,
#   'round': 8,
#   'minutes': 90,
#   'goals_scored': 0,
#   'assists': 0,
#   'clean_sheets': 0,
#   'goals_conceded': 1,
#   'own_goals': 0,
#   'penalties_saved': 0,
#   'penalties_missed': 0,
#   'yellow_cards': 0,
#   'red_cards': 0,
#   'saves': 0,
#   'bonus': 0,
#   'bps': 11,
#   'influence': '7.8',
#   'creativity': '21.8',
#   'threat': '8.0',
#   'ict_index': '3.8',
#   'starts': 1,
#   'expected_goals': '0.00',
#   'expected_assists': '0.17',
#   'expected_goal_involvements': '0.17',
#   'expected_goals_conceded': '0.41',
#   'value': 141,
#   'transfers_balance': -236407,
#   'selected': 9008161,
#   'transfers_in': 28394,
#   'transfers_out': 264801}]

# %%
data3['history_past']
# Out:
# [{'season_name': '2022/23',
#   'element_code': 223094,
#   'start_cost': 115,
#   'end_cost': 124,
#   'total_points': 272,
#   'minutes': 2767,
#   'goals_scored': 36,
#   'assists': 9,
#   'clean_sheets': 13,
#   'goals_conceded': 26,
#   'own_goals': 0,
#   'penalties_saved': 0,
#   'penalties_missed': 0,
#   'yellow_cards': 5,
#   'red_cards': 0,
#   'saves': 0,
#   'bonus': 40,
#   'bps': 1040,
#   'influence': '1390.0',
#   'creativity': '371.0',
#   'threat': '1825.0',
#   'ict_index': '358.1',
#   'starts': 33,
#   'expected_goals': '28.54',
#   'expected_assists': '3.11',
#   'expected_goal_involvements': '31.65',
#   'expected_goals_conceded': '25.24'}]
