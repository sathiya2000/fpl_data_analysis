# %%
# !pip install bs4
# Out:
# Collecting bs4
#   Downloading bs4-0.0.1.tar.gz (1.1 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Requirement already satisfied: beautifulsoup4 in g:\big data\big data bootcamp\anaconda\conda\lib\site-packages (from bs4) (4.11.1)
# Requirement already satisfied: soupsieve>1.2 in g:\big data\big data bootcamp\anaconda\conda\lib\site-packages (from beautifulsoup4->bs4) (2.3.1)
# Building wheels for collected packages: bs4
#   Building wheel for bs4 (setup.py): started
#   Building wheel for bs4 (setup.py): finished with status 'done'
#   Created wheel for bs4: filename=bs4-0.0.1-py3-none-any.whl size=1257 sha256=eedef05d81b4614d3a4eeaedda58f775269debf57ea1d56ebb0c926ba57ecce5
#   Stored in directory: c:\users\sathi\appdata\local\pip\cache\wheels\73\2b\cb\099980278a0c9a3e57ff1a89875ec07bfa0b6fcbebb9a8cad3
# Successfully built bs4
# Installing collected packages: bs4
# Successfully installed bs4-0.0.1

# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd

# %%
url = 'https://www.premierleague.com/tables'

page = requests.get(url)

soup = BeautifulSoup(page.text, 'html')

# %%
soup
# Out:
# <!DOCTYPE html>
# <html lang="en">
# <head>
# <meta content="Premier League Table, Form Guide &amp; Season Archives" name="twitter:title"/>
# <meta content="Premier League Table, Form Guide &amp; Season Archives" property="og:title"/>
# <title>Premier League Table, Form Guide &amp; Season Archives</title>
# <!-- Designed and built by Pulselive - www.pulselive.com -->
# <meta charset="utf-8"/>
# <meta content="IE=edge,chrome=1" http-equiv="X-UA-Compatible"/>
# <meta content="width=device-width, initial-scale=1" name="viewport"/>
# <script>
# 		dataLayer = [];
#         window.RESOURCE_VERSION_REBRAND = 'rebrand/v7.130.2';
# 		window.RESOURCE_VERSION = 'rebrand/v7.130.2';
# 		window.BASE_RESOURCE_URL = 'https://www.premierleague.com/resources';
# 	</script>
# <!--[if gt IE 8]><!-->
# <!--<link rel="stylesheet" href="https://www.premierleague.com/resources/rebrand/v7.130.2/styles/badge-abbreviations.css">-->
# <link href="/resources/rebrand/v7.130.2/styles/screen.css" rel="stylesheet"/>
# <!--<![endif]--><script charset="UTF-8" src="/resources/prod/v6.122.4-6039/i18n/i18n-en.js"></script><script charset="UTF-8" src="//translations.platform.pulselive.com/premierleague/en.js"></script><!-- OneTrust Cookies Consent Notice start for premierleague.com --> <script charset="UTF-8" data-domain-script="cdf436a9-4615-4772-a4b4-7660a91cc3a2" src="https://cdn-ukwest.onetrust.com/scripttemplates/otSDKStub.js" type="text/javascript"></script> <script type="text/javascript"> function OptanonWrapper() { } </script> <!-- OneTrust Cookies Consent Notice end for premierleague.com -->
# <script async="" src="https://securepubads.g.doubleclick.net/tag/js/gpt.js"></script>
# <script>
#   var googletag = googletag || {};
#   googletag.cmd = googletag.cmd || [];
# </script>
# <link href="https://fonts.googleapis.com/css?family=Poppins:400,700" rel="stylesheet" type="text/css"/>
# <!-- Google Tag Manager -->
# <script async="" src="https://www.googletagmanager.com/gtag/js?id=GTM-MS75QT"></script>
# <script>
#                 (function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':
#                 new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],
#                 j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src=
#                 'https://www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);
#                 })(window,document,'script','dataLayer','GTM-MS75QT');
#         </script>
# <!-- End Google Tag Manager -->
# <!-- Polyfill service provided by the FT - https://github.com/Financial-Times/polyfill-service -->
# <script src="//cdn.polyfill.io/v2/polyfill.min.js"></script>
# <link href="https://www.premierleague.com/resources/rebrand/v7.130.2/i/favicon/apple-touch-icon-57x57.png" rel="apple-touch-icon-precomposed" sizes="57x57"/>
# <link href="https://www.premierleague.com/resources/rebrand/v7.130.2/i/favicon/apple-touch-icon-114x114.png" rel="apple-touch-icon-precomposed" sizes="114x114"/>
# <link href="https://www.premierleague.com/resources/rebrand/v7.130.2/i/favicon/apple-touch-icon-72x72.png" rel="apple-touch-icon-precomposed" sizes="72x72"/>
# <link href="https://www.premierleague.com/resources/rebrand/v7.130.2/i/favicon/apple-touch-icon-144x144.png" rel="apple-touch-icon-precomposed" sizes="144x144"/>
# <link href="https://www.premierleague.com/resources/rebrand/v7.130.2/i/favicon/apple-touch-icon-60x60.png" rel="apple-touch-icon-precomposed" sizes="60x60"/>
# <link href="https://www.premierleague.com/resources/rebrand/v7.130.2/i/favicon/apple-touch-icon-120x120.png" rel="apple-touch-icon-precomposed" sizes="120x120"/>
# <link href="https://www.premierleague.com/resources/rebrand/v7.130.2/i/favicon/apple-touch-icon-76x76.png" rel="apple-touch-icon-precomposed" sizes="76x76"/>
# <link href="https://www.premierleague.com/resources/rebrand/v7.130.2/i/favicon/apple-touch-icon-152x152.png" rel="apple-touch-icon-precomposed" sizes="152x152"/>
# <link href="https://www.premierleague.com/resources/rebrand/v7.130.2/i/favicon/favicon-196x196.png" rel="icon" sizes="196x196" type="image/png"/>
# <link href="https://www.premierleague.com/resources/rebrand/v7.130.2/i/favicon/favicon-96x96.png" rel="icon" sizes="96x96" type="image/png"/>
# <link href="https://www.premierleague.com/resources/rebrand/v7.130.2/i/favicon/favicon-32x32.png" rel="icon" sizes="32x32" type="image/png"/>
# <link href="https://www.premierleague.com/resources/rebrand/v7.130.2/i/favicon/favicon-16x16.png" rel="icon" sizes="16x16" type="image/png"/>
# <link href="https://www.premierleague.com/resources/rebrand/v7.130.2/i/favicon/favicon-128.png" rel="icon" sizes="128x128" type="image/png"/>
# <link href="https://www.premierleague.com/resources/rebrand/v7.130.2/i/favicon/favicon.ico" rel="shortcut icon"/>
# <meta content=" " name="application-name"/>
# <meta content="#FFFFFF" name="msapplication-TileColor"/>
# <meta content="mstile-144x144.png" name="msapplication-TileImage"/>
# <meta content="mstile-70x70.png" name="msapplication-square70x70logo"/>
# <meta content="mstile-150x150.png" name="msapplication-square150x150logo"/>
# <meta content="mstile-310x150.png" name="msapplication-wide310x150logo"/>
# <meta content="mstile-310x310.png" name="msapplication-square310x310logo"/>
# <meta content="app-id=1138895159" name="apple-itunes-app"/>
# <!--
# 	Enables or disables automatic detection of possible phone numbers in a webpage in Safari on iOS.
# 	https://developer.apple.com/library/content/documentation/AppleApplications/Reference/SafariHTMLRef/Articles/MetaTags.html#//apple_ref/doc/uid/TP40008193-SW5
# 	-->
# <meta content="telephone=no" name="format-detection"/>
# </head>
# <body>
# <!-- Google Tag Manager (noscript) -->
# <noscript><iframe height="0" src="https://www.googletagmanager.com/ns.html?id=GTM-MS75QT" style="display:none;visibility:hidden" width="0"></iframe></noscript>
# <!-- End Google Tag Manager (noscript) -->
# <header class="masthead">
# <a class="skipTo" href="#mainNav">Skip to main navigation</a>
# <a class="skipTo" href="#mainContent">Skip to main content</a>
# <nav class="clubNavigation js-club-navigation" data-script="pl_global-header" role="menubar">
# <h4 class="clubSitesHeading">
#         Club Sites
#
# 	<svg class="clubSitesHeading__icon">
# <use xlink:href="https://www.premierleague.com/resources/rebrand/v7.130.2/i/svg-output/icons.svg#icn-external-no-fill" xmlns:xlink="http://www.w3.org/1999/xlink"></use>
# </svg>
# </h4>
# <ul class="clubList" role="menu">
# <li class="clubList__club">
# <a class="clubList__link" href="        http://www.arsenal.com?utm_source=premier-league-website&amp;utm_campaign=website&amp;utm_medium=link
# " role="menuitem" target="_blank">
# <div class="badge badge--large badge-image-container" data-size="50" data-widget="club-badge-image">
# <img class="badge-image badge-image--50 js-badge-image" src="https://resources.premierleague.com/premierleague/badges/50/t3.png" srcset="https://resources.premierleague.com/premierleague/badges/50/t3@x2.png 2x"/>
# <span class="visuallyHidden">Arsenal</span>
# </div>
# <span class="name">Arsenal</span>
# </a>
# </li>
# <li class="clubList__club">
# <a class="clubList__link" href="        https://www.avfc.co.uk/?utm_source=premier-league-website&amp;utm_campaign=website&amp;utm_medium=link
# " role="menuitem" target="_blank">
# <div class="badge badge--large badge-image-container" data-size="50" data-widget="club-badge-image">
# <img class="badge-image badge-image--50 js-badge-image" src="https://resources.premierleague.com/premierleague/badges/50/t7.png" srcset="https://resources.premierleague.com/premierleague/badges/50/t7@x2.png 2x"/>
# <span class="visuallyHidden">Aston Villa</span>
# </div>
# <span class="name">Aston Villa</span>
# </a>
# </li>
# <li class="clubList__club">
# <a class="clubList__link" href="        https://www.afcb.co.uk/?utm_source=premier-league-website&amp;utm_campaign=website&amp;utm_medium=link
# " role="menuitem" target="_blank">
# <div class="badge badge--large badge-image-container" data-size="50" data-widget="club-badge-image">
# <img class="badge-image badge-image--50 js-badge-image" src="https://resources.premierleague.com/premierleague/badges/50/t91.png" srcset="https://resources.premierleague.com/premierleague/badges/50/t91@x2.png 2x"/>
# <span class="visuallyHidden">AFC Bournemouth</span>
# </div>
# <span class="name">AFC Bournemouth</span>
# </a>
# </li>
# <li class="clubList__club">
# <a class="clubList__link" href="        https://www.brentfordfc.com/?utm_source=premier-league-website&amp;utm_campaign=website&amp;utm_medium=link
# " role="menuitem" target="_blank">
# <div class="badge badge--large badge-image-container" data-size="50" data-widget="club-badge-image">
# <img class="badge-image badge-image--50 js-badge-image" src="https://resources.premierleague.com/premierleague/badges/50/t94.png" srcset="https://resources.premierleague.com/premierleague/badges/50/t94@x2.png 2x"/>
# <span class="visuallyHidden">Brentford</span>
# </div>
# <span class="name">Brentford</span>
# </a>
# </li>
# <li class="clubList__club">
# <a class="clubList__link" href="        https://www.brightonandhovealbion.com?utm_source=premier-league-website&amp;utm_campaign=website&amp;utm_medium=link
# " role="menuitem" target="_blank">
# <div class="badge badge--large badge-image-container" data-size="50" data-widget="club-badge-image">
# <img class="badge-image badge-image--50 js-badge-image" src="https://resources.premierleague.com/premierleague/badges/50/t36.png" srcset="https://resources.premierleague.com/premierleague/badges/50/t36@x2.png 2x"/>
# <span class="visuallyHidden">Brighton &amp; Hove Albion</span>
# </div>
# <span class="name">Brighton &amp; Hove Albion</span>
# </a>
# </li>
# <li class="clubList__club">
# <a class="clubList__link" href="        https://www.burnleyfootballclub.com/?utm_source=premier-league-website&amp;utm_campaign=website&amp;utm_medium=link
# " role="menuitem" target="_blank">
# <div class="badge badge--large badge-image-container" data-size="50" data-widget="club-badge-image">
# <img class="badge-image badge-image--50 js-badge-image" src="https://resources.premierleague.com/premierleague/badges/50/t90.png" srcset="https://resources.premierleague.com/premierleague/badges/50/t90@x2.png 2x"/>
# <span class="visuallyHidden">Burnley</span>
# </div>
# <span class="name">Burnley</span>
# </a>
# </li>
# <li class="clubList__club">
# <a class="clubList__link" href="        https://www.chelseafc.com/?utm_source=premier-league-website&amp;utm_campaign=website&amp;utm_medium=link
# " role="menuitem" target="_blank">
# <div class="badge badge--large badge-image-container" data-size="50" data-widget="club-badge-image">
# <img class="badge-image badge-image--50 js-badge-image" src="https://resources.premierleague.com/premierleague/badges/50/t8.png" srcset="https://resources.premierleague.com/premierleague/badges/50/t8@x2.png 2x"/>
# <span class="visuallyHidden">Chelsea</span>
# </div>
# <span class="name">Chelsea</span>
# </a>
# </li>
# <li class="clubList__club">
# <a class="clubList__link" href="        http://www.cpfc.co.uk/?utm_source=premier-league-website&amp;utm_campaign=website&amp;utm_medium=link
# " role="menuitem" target="_blank">
# <div class="badge badge--large badge-image-container" data-size="50" data-widget="club-badge-image">
# <img class="badge-image badge-image--50 js-badge-image" src="https://resources.premierleague.com/premierleague/badges/50/t31.png" srcset="https://resources.premierleague.com/premierleague/badges/50/t31@x2.png 2x"/>
# <span class="visuallyHidden">Crystal Palace</span>
# </div>
# <span class="name">Crystal Palace</span>
# </a>
# </li>
# <li class="clubList__club">
# <a class="clubList__link" href="        http://www.evertonfc.com/?utm_source=premier-league-website&amp;utm_campaign=website&amp;utm_medium=link
# " role="menuitem" target="_blank">
# <div class="badge badge--large badge-image-container" data-size="50" data-widget="club-badge-image">
# <img class="badge-image badge-image--50 js-badge-image" src="https://resources.premierleague.com/premierleague/badges/50/t11.png" srcset="https://resources.premierleague.com/premierleague/badges/50/t11@x2.png 2x"/>
# <span class="visuallyHidden">Everton </span>
# </div>
# <span class="name">Everton </span>
# </a>
# </li>
# <li class="clubList__club">
# <a class="clubList__link" href="        https://www.fulhamfc.com/?utm_source=premier-league-website&amp;utm_campaign=website&amp;utm_medium=link
# " role="menuitem" target="_blank">
# <div class="badge badge--large badge-image-container" data-size="50" data-widget="club-badge-image">
# <img class="badge-image badge-image--50 js-badge-image" src="https://resources.premierleague.com/premierleague/badges/50/t54.png" srcset="https://resources.premierleague.com/premierleague/badges/50/t54@x2.png 2x"/>
# <span class="visuallyHidden">Fulham</span>
# </div>
# <span class="name">Fulham</span>
# </a>
# </li>
# <li class="clubList__club">
# <a class="clubList__link" href="        http://www.liverpoolfc.com/?utm_source=premier-league-website&amp;utm_campaign=website&amp;utm_medium=link
# " role="menuitem" target="_blank">
# <div class="badge badge--large badge-image-container" data-size="50" data-widget="club-badge-image">
# <img class="badge-image badge-image--50 js-badge-image" src="https://resources.premierleague.com/premierleague/badges/50/t14.png" srcset="https://resources.premierleague.com/premierleague/badges/50/t14@x2.png 2x"/>
# <span class="visuallyHidden">Liverpool</span>
# </div>
# <span class="name">Liverpool</span>
# </a>
# </li>
# <li class="clubList__club">
# <a class="clubList__link" href="        https://www.lutontown.co.uk/?utm_source=premier-league-website&amp;utm_campaign=website&amp;utm_medium=link
# " role="menuitem" target="_blank">
# <div class="badge badge--large badge-image-container" data-size="50" data-widget="club-badge-image">
# <img class="badge-image badge-image--50 js-badge-image" src="https://resources.premierleague.com/premierleague/badges/50/t102.png" srcset="https://resources.premierleague.com/premierleague/badges/50/t102@x2.png 2x"/>
# <span class="visuallyHidden">Luton Town</span>
# </div>
# <span class="name">Luton Town</span>
# </a>
# </li>
# <li class="clubList__club">
# <a class="clubList__link" href="        https://www.mancity.com?utm_source=premier-league-website&amp;utm_campaign=website&amp;utm_medium=link
# " role="menuitem" target="_blank">
# <div class="badge badge--large badge-image-container" data-size="50" data-widget="club-badge-image">
# <img class="badge-image badge-image--50 js-badge-image" src="https://resources.premierleague.com/premierleague/badges/50/t43.png" srcset="https://resources.premierleague.com/premierleague/badges/50/t43@x2.png 2x"/>
# <span class="visuallyHidden">Manchester City</span>
# </div>
# <span class="name">Manchester City</span>
# </a>
# </li>
# <li class="clubList__club">
# <a class="clubList__link" href="        http://www.manutd.com/?utm_source=premier-league-website&amp;utm_campaign=website&amp;utm_medium=link
# " role="menuitem" target="_blank">
# <div class="badge badge--large badge-image-container" data-size="50" data-widget="club-badge-image">
# <img class="badge-image badge-image--50 js-badge-image" src="https://resources.premierleague.com/premierleague/badges/50/t1.png" srcset="https://resources.premierleague.com/premierleague/badges/50/t1@x2.png 2x"/>
# <span class="visuallyHidden">Manchester United</span>
# </div>
# <span class="name">Manchester United</span>
# </a>
# </li>
# <li class="clubList__club">
# <a class="clubList__link" href="        https://www.nufc.co.uk/?utm_source=premier-league-website&amp;utm_campaign=website&amp;utm_medium=link
# " role="menuitem" target="_blank">
# <div class="badge badge--large badge-image-container" data-size="50" data-widget="club-badge-image">
# <img class="badge-image badge-image--50 js-badge-image" src="https://resources.premierleague.com/premierleague/badges/50/t4.png" srcset="https://resources.premierleague.com/premierleague/badges/50/t4@x2.png 2x"/>
# <span class="visuallyHidden">Newcastle United</span>
# </div>
# <span class="name">Newcastle United</span>
# </a>
# </li>
# <li class="clubList__club">
# <a class="clubList__link" href="        https://www.nottinghamforest.co.uk/?utm_source=premier-league-website&amp;utm_campaign=website&amp;utm_medium=link
# " role="menuitem" target="_blank">
# <div class="badge badge--large badge-image-container" data-size="50" data-widget="club-badge-image">
# <img class="badge-image badge-image--50 js-badge-image" src="https://resources.premierleague.com/premierleague/badges/50/t17.png" srcset="https://resources.premierleague.com/premierleague/badges/50/t17@x2.png 2x"/>
# <span class="visuallyHidden">Nottingham Forest</span>
# </div>
# <span class="name">Nottingham Forest</span>
# </a>
# </li>
# <li class="clubList__club">
# <a class="clubList__link" href="        https://www.sufc.co.uk/?utm_source=premier-league-website&amp;utm_campaign=website&amp;utm_medium=link
# " role="menuitem" target="_blank">
# <div class="badge badge--large badge-image-container" data-size="50" data-widget="club-badge-image">
# <img class="badge-image badge-image--50 js-badge-image" src="https://resources.premierleague.com/premierleague/badges/50/t49.png" srcset="https://resources.premierleague.com/premierleague/badges/50/t49@x2.png 2x"/>
# <span class="visuallyHidden">Sheffield United</span>
# </div>
# <span class="name">Sheffield United</span>
# </a>
# </li>
# <li class="clubList__club">
# <a class="clubList__link" href="        http://www.tottenhamhotspur.com/?utm_source=premier-league-website&amp;utm_campaign=website&amp;utm_medium=link
# " role="menuitem" target="_blank">
# <div class="badge badge--large badge-image-container" data-size="50" data-widget="club-badge-image">
# <img class="badge-image badge-image--50 js-badge-image" src="https://resources.premierleague.com/premierleague/badges/50/t6.png" srcset="https://resources.premierleague.com/premierleague/badges/50/t6@x2.png 2x"/>
# <span class="visuallyHidden">Tottenham Hotspur</span>
# </div>
# <span class="name">Tottenham Hotspur</span>
# </a>
# </li>
# <li class="clubList__club">
# <a class="clubList__link" href="        http://www.whufc.com/?utm_source=premier-league-website&amp;utm_campaign=website&amp;utm_medium=link
# " role="menuitem" target="_blank">
# <div class="badge badge--large badge-image-container" data-size="50" data-widget="club-badge-image">
# <img class="badge-image badge-image--50 js-badge-image" src="https://resources.premierleague.com/premierleague/badges/50/t21.png" srcset="https://resources.premierleague.com/premierleague/badges/50/t21@x2.png 2x"/>
# <span class="visuallyHidden">West Ham United</span>
# </div>
# <span class="name">West Ham United</span>
# </a>
# </li>
# <li class="clubList__club">
# <a class="clubList__link" href="        https://www.wolves.co.uk/?utm_source=premier-league-website&amp;utm_campaign=website&amp;utm_medium=link
# " role="menuitem" target="_blank">
# <div class="badge badge--large badge-image-container" data-size="50" data-widget="club-badge-image">
# <img class="badge-image badge-image--50 js-badge-image" src="https://resources.premierleague.com/premierleague/badges/50/t39.png" srcset="https://resources.premierleague.com/premierleague/badges/50/t39@x2.png 2x"/>
# <span class="visuallyHidden">Wolverhampton Wanderers</span>
# </div>
# <span class="name">Wolverhampton Wanderers</span>
# </a>
# </li>
# </ul>
# </nav>
# <div class="fixedContainer js-fixed-container">
# <a aria-label="Premier League Home Page on logo link" class="logoContainer js-logo-container" href="https://www.premierleague.com/home">
# <img alt="Premier League Logo" class="pl-header-logo" src="https://www.premierleague.com/resources/rebrand/v7.130.2/i/elements/pl-main-logo.png"/>
# <div class="logoBackground"></div>
# </a>
# <div class="navContainer" data-script="pl_global-header">
# <section class="navBar js-nav-bar" id="mainNav" role="menubar">
# <div aria-expanded="false" class="menuBtn js-hamburger-toggle" id="hamburgerToggle" role="button">
# <div class="menuBtnContainer">
# <div></div>
# <div></div>
# <div></div>
# </div>
# </div>
# <nav class="mainNav">
# <ul class="pageLinks js-page-links" role="menu">
# <li aria-haspopup="true" class="premierleague" role="menuitem" tabindex="0">
# <div class="navLink active" role="button" tabindex="index">
# <span class="navText">Premier League</span>
# <span class="chevron-dropdown"></span>
# </div>
# <div aria-hidden="true" class="dropdown">
# <ul role="menu">
# <li tabindex="-1">
# <a href="/" role="menuitem" tabindex="0">
#                             Home
#                             </a>
# </li>
# <li tabindex="-1">
# <a href="/fixtures" role="menuitem" tabindex="0">
#                             Fixtures
#                             </a>
# </li>
# <li tabindex="-1">
# <a href="/results" role="menuitem" tabindex="0">
#                             Results
#                             </a>
# </li>
# <li tabindex="-1">
# <a href="/tables" role="menuitem" tabindex="0">
#                             Tables
#                             </a>
# </li>
# <li tabindex="-1">
# <a href="/transfers" role="menuitem" tabindex="0">
#                             Transfers
#                             </a>
# </li>
# <li tabindex="-1">
# <a href="/stats" role="menuitem" tabindex="0">
#                             Stats
#                             </a>
# </li>
# <li tabindex="-1">
# <a href="/news" role="menuitem" tabindex="0">
#                             News
#                             </a>
# </li>
# <li tabindex="-1">
# <a href="/video" role="menuitem" tabindex="0">
#                             Video
#                             </a>
# </li>
# <li tabindex="-1">
# <a href="/broadcast-schedules" role="menuitem" tabindex="0">
#                             Watch Live
#                             </a>
# </li>
# <li tabindex="-1">
# <a href="/clubs" role="menuitem" tabindex="0">
#                             Clubs
#                             </a>
# </li>
# <li tabindex="-1">
# <a href="/players" role="menuitem" tabindex="0">
#                             Players
#                             </a>
# </li>
# <li tabindex="-1">
# <a href="/awards" role="menuitem" tabindex="0">
#                             Awards
#                             </a>
# </li>
# </ul>
# </div>
# </li>
# <li class="fantasy" role="menuitem">
# <div class="navLink" role="button" tabindex="index">
# <span class="navText">Fantasy</span>
# <span class="chevron-dropdown"></span>
# </div>
# <div aria-hidden="true" class="dropdown">
# <ul role="menu">
# <li tabindex="-1">
# <a href="/fantasy" role="menuitem" tabindex="0">
#                             Fantasy
#                             </a>
# </li>
# <li tabindex="-1">
# <a href="/draft" role="menuitem" tabindex="0">
#                             Fantasy Draft
#                             </a>
# </li>
# </ul>
# </div>
# </li>
# <li class="football&amp;community communities" role="menuitem">
# <div class="navLink" role="button" tabindex="index">
# <span class="navText">Football &amp; Community</span>
# <span class="chevron-dropdown"></span>
# </div>
# <div aria-hidden="true" class="dropdown">
# <ul role="menu">
# <li tabindex="-1">
# <a href="/footballandcommunity/wider-football" role="menuitem" tabindex="0">
#                             Wider Football
#                             </a>
# </li>
# <li tabindex="-1">
# <a href="/footballandcommunity/premier-league-charitable-fund" role="menuitem" tabindex="0">
#                             PL Charitable Fund
#                             </a>
# </li>
# <li tabindex="-1">
# <a href="/footballandcommunity/community" role="menuitem" tabindex="0">
#                             Community
#                             </a>
# </li>
# <li tabindex="-1">
# <a href="/footballandcommunity/youth-development" role="menuitem" tabindex="0">
#                             Youth Development
#                             </a>
# </li>
# <li tabindex="-1">
# <a href="/footballandcommunity/NoRoomForRacism" role="menuitem" tabindex="0">
#                             No Room for Racism
#                             </a>
# </li>
# <li tabindex="-1">
# <a href="/footballandcommunity/mental-health" role="menuitem" tabindex="0">
#                             Mental Health
#                             </a>
# </li>
# <li tabindex="-1">
# <a href="/footballandcommunity/RainbowLaces" role="menuitem" tabindex="0">
#                             Rainbow Laces
#                             </a>
# </li>
# <li tabindex="-1">
# <a href="/footballandcommunity/poppy" role="menuitem" tabindex="0">
#                             Poppy
#                             </a>
# </li>
# </ul>
# </div>
# </li>
# <li class="about" role="menuitem">
# <div class="navLink" role="button" tabindex="index">
# <span class="navText">About</span>
# <span class="chevron-dropdown"></span>
# </div>
# <div aria-hidden="true" class="dropdown">
# <ul role="menu">
# <li tabindex="-1">
# <a href="/about" role="menuitem" tabindex="0">
#                             Overview
#                             </a>
# </li>
# <li tabindex="-1">
# <a href="/about/what-we-do" role="menuitem" tabindex="0">
#                             What we do
#                             </a>
# </li>
# <li tabindex="-1">
# <a href="/about/governance" role="menuitem" tabindex="0">
#                             Governance
#                             </a>
# </li>
# <li tabindex="-1">
# <a href="/about/statement-of-principles" role="menuitem" tabindex="0">
#                             Statement of Principles
#                             </a>
# </li>
# <li tabindex="-1">
# <a href="/about/inclusion" role="menuitem" tabindex="0">
#                             Inclusion
#                             </a>
# </li>
# <li tabindex="-1">
# <a href="/about/publications" role="menuitem" tabindex="0">
#                             Publications
#                             </a>
# </li>
# <li tabindex="-1">
# <a href="/about/partners" role="menuitem" tabindex="0">
#                             Partners
#                             </a>
# </li>
# <li tabindex="-1">
# <a href="/about/legal" role="menuitem" tabindex="0">
#                             Legal
#                             </a>
# </li>
# <li tabindex="-1">
# <a href="/about/safeguarding" role="menuitem" tabindex="0">
#                             Safeguarding
#                             </a>
# </li>
# <li tabindex="-1">
# <a href="/about/careers" role="menuitem" tabindex="0">
#                             Careers
#                             </a>
# </li>
# <li tabindex="-1">
# <a href="/about/media" role="menuitem" tabindex="0">
#                             Media
#                             </a>
# </li>
# </ul>
# </div>
# </li>
# <li class="show-ms noroomforracism noDrop" role="menuitem">
# <a class="navLink" data-link-index="16" href="/footballandcommunity/NoRoomForRacism" role="menuitem">
#                 No Room For Racism
#             </a>
# <div class="navLink" data-nochildrenlink="/footballandcommunity/NoRoomForRacism" role="button" tabindex="index">
# <span class="navText">No Room For Racism</span>
# </div>
# <div aria-hidden="true" class="dropdown">
# </div>
# </li>
# <li aria-haspopup="true" class="more" role="menuitem" tabindex="0">
# <div class="navLink" role="button">More<span class="chevron-dropdown"></span></div>
# <div aria-hidden="true" class="dropdown">
# <ul role="menu">
# <li>
# <a href="/history" role="menuitem">History</a>
# </li>
# <li>
# <a href="/hall-of-fame" role="menuitem">Hall of Fame</a>
# </li>
# <li>
# <a href="/PL30" role="menuitem">PL30</a>
# </li>
# <li>
# <a href="/referees/overview" role="menuitem">Referees</a>
# </li>
# <li>
# <a href="/managers" role="menuitem">Managers</a>
# </li>
# <li>
# <a href="/man-of-the-match" role="menuitem">Man of the Match</a>
# </li>
# <li>
# <a href="/epl" role="menuitem">ePremier League</a>
# </li>
# <li>
# <a href="/nike-ball-hub" role="menuitem">Nike Ball Hub</a>
# </li>
# <li>
# <a href="/contact/faqs" role="menuitem">FAQs</a>
# </li>
# <li>
# <a href="/contact" role="menuitem">Contact Us</a>
# </li>
# <li>
# <a href="/SummerSeries" role="menuitem">Summer Series</a>
# </li>
# </ul>
# </div>
# </li>
# <!--TO-TRANSLATE -->
# <li aria-haspopup="true" class="clubs">
# <div class="navLink clubListMobileButton" role="button">Clubs<span class="icn external-w"><span class="visuallyHidden">External Link</span></span></div>
# <div aria-hidden="true" class="dropdown" role="menu">
# </div>
# </li>
# </ul>
# </nav>
# <div class="navOption search">
# <div class="searchBtn headerSearchButton js-header-search-btn" role="button" tabindex="0"><span class="visuallyHidden">Search</span><div alt="" class="icn search-w"></div></div>
# </div>
# <a class="navLink navOption navOption--no-border fantasySignIn nav-sign-in-btn" href="#!" role="button" tabindex="0">
# <span class="fantasySignInLabel">Sign in</span>
# </a>
# <a class="navLink navOption navOption--no-border fantasySignOut" href="#!" role="button" tabindex="0">
# <span class="fantasyUsername"></span>
# </a>
# <a class="noroomforracism featured-link navLink navOption" href="/footballandcommunity/NoRoomForRacism" role="button" tabindex="0">
# <div class="icn user-w show-m"></div>
# <span class="featuredLinkTitle">No Room For Racism</span>
# </a>
# </section>
# <div class="searchBar searchBarContainer js-search-bar-container" data-widget="search-header-redirect" role="search">
# <div class="searchBox">
# <div class="plSearch js-search-input-container">
# <input class="searchInput searchInputContainer js-search-input" id="searchPremierLeagueInput" placeholder="Search for News, Players &amp; Clubs" type="text"/>
# <div class="searchBar__predicted-search-wrapper">
# <div class="searchBar__predicted-search-content-wrapper js-predicted-search-wrapper"></div>
# <div class="loader js-loader u-hide">
# <div class="loader-small"><div class="line"></div></div>
# </div>
# </div>
# <button class="search-input__button search-input__button--dark js-empty-input-btn">
# <svg aria-hidden="true" class="icon search-input__icon">
# <use xlink:href="https://www.premierleague.com/resources/rebrand/v7.130.2/i/svg-output/icons.svg#icn-close" xmlns:xlink="http://www.w3.org/1999/xlink"></use>
# </svg>
# </button>
# <label class="visuallyHidden" for="searchPremierLeagueInput">Search for News, Players &amp; Clubs</label>
# <span class="focusBorder"></span>
# <span class="searchBtnContainer searchButtonContainer">
# <input aria-label="Submit search" class="searchInputBtn js-search-input-btn" id="searchPremierLeagueInput" tabindex="0" type="submit"/>
# <svg aria-hidden="true" class="icon icn search-sm">
# <use xlink:href="https://www.premierleague.com/resources/rebrand/v7.130.2/i/svg-output/icons.svg#icn-search" xmlns:xlink="http://www.w3.org/1999/xlink"></use>
# </svg>
# <span class="visuallyHidden">Submit search</span>
# </span>
# </div>
# </div>
# <div class="searchBar__suggested-wrapper">
# <div class="searchBar__suggested-content-wrapper">
# <div class="searchBar__suggested-section">
# <h3 class="searchBar__suggested-section-title">Suggested Searches</h3>
# <div class="searchBar__suggested-item-wrapper">
# <button class="searchBar__suggested-item btn js-suggested-item" data-title="Premier League Fixtures" data-type="hot-topic">Premier League Fixtures</button>
# <button class="searchBar__suggested-item btn js-suggested-item" data-title="Fantasy Premier League" data-type="hot-topic">Fantasy Premier League</button>
# <button class="searchBar__suggested-item btn js-suggested-item" data-title="Goal Of The Month" data-type="hot-topic">Goal Of The Month</button>
# <button class="searchBar__suggested-item btn js-suggested-item" data-title="Ones to watch" data-type="hot-topic">Ones to watch</button>
# <button class="searchBar__suggested-item btn js-suggested-item" data-title="USA Summer Series" data-type="hot-topic">USA Summer Series</button>
# <button class="searchBar__suggested-item btn js-suggested-item" data-title="Tickets" data-type="hot-topic">Tickets</button>
# <button class="searchBar__suggested-item btn js-suggested-item" data-title="FPL Player Price changes" data-type="hot-topic">FPL Player Price changes</button>
# </div>
# </div>
# <div class="searchBar__suggested-section">
# <h3 class="searchBar__suggested-section-title">Players</h3>
# <div class="searchBar__suggested-item-wrapper">
# <button class="searchBar__suggested-item btn js-suggested-item" data-player-id="65970" data-title="Erling Haaland">Erling Haaland</button>
# <button class="searchBar__suggested-item btn js-suggested-item" data-player-id="5178" data-title="Mohamed Salah">Mohamed Salah</button>
# <button class="searchBar__suggested-item btn js-suggested-item" data-player-id="24630" data-title="Richarlison">Richarlison</button>
# <button class="searchBar__suggested-item btn js-suggested-item" data-player-id="70287" data-title="Darwin Núñez">Darwin Núñez</button>
# <button class="searchBar__suggested-item btn js-suggested-item" data-player-id="54312" data-title="Miguel Almirón">Miguel Almirón</button>
# <button class="searchBar__suggested-item btn js-suggested-item" data-player-id="13565" data-title="Marcus Rashford">Marcus Rashford</button>
# <button class="searchBar__suggested-item btn js-suggested-item" data-player-id="3960" data-title="Harry Kane">Harry Kane</button>
# <button class="searchBar__suggested-item btn js-suggested-item" data-player-id="11419" data-title="Martin Ødegaard">Martin Ødegaard</button>
# <button class="searchBar__suggested-item btn js-suggested-item" data-player-id="14732" data-title="Trent Alexander-Arnold">Trent Alexander-Arnold</button>
# <button class="searchBar__suggested-item btn js-suggested-item" data-player-id="51775" data-title="Mohammed Salisu">Mohammed Salisu</button>
# </div>
# </div>
# <div class="searchBar__suggested-section">
# <section class="editorial-list editorial-list--3 widget widget--border widget--has-cta" data-script="pl_editorial-lists" data-widget="video-list">
# <header class="widget-header">
# <h2 class="widget-header__title">Videos</h2>
# <a class="widget-header__cta" href="/video">
# <span>View more</span>
# <svg aria-hidden="true" class="icon widget-header__cta-icon">
# <use xlink:href="https://www.premierleague.com/resources/rebrand/v7.130.2/i/svg-output/icons.svg#icn-arrow-right" xmlns:xlink="http://www.w3.org/1999/xlink"></use>
# </svg>
# </a>
# </header>
# <div class="editorial-list__wrapper js-video-list">
# <div class="editorial-list__item">
# <article class="media-thumbnail" data-widget="lazy-load-images">
# <a class="media-thumbnail__link" data-title="FPL Pod: Kelly Somers reveals her Wildcard squad" data-ui-args='{"contentId": 3722939, "mediaId":6338457227112, "mediaTitle":"FPL Pod: Kelly Somers reveals her Wildcard squad", "mediaCategory":"Video: ", "mediaDescription":"Thinking of playing your chip for Gameweek 8? Find out some players Kelly Somers is picking", "mediaDate":"2023-10-06T08:50:00Z","mediaDuration":"00:37 ","mediaHotlinkUrl":"", "mediaHotlinkText":""}' data-ui-modal="#videoPlayer" data-widget="media-thumbnail-tracking" href="/video/single/3722939?TAG=Fantasy" title="FPL Pod: Kelly Somers reveals her Wildcard squad">
# <header class="media-thumbnail__header">
# <div class="media-thumbnail__image-container placeholder">
# <div class="js-lazy-load u-observed lazy-image-wrapper">
# <!--     <div class="picture-wrapper">
#         <picture class=" object-fit-cover-picture ">
#                     <source class="" srcset="https://resources.premierleague.com/photos/2023/10/06/a077888e-96c8-4486-af15-877e2e72b8d2/RFiMCd9e.jpg?width=344&height=215, https://resources.premierleague.com/photos/2023/10/06/a077888e-96c8-4486-af15-877e2e72b8d2/RFiMCd9e.jpg?width=688&height=430 2x, https://resources.premierleague.com/photos/2023/10/06/a077888e-96c8-4486-af15-877e2e72b8d2/RFiMCd9e.jpg?width=1032&height=645 3x" media="(max-width: 640px)">
#                     <source class="" srcset="https://resources.premierleague.com/photos/2023/10/06/a077888e-96c8-4486-af15-877e2e72b8d2/RFiMCd9e.jpg?width=808&height=505, https://resources.premierleague.com/photos/2023/10/06/a077888e-96c8-4486-af15-877e2e72b8d2/RFiMCd9e.jpg?width=1616&height=1010 2x, https://resources.premierleague.com/photos/2023/10/06/a077888e-96c8-4486-af15-877e2e72b8d2/RFiMCd9e.jpg?width=2424&height=1515 3x" media="(max-width: 839px)">
#                     <source class="" srcset="https://resources.premierleague.com/photos/2023/10/06/a077888e-96c8-4486-af15-877e2e72b8d2/RFiMCd9e.jpg?width=451&height=268, https://resources.premierleague.com/photos/2023/10/06/a077888e-96c8-4486-af15-877e2e72b8d2/RFiMCd9e.jpg?width=902&height=536 2x, https://resources.premierleague.com/photos/2023/10/06/a077888e-96c8-4486-af15-877e2e72b8d2/RFiMCd9e.jpg?width=1353&height=804 3x" media="(min-width: 840px)">
#                     <img class=" js-faded-image fade-in-on-load object-fit-cover-picture__img" src="https://resources.premierleague.com/photos/2023/10/06/a077888e-96c8-4486-af15-877e2e72b8d2/RFiMCd9e.jpg?width=451&height=268" alt="FPL Pod: Kelly Somers reveals her Wildcard squad" title="FPL Pod: Kelly Somers reveals her Wildcard squad" style="">
#         </picture>
#     </div>
#  -->
# </div>
# <div class="media-thumbnail__meta-tag">
# <svg aria-hidden="true" class="icon media-thumbnail__meta-tag-icon">
# <use xlink:href="https://www.premierleague.com/resources/rebrand/v7.130.2/i/svg-output/icons.svg#icn-play" xmlns:xlink="http://www.w3.org/1999/xlink"></use>
# </svg>
#                                 00:37
#                         </div>
# </div>
# </header>
# <div class="media-thumbnail__content">
# <span class="media-thumbnail__tag">
#                             Video
#                     </span>
# <div class="media-thumbnail__video-tags">
# </div>
# <span class="media-thumbnail__title">FPL Pod: Kelly Somers reveals her Wildcard squad
#                 </span>
# </div>
# </a>
# </article>
# </div>
# <div class="editorial-list__item">
# <article class="media-thumbnail" data-widget="lazy-load-images">
# <a class="media-thumbnail__link" data-title="FPL Pod: 'Why I'm not captaining Haaland'" data-ui-args="{&quot;contentId&quot;: 3722948, &quot;mediaId&quot;:6338455467112, &quot;mediaTitle&quot;:&quot;FPL Pod: 'Why I'm not captaining Haaland'&quot;, &quot;mediaCategory&quot;:&quot;Video: &quot;, &quot;mediaDescription&quot;:&quot;Fantasy expert Sam Bonfield explains why she's ignoring the Man City forward in Gameweek 8. But who is she picking instead?&quot;, &quot;mediaDate&quot;:&quot;2023-10-06T10:48:00Z&quot;,&quot;mediaDuration&quot;:&quot;01:22 &quot;,&quot;mediaHotlinkUrl&quot;:&quot;&quot;, &quot;mediaHotlinkText&quot;:&quot;&quot;}" data-ui-modal="#videoPlayer" data-widget="media-thumbnail-tracking" href="/video/single/3722948?TAG=Fantasy" title="FPL Pod: 'Why I'm not captaining Haaland'">
# <header class="media-thumbnail__header">
# <div class="media-thumbnail__image-container placeholder">
# <div class="js-lazy-load u-observed lazy-image-wrapper">
# <!--     <div class="picture-wrapper">
#         <picture class=" object-fit-cover-picture ">
#                     <source class="" srcset="https://resources.premierleague.com/photos/2023/10/06/e3ef04a5-8acf-41e7-ab5e-2459db0e5c54/nF9FrAM4.jpg?width=344&height=215, https://resources.premierleague.com/photos/2023/10/06/e3ef04a5-8acf-41e7-ab5e-2459db0e5c54/nF9FrAM4.jpg?width=688&height=430 2x, https://resources.premierleague.com/photos/2023/10/06/e3ef04a5-8acf-41e7-ab5e-2459db0e5c54/nF9FrAM4.jpg?width=1032&height=645 3x" media="(max-width: 640px)">
#                     <source class="" srcset="https://resources.premierleague.com/photos/2023/10/06/e3ef04a5-8acf-41e7-ab5e-2459db0e5c54/nF9FrAM4.jpg?width=808&height=505, https://resources.premierleague.com/photos/2023/10/06/e3ef04a5-8acf-41e7-ab5e-2459db0e5c54/nF9FrAM4.jpg?width=1616&height=1010 2x, https://resources.premierleague.com/photos/2023/10/06/e3ef04a5-8acf-41e7-ab5e-2459db0e5c54/nF9FrAM4.jpg?width=2424&height=1515 3x" media="(max-width: 839px)">
#                     <source class="" srcset="https://resources.premierleague.com/photos/2023/10/06/e3ef04a5-8acf-41e7-ab5e-2459db0e5c54/nF9FrAM4.jpg?width=451&height=268, https://resources.premierleague.com/photos/2023/10/06/e3ef04a5-8acf-41e7-ab5e-2459db0e5c54/nF9FrAM4.jpg?width=902&height=536 2x, https://resources.premierleague.com/photos/2023/10/06/e3ef04a5-8acf-41e7-ab5e-2459db0e5c54/nF9FrAM4.jpg?width=1353&height=804 3x" media="(min-width: 840px)">
#                     <img class=" js-faded-image fade-in-on-load object-fit-cover-picture__img" src="https://resources.premierleague.com/photos/2023/10/06/e3ef04a5-8acf-41e7-ab5e-2459db0e5c54/nF9FrAM4.jpg?width=451&height=268" alt="FPL Pod: Why I'm not captaining Haaland" title="FPL Pod: Why I'm not captaining Haaland" style="">
#         </picture>
#     </div>
#  -->
# </div>
# <div class="media-thumbnail__meta-tag">
# <svg aria-hidden="true" class="icon media-thumbnail__meta-tag-icon">
# <use xlink:href="https://www.premierleague.com/resources/rebrand/v7.130.2/i/svg-output/icons.svg#icn-play" xmlns:xlink="http://www.w3.org/1999/xlink"></use>
# </svg>
#                                 01:22
#                         </div>
# </div>
# </header>
# <div class="media-thumbnail__content">
# <span class="media-thumbnail__tag">
#                             Video
#                     </span>
# <div class="media-thumbnail__video-tags">
# </div>
# <span class="media-thumbnail__title">FPL Pod: 'Why I'm not captaining Haaland'
#                 </span>
# </div>
# </a>
# </article>
# </div>
# <div class="editorial-list__item">
# <article class="media-thumbnail" data-widget="lazy-load-images">
# <a class="media-thumbnail__link" data-title="Arsenal v Man City: Five memorable moments" data-ui-args="{&quot;contentId&quot;: 3723171, &quot;mediaId&quot;:6338463850112, &quot;mediaTitle&quot;:&quot;Arsenal v Man City: Five memorable moments&quot;, &quot;mediaCategory&quot;:&quot;Video: &quot;, &quot;mediaDescription&quot;:&quot;From Arteta scoring a dramatic winner to Haaland's hair, watch some of the best Premier League moments between these teams&quot;, &quot;mediaDate&quot;:&quot;2023-10-06T09:59:00Z&quot;,&quot;mediaDuration&quot;:&quot;01:55 &quot;,&quot;mediaHotlinkUrl&quot;:&quot;&quot;, &quot;mediaHotlinkText&quot;:&quot;&quot;}" data-ui-modal="#videoPlayer" data-widget="media-thumbnail-tracking" href="/video/single/3723171?FOOTBALL_CLUBS=1,11" title="Arsenal v Man City: Five memorable moments">
# <header class="media-thumbnail__header">
# <div class="media-thumbnail__image-container placeholder">
# <div class="js-lazy-load u-observed lazy-image-wrapper">
# <!--     <div class="picture-wrapper">
#         <picture class=" object-fit-cover-picture ">
#                     <source class="" srcset="https://resources.premierleague.com/photos/2023/10/06/6a8dab60-b897-4f77-ba60-6e86bbfe399f/KYoCZb7G.jpg?width=344&height=215, https://resources.premierleague.com/photos/2023/10/06/6a8dab60-b897-4f77-ba60-6e86bbfe399f/KYoCZb7G.jpg?width=688&height=430 2x, https://resources.premierleague.com/photos/2023/10/06/6a8dab60-b897-4f77-ba60-6e86bbfe399f/KYoCZb7G.jpg?width=1032&height=645 3x" media="(max-width: 640px)">
#                     <source class="" srcset="https://resources.premierleague.com/photos/2023/10/06/6a8dab60-b897-4f77-ba60-6e86bbfe399f/KYoCZb7G.jpg?width=808&height=505, https://resources.premierleague.com/photos/2023/10/06/6a8dab60-b897-4f77-ba60-6e86bbfe399f/KYoCZb7G.jpg?width=1616&height=1010 2x, https://resources.premierleague.com/photos/2023/10/06/6a8dab60-b897-4f77-ba60-6e86bbfe399f/KYoCZb7G.jpg?width=2424&height=1515 3x" media="(max-width: 839px)">
#                     <source class="" srcset="https://resources.premierleague.com/photos/2023/10/06/6a8dab60-b897-4f77-ba60-6e86bbfe399f/KYoCZb7G.jpg?width=451&height=268, https://resources.premierleague.com/photos/2023/10/06/6a8dab60-b897-4f77-ba60-6e86bbfe399f/KYoCZb7G.jpg?width=902&height=536 2x, https://resources.premierleague.com/photos/2023/10/06/6a8dab60-b897-4f77-ba60-6e86bbfe399f/KYoCZb7G.jpg?width=1353&height=804 3x" media="(min-width: 840px)">
#                     <img class=" js-faded-image fade-in-on-load object-fit-cover-picture__img" src="https://resources.premierleague.com/photos/2023/10/06/6a8dab60-b897-4f77-ba60-6e86bbfe399f/KYoCZb7G.jpg?width=451&height=268" alt="Arsenal v Man City: Five memorable moments " title="Arsenal v Man City: Five memorable moments " style="">
#         </picture>
#     </div>
#  -->
# </div>
# <div class="media-thumbnail__meta-tag">
# <svg aria-hidden="true" class="icon media-thumbnail__meta-tag-icon">
# <use xlink:href="https://www.premierleague.com/resources/rebrand/v7.130.2/i/svg-output/icons.svg#icn-play" xmlns:xlink="http://www.w3.org/1999/xlink"></use>
# </svg>
#                                 01:54
#                         </div>
# </div>
# </header>
# <div class="media-thumbnail__content">
# <span class="media-thumbnail__tag">
#                             Video
#                     </span>
# <div class="media-thumbnail__video-tags">
# </div>
# <span class="media-thumbnail__title">Arsenal v Man City: Five memorable moments
#                 </span>
# </div>
# </a>
# </article>
# </div>
# </div>
# </section>
# </div>
# </div>
# </div>
# </div>
# <div class="searchOverlay js-search-overlay"></div>
# </div>
# <nav class="subNav js-sub-nav" role="menubar">
# <ul>
# <li><a class="" data-link-index="0" href="/" role="menuitem">Home</a></li>
# <li><a class="" data-link-index="1" href="/fixtures" role="menuitem">Fixtures</a></li>
# <li><a class="" data-link-index="2" href="/results" role="menuitem">Results</a></li>
# <li><a class="active" data-link-index="3" href="/tables" role="menuitem">Tables</a></li>
# <li><a class="" data-link-index="4" href="/transfers" role="menuitem">Transfers</a></li>
# <li><a class="hideNavDropdown" data-link-index="5" href="/stats" role="menuitem">Stats</a></li>
# <li><a class="" data-link-index="6" href="/news" role="menuitem">News</a></li>
# <li><a class="" data-link-index="7" href="/video" role="menuitem">Video</a></li>
# <li><a class="" data-link-index="8" href="/broadcast-schedules" role="menuitem">Watch Live</a></li>
# <li><a class="" data-link-index="9" href="/clubs" role="menuitem">Clubs</a></li>
# <li><a class="" data-link-index="10" href="/players" role="menuitem">Players</a></li>
# <li><a class="" data-link-index="11" href="/awards" role="menuitem">Awards</a></li>
# </ul>
# </nav>
# </div>
# </header>
# <main id="mainContent" tabindex="0">
# <!-- /131332370/GeneralTakeover_0 -->
# <div class="ad-takeover js-ad-takeover">
# <nav class="navBar">
# <a class="plLogo" href="#!" id="logoClose">
# <img alt="Premier League Logo" src="/resources/prod/v6.122.4-6039/i/elements/premier-league-logo-header-full.png"/>
# </a>
# <a class="closeBtn" href="#!" id="advertClose">
# <svg aria-hidden="true" class="icon icn">
# <use xlink:href="https://www.premierleague.com/resources/rebrand/v7.130.2/i/svg-output/icons.svg#icn-close" xmlns:xlink="http://www.w3.org/1999/xlink"></use>
# </svg>
#             Close Advert
#         </a>
# </nav>
# <div class="DFP-takeover" id="div-gpt-ad-1503491171981-0" style="display: none;"></div>
# <script type="text/javascript">
#         // GOOGLE ADS SCRIPT
#         var adWrap = document.querySelector('.js-ad-takeover');
#         var slotId = '/131332370/GeneralTakeover_0';
#
#         googletag.cmd.push(function() {
#
#             var mapping = googletag.sizeMapping().
#             addSize([0, 0], []).
#             addSize([200, 300], [[320, 50], [320, 480]]).
#             addSize([450, 300], [[320, 50], [1600, 900]]).
#             addSize([750, 300], [[728, 90], [1600, 900]]).
#             addSize([990, 300], [[1600, 900], [970, 250], [728, 90]]).build();
#
#             googletag.defineSlot('/131332370/GeneralTakeover', [
#                 [1600, 900],
#                 [320, 480]
#             ], 'div-gpt-ad-1503491171981-0').
#                 defineSizeMapping(mapping).
#                 addService(googletag.pubads());
#             googletag.pubads().enableSingleRequest();
#             googletag.enableServices();
#
#             googletag.pubads().addEventListener('slotRenderEnded', function (event) {
#
#                 if ( slotId === event.slot.getSlotId().toString() ) {
#                     if (event.isEmpty) {
#                         adWrap.style.display = 'none';
#                     } else {
#                         adWrap.style.display = 'block';
#                     }
#                 }
#             });
#
#             googletag.display('div-gpt-ad-1503491171981-0');
#
#         });
#
#         // PULSELIVE SCRIPT
#         var closeBtn = document.getElementById('advertClose');
#         var closeLogo = document.getElementById('logoClose');
#
#         closeBtn.addEventListener('click', function( e ){
#             e.preventDefault();
#             adWrap.innerHTML = "";
#             adWrap.style.width = 0;
#             adWrap.style.height = 0;
#         });
#
#         closeLogo.addEventListener('click', function( e ){
#             e.preventDefault();
#             adWrap.innerHTML = "";
#             adWrap.style.width = 0;
#             adWrap.style.height = 0;
#         });
#     </script>
# </div>
# ...
# <a class="footer-link" href="//www.premierleague.com/footballandcommunity/premier-league-charitable-fund" role="menuitem" target="_self">
#             PL Charitable Fund
#         </a>
# </li>
# <li class="footer-link-wrapper">
# <a class="footer-link" href="//www.premierleague.com/footballandcommunity/community" role="menuitem" target="_self">
#             Community
#         </a>
# </li>
# <li class="footer-link-wrapper">
# <a class="footer-link" href="//www.premierleague.com/footballandcommunity/youth-development" role="menuitem" target="_self">
#             Youth Development
#         </a>
# </li>
# <li class="footer-link-wrapper">
# <a class="footer-link" href="//www.premierleague.com/footballandcommunity/NoRoomForRacism" role="menuitem" target="_self">
#             No Room for Racism
#         </a>
# </li>
# <li class="footer-link-wrapper">
# <a class="footer-link" href="//www.premierleague.com/footballandcommunity/mental-health" role="menuitem" target="_self">
#             Mental Health
#         </a>
# </li>
# <li class="footer-link-wrapper">
# <a class="footer-link" href="//www.premierleague.com/footballandcommunity/RainbowLaces" role="menuitem" target="_self">
#             Rainbow Laces
#         </a>
# </li>
# <li class="footer-link-wrapper">
# <a class="footer-link" href="//www.premierleague.com/footballandcommunity/poppy" role="menuitem" target="_self">
#             Poppy
#         </a>
# </li>
# </ul>
# </div>
# <div class="footerCol">
# <h3 class="subHeader">About</h3>
# <ul class="list--about" role="menu">
# <li class="footer-link-wrapper">
# <a class="footer-link" href="//www.premierleague.com/about" role="menuitem" target="_self">
#             Overview
#         </a>
# </li>
# <li class="footer-link-wrapper">
# <a class="footer-link" href="//www.premierleague.com/about/what-we-do" role="menuitem" target="_self">
#             What we do
#         </a>
# </li>
# <li class="footer-link-wrapper">
# <a class="footer-link" href="//www.premierleague.com/about/governance" role="menuitem" target="_self">
#             Governance
#         </a>
# </li>
# <li class="footer-link-wrapper">
# <a class="footer-link" href="//www.premierleague.com/about/statement-of-principles" role="menuitem" target="_self">
#             Statement of Principles
#         </a>
# </li>
# <li class="footer-link-wrapper">
# <a class="footer-link" href="//www.premierleague.com/about/inclusion" role="menuitem" target="_self">
#             Inclusion
#         </a>
# </li>
# <li class="footer-link-wrapper">
# <a class="footer-link" href="//www.premierleague.com/about/publications" role="menuitem" target="_self">
#             Publications
#         </a>
# </li>
# <li class="footer-link-wrapper">
# <a class="footer-link" href="//www.premierleague.com/about/partners" role="menuitem" target="_self">
#             Partners
#         </a>
# </li>
# <li class="footer-link-wrapper">
# <a class="footer-link" href="//www.premierleague.com/about/legal" role="menuitem" target="_self">
#             Legal
#         </a>
# </li>
# <li class="footer-link-wrapper">
# <a class="footer-link" href="//www.premierleague.com/about/safeguarding" role="menuitem" target="_self">
#             Safeguarding
#         </a>
# </li>
# <li class="footer-link-wrapper">
# <a class="footer-link" href="//www.premierleague.com/about/careers" role="menuitem" target="_self">
#             Careers
#         </a>
# </li>
# <li class="footer-link-wrapper">
# <a class="footer-link" href="//www.premierleague.com/about/media" role="menuitem" target="_self">
#             Media
#         </a>
# </li>
# </ul>
# </div>
# <div class="footerCol">
# <h3 class="subHeader">Stats</h3>
# <ul class="list--stats" role="menu">
# <li class="footer-link-wrapper">
# <a class="footer-link" href="//www.premierleague.com/stats" role="menuitem" target="_self">
#             Dashboard
#         </a>
# </li>
# <li class="footer-link-wrapper">
# <a class="footer-link" href="//www.premierleague.com/stats/top/players/goals?se=418" role="menuitem" target="_self">
#             Player Stats
#         </a>
# </li>
# <li class="footer-link-wrapper">
# <a class="footer-link" href="//www.premierleague.com/stats/top/clubs/wins?se=418" role="menuitem" target="_self">
#             Club Stats
#         </a>
# </li>
# <li class="footer-link-wrapper">
# <a class="footer-link" href="//www.premierleague.com/stats/all-time" role="menuitem" target="_self">
#             All-time Stats
#         </a>
# </li>
# <li class="footer-link-wrapper">
# <a class="footer-link" href="//www.premierleague.com/stats/records" role="menuitem" target="_self">
#             Records
#         </a>
# </li>
# <li class="footer-link-wrapper">
# <a class="footer-link" href="//www.premierleague.com/stats/head-to-head" role="menuitem" target="_self">
#             Head-to-Head
#         </a>
# </li>
# <li class="footer-link-wrapper">
# <a class="footer-link" href="//www.premierleague.com/stats/player-comparison" role="menuitem" target="_self">
#             Player Comparison
#         </a>
# </li>
# <li class="footer-link-wrapper">
# <a class="footer-link" href="//www.premierleague.com/stats/awards" role="menuitem" target="_self">
#             Awards
#         </a>
# </li>
# </ul>
# </div>
# <div class="footerCol">
# <h3 class="subHeader">More</h3>
# <ul class="list--more" role="menu">
# <li class="footer-link-wrapper">
# <a class="footer-link" href="//www.premierleague.com/history" role="menuitem" target="_self">
#             History
#         </a>
# </li>
# <li class="footer-link-wrapper">
# <a class="footer-link" href="//www.premierleague.com/hall-of-fame" role="menuitem" target="_self">
#             Hall of Fame
#         </a>
# </li>
# <li class="footer-link-wrapper">
# <a class="footer-link" href="//www.premierleague.com/PL30" role="menuitem" target="_self">
#             PL30
#         </a>
# </li>
# <li class="footer-link-wrapper">
# <a class="footer-link" href="//www.premierleague.com/referees" role="menuitem" target="_self">
#             Referees
#         </a>
# </li>
# <li class="footer-link-wrapper">
# <a class="footer-link" href="//www.premierleague.com/managers" role="menuitem" target="_self">
#             Managers
#         </a>
# </li>
# <li class="footer-link-wrapper">
# <a class="footer-link" href="//www.premierleague.com/epl" role="menuitem" target="_self">
#             ePremier League
#         </a>
# </li>
# <li class="footer-link-wrapper">
# <a class="footer-link" href="//www.premierleague.com/nike-ball-hub" role="menuitem" target="_self">
#             Nike Ball Hub
#         </a>
# </li>
# <li class="footer-link-wrapper">
# <a class="footer-link" href="//www.premierleague.com/contact/faqs" role="menuitem" target="_self">
#             FAQs
#         </a>
# </li>
# <li class="footer-link-wrapper">
# <a class="footer-link" href="//www.premierleague.com/contact" role="menuitem" target="_self">
#             Contact Us
#         </a>
# </li>
# </ul>
# </div>
# <div class="footerCol">
# <h3 class="subHeader">Social</h3>
# <ul class="list--social" role="menu">
# <li class="footer-link-wrapper">
# <a class="footer-link" href="https://www.youtube.com/premierleague" role="menuitem" target="_blank">
#             PL on YouTube
#         </a>
# <span class="icon">
# <span class="visuallyHidden">External Link</span>
# <svg class="svg">
# <use xlink:href="https://www.premierleague.com/resources/rebrand/v7.130.2/i/svg-output/icons.svg#icn-external-square" xmlns:xlink="http://www.w3.org/1999/xlink"></use>
# </svg>
# </span>
# </li>
# <li class="footer-link-wrapper">
# <a class="footer-link" href="https://www.tiktok.com/@premierleague" role="menuitem" target="_blank">
#             PL on Tik Tok
#         </a>
# <span class="icon">
# <span class="visuallyHidden">External Link</span>
# <svg class="svg">
# <use xlink:href="https://www.premierleague.com/resources/rebrand/v7.130.2/i/svg-output/icons.svg#icn-external-square" xmlns:xlink="http://www.w3.org/1999/xlink"></use>
# </svg>
# </span>
# </li>
# <li class="footer-link-wrapper">
# <a class="footer-link" href="https://www.facebook.com/premierleague" role="menuitem" target="_blank">
#             PL on Facebook
#         </a>
# <span class="icon">
# <span class="visuallyHidden">External Link</span>
# <svg class="svg">
# <use xlink:href="https://www.premierleague.com/resources/rebrand/v7.130.2/i/svg-output/icons.svg#icn-external-square" xmlns:xlink="http://www.w3.org/1999/xlink"></use>
# </svg>
# </span>
# </li>
# <li class="footer-link-wrapper">
# <a class="footer-link" href="https://www.facebook.com/OfficialFPL/" role="menuitem" target="_blank">
#             FPL on Facebook
#         </a>
# <span class="icon">
# <span class="visuallyHidden">External Link</span>
# <svg class="svg">
# <use xlink:href="https://www.premierleague.com/resources/rebrand/v7.130.2/i/svg-output/icons.svg#icn-external-square" xmlns:xlink="http://www.w3.org/1999/xlink"></use>
# </svg>
# </span>
# </li>
# <li class="footer-link-wrapper">
# <a class="footer-link" href="https://twitter.com/premierleague" role="menuitem" target="_blank">
#             PL on Twitter
#         </a>
# <span class="icon">
# <span class="visuallyHidden">External Link</span>
# <svg class="svg">
# <use xlink:href="https://www.premierleague.com/resources/rebrand/v7.130.2/i/svg-output/icons.svg#icn-external-square" xmlns:xlink="http://www.w3.org/1999/xlink"></use>
# </svg>
# </span>
# </li>
# <li class="footer-link-wrapper">
# <a class="footer-link" href="https://twitter.com/OfficialFPL" role="menuitem" target="_blank">
#             FPL on Twitter
#         </a>
# <span class="icon">
# <span class="visuallyHidden">External Link</span>
# <svg class="svg">
# <use xlink:href="https://www.premierleague.com/resources/rebrand/v7.130.2/i/svg-output/icons.svg#icn-external-square" xmlns:xlink="http://www.w3.org/1999/xlink"></use>
# </svg>
# </span>
# </li>
# <li class="footer-link-wrapper">
# <a class="footer-link" href="https://twitter.com/PLCommunities" role="menuitem" target="_blank">
#             PL Communities on Twitter
#         </a>
# <span class="icon">
# <span class="visuallyHidden">External Link</span>
# <svg class="svg">
# <use xlink:href="https://www.premierleague.com/resources/rebrand/v7.130.2/i/svg-output/icons.svg#icn-external-square" xmlns:xlink="http://www.w3.org/1999/xlink"></use>
# </svg>
# </span>
# </li>
# <li class="footer-link-wrapper">
# <a class="footer-link" href="https://twitter.com/PLYouth" role="menuitem" target="_blank">
#             PL Youth on Twitter
#         </a>
# <span class="icon">
# <span class="visuallyHidden">External Link</span>
# <svg class="svg">
# <use xlink:href="https://www.premierleague.com/resources/rebrand/v7.130.2/i/svg-output/icons.svg#icn-external-square" xmlns:xlink="http://www.w3.org/1999/xlink"></use>
# </svg>
# </span>
# </li>
# <li class="footer-link-wrapper">
# <a class="footer-link" href="https://www.instagram.com/premierleague" role="menuitem" target="_blank">
#             PL on Instagram
#         </a>
# <span class="icon">
# <span class="visuallyHidden">External Link</span>
# <svg class="svg">
# <use xlink:href="https://www.premierleague.com/resources/rebrand/v7.130.2/i/svg-output/icons.svg#icn-external-square" xmlns:xlink="http://www.w3.org/1999/xlink"></use>
# </svg>
# </span>
# </li>
# <li class="footer-link-wrapper">
# <a class="footer-link" href="https://twitter.com/PLinUSA" role="menuitem" target="_blank">
#             PL USA on Twitter
#         </a>
# <span class="icon">
# <span class="visuallyHidden">External Link</span>
# <svg class="svg">
# <use xlink:href="https://www.premierleague.com/resources/rebrand/v7.130.2/i/svg-output/icons.svg#icn-external-square" xmlns:xlink="http://www.w3.org/1999/xlink"></use>
# </svg>
# </span>
# </li>
# <li class="footer-link-wrapper">
# <a class="footer-link" href="https://www.instagram.com/plinusa/" role="menuitem" target="_blank">
#             PL USA on Instagram
#         </a>
# <span class="icon">
# <span class="visuallyHidden">External Link</span>
# <svg class="svg">
# <use xlink:href="https://www.premierleague.com/resources/rebrand/v7.130.2/i/svg-output/icons.svg#icn-external-square" xmlns:xlink="http://www.w3.org/1999/xlink"></use>
# </svg>
# </span>
# </li>
# <li class="footer-link-wrapper">
# <a class="footer-link" href="https://twitter.com/PLforIndia" role="menuitem" target="_blank">
#             PL India on Twitter
#         </a>
# <span class="icon">
# <span class="visuallyHidden">External Link</span>
# <svg class="svg">
# <use xlink:href="https://www.premierleague.com/resources/rebrand/v7.130.2/i/svg-output/icons.svg#icn-external-square" xmlns:xlink="http://www.w3.org/1999/xlink"></use>
# </svg>
# </span>
# </li>
# <li class="footer-link-wrapper">
# <a class="footer-link" href="https://www.instagram.com/plforindia/" role="menuitem" target="_blank">
#             PL India on Instagram
#         </a>
# <span class="icon">
# <span class="visuallyHidden">External Link</span>
# <svg class="svg">
# <use xlink:href="https://www.premierleague.com/resources/rebrand/v7.130.2/i/svg-output/icons.svg#icn-external-square" xmlns:xlink="http://www.w3.org/1999/xlink"></use>
# </svg>
# </span>
# </li>
# <li class="footer-link-wrapper">
# <a class="footer-link" href="https://twitter.com/PLinArabic" role="menuitem" target="_blank">
#             PL Arabic on Twitter
#         </a>
# <span class="icon">
# <span class="visuallyHidden">External Link</span>
# <svg class="svg">
# <use xlink:href="https://www.premierleague.com/resources/rebrand/v7.130.2/i/svg-output/icons.svg#icn-external-square" xmlns:xlink="http://www.w3.org/1999/xlink"></use>
# </svg>
# </span>
# </li>
# <li class="footer-link-wrapper">
# <a class="footer-link" href="https://www.instagram.com/plinarabic/" role="menuitem" target="_blank">
#             PL Arabic on Instagram
#         </a>
# <span class="icon">
# <span class="visuallyHidden">External Link</span>
# <svg class="svg">
# <use xlink:href="https://www.premierleague.com/resources/rebrand/v7.130.2/i/svg-output/icons.svg#icn-external-square" xmlns:xlink="http://www.w3.org/1999/xlink"></use>
# </svg>
# </span>
# </li>
# <li class="footer-link-wrapper">
# <a class="footer-link" href="https://open.spotify.com/user/plplaylists" role="menuitem" target="_blank">
#             PL Music on Spotify
#         </a>
# <span class="icon">
# <span class="visuallyHidden">External Link</span>
# <svg class="svg">
# <use xlink:href="https://www.premierleague.com/resources/rebrand/v7.130.2/i/svg-output/icons.svg#icn-external-square" xmlns:xlink="http://www.w3.org/1999/xlink"></use>
# </svg>
# </span>
# </li>
# </ul>
# </div>
# </div>
# </div>
# <div class="footerCorporate" data-script="pl_footer" data-widget="footer-corporate">
# <div class="wrapper col-12">
# <ul role="menu">
# <li><strong>© PREMIER LEAGUE 2023</strong></li>
# <li>
# <a class="" href="//www.premierleague.com/modern-slavery-statement" role="menuitem">Modern Slavery Statement</a>
# </li>
# <li>
# <a class="" href="//www.premierleague.com/equality-diversity-and-inclusion-standard" role="menuitem">Equality, Diversity and Inclusion Standard</a>
# </li>
# <li>
# <a class="" href="//www.premierleague.com/terms-and-conditions" role="menuitem">Terms &amp; Conditions</a>
# </li>
# <li>
# <a class="" href="//www.premierleague.com/premier-league-policies" role="menuitem">Policies</a>
# </li>
# <li>
# <a class="" href="//www.premierleague.com/cookie-policy" role="menuitem">Cookie Policy</a>
# </li>
# <li>
# <a class="" href="//www.premierleague.com#" role="menuitem">Back To Top</a>
# </li>
# </ul>
# <div class="official">
# <a class="footerCorporate__logo-container" href="/">
# <img alt="Premier League" class="footerCorporate__logo" src="https://www.premierleague.com/resources/rebrand/v7.130.2/i/elements/pl-logo-full.svg"/>
# </a>
# </div>
# </div>
# </div>
# </footer>
# <script src="https://www.premierleague.com/resources/rebrand/v7.130.2/scripts/vendors.min.js"></script>
# <script src="https://www.premierleague.com/resources/rebrand/v7.130.2/scripts/main.min.js"></script>
# <script src="https://www.premierleague.com/resources/rebrand/v7.130.2/widgets/common.min.js"></script>
# <!-- S3 -->
# <!-- Adform tracking code begin -->
# <script type="text/javascript">
# (function() {
#     var adfScr = document.createElement("script");
#     adfScr.src = "https://track.adform.net/serving/scripts/trackpoint/";
#     adfScr.onload = function() {
#         adf.container(998269, 'Master Tag');
#     };
#     document.head.appendChild(adfScr);
# })();
# </script>
# <!-- Adform tracking code end -->
# <div data-chartbeat-uid="67021" data-page-section="Premier League" data-page-title="" data-script="pl_chartbeat" data-widget="chartbeat-generic"></div>
# </body>
# </html>

# %%
table = soup.find('table')

# %%
table
# Out:
# <table>
# <summary class="visuallyHidden">This table charts the Premier League teams</summary>
# <thead>
# <tr>
# <th class="league-table__pos-header" scope="col">
# <div class="league-table__thFull thFull">Position</div>
# <div class="league-table__thShort thShort">Pos</div>
# </th>
# <th class="league-table__team-header" scope="col">Club</th>
# <th scope="col">
# <div class="league-table__thFull thFull">Played</div>
# <div class="league-table__thShort thShort">Pl</div>
# </th>
# <th scope="col">
# <div class="league-table__thFull thFull">Won</div>
# <div class="league-table__thShort thShort">W</div>
# </th>
# <th scope="col">
# <div class="league-table__thFull thFull">Drawn</div>
# <div class="league-table__thShort thShort">D</div>
# </th>
# <th scope="col">
# <div class="league-table__thFull thFull">Lost</div>
# <div class="league-table__thShort thShort">L</div>
# </th>
# <th class="hideSmall" scope="col"><abbr title="Goals For">GF</abbr></th>
# <th class="hideSmall" scope="col"><abbr title="Goals Against">GA</abbr></th>
# <th scope="col"><abbr title="Goal Difference">GD</abbr></th>
# <th class="league-table__points points" scope="col">
# <div class="league-table__thFull thFull">Points</div>
# <div class="league-table__thShort thShort">Pts</div>
# </th>
# <th class="league-table__team-form hideMed" scope="col">Form</th>
# <th class="hideMed text-centre" scope="col">Next</th>
# <th class="league-table__reveal-more-header js-reveal-more-header text-centre" scope="col" style="display:none;">More</th>
# </tr>
# </thead>
# <tbody class="league-table__tbody isPL standingEntriesContainer">
# <tr class="tableDark" data-compseason="578" data-filtered-entry-size="20" data-filtered-table-row="11" data-filtered-table-row-abbr="11" data-filtered-table-row-name="Manchester City" data-filtered-table-row-opta="t43" data-position="1">
# <td class="league-table__pos pos button-tooltip" id="Tooltip" tabindex="0">
# <span class="league-table__value value">1</span>
# <span class="league-table__movement none">
# <span class="league-table__tooltip-container tooltipContainer tooltip-left" role="tooltip">
# <span class="league-table__tooltip-content tooltip-content">
#                             Previous Position
#
#                             <span class="league-table__result-highlight">
#                                 1
#                             </span>
# </span>
# </span>
# </span>
# </td>
# <td class="league-table__team team" scope="row">
# <a href="/clubs/11/Manchester-City/overview">
# <span class="badge badge-image-container u-hide-tablet" data-size="50" data-widget="club-badge-image">
# <img class="badge-image badge-image--32" src="https://resources.premierleague.com/premierleague/badges/50/t43.png" srcset="https://resources.premierleague.com/premierleague/badges/50/t43@x2.png 2x"/>
# </span>
# <span class="badge badge-image-container u-show-tablet" data-size="25" data-widget="club-badge-image">
# <img class="badge-image badge-image--25" src="https://resources.premierleague.com/premierleague/badges/25/t43.png" srcset="https://resources.premierleague.com/premierleague/badges/25/t43@x2.png 2x"/>
# </span>
# <span class="league-table__team-name league-table__team-name--long long">Manchester City</span>
# <span class="league-table__team-name league-table__team-name--short short">MCI</span>
# </a>
# </td>
# <td>7</td>
# <td>6</td>
# <td>0</td>
# <td>1</td>
# <td class="hideSmall">17</td>
# <td class="hideSmall">5</td>
# <td>
#         +12
#
#  </td>
# <td class="league-table__points points">18</td>
# <td class="league-table__form form hideMed">
# <li class="win button-tooltip" id="Tooltip" tabindex="0">
# <abbr class="form-abbreviation" title="Won">W</abbr>
# <a class="tooltipContainer linkable tooltip-link tooltip-right" href="/match/93350" role="tooltip">
# <span class="tooltip-content">
# <div class="match-fixture match-fixture--small">
# <span class="match-fixture__match-info matchInfo">Sunday 27 August 2023</span>
# <div class="match-fixture__team-score-container">
# <div class="match-fixture__team match-fixture__team--home">
# <span class="match-fixture__team-name"><abbr title="Sheffield United">SHU</abbr></span>
# <span class="badge badge--home-team badge-image-container" data-size="50" data-widget="club-badge-image">
# <img class="badge-image badge-image--30" src="https://resources.premierleague.com/premierleague/badges/50/t49.png" srcset="https://resources.premierleague.com/premierleague/badges/50/t49@x2.png 2x"/>
# </span>
# </div>
# <span class="match-fixture__score score">1 <span>-</span>2</span>
# <div class="match-fixture__team match-fixture__team--away">
# <span class="badge badge--away-team badge-image-container" data-size="50" data-widget="club-badge-image">
# <img class="badge-image badge-image--30" src="https://resources.premierleague.com/premierleague/badges/50/t43.png" srcset="https://resources.premierleague.com/premierleague/badges/50/t43@x2.png 2x"/>
# </span>
# <span class="match-fixture__team-name"><abbr title="Manchester City">MCI</abbr></span>
# </div>
# <svg class="match-fixture__end-icon">
# <use xlink:href="https://www.premierleague.com/resources/rebrand/v7.130.2/i/svg-output/icons.svg#icn-arrow-right" xmlns:xlink="http://www.w3.org/1999/xlink"></use>
# </svg>
# </div>
# </div>
# </span>
# </a>
# </li>
# <li class="win button-tooltip" id="Tooltip" tabindex="0">
# <abbr class="form-abbreviation" title="Won">W</abbr>
# <a class="tooltipContainer linkable tooltip-link tooltip-right" href="/match/93359" role="tooltip">
# <span class="tooltip-content">
# <div class="match-fixture match-fixture--small">
# <span class="match-fixture__match-info matchInfo">Saturday 2 September 2023</span>
# <div class="match-fixture__team-score-container">
# <div class="match-fixture__team match-fixture__team--home">
# <span class="match-fixture__team-name"><abbr title="Manchester City">MCI</abbr></span>
# <span class="badge badge--home-team badge-image-container" data-size="50" data-widget="club-badge-image">
# <img class="badge-image badge-image--30" src="https://resources.premierleague.com/premierleague/badges/50/t43.png" srcset="https://resources.premierleague.com/premierleague/badges/50/t43@x2.png 2x"/>
# </span>
# </div>
# <span class="match-fixture__score score">5 <span>-</span>1</span>
# <div class="match-fixture__team match-fixture__team--away">
# <span class="badge badge--away-team badge-image-container" data-size="50" data-widget="club-badge-image">
# <img class="badge-image badge-image--30" src="https://resources.premierleague.com/premierleague/badges/50/t54.png" srcset="https://resources.premierleague.com/premierleague/badges/50/t54@x2.png 2x"/>
# </span>
# <span class="match-fixture__team-name"><abbr title="Fulham">FUL</abbr></span>
# </div>
# <svg class="match-fixture__end-icon">
# <use xlink:href="https://www.premierleague.com/resources/rebrand/v7.130.2/i/svg-output/icons.svg#icn-arrow-right" xmlns:xlink="http://www.w3.org/1999/xlink"></use>
# </svg>
# </div>
# </div>
# </span>
# </a>
# </li>
# <li class="win button-tooltip" id="Tooltip" tabindex="0">
# <abbr class="form-abbreviation" title="Won">W</abbr>
# <a class="tooltipContainer linkable tooltip-link tooltip-right" href="/match/93369" role="tooltip">
# <span class="tooltip-content">
# <div class="match-fixture match-fixture--small">
# <span class="match-fixture__match-info matchInfo">Saturday 16 September 2023</span>
# <div class="match-fixture__team-score-container">
# <div class="match-fixture__team match-fixture__team--home">
# <span class="match-fixture__team-name"><abbr title="West Ham United">WHU</abbr></span>
# <span class="badge badge--home-team badge-image-container" data-size="50" data-widget="club-badge-image">
# <img class="badge-image badge-image--30" src="https://resources.premierleague.com/premierleague/badges/50/t21.png" srcset="https://resources.premierleague.com/premierleague/badges/50/t21@x2.png 2x"/>
# </span>
# </div>
# <span class="match-fixture__score score">1 <span>-</span>3</span>
# <div class="match-fixture__team match-fixture__team--away">
# <span class="badge badge--away-team badge-image-container" data-size="50" data-widget="club-badge-image">
# <img class="badge-image badge-image--30" src="https://resources.premierleague.com/premierleague/badges/50/t43.png" srcset="https://resources.premierleague.com/premierleague/badges/50/t43@x2.png 2x"/>
# </span>
# <span class="match-fixture__team-name"><abbr title="Manchester City">MCI</abbr></span>
# </div>
# <svg class="match-fixture__end-icon">
# <use xlink:href="https://www.premierleague.com/resources/rebrand/v7.130.2/i/svg-output/icons.svg#icn-arrow-right" xmlns:xlink="http://www.w3.org/1999/xlink"></use>
# </svg>
# </div>
# </div>
# </span>
# </a>
# </li>
# <li class="win button-tooltip" id="Tooltip" tabindex="0">
# <abbr class="form-abbreviation" title="Won">W</abbr>
# <a class="tooltipContainer linkable tooltip-link tooltip-right" href="/match/93379" role="tooltip">
# <span class="tooltip-content">
# <div class="match-fixture match-fixture--small">
# <span class="match-fixture__match-info matchInfo">Saturday 23 September 2023</span>
# <div class="match-fixture__team-score-container">
# <div class="match-fixture__team match-fixture__team--home">
# <span class="match-fixture__team-name"><abbr title="Manchester City">MCI</abbr></span>
# <span class="badge badge--home-team badge-image-container" data-size="50" data-widget="club-badge-image">
# <img class="badge-image badge-image--30" src="https://resources.premierleague.com/premierleague/badges/50/t43.png" srcset="https://resources.premierleague.com/premierleague/badges/50/t43@x2.png 2x"/>
# </span>
# </div>
# <span class="match-fixture__score score">2 <span>-</span>0</span>
# <div class="match-fixture__team match-fixture__team--away">
# <span class="badge badge--away-team badge-image-container" data-size="50" data-widget="club-badge-image">
# <img class="badge-image badge-image--30" src="https://resources.premierleague.com/premierleague/badges/50/t17.png" srcset="https://resources.premierleague.com/premierleague/badges/50/t17@x2.png 2x"/>
# </span>
# <span class="match-fixture__team-name"><abbr title="Nottingham Forest">NFO</abbr></span>
# </div>
# <svg class="match-fixture__end-icon">
# <use xlink:href="https://www.premierleague.com/resources/rebrand/v7.130.2/i/svg-output/icons.svg#icn-arrow-right" xmlns:xlink="http://www.w3.org/1999/xlink"></use>
# </svg>
# </div>
# </div>
# </span>
# </a>
# </li>
# <li class="lose button-tooltip" id="Tooltip" tabindex="0">
# <abbr class="form-abbreviation" title="Lost">L</abbr>
# <a class="tooltipContainer linkable tooltip-link tooltip-right" href="/match/93390" role="tooltip">
# <span class="tooltip-content">
# <div class="match-fixture match-fixture--small">
# <span class="match-fixture__match-info matchInfo">Saturday 30 September 2023</span>
# <div class="match-fixture__team-score-container">
# <div class="match-fixture__team match-fixture__team--home">
# <span class="match-fixture__team-name"><abbr title="Wolverhampton Wanderers">WOL</abbr></span>
# <span class="badge badge--home-team badge-image-container" data-size="50" data-widget="club-badge-image">
# <img class="badge-image badge-image--30" src="https://resources.premierleague.com/premierleague/badges/50/t39.png" srcset="https://resources.premierleague.com/premierleague/badges/50/t39@x2.png 2x"/>
# </span>
# </div>
# <span class="match-fixture__score score">2 <span>-</span>1</span>
# <div class="match-fixture__team match-fixture__team--away">
# <span class="badge badge--away-team badge-image-container" data-size="50" data-widget="club-badge-image">
# <img class="badge-image badge-image--30" src="https://resources.premierleague.com/premierleague/badges/50/t43.png" srcset="https://resources.premierleague.com/premierleague/badges/50/t43@x2.png 2x"/>
# </span>
# <span class="match-fixture__team-name"><abbr title="Manchester City">MCI</abbr></span>
# </div>
# <svg class="match-fixture__end-icon">
# <use xlink:href="https://www.premierleague.com/resources/rebrand/v7.130.2/i/svg-output/icons.svg#icn-arrow-right" xmlns:xlink="http://www.w3.org/1999/xlink"></use>
# </svg>
# </div>
# </div>
# </span>
# </a>
# </li>
# </td>
# <td class="nextMatchCol hideMed">
# <span class="button-tooltip" id="Tooltip" tabindex="0">
# <span class="nextMatch">
# <span class="badge badge-image-container" data-size="50" data-widget="club-badge-image">
# <img class="badge-image badge-image--32" src="https://resources.premierleague.com/premierleague/badges/50/t3.png" srcset="https://resources.premierleague.com/premierleague/badges/50/t3.png, https://resources.premierleague.com/premierleague/badges/50/t3@x2.png 2x"/>
# <span class="visuallyHidden">Arsenal</span>
# </span>
# </span>
# <a class="tooltipContainer linkable tooltip-link tooltip-right" href="/match/93391" role="tooltip">
# <span class="tooltip-content">
# <div class="match-fixture match-fixture--small">
# <span class="match-fixture__match-info">Sunday 08 October 2023</span>
# <div class="match-fixture__team-score-container">
# <div class="match-fixture__team match-fixture__team--home">
# <span class="match-fixture__team-name"><abbr title="Arsenal">ARS</abbr></span>
# <span class="badge badge--home-team badge-image-container" data-size="50" data-widget="club-badge-image">
# <img class="badge-image badge-image--30" src="https://resources.premierleague.com/premierleague/badges/50/t3.png" srcset="https://resources.premierleague.com/premierleague/badges/50/t3@x2.png 2x"/>
# </span>
# </div>
# <time>16:30</time>
# <div class="match-fixture__team match-fixture__team--away">
# <span class="badge badge--away-team badge-image-container" data-size="50" data-widget="club-badge-image">
# <img class="badge-image badge-image--30" src="https://resources.premierleague.com/premierleague/badges/50/t43.png" srcset="https://resources.premierleague.com/premierleague/badges/50/t43@x2.png 2x"/>
# </span>
# <span class="match-fixture__team-name"><abbr title="Manchester City">MCI</abbr></span>
# </div>
# <svg class="match-fixture__end-icon">
# <use xlink:href="https://www.premierleague.com/resources/rebrand/v7.130.2/i/svg-output/icons.svg#icn-arrow-right" xmlns:xlink="http://www.w3.org/1999/xlink"></use>
# </svg>
# </div>
# </div>
# </span>
# </a>
# </span>
# </td>
# <td class="league-table__reveal-more js-reveal-more" role="button" style="display:none;" tabindex="0">
# <svg class="league-table__reveal-more-icon">
# <use xlink:href="https://www.premierleague.com/resources/rebrand/v7.130.2/i/svg-output/icons.svg#icn-chevron-down" xmlns:xlink="http://www.w3.org/1999/xlink"></use>
# </svg>
# </td>
# </tr>
# <tr class="league-table__expandable expandable" data-filtered-table-row-expander="11">
# <td colspan="13">
# <div class="league-table__expandable-container">
# <a class="league-table__expandable-team expandableTeam" href="/clubs/11/Manchester-City/overview">
# <span class="badge badge-image-container" data-size="50" data-widget="club-badge-image">
# <img class="badge-image badge-image--40" src="https://resources.premierleague.com/premierleague/badges/50/t43.png" srcset="https://resources.premierleague.com/premierleague/badges/50/t43@x2.png 2x"/>
# </span>
# <span class="league-table__team-name teamName">Manchester City</span>
# </a>
# <div class="league-table__expandable-matches-container">
# <div class="league-table__result-widget resultWidget">
# <div class="league-table__result-widget-label label"><strong>Recent Result</strong>: Saturday 30 September 2023</div>
# <a class="league-table__match-fixture match-fixture match-fixture--small pre" href="/match/93390">
# <div class="match-fixture__team match-fixture__team--home">
# <span class="match-fixture__team-name"><abbr title="Wolverhampton Wanderers">WOL</abbr></span>
# <span class="badge badge--home-team badge-image-container" data-size="50" data-widget="club-badge-image">
# <img class="badge-image badge-image--30" src="https://resources.premierleague.com/premierleague/badges/50/t39.png" srcset="https://resources.premierleague.com/premierleague/badges/50/t39@x2.png 2x"/>
# </span>
# </div>
# <span class="match-fixture__score score">2 <span>-</span>1</span>
# <div class="match-fixture__team match-fixture__team--away">
# <span class="badge badge--away-team badge-image-container" data-size="50" data-widget="club-badge-image">
# <img class="badge-image badge-image--30" src="https://resources.premierleague.com/premierleague/badges/50/t43.png" srcset="https://resources.premierleague.com/premierleague/badges/50/t43@x2.png 2x"/>
# </span>
# <span class="match-fixture__team-name"><abbr title="Manchester City">MCI</abbr></span>
# </div>
# <svg class="match-fixture__end-icon">
# <use xlink:href="https://www.premierleague.com/resources/rebrand/v7.130.2/i/svg-output/icons.svg#icn-arrow-right" xmlns:xlink="http://www.w3.org/1999/xlink"></use>
# </svg>
# </a>
# </div>
# <div class="league-table__result-widget resultWidget">
# <div class="league-table__result-widget-label label"><strong>Next Fixture</strong>: Sunday 8 October 2023</div>
# <a class="league-table__match-fixture match-fixture match-fixture--small pre" href="/match/93391">
# <div class="match-fixture__team match-fixture__team--home">
# <span class="match-fixture__team-name"><abbr title="Arsenal">ARS</abbr></span>
# <span class="badge badge--home-team badge-image-container" data-size="50" data-widget="club-badge-image">
# <img class="badge-image badge-image--30" src="https://resources.premierleague.com/premierleague/badges/50/t3.png" srcset="https://resources.premierleague.com/premierleague/badges/50/t3@x2.png 2x"/>
# </span>
# </div>
# <time>16:30</time>
# <div class="match-fixture__team match-fixture__team--away">
# <span class="badge badge--away-team badge-image-container" data-size="50" data-widget="club-badge-image">
# <img class="badge-image badge-image--30" src="https://resources.premierleague.com/premierleague/badges/50/t43.png" srcset="https://resources.premierleague.com/premierleague/badges/50/t43@x2.png 2x"/>
# </span>
# <span class="match-fixture__team-name"><abbr title="Manchester City">MCI</abbr></span>
# </div>
# <svg class="match-fixture__end-icon">
# <use xlink:href="https://www.premierleague.com/resources/rebrand/v7.130.2/i/svg-output/icons.svg#icn-arrow-right" xmlns:xlink="http://www.w3.org/1999/xlink"></use>
# </svg>
# </a>
# </div>
# <div class="league-table__btn-container btnContainer">
# <a class="league-table__club-page-btn global-btn btn-highlight" href="/clubs/11/Manchester-City/overview" role="btn">
#                             Visit Club Page
#                             <span class="visuallyHidden">VisitManchester CityClub Page</span>
# <svg class="league-table__btn-icon">
# <use xlink:href="https://www.premierleague.com/resources/rebrand/v7.130.2/i/svg-output/icons.svg#icn-arrow-right" xmlns:xlink="http://www.w3.org/1999/xlink"></use>
# </svg>
# </a>
# </div>
# </div>
# </div>
# <div class="league-table__team-performance-container teamPerformanceStandingsArea" style="display:none;">
# <header>
# <h3 class="league-table__sub-header subHeader left">Performance Chart</h3>
# <a class="global-btn btn right" href="/stats/comparison">
#                         Compare against another team
# 	<svg class="league-table__btn-icon">
# <use xlink:href="https://www.premierleague.com/resources/rebrand/v7.130.2/i/svg-output/icons.svg#icn-arrow-right" xmlns:xlink="http://www.w3.org/1999/xlink"></use>
# </svg>
# </a>
# </header>
# <div class="league-table__team-performance-standings-container teamPerformanceStandingsContainer"></div>
# </div>
# </td>
# </tr>
# <tr class="tableMid" data-compseason="578" data-filtered-entry-size="20" data-filtered-table-row="21" data-filtered-table-row-abbr="21" data-filtered-table-row-name="Tottenham Hotspur" data-filtered-table-row-opta="t6" data-position="2">
# <td class="league-table__pos pos button-tooltip" id="Tooltip" tabindex="0">
# <span class="league-table__value value">2</span>
# <span class="league-table__movement up">
# <span class="league-table__tooltip-container tooltipContainer tooltip-left" role="tooltip">
# <span class="league-table__tooltip-content tooltip-content">
#                             Previous Position
#
#                             <span class="league-table__result-highlight">
#                                 4
#                             </span>
# </span>
# </span>
# </span>
# </td>
# <td class="league-table__team team" scope="row">
# <a href="/clubs/21/Tottenham-Hotspur/overview">
# <span class="badge badge-image-container u-hide-tablet" data-size="50" data-widget="club-badge-image">
# <img class="badge-image badge-image--32" src="https://resources.premierleague.com/premierleague/badges/50/t6.png" srcset="https://resources.premierleague.com/premierleague/badges/50/t6@x2.png 2x"/>
# </span>
# <span class="badge badge-image-container u-show-tablet" data-size="25" data-widget="club-badge-image">
# <img class="badge-image badge-image--25" src="https://resources.premierleague.com/premierleague/badges/25/t6.png" srcset="https://resources.premierleague.com/premierleague/badges/25/t6@x2.png 2x"/>
# </span>
# <span class="league-table__team-name league-table__team-name--long long">Tottenham Hotspur</span>
# <span class="league-table__team-name league-table__team-name--short short">TOT</span>
# </a>
# </td>
# <td>7</td>
# <td>5</td>
# <td>2</td>
# <td>0</td>
# <td class="hideSmall">17</td>
# <td class="hideSmall">8</td>
# <td>
#         +9
#
#  </td>
# <td class="league-table__points points">17</td>
# <td class="league-table__form form hideMed">
# <li class="win button-tooltip" id="Tooltip" tabindex="0">
# <abbr class="form-abbreviation" title="Won">W</abbr>
# <a class="tooltipContainer linkable tooltip-link tooltip-right" href="/match/93342" role="tooltip">
# <span class="tooltip-content">
# <div class="match-fixture match-fixture--small">
# <span class="match-fixture__match-info matchInfo">Saturday 26 August 2023</span>
# <div class="match-fixture__team-score-container">
# <div class="match-fixture__team match-fixture__team--home">
# <span class="match-fixture__team-name"><abbr title="Bournemouth">BOU</abbr></span>
# <span class="badge badge--home-team badge-image-container" data-size="50" data-widget="club-badge-image">
# <img class="badge-image badge-image--30" src="https://resources.premierleague.com/premierleague/badges/50/t91.png" srcset="https://resources.premierleague.com/premierleague/badges/50/t91@x2.png 2x"/>
# </span>
# </div>
# <span class="match-fixture__score score">0 <span>-</span>2</span>
# <div class="match-fixture__team match-fixture__team--away">
# <span class="badge badge--away-team badge-image-container" data-size="50" data-widget="club-badge-image">
# <img class="badge-image badge-image--30" src="https://resources.premierleague.com/premierleague/badges/50/t6.png" srcset="https://resources.premierleague.com/premierleague/badges/50/t6@x2.png 2x"/>
# </span>
# <span class="match-fixture__team-name"><abbr title="Tottenham Hotspur">TOT</abbr></span>
# </div>
# <svg class="match-fixture__end-icon">
# <use xlink:href="https://www.premierleague.com/resources/rebrand/v7.130.2/i/svg-output/icons.svg#icn-arrow-right" xmlns:xlink="http://www.w3.org/1999/xlink"></use>
# </svg>
# </div>
# </div>
# </span>
# </a>
# </li>
# <li class="win button-tooltip" id="Tooltip" tabindex="0">
# <abbr class="form-abbreviation" title="Won">W</abbr>
# <a class="tooltipContainer linkable tooltip-link tooltip-right" href="/match/93354" role="tooltip">
# <span class="tooltip-content">
# <div class="match-fixture match-fixture--small">
# <span class="match-fixture__match-info matchInfo">Saturday 2 September 2023</span>
# <div class="match-fixture__team-score-container">
# <div class="match-fixture__team match-fixture__team--home">
# <span class="match-fixture__team-name"><abbr title="Burnley">BUR</abbr></span>
# <span class="badge badge--home-team badge-image-container" data-size="50" data-widget="club-badge-image">
# <img class="badge-image badge-image--30" src="https://resources.premierleague.com/premierleague/badges/50/t90.png" srcset="https://resources.premierleague.com/premierleague/badges/50/t90@x2.png 2x"/>
# </span>
# </div>
# <span class="match-fixture__score score">2 <span>-</span>5</span>
# <div class="match-fixture__team match-fixture__team--away">
# <span class="badge badge--away-team badge-image-container" data-size="50" data-widget="club-badge-image">
# <img class="badge-image badge-image--30" src="https://resources.premierleague.com/premierleague/badges/50/t6.png" srcset="https://resources.premierleague.com/premierleague/badges/50/t6@x2.png 2x"/>
# </span>
# <span class="match-fixture__team-name"><abbr title="Tottenham Hotspur">TOT</abbr></span>
# </div>
# <svg class="match-fixture__end-icon">
# <use xlink:href="https://www.premierleague.com/resources/rebrand/v7.130.2/i/svg-output/icons.svg#icn-arrow-right" xmlns:xlink="http://www.w3.org/1999/xlink"></use>
# </svg>
# </div>
# </div>
# </span>
# </a>
# </li>
# <li class="win button-tooltip" id="Tooltip" tabindex="0">
# <abbr class="form-abbreviation" title="Won">W</abbr>
# <a class="tooltipContainer linkable tooltip-link tooltip-right" href="/match/93368" role="tooltip">
# <span class="tooltip-content">
# <div class="match-fixture match-fixture--small">
# <span class="match-fixture__match-info matchInfo">Saturday 16 September 2023</span>
# <div class="match-fixture__team-score-container">
# <div class="match-fixture__team match-fixture__team--home">
# <span class="match-fixture__team-name"><abbr title="Tottenham Hotspur">TOT</abbr></span>
# <span class="badge badge--home-team badge-image-container" data-size="50" data-widget="club-badge-image">
# <img class="badge-image badge-image--30" src="https://resources.premierleague.com/premierleague/badges/50/t6.png" srcset="https://resources.premierleague.com/premierleague/badges/50/t6@x2.png 2x"/>
# </span>
# </div>
# <span class="match-fixture__score score">2 <span>-</span>1</span>
# <div class="match-fixture__team match-fixture__team--away">
# <span class="badge badge--away-team badge-image-container" data-size="50" data-widget="club-badge-image">
# <img class="badge-image badge-image--30" src="https://resources.premierleague.com/premierleague/badges/50/t49.png" srcset="https://resources.premierleague.com/premierleague/badges/50/t49@x2.png 2x"/>
# </span>
# <span class="match-fixture__team-name"><abbr title="Sheffield United">SHU</abbr></span>
# </div>
# <svg class="match-fixture__end-icon">
# <use xlink:href="https://www.premierleague.com/resources/rebrand/v7.130.2/i/svg-output/icons.svg#icn-arrow-right" xmlns:xlink="http://www.w3.org/1999/xlink"></use>
# </svg>
# </div>
# </div>
# </span>
# </a>
# </li>
# <li class="draw button-tooltip" id="Tooltip" tabindex="0">
# <abbr class="form-abbreviation" title="Drawn">D</abbr>
# <a class="tooltipContainer linkable tooltip-link tooltip-right" href="/match/93371" role="tooltip">
# <span class="tooltip-content">
# <div class="match-fixture match-fixture--small">
# <span class="match-fixture__match-info matchInfo">Sunday 24 September 2023</span>
# <div class="match-fixture__team-score-container">
# <div class="match-fixture__team match-fixture__team--home">
# <span class="match-fixture__team-name"><abbr title="Arsenal">ARS</abbr></span>
# <span class="badge badge--home-team badge-image-container" data-size="50" data-widget="club-badge-image">
# <img class="badge-image badge-image--30" src="https://resources.premierleague.com/premierleague/badges/50/t3.png" srcset="https://resources.premierleague.com/premierleague/badges/50/t3@x2.png 2x"/>
# </span>
# </div>
# <span class="match-fixture__score score">2 <span>-</span>2</span>
# <div class="match-fixture__team match-fixture__team--away">
# <span class="badge badge--away-team badge-image-container" data-size="50" data-widget="club-badge-image">
# <img class="badge-image badge-image--30" src="https://resources.premierleague.com/premierleague/badges/50/t6.png" srcset="https://resources.premierleague.com/premierleague/badges/50/t6@x2.png 2x"/>
# </span>
# <span class="match-fixture__team-name"><abbr title="Tottenham Hotspur">TOT</abbr></span>
# </div>
# <svg class="match-fixture__end-icon">
# <use xlink:href="https://www.premierleague.com/resources/rebrand/v7.130.2/i/svg-output/icons.svg#icn-arrow-right" xmlns:xlink="http://www.w3.org/1999/xlink"></use>
# </svg>
# </div>
# </div>
# </span>
# </a>
# </li>
# <li class="win button-tooltip" id="Tooltip" tabindex="0">
# <abbr class="form-abbreviation" title="Won">W</abbr>
# <a class="tooltipContainer linkable tooltip-link tooltip-right" href="/match/93388" role="tooltip">
# <span class="tooltip-content">
# <div class="match-fixture match-fixture--small">
# <span class="match-fixture__match-info matchInfo">Saturday 30 September 2023</span>
# <div class="match-fixture__team-score-container">
# <div class="match-fixture__team match-fixture__team--home">
# <span class="match-fixture__team-name"><abbr title="Tottenham Hotspur">TOT</abbr></span>
# <span class="badge badge--home-team badge-image-container" data-size="50" data-widget="club-badge-image">
# <img class="badge-image badge-image--30" src="https://resources.premierleague.com/premierleague/badges/50/t6.png" srcset="https://resources.premierleague.com/premierleague/badges/50/t6@x2.png 2x"/>
# </span>
# </div>
# <span class="match-fixture__score score">2 <span>-</span>1</span>
# <div class="match-fixture__team match-fixture__team--away">
# <span class="badge badge--away-team badge-image-container" data-size="50" data-widget="club-badge-image">
# <img class="badge-image badge-image--30" src="https://resources.premierleague.com/premierleague/badges/50/t14.png" srcset="https://resources.premierleague.com/premierleague/badges/50/t14@x2.png 2x"/>
# </span>
# <span class="match-fixture__team-name"><abbr title="Liverpool">LIV</abbr></span>
# </div>
# <svg class="match-fixture__end-icon">
# <use xlink:href="https://www.premierleague.com/resources/rebrand/v7.130.2/i/svg-output/icons.svg#icn-arrow-right" xmlns:xlink="http://www.w3.org/1999/xlink"></use>
# </svg>
# </div>
# </div>
# </span>
# </a>
# </li>
# </td>
# <td class="nextMatchCol hideMed">
# <span class="button-tooltip" id="Tooltip" tabindex="0">
# <span class="nextMatch">
# <span class="badge badge-image-container" data-size="50" data-widget="club-badge-image">
# <img class="badge-image badge-image--32" src="https://resources.premierleague.com/premierleague/badges/50/t102.png" srcset="https://resources.premierleague.com/premierleague/badges/50/t102.png, https://resources.premierleague.com/premierleague/badges/50/t102@x2.png 2x"/>
# <span class="visuallyHidden">Luton Town</span>
# </span>
# </span>
# <a class="tooltipContainer linkable tooltip-link tooltip-right" href="/match/93397" role="tooltip">
# <span class="tooltip-content">
# <div class="match-fixture match-fixture--small">
# <span class="match-fixture__match-info">Saturday 07 October 2023</span>
# <div class="match-fixture__team-score-container">
# <div class="match-fixture__team match-fixture__team--home">
# <span class="match-fixture__team-name"><abbr title="Luton Town">LUT</abbr></span>
# <span class="badge badge--home-team badge-image-container" data-size="50" data-widget="club-badge-image">
# <img class="badge-image badge-image--30" src="https://resources.premierleague.com/premierleague/badges/50/t102.png" srcset="https://resources.premierleague.com/premierleague/badges/50/t102@x2.png 2x"/>
# </span>
# </div>
# <time>12:30</time>
# <div class="match-fixture__team match-fixture__team--away">
# <span class="badge badge--away-team badge-image-container" data-size="50" data-widget="club-badge-image">
# <img class="badge-image badge-image--30" src="https://resources.premierleague.com/premierleague/badges/50/t6.png" srcset="https://resources.premierleague.com/premierleague/badges/50/t6@x2.png 2x"/>
# </span>
# <span class="match-fixture__team-name"><abbr title="Tottenham Hotspur">TOT</abbr></span>
# </div>
# <svg class="match-fixture__end-icon">
# <use xlink:href="https://www.premierleague.com/resources/rebrand/v7.130.2/i/svg-output/icons.svg#icn-arrow-right" xmlns:xlink="http://www.w3.org/1999/xlink"></use>
# </svg>
# </div>
# </div>
# </span>
# </a>
# </span>
# </td>
# <td class="league-table__reveal-more js-reveal-more" role="button" style="display:none;" tabindex="0">
# <svg class="league-table__reveal-more-icon">
# <use xlink:href="https://www.premierleague.com/resources/rebrand/v7.130.2/i/svg-output/icons.svg#icn-chevron-down" xmlns:xlink="http://www.w3.org/1999/xlink"></use>
# </svg>
# </td>
# </tr>
# <tr class="league-table__expandable expandable" data-filtered-table-row-expander="21">
# <td colspan="13">
# <div class="league-table__expandable-container">
# <a class="league-table__expandable-team expandableTeam" href="/clubs/21/Tottenham-Hotspur/overview">
# <span class="badge badge-image-container" data-size="50" data-widget="club-badge-image">
# <img class="badge-image badge-image--40" src="https://resources.premierleague.com/premierleague/badges/50/t6.png" srcset="https://resources.premierleague.com/premierleague/badges/50/t6@x2.png 2x"/>
# </span>
# <span class="league-table__team-name teamName">Tottenham Hotspur</span>
# </a>
# <div class="league-table__expandable-matches-container">
# <div class="league-table__result-widget resultWidget">
# <div class="league-table__result-widget-label label"><strong>Recent Result</strong>: Saturday 30 September 2023</div>
# <a class="league-table__match-fixture match-fixture match-fixture--small pre" href="/match/93388">
# <div class="match-fixture__team match-fixture__team--home">
# <span class="match-fixture__team-name"><abbr title="Tottenham Hotspur">TOT</abbr></span>
# <span class="badge badge--home-team badge-image-container" data-size="50" data-widget="club-badge-image">
# <img class="badge-image badge-image--30" src="https://resources.premierleague.com/premierleague/badges/50/t6.png" srcset="https://resources.premierleague.com/premierleague/badges/50/t6@x2.png 2x"/>
# </span>
# </div>
# <span class="match-fixture__score score">2 <span>-</span>1</span>
# <div class="match-fixture__team match-fixture__team--away">
# <span class="badge badge--away-team badge-image-container" data-size="50" data-widget="club-badge-image">
# <img class="badge-image badge-image--30" src="https://resources.premierleague.com/premierleague/badges/50/t14.png" srcset="https://resources.premierleague.com/premierleague/badges/50/t14@x2.png 2x"/>
# </span>
# <span class="match-fixture__team-name"><abbr title="Liverpool">LIV</abbr></span>
# </div>
# <svg class="match-fixture__end-icon">
# <use xlink:href="https://www.premierleague.com/resources/rebrand/v7.130.2/i/svg-output/icons.svg#icn-arrow-right" xmlns:xlink="http://www.w3.org/1999/xlink"></use>
# </svg>
# </a>
# </div>
# <div class="league-table__result-widget resultWidget">
# <div class="league-table__result-widget-label label"><strong>Next Fixture</strong>: Saturday 7 October 2023</div>
# <a class="league-table__match-fixture match-fixture match-fixture--small pre" href="/match/93397">
# <div class="match-fixture__team match-fixture__team--home">
# <span class="match-fixture__team-name"><abbr title="Luton Town">LUT</abbr></span>
# <span class="badge badge--home-team badge-image-container" data-size="50" data-widget="club-badge-image">
# <img class="badge-image badge-image--30" src="https://resources.premierleague.com/premierleague/badges/50/t102.png" srcset="https://resources.premierleague.com/premierleague/badges/50/t102@x2.png 2x"/>
# </span>
# </div>
# <time>12:30</time>
# <div class="match-fixture__team match-fixture__team--away">
# <span class="badge badge--away-team badge-image-container" data-size="50" data-widget="club-badge-image">
# <img class="badge-image badge-image--30" src="https://resources.premierleague.com/premierleague/badges/50/t6.png" srcset="https://resources.premierleague.com/premierleague/badges/50/t6@x2.png 2x"/>
# </span>
# <span class="match-fixture__team-name"><abbr title="Tottenham Hotspur">TOT</abbr></span>
# </div>
# <svg class="match-fixture__end-icon">
# <use xlink:href="https://www.premierleague.com/resources/rebrand/v7.130.2/i/svg-output/icons.svg#icn-arrow-right" xmlns:xlink="http://www.w3.org/1999/xlink"></use>
# </svg>
# </a>
# </div>
# <div class="league-table__btn-container btnContainer">
# <a class="league-table__club-page-btn global-btn btn-highlight" href="/clubs/21/Tottenham-Hotspur/overview" role="btn">
#                             Visit Club Page
#                             <span class="visuallyHidden">VisitTottenham HotspurClub Page</span>
# <svg class="league-table__btn-icon">
# <use xlink:href="https://www.premierleague.com/resources/rebrand/v7.130.2/i/svg-output/icons.svg#icn-arrow-right" xmlns:xlink="http://www.w3.org/1999/xlink"></use>
# </svg>
# </a>
# </div>
# </div>
# </div>
# <div class="league-table__team-performance-container teamPerformanceStandingsArea" style="display:none;">
# <header>
# <h3 class="league-table__sub-header subHeader left">Performance Chart</h3>
# <a class="global-btn btn right" href="/stats/comparison">
#                         Compare against another team
# 	<svg class="league-table__btn-icon">
# <use xlink:href="https://www.premierleague.com/resources/rebrand/v7.130.2/i/svg-output/icons.svg#icn-arrow-right" xmlns:xlink="http://www.w3.org/1999/xlink"></use>
# </svg>
# </a>
# </header>
# <div class="league-table__team-performance-standings-container teamPerformanceStandingsContainer"></div>
# </div>
# </td>
# </tr>
# <tr class="tableMid" data-compseason="578" data-filtered-entry-size="20" data-filtered-table-row="1" data-filtered-table-row-abbr="1" data-filtered-table-row-name="Arsenal" data-filtered-table-row-opta="t3" data-position="3">
# <td class="league-table__pos pos button-tooltip" id="Tooltip" tabindex="0">
# <span class="league-table__value value">3</span>
# <span class="league-table__movement up">
# <span class="league-table__tooltip-container tooltipContainer tooltip-left" role="tooltip">
# <span class="league-table__tooltip-content tooltip-content">
#                             Previous Position
#
#                             <span class="league-table__result-highlight">
#                                 5
#                             </span>
# </span>
# </span>
# </span>
# </td>
# <td class="league-table__team team" scope="row">
# <a href="/clubs/1/Arsenal/overview">
# <span class="badge badge-image-container u-hide-tablet" data-size="50" data-widget="club-badge-image">
# <img class="badge-image badge-image--32" src="https://resources.premierleague.com/premierleague/badges/50/t3.png" srcset="https://resources.premierleague.com/premierleague/badges/50/t3@x2.png 2x"/>
# </span>
# <span class="badge badge-image-container u-show-tablet" data-size="25" data-widget="club-badge-image">
# <img class="badge-image badge-image--25" src="https://resources.premierleague.com/premierleague/badges/25/t3.png" srcset="https://resources.premierleague.com/premierleague/badges/25/t3@x2.png 2x"/>
# </span>
# <span class="league-table__team-name league-table__team-name--long long">Arsenal</span>
# <span class="league-table__team-name league-table__team-name--short short">ARS</span>
# </a>
# </td>
# <td>7</td>
# <td>5</td>
# <td>2</td>
# <td>0</td>
# <td class="hideSmall">15</td>
# <td class="hideSmall">6</td>
# <td>
#         +9
#
#  </td>
# <td class="league-table__points points">17</td>
# <td class="league-table__form form hideMed">
# <li class="draw button-tooltip" id="Tooltip" tabindex="0">
# <abbr class="form-abbreviation" title="Drawn">D</abbr>
# <a class="tooltipContainer linkable tooltip-link tooltip-right" href="/match/93341" role="tooltip">
# <span class="tooltip-content">
# <div class="match-fixture match-fixture--small">
# <span class="match-fixture__match-info matchInfo">Saturday 26 August 2023</span>
# <div class="match-fixture__team-score-container">
# <div class="match-fixture__team match-fixture__team--home">
# <span class="match-fixture__team-name"><abbr title="Arsenal">ARS</abbr></span>
# <span class="badge badge--home-team badge-image-container" data-size="50" data-widget="club-badge-image">
# <img class="badge-image badge-image--30" src="https://resources.premierleague.com/premierleague/badges/50/t3.png" srcset="https://resources.premierleague.com/premierleague/badges/50/t3@x2.png 2x"/>
# </span>
# </div>
# <span class="match-fixture__score score">2 <span>-</span>2</span>
# <div class="match-fixture__team match-fixture__team--away">
# <span class="badge badge--away-team badge-image-container" data-size="50" data-widget="club-badge-image">
# <img class="badge-image badge-image--30" src="https://resources.premierleague.com/premierleague/badges/50/t54.png" srcset="https://resources.premierleague.com/premierleague/badges/50/t54@x2.png 2x"/>
# </span>
# <span class="match-fixture__team-name"><abbr title="Fulham">FUL</abbr></span>
# </div>
# <svg class="match-fixture__end-icon">
# <use xlink:href="https://www.premierleague.com/resources/rebrand/v7.130.2/i/svg-output/icons.svg#icn-arrow-right" xmlns:xlink="http://www.w3.org/1999/xlink"></use>
# </svg>
# </div>
# </div>
# </span>
# </a>
# </li>
# <li class="win button-tooltip" id="Tooltip" tabindex="0">
# <abbr class="form-abbreviation" title="Won">W</abbr>
# <a class="tooltipContainer linkable tooltip-link tooltip-right" href="/match/93351" role="tooltip">
# <span class="tooltip-content">
# <div class="match-fixture match-fixture--small">
# <span class="match-fixture__match-info matchInfo">Sunday 3 September 2023</span>
# <div class="match-fixture__team-score-container">
# <div class="match-fixture__team match-fixture__team--home">
# <span class="match-fixture__team-name"><abbr title="Arsenal">ARS</abbr></span>
# <span class="badge badge--home-team badge-image-container" data-size="50" data-widget="club-badge-image">
# <img class="badge-image badge-image--30" src="https://resources.premierleague.com/premierleague/badges/50/t3.png" srcset="https://resources.premierleague.com/premierleague/badges/50/t3@x2.png 2x"/>
# </span>
# </div>
# <span class="match-fixture__score score">3 <span>-</span>1</span>
# <div class="match-fixture__team match-fixture__team--away">
# <span class="badge badge--away-team badge-image-container" data-size="50" data-widget="club-badge-image">
# <img class="badge-image badge-image--30" src="https://resources.premierleague.com/premierleague/badges/50/t1.png" srcset="https://resources.premierleague.com/premierleague/badges/50/t1@x2.png 2x"/>
# </span>
# <span class="match-fixture__team-name"><abbr title="Manchester United">MUN</abbr></span>
# </div>
# <svg class="match-fixture__end-icon">
# <use xlink:href="https://www.premierleague.com/resources/rebrand/v7.130.2/i/svg-output/icons.svg#icn-arrow-right" xmlns:xlink="http://www.w3.org/1999/xlink"></use>
# </svg>
# </div>
# </div>
# </span>
# </a>
# </li>
# <li class="win button-tooltip" id="Tooltip" tabindex="0">
# <abbr class="form-abbreviation" title="Won">W</abbr>
# <a class="tooltipContainer linkable tooltip-link tooltip-right" href="/match/93363" role="tooltip">
# <span class="tooltip-content">
# <div class="match-fixture match-fixture--small">
# <span class="match-fixture__match-info matchInfo">Sunday 17 September 2023</span>
# <div class="match-fixture__team-score-container">
# <div class="match-fixture__team match-fixture__team--home">
# <span class="match-fixture__team-name"><abbr title="Everton">EVE</abbr></span>
# <span class="badge badge--home-team badge-image-container" data-size="50" data-widget="club-badge-image">
# <img class="badge-image badge-image--30" src="https://resources.premierleague.com/premierleague/badges/50/t11.png" srcset="https://resources.premierleague.com/premierleague/badges/50/t11@x2.png 2x"/>
# </span>
# </div>
# <span class="match-fixture__score score">0 <span>-</span>1</span>
# <div class="match-fixture__team match-fixture__team--away">
# <span class="badge badge--away-team badge-image-container" data-size="50" data-widget="club-badge-image">
# <img class="badge-image badge-image--30" src="https://resources.premierleague.com/premierleague/badges/50/t3.png" srcset="https://resources.premierleague.com/premierleague/badges/50/t3@x2.png 2x"/>
# </span>
# <span class="match-fixture__team-name"><abbr title="Arsenal">ARS</abbr></span>
# </div>
# <svg class="match-fixture__end-icon">
# <use xlink:href="https://www.premierleague.com/resources/rebrand/v7.130.2/i/svg-output/icons.svg#icn-arrow-right" xmlns:xlink="http://www.w3.org/1999/xlink"></use>
# </svg>
# </div>
# </div>
# </span>
# </a>
# </li>
# <li class="draw button-tooltip" id="Tooltip" tabindex="0">
# <abbr class="form-abbreviation" title="Drawn">D</abbr>
# <a class="tooltipContainer linkable tooltip-link tooltip-right" href="/match/93371" role="tooltip">
# <span class="tooltip-content">
# <div class="match-fixture match-fixture--small">
# <span class="match-fixture__match-info matchInfo">Sunday 24 September 2023</span>
# <div class="match-fixture__team-score-container">
# <div class="match-fixture__team match-fixture__team--home">
# <span class="match-fixture__team-name"><abbr title="Arsenal">ARS</abbr></span>
# <span class="badge badge--home-team badge-image-container" data-size="50" data-widget="club-badge-image">
# <img class="badge-image badge-image--30" src="https://resources.premierleague.com/premierleague/badges/50/t3.png" srcset="https://resources.premierleague.com/premierleague/badges/50/t3@x2.png 2x"/>
# </span>
# </div>
# <span class="match-fixture__score score">2 <span>-</span>2</span>
# <div class="match-fixture__team match-fixture__team--away">
# <span class="badge badge--away-team badge-image-container" data-size="50" data-widget="club-badge-image">
# <img class="badge-image badge-image--30" src="https://resources.premierleague.com/premierleague/badges/50/t6.png" srcset="https://resources.premierleague.com/premierleague/badges/50/t6@x2.png 2x"/>
# </span>
# <span class="match-fixture__team-name"><abbr title="Tottenham Hotspur">TOT</abbr></span>
# </div>
# <svg class="match-fixture__end-icon">
# <use xlink:href="https://www.premierleague.com/resources/rebrand/v7.130.2/i/svg-output/icons.svg#icn-arrow-right" xmlns:xlink="http://www.w3.org/1999/xlink"></use>
# </svg>
# </div>
# </div>
# </span>
# </a>
# </li>
# <li class="win button-tooltip" id="Tooltip" tabindex="0">
# <abbr class="form-abbreviation" title="Won">W</abbr>
# <a class="tooltipContainer linkable tooltip-link tooltip-right" href="/match/93382" role="tooltip">
# <span class="tooltip-content">
# <div class="match-fixture match-fixture--small">
# <span class="match-fixture__match-info matchInfo">Saturday 30 September 2023</span>
# <div class="match-fixture__team-score-container">
# <div class="match-fixture__team match-fixture__team--home">
# <span class="match-fixture__team-name"><abbr title="Bournemouth">BOU</abbr></span>
# <span class="badge badge--home-team badge-image-container" data-size="50" data-widget="club-badge-image">
# <img class="badge-image badge-image--30" src="https://resources.premierleague.com/premierleague/badges/50/t91.png" srcset="https://resources.premierleague.com/premierleague/badges/50/t91@x2.png 2x"/>
# </span>
# </div>
# <span class="match-fixture__score score">0 <span>-</span>4</span>
# <div class="match-fixture__team match-fixture__team--away">
# <span class="badge badge--away-team badge-image-container" data-size="50" data-widget="club-badge-image">
# <img class="badge-image badge-image--30" src="https://resources.premierleague.com/premierleague/badges/50/t3.png" srcset="https://resources.premierleague.com/premierleague/badges/50/t3@x2.png 2x"/>
# </span>
# <span class="match-fixture__team-name"><abbr title="Arsenal">ARS</abbr></span>
# </div>
# <svg class="match-fixture__end-icon">
# <use xlink:href="https://www.premierleague.com/resources/rebrand/v7.130.2/i/svg-output/icons.svg#icn-arrow-right" xmlns:xlink="http://www.w3.org/1999/xlink"></use>
# </svg>
# </div>
# </div>
# </span>
# </a>
# </li>
# </td>
# <td class="nextMatchCol hideMed">
# <span class="button-tooltip" id="Tooltip" tabindex="0">
# <span class="nextMatch">
# <span class="badge badge-image-container" data-size="50" data-widget="club-badge-image">
# <img class="badge-image badge-image--32" src="https://resources.premierleague.com/premierleague/badges/50/t43.png" srcset="https://resources.premierleague.com/premierleague/badges/50/t43.png, https://resources.premierleague.com/premierleague/badges/50/t43@x2.png 2x"/>
# <span class="visuallyHidden">Manchester City</span>
# </span>
# </span>
# <a class="tooltipContainer linkable tooltip-link tooltip-right" href="/match/93391" role="tooltip">
# <span class="tooltip-content">
# <div class="match-fixture match-fixture--small">
# <span class="match-fixture__match-info">Sunday 08 October 2023</span>
# <div class="match-fixture__team-score-container">
# <div class="match-fixture__team match-fixture__team--home">
# <span class="match-fixture__team-name"><abbr title="Arsenal">ARS</abbr></span>
# <span class="badge badge--home-team badge-image-container" data-size="50" data-widget="club-badge-image">
# <img class="badge-image badge-image--30" src="https://resources.premierleague.com/premierleague/badges/50/t3.png" srcset="https://resources.premierleague.com/premierleague/badges/50/t3@x2.png 2x"/>
# </span>
# </div>
# <time>16:30</time>
# <div class="match-fixture__team match-fixture__team--away">
# ...
# </span>
# <span class="league-table__team-name league-table__team-name--long long">Sheffield United</span>
# <span class="league-table__team-name league-table__team-name--short short">SHU</span>
# </a>
# </td>
# <td>7</td>
# <td>0</td>
# <td>1</td>
# <td>6</td>
# <td class="hideSmall">5</td>
# <td class="hideSmall">19</td>
# <td>
#         -14
#
#  </td>
# <td class="league-table__points points">1</td>
# <td class="league-table__form form hideMed">
# <li class="lose button-tooltip" id="Tooltip" tabindex="0">
# <abbr class="form-abbreviation" title="Lost">L</abbr>
# <a class="tooltipContainer linkable tooltip-link tooltip-right" href="/match/93350" role="tooltip">
# <span class="tooltip-content">
# <div class="match-fixture match-fixture--small">
# <span class="match-fixture__match-info matchInfo">Sunday 27 August 2023</span>
# <div class="match-fixture__team-score-container">
# <div class="match-fixture__team match-fixture__team--home">
# <span class="match-fixture__team-name"><abbr title="Sheffield United">SHU</abbr></span>
# <span class="badge badge--home-team badge-image-container" data-size="50" data-widget="club-badge-image">
# <img class="badge-image badge-image--30" src="https://resources.premierleague.com/premierleague/badges/50/t49.png" srcset="https://resources.premierleague.com/premierleague/badges/50/t49@x2.png 2x"/>
# </span>
# </div>
# <span class="match-fixture__score score">1 <span>-</span>2</span>
# <div class="match-fixture__team match-fixture__team--away">
# <span class="badge badge--away-team badge-image-container" data-size="50" data-widget="club-badge-image">
# <img class="badge-image badge-image--30" src="https://resources.premierleague.com/premierleague/badges/50/t43.png" srcset="https://resources.premierleague.com/premierleague/badges/50/t43@x2.png 2x"/>
# </span>
# <span class="match-fixture__team-name"><abbr title="Manchester City">MCI</abbr></span>
# </div>
# <svg class="match-fixture__end-icon">
# <use xlink:href="https://www.premierleague.com/resources/rebrand/v7.130.2/i/svg-output/icons.svg#icn-arrow-right" xmlns:xlink="http://www.w3.org/1999/xlink"></use>
# </svg>
# </div>
# </div>
# </span>
# </a>
# </li>
# <li class="draw button-tooltip" id="Tooltip" tabindex="0">
# <abbr class="form-abbreviation" title="Drawn">D</abbr>
# <a class="tooltipContainer linkable tooltip-link tooltip-right" href="/match/93360" role="tooltip">
# <span class="tooltip-content">
# <div class="match-fixture match-fixture--small">
# <span class="match-fixture__match-info matchInfo">Saturday 2 September 2023</span>
# <div class="match-fixture__team-score-container">
# <div class="match-fixture__team match-fixture__team--home">
# <span class="match-fixture__team-name"><abbr title="Sheffield United">SHU</abbr></span>
# <span class="badge badge--home-team badge-image-container" data-size="50" data-widget="club-badge-image">
# <img class="badge-image badge-image--30" src="https://resources.premierleague.com/premierleague/badges/50/t49.png" srcset="https://resources.premierleague.com/premierleague/badges/50/t49@x2.png 2x"/>
# </span>
# </div>
# <span class="match-fixture__score score">2 <span>-</span>2</span>
# <div class="match-fixture__team match-fixture__team--away">
# <span class="badge badge--away-team badge-image-container" data-size="50" data-widget="club-badge-image">
# <img class="badge-image badge-image--30" src="https://resources.premierleague.com/premierleague/badges/50/t11.png" srcset="https://resources.premierleague.com/premierleague/badges/50/t11@x2.png 2x"/>
# </span>
# <span class="match-fixture__team-name"><abbr title="Everton">EVE</abbr></span>
# </div>
# <svg class="match-fixture__end-icon">
# <use xlink:href="https://www.premierleague.com/resources/rebrand/v7.130.2/i/svg-output/icons.svg#icn-arrow-right" xmlns:xlink="http://www.w3.org/1999/xlink"></use>
# </svg>
# </div>
# </div>
# </span>
# </a>
# </li>
# <li class="lose button-tooltip" id="Tooltip" tabindex="0">
# <abbr class="form-abbreviation" title="Lost">L</abbr>
# <a class="tooltipContainer linkable tooltip-link tooltip-right" href="/match/93368" role="tooltip">
# <span class="tooltip-content">
# <div class="match-fixture match-fixture--small">
# <span class="match-fixture__match-info matchInfo">Saturday 16 September 2023</span>
# <div class="match-fixture__team-score-container">
# <div class="match-fixture__team match-fixture__team--home">
# <span class="match-fixture__team-name"><abbr title="Tottenham Hotspur">TOT</abbr></span>
# <span class="badge badge--home-team badge-image-container" data-size="50" data-widget="club-badge-image">
# <img class="badge-image badge-image--30" src="https://resources.premierleague.com/premierleague/badges/50/t6.png" srcset="https://resources.premierleague.com/premierleague/badges/50/t6@x2.png 2x"/>
# </span>
# </div>
# <span class="match-fixture__score score">2 <span>-</span>1</span>
# <div class="match-fixture__team match-fixture__team--away">
# <span class="badge badge--away-team badge-image-container" data-size="50" data-widget="club-badge-image">
# <img class="badge-image badge-image--30" src="https://resources.premierleague.com/premierleague/badges/50/t49.png" srcset="https://resources.premierleague.com/premierleague/badges/50/t49@x2.png 2x"/>
# </span>
# <span class="match-fixture__team-name"><abbr title="Sheffield United">SHU</abbr></span>
# </div>
# <svg class="match-fixture__end-icon">
# <use xlink:href="https://www.premierleague.com/resources/rebrand/v7.130.2/i/svg-output/icons.svg#icn-arrow-right" xmlns:xlink="http://www.w3.org/1999/xlink"></use>
# </svg>
# </div>
# </div>
# </span>
# </a>
# </li>
# <li class="lose button-tooltip" id="Tooltip" tabindex="0">
# <abbr class="form-abbreviation" title="Lost">L</abbr>
# <a class="tooltipContainer linkable tooltip-link tooltip-right" href="/match/93380" role="tooltip">
# <span class="tooltip-content">
# <div class="match-fixture match-fixture--small">
# <span class="match-fixture__match-info matchInfo">Sunday 24 September 2023</span>
# <div class="match-fixture__team-score-container">
# <div class="match-fixture__team match-fixture__team--home">
# <span class="match-fixture__team-name"><abbr title="Sheffield United">SHU</abbr></span>
# <span class="badge badge--home-team badge-image-container" data-size="50" data-widget="club-badge-image">
# <img class="badge-image badge-image--30" src="https://resources.premierleague.com/premierleague/badges/50/t49.png" srcset="https://resources.premierleague.com/premierleague/badges/50/t49@x2.png 2x"/>
# </span>
# </div>
# <span class="match-fixture__score score">0 <span>-</span>8</span>
# <div class="match-fixture__team match-fixture__team--away">
# <span class="badge badge--away-team badge-image-container" data-size="50" data-widget="club-badge-image">
# <img class="badge-image badge-image--30" src="https://resources.premierleague.com/premierleague/badges/50/t4.png" srcset="https://resources.premierleague.com/premierleague/badges/50/t4@x2.png 2x"/>
# </span>
# <span class="match-fixture__team-name"><abbr title="Newcastle United">NEW</abbr></span>
# </div>
# <svg class="match-fixture__end-icon">
# <use xlink:href="https://www.premierleague.com/resources/rebrand/v7.130.2/i/svg-output/icons.svg#icn-arrow-right" xmlns:xlink="http://www.w3.org/1999/xlink"></use>
# </svg>
# </div>
# </div>
# </span>
# </a>
# </li>
# <li class="lose button-tooltip" id="Tooltip" tabindex="0">
# <abbr class="form-abbreviation" title="Lost">L</abbr>
# <a class="tooltipContainer linkable tooltip-link tooltip-right" href="/match/93389" role="tooltip">
# <span class="tooltip-content">
# <div class="match-fixture match-fixture--small">
# <span class="match-fixture__match-info matchInfo">Saturday 30 September 2023</span>
# <div class="match-fixture__team-score-container">
# <div class="match-fixture__team match-fixture__team--home">
# <span class="match-fixture__team-name"><abbr title="West Ham United">WHU</abbr></span>
# <span class="badge badge--home-team badge-image-container" data-size="50" data-widget="club-badge-image">
# <img class="badge-image badge-image--30" src="https://resources.premierleague.com/premierleague/badges/50/t21.png" srcset="https://resources.premierleague.com/premierleague/badges/50/t21@x2.png 2x"/>
# </span>
# </div>
# <span class="match-fixture__score score">2 <span>-</span>0</span>
# <div class="match-fixture__team match-fixture__team--away">
# <span class="badge badge--away-team badge-image-container" data-size="50" data-widget="club-badge-image">
# <img class="badge-image badge-image--30" src="https://resources.premierleague.com/premierleague/badges/50/t49.png" srcset="https://resources.premierleague.com/premierleague/badges/50/t49@x2.png 2x"/>
# </span>
# <span class="match-fixture__team-name"><abbr title="Sheffield United">SHU</abbr></span>
# </div>
# <svg class="match-fixture__end-icon">
# <use xlink:href="https://www.premierleague.com/resources/rebrand/v7.130.2/i/svg-output/icons.svg#icn-arrow-right" xmlns:xlink="http://www.w3.org/1999/xlink"></use>
# </svg>
# </div>
# </div>
# </span>
# </a>
# </li>
# </td>
# <td class="nextMatchCol hideMed">
# <span class="button-tooltip" id="Tooltip" tabindex="0">
# <span class="nextMatch">
# <span class="badge badge-image-container" data-size="50" data-widget="club-badge-image">
# <img class="badge-image badge-image--32" src="https://resources.premierleague.com/premierleague/badges/50/t54.png" srcset="https://resources.premierleague.com/premierleague/badges/50/t54.png, https://resources.premierleague.com/premierleague/badges/50/t54@x2.png 2x"/>
# <span class="visuallyHidden">Fulham</span>
# </span>
# </span>
# <a class="tooltipContainer linkable tooltip-link tooltip-right" href="/match/93396" role="tooltip">
# <span class="tooltip-content">
# <div class="match-fixture match-fixture--small">
# <span class="match-fixture__match-info">Saturday 07 October 2023</span>
# <div class="match-fixture__team-score-container">
# <div class="match-fixture__team match-fixture__team--home">
# <span class="match-fixture__team-name"><abbr title="Fulham">FUL</abbr></span>
# <span class="badge badge--home-team badge-image-container" data-size="50" data-widget="club-badge-image">
# <img class="badge-image badge-image--30" src="https://resources.premierleague.com/premierleague/badges/50/t54.png" srcset="https://resources.premierleague.com/premierleague/badges/50/t54@x2.png 2x"/>
# </span>
# </div>
# <time>15:00</time>
# <div class="match-fixture__team match-fixture__team--away">
# <span class="badge badge--away-team badge-image-container" data-size="50" data-widget="club-badge-image">
# <img class="badge-image badge-image--30" src="https://resources.premierleague.com/premierleague/badges/50/t49.png" srcset="https://resources.premierleague.com/premierleague/badges/50/t49@x2.png 2x"/>
# </span>
# <span class="match-fixture__team-name"><abbr title="Sheffield United">SHU</abbr></span>
# </div>
# <svg class="match-fixture__end-icon">
# <use xlink:href="https://www.premierleague.com/resources/rebrand/v7.130.2/i/svg-output/icons.svg#icn-arrow-right" xmlns:xlink="http://www.w3.org/1999/xlink"></use>
# </svg>
# </div>
# </div>
# </span>
# </a>
# </span>
# </td>
# <td class="league-table__reveal-more js-reveal-more" role="button" style="display:none;" tabindex="0">
# <svg class="league-table__reveal-more-icon">
# <use xlink:href="https://www.premierleague.com/resources/rebrand/v7.130.2/i/svg-output/icons.svg#icn-chevron-down" xmlns:xlink="http://www.w3.org/1999/xlink"></use>
# </svg>
# </td>
# </tr>
# <tr class="league-table__expandable expandable" data-filtered-table-row-expander="18">
# <td colspan="13">
# <div class="league-table__expandable-container">
# <a class="league-table__expandable-team expandableTeam" href="/clubs/18/Sheffield-United/overview">
# <span class="badge badge-image-container" data-size="50" data-widget="club-badge-image">
# <img class="badge-image badge-image--40" src="https://resources.premierleague.com/premierleague/badges/50/t49.png" srcset="https://resources.premierleague.com/premierleague/badges/50/t49@x2.png 2x"/>
# </span>
# <span class="league-table__team-name teamName">Sheffield United</span>
# </a>
# <div class="league-table__expandable-matches-container">
# <div class="league-table__result-widget resultWidget">
# <div class="league-table__result-widget-label label"><strong>Recent Result</strong>: Saturday 30 September 2023</div>
# <a class="league-table__match-fixture match-fixture match-fixture--small pre" href="/match/93389">
# <div class="match-fixture__team match-fixture__team--home">
# <span class="match-fixture__team-name"><abbr title="West Ham United">WHU</abbr></span>
# <span class="badge badge--home-team badge-image-container" data-size="50" data-widget="club-badge-image">
# <img class="badge-image badge-image--30" src="https://resources.premierleague.com/premierleague/badges/50/t21.png" srcset="https://resources.premierleague.com/premierleague/badges/50/t21@x2.png 2x"/>
# </span>
# </div>
# <span class="match-fixture__score score">2 <span>-</span>0</span>
# <div class="match-fixture__team match-fixture__team--away">
# <span class="badge badge--away-team badge-image-container" data-size="50" data-widget="club-badge-image">
# <img class="badge-image badge-image--30" src="https://resources.premierleague.com/premierleague/badges/50/t49.png" srcset="https://resources.premierleague.com/premierleague/badges/50/t49@x2.png 2x"/>
# </span>
# <span class="match-fixture__team-name"><abbr title="Sheffield United">SHU</abbr></span>
# </div>
# <svg class="match-fixture__end-icon">
# <use xlink:href="https://www.premierleague.com/resources/rebrand/v7.130.2/i/svg-output/icons.svg#icn-arrow-right" xmlns:xlink="http://www.w3.org/1999/xlink"></use>
# </svg>
# </a>
# </div>
# <div class="league-table__result-widget resultWidget">
# <div class="league-table__result-widget-label label"><strong>Next Fixture</strong>: Saturday 7 October 2023</div>
# <a class="league-table__match-fixture match-fixture match-fixture--small pre" href="/match/93396">
# <div class="match-fixture__team match-fixture__team--home">
# <span class="match-fixture__team-name"><abbr title="Fulham">FUL</abbr></span>
# <span class="badge badge--home-team badge-image-container" data-size="50" data-widget="club-badge-image">
# <img class="badge-image badge-image--30" src="https://resources.premierleague.com/premierleague/badges/50/t54.png" srcset="https://resources.premierleague.com/premierleague/badges/50/t54@x2.png 2x"/>
# </span>
# </div>
# <time>15:00</time>
# <div class="match-fixture__team match-fixture__team--away">
# <span class="badge badge--away-team badge-image-container" data-size="50" data-widget="club-badge-image">
# <img class="badge-image badge-image--30" src="https://resources.premierleague.com/premierleague/badges/50/t49.png" srcset="https://resources.premierleague.com/premierleague/badges/50/t49@x2.png 2x"/>
# </span>
# <span class="match-fixture__team-name"><abbr title="Sheffield United">SHU</abbr></span>
# </div>
# <svg class="match-fixture__end-icon">
# <use xlink:href="https://www.premierleague.com/resources/rebrand/v7.130.2/i/svg-output/icons.svg#icn-arrow-right" xmlns:xlink="http://www.w3.org/1999/xlink"></use>
# </svg>
# </a>
# </div>
# <div class="league-table__btn-container btnContainer">
# <a class="league-table__club-page-btn global-btn btn-highlight" href="/clubs/18/Sheffield-United/overview" role="btn">
#                             Visit Club Page
#                             <span class="visuallyHidden">VisitSheffield UnitedClub Page</span>
# <svg class="league-table__btn-icon">
# <use xlink:href="https://www.premierleague.com/resources/rebrand/v7.130.2/i/svg-output/icons.svg#icn-arrow-right" xmlns:xlink="http://www.w3.org/1999/xlink"></use>
# </svg>
# </a>
# </div>
# </div>
# </div>
# <div class="league-table__team-performance-container teamPerformanceStandingsArea" style="display:none;">
# <header>
# <h3 class="league-table__sub-header subHeader left">Performance Chart</h3>
# <a class="global-btn btn right" href="/stats/comparison">
#                         Compare against another team
# 	<svg class="league-table__btn-icon">
# <use xlink:href="https://www.premierleague.com/resources/rebrand/v7.130.2/i/svg-output/icons.svg#icn-arrow-right" xmlns:xlink="http://www.w3.org/1999/xlink"></use>
# </svg>
# </a>
# </header>
# <div class="league-table__team-performance-standings-container teamPerformanceStandingsContainer"></div>
# </div>
# </td>
# </tr>
# </tbody>
# </table>

# %%
table.find_all('th')
# Out:
# [<th class="league-table__pos-header" scope="col">
#  <div class="league-table__thFull thFull">Position</div>
#  <div class="league-table__thShort thShort">Pos</div>
#  </th>,
#  <th class="league-table__team-header" scope="col">Club</th>,
#  <th scope="col">
#  <div class="league-table__thFull thFull">Played</div>
#  <div class="league-table__thShort thShort">Pl</div>
#  </th>,
#  <th scope="col">
#  <div class="league-table__thFull thFull">Won</div>
#  <div class="league-table__thShort thShort">W</div>
#  </th>,
#  <th scope="col">
#  <div class="league-table__thFull thFull">Drawn</div>
#  <div class="league-table__thShort thShort">D</div>
#  </th>,
#  <th scope="col">
#  <div class="league-table__thFull thFull">Lost</div>
#  <div class="league-table__thShort thShort">L</div>
#  </th>,
#  <th class="hideSmall" scope="col"><abbr title="Goals For">GF</abbr></th>,
#  <th class="hideSmall" scope="col"><abbr title="Goals Against">GA</abbr></th>,
#  <th scope="col"><abbr title="Goal Difference">GD</abbr></th>,
#  <th class="league-table__points points" scope="col">
#  <div class="league-table__thFull thFull">Points</div>
#  <div class="league-table__thShort thShort">Pts</div>
#  </th>,
#  <th class="league-table__team-form hideMed" scope="col">Form</th>,
#  <th class="hideMed text-centre" scope="col">Next</th>,
#  <th class="league-table__reveal-more-header js-reveal-more-header text-centre" scope="col" style="display:none;">More</th>]

# %%
titles = table.find_all('th')

# %%
header = [i.text.split()[0] for i in titles]

header
# Out:
# ['Position',
#  'Club',
#  'Played',
#  'Won',
#  'Drawn',
#  'Lost',
#  'GF',
#  'GA',
#  'GD',
#  'Points',
#  'Form',
#  'Next',
#  'More']

# %%
header.remove('More')

# %%
header.remove('Form')

# %%
header
# Out:
# ['Position',
#  'Club',
#  'Played',
#  'Won',
#  'Drawn',
#  'Lost',
#  'GF',
#  'GA',
#  'GD',
#  'Points',
#  'Next']

# %%
df = pd.DataFrame(columns = header)

df
# Out:
# Empty DataFrame
# Columns: [Position, Club, Played, Won, Drawn, Lost, GF, GA, GD, Points, Next]
# Index: []

# %%
col_data = table.find_all('tr')

# %%
data = []
for i  in col_data:
    row_data = i.find_all('td')
    indi_row_data = [i.text.split() for i in row_data]
    data.append(indi_row_data)

# %%
raw_data = []
for i in data[1:40:2]:
    pos = i[0][0]
    club = i[1][-1]
    played = i[2][0]
    won = i[3][0]
    draw = i[4][0]
    loss = i[5][0]
    GF = i[6][0]
    GA = i[7][0]
    GD = i[8][0]
    points = i[9][0]
    nextm = i[11][5]
    data_element = {'Position':pos,'Club':club,'Played':played,'Won':won,'Draw':draw,'Loss':loss,
                   'GF':GF,'GA':GA,'GD':GD,'Points':points,'Next Match':nextm}
    raw_data.append(data_element)

# %%
raw_data
# Out:
# [{'Position': '1',
#   'Club': 'MCI',
#   'Played': '7',
#   'Won': '6',
#   'Draw': '0',
#   'Loss': '1',
#   'GF': '17',
#   'GA': '5',
#   'GD': '+12',
#   'Points': '18',
#   'Next Match': 'ARS'},
#  {'Position': '2',
#   'Club': 'TOT',
#   'Played': '7',
#   'Won': '5',
#   'Draw': '2',
#   'Loss': '0',
#   'GF': '17',
#   'GA': '8',
#   'GD': '+9',
#   'Points': '17',
#   'Next Match': '2023'},
#  {'Position': '3',
#   'Club': 'ARS',
#   'Played': '7',
#   'Won': '5',
#   'Draw': '2',
#   'Loss': '0',
#   'GF': '15',
#   'GA': '6',
#   'GD': '+9',
#   'Points': '17',
#   'Next Match': '2023'},
#  {'Position': '4',
#   'Club': 'LIV',
#   'Played': '7',
#   'Won': '5',
#   'Draw': '1',
#   'Loss': '1',
#   'GF': '16',
#   'GA': '7',
#   'GD': '+9',
#   'Points': '16',
#   'Next Match': '08'},
#  {'Position': '5',
#   'Club': 'AVL',
#   'Played': '7',
#   'Won': '5',
#   'Draw': '0',
#   'Loss': '2',
#   'GF': '18',
#   'GA': '11',
#   'GD': '+7',
#   'Points': '15',
#   'Next Match': '2023'},
#  {'Position': '6',
#   'Club': 'BHA',
#   'Played': '7',
#   'Won': '5',
#   'Draw': '0',
#   'Loss': '2',
#   'GF': '19',
#   'GA': '14',
#   'GD': '+5',
#   'Points': '15',
#   'Next Match': 'BHA'},
#  {'Position': '7',
#   'Club': 'WHU',
#   'Played': '7',
#   'Won': '4',
#   'Draw': '1',
#   'Loss': '2',
#   'GF': '13',
#   'GA': '10',
#   'GD': '+3',
#   'Points': '13',
#   'Next Match': '2023'},
#  {'Position': '8',
#   'Club': 'NEW',
#   'Played': '7',
#   'Won': '4',
#   'Draw': '0',
#   'Loss': '3',
#   'GF': '18',
#   'GA': '7',
#   'GD': '+11',
#   'Points': '12',
#   'Next Match': 'October'},
#  {'Position': '9',
#   'Club': 'CRY',
#   'Played': '7',
#   'Won': '3',
#   'Draw': '2',
#   'Loss': '2',
#   'GF': '7',
#   'GA': '7',
#   'GD': '0',
#   'Points': '11',
#   'Next Match': '2023'},
#  {'Position': '10',
#   'Club': 'MUN',
#   'Played': '7',
#   'Won': '3',
#   'Draw': '0',
#   'Loss': '4',
#   'GF': '7',
#   'GA': '11',
#   'GD': '-4',
#   'Points': '9',
#   'Next Match': 'MUN'},
#  {'Position': '11',
#   'Club': 'CHE',
#   'Played': '7',
#   'Won': '2',
#   'Draw': '2',
#   'Loss': '3',
#   'GF': '7',
#   'GA': '6',
#   'GD': '+1',
#   'Points': '8',
#   'Next Match': 'BUR'},
#  {'Position': '12',
#   'Club': 'NFO',
#   'Played': '7',
#   'Won': '2',
#   'Draw': '2',
#   'Loss': '3',
#   'GF': '8',
#   'GA': '10',
#   'GD': '-2',
#   'Points': '8',
#   'Next Match': '2023'},
#  {'Position': '13',
#   'Club': 'FUL',
#   'Played': '7',
#   'Won': '2',
#   'Draw': '2',
#   'Loss': '3',
#   'GF': '5',
#   'GA': '12',
#   'GD': '-7',
#   'Points': '8',
#   'Next Match': '2023'},
#  {'Position': '14',
#   'Club': 'BRE',
#   'Played': '7',
#   'Won': '1',
#   'Draw': '4',
#   'Loss': '2',
#   'GF': '10',
#   'GA': '10',
#   'GD': '0',
#   'Points': '7',
#   'Next Match': '2023'},
#  {'Position': '15',
#   'Club': 'WOL',
#   'Played': '7',
#   'Won': '2',
#   'Draw': '1',
#   'Loss': '4',
#   'GF': '8',
#   'GA': '13',
#   'GD': '-5',
#   'Points': '7',
#   'Next Match': '2023'},
#  {'Position': '16',
#   'Club': 'EVE',
#   'Played': '7',
#   'Won': '1',
#   'Draw': '1',
#   'Loss': '5',
#   'GF': '6',
#   'GA': '12',
#   'GD': '-6',
#   'Points': '4',
#   'Next Match': 'EVE'},
#  {'Position': '17',
#   'Club': 'LUT',
#   'Played': '7',
#   'Won': '1',
#   'Draw': '1',
#   'Loss': '5',
#   'GF': '6',
#   'GA': '14',
#   'GD': '-8',
#   'Points': '4',
#   'Next Match': '2023'},
#  {'Position': '18',
#   'Club': 'BUR',
#   'Played': '7',
#   'Won': '1',
#   'Draw': '1',
#   'Loss': '5',
#   'GF': '6',
#   'GA': '16',
#   'GD': '-10',
#   'Points': '4',
#   'Next Match': 'BUR'},
#  {'Position': '19',
#   'Club': 'BOU',
#   'Played': '7',
#   'Won': '0',
#   'Draw': '3',
#   'Loss': '4',
#   'GF': '5',
#   'GA': '15',
#   'GD': '-10',
#   'Points': '3',
#   'Next Match': 'EVE'},
#  {'Position': '20',
#   'Club': 'SHU',
#   'Played': '7',
#   'Won': '0',
#   'Draw': '1',
#   'Loss': '6',
#   'GF': '5',
#   'GA': '19',
#   'GD': '-14',
#   'Points': '1',
#   'Next Match': 'FUL'}]

# %%
df2 = pd.DataFrame.from_dict(raw_data)

# %%
df2.head(20)
# Out:
#    Position Club Played Won Draw Loss  GF  GA   GD Points Next Match
# 0         1  MCI      7   6    0    1  17   5  +12     18        ARS
# 1         2  TOT      7   5    2    0  17   8   +9     17       2023
# 2         3  ARS      7   5    2    0  15   6   +9     17       2023
# 3         4  LIV      7   5    1    1  16   7   +9     16         08
# 4         5  AVL      7   5    0    2  18  11   +7     15       2023
# 5         6  BHA      7   5    0    2  19  14   +5     15        BHA
# 6         7  WHU      7   4    1    2  13  10   +3     13       2023
# 7         8  NEW      7   4    0    3  18   7  +11     12    October
# 8         9  CRY      7   3    2    2   7   7    0     11       2023
# 9        10  MUN      7   3    0    4   7  11   -4      9        MUN
# 10       11  CHE      7   2    2    3   7   6   +1      8        BUR
# 11       12  NFO      7   2    2    3   8  10   -2      8       2023
# 12       13  FUL      7   2    2    3   5  12   -7      8       2023
# 13       14  BRE      7   1    4    2  10  10    0      7       2023
# 14       15  WOL      7   2    1    4   8  13   -5      7       2023
# 15       16  EVE      7   1    1    5   6  12   -6      4        EVE
# 16       17  LUT      7   1    1    5   6  14   -8      4       2023
# 17       18  BUR      7   1    1    5   6  16  -10      4        BUR
# 18       19  BOU      7   0    3    4   5  15  -10      3        EVE
# 19       20  SHU      7   0    1    6   5  19  -14      1        FUL

# %%
data[1][0][0]
# Out:
# '1'

# %%
data[1][1][-1]
# Out:
# 'MCI'

# %%
data[1][2][0]
# Out:
# '7'

# %%
data[1][3][0]
# Out:
# '6'

# %%
data[1][4][0]
# Out:
# '0'

# %%
data[1][5][0]
# Out:
# '1'

# %%
data[1][6][0]
# Out:
# '17'

# %%
data[1][7][0]
# Out:
# '5'

# %%
data[1][8][0]
# Out:
# '+12'

# %%
data[1][9][0]
# Out:
# '18'

# %%
data[1][11][5]
# Out:
# 'ARS'

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 11 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Position    20 non-null     object
#  1   Club        20 non-null     object
#  2   Played      20 non-null     object
#  3   Won         20 non-null     object
#  4   Draw        20 non-null     object
#  5   Loss        20 non-null     object
#  6   GF          20 non-null     object
#  7   GA          20 non-null     object
#  8   GD          20 non-null     object
#  9   Points      20 non-null     object
#  10  Next Match  20 non-null     object
# dtypes: object(11)
# memory usage: 1.8+ KB

# %%
df2[df2['GD']].max()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_5224\2112733656.py in <module>
# ----> 1 df2[df2['GD']].max()
#
# G:\Big Data\Big Data Bootcamp\Anaconda\conda\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    3509             if is_iterator(key):
#    3510                 key = list(key)
# -> 3511             indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    3512
#    3513         # take() does not accept boolean indexers
#
# G:\Big Data\Big Data Bootcamp\Anaconda\conda\lib\site-packages\pandas\core\indexes\base.py in _get_indexer_strict(self, key, axis_name)
#    5794             keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
#    5795
# -> 5796         self._raise_if_missing(keyarr, indexer, axis_name)
#    5797
#    5798         keyarr = self.take(indexer)
#
# G:\Big Data\Big Data Bootcamp\Anaconda\conda\lib\site-packages\pandas\core\indexes\base.py in _raise_if_missing(self, key, indexer, axis_name)
#    5854                 if use_interval_msg:
#    5855                     key = list(key)
# -> 5856                 raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    5857
#    5858             not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
#
# KeyError: "None of [Index(['+12', '+9', '+9', '+9', '+7', '+5', '+3', '+11', '0', '-4', '+1', '-2',\n       '-7', '0', '-5', '-6', '-8', '-10', '-10', '-14'],\n      dtype='object')] are in the [columns]"

# %%
df2.head(20)
# Out:
#    Position Club Played Won Draw Loss  GF  GA   GD Points Next Match
# 0         1  MCI      7   6    0    1  17   5  +12     18        ARS
# 1         2  TOT      7   5    2    0  17   8   +9     17       2023
# 2         3  ARS      7   5    2    0  15   6   +9     17       2023
# 3         4  LIV      7   5    1    1  16   7   +9     16         08
# 4         5  AVL      7   5    0    2  18  11   +7     15       2023
# 5         6  BHA      7   5    0    2  19  14   +5     15        BHA
# 6         7  WHU      7   4    1    2  13  10   +3     13       2023
# 7         8  NEW      7   4    0    3  18   7  +11     12    October
# 8         9  CRY      7   3    2    2   7   7    0     11       2023
# 9        10  MUN      7   3    0    4   7  11   -4      9        MUN
# 10       11  CHE      7   2    2    3   7   6   +1      8        BUR
# 11       12  NFO      7   2    2    3   8  10   -2      8       2023
# 12       13  FUL      7   2    2    3   5  12   -7      8       2023
# 13       14  BRE      7   1    4    2  10  10    0      7       2023
# 14       15  WOL      7   2    1    4   8  13   -5      7       2023
# 15       16  EVE      7   1    1    5   6  12   -6      4        EVE
# 16       17  LUT      7   1    1    5   6  14   -8      4       2023
# 17       18  BUR      7   1    1    5   6  16  -10      4        BUR
# 18       19  BOU      7   0    3    4   5  15  -10      3        EVE
# 19       20  SHU      7   0    1    6   5  19  -14      1        FUL
